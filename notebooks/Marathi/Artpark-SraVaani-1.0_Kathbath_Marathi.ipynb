# %% [markdown]
# # SraVaani-1.0 — Kathbath ASR evaluation (Hindi / Tamil / Telugu / Marathi / Bengali)
#
# Evaluates [`ARTPARK-IISc/SraVaani-1.0`](https://huggingface.co/ARTPARK-IISc/SraVaani-1.0) on the Kathbath test sets, downloaded automatically from the public Vistaar-benchmark mirror:
#
# ```
# https://indicwhisper.objectstore.e2enetworks.net/vistaar_benchmarks/kathbath.zip
# ```
#
# **What this notebook does**
# 1. Downloads + extracts `kathbath.zip` (cached — reruns skip this).
# 2. Locates each language's `test/` folder (`audio/` + `transcript.txt`), indexing audio files recursively to route around nested subfolders.
# 3. Loads SraVaani-1.0 (`trust_remote_code=True`) — **gated**, needs an HF token with accepted terms on the model page.
# 4. Runs inference in batches, printing reference / predicted text and running WER/CER as it goes.
# 5. Checkpoints every sample to a resumable `.jsonl` cache per language, so a Kaggle session timeout doesn't lose progress.
# 6. Writes one CSV per language (`id, reference, prediction, wer, cer`) plus a combined summary CSV.
#
# **Before running:** accept the gated-access terms at https://huggingface.co/ARTPARK-IISc/SraVaani-1.0, then add an HF token as a Kaggle secret named `HF_TOKEN` (Add-ons → Secrets) and enable it for this notebook — or set it directly in the cell below.

# %% [markdown]
# ## 1. Install dependencies

# %%
import os, sys

def _ensure(pkg_import, pip_name=None):
    try:
        __import__(pkg_import)
    except ImportError:
        os.system(f"{sys.executable} -m pip install -q {pip_name or pkg_import}")

for mod, pip_name in [
    ("editdistance", "editdistance"),
    ("soundfile", "soundfile"),
    ("librosa", "librosa"),
    ("tqdm", "tqdm"),
    ("requests", "requests"),
]:
    _ensure(mod, pip_name)

print("Dependencies ready.")
# Out:
# Dependencies ready.

# %% [markdown]
# ## 2. Imports and config

# %%
import gc
import json
import re
import time
import unicodedata
import zipfile
from pathlib import Path

import pandas as pd
import editdistance
import requests
import soundfile as sf
import librosa
import torch
from tqdm.auto import tqdm
from transformers import AutoModel

MODEL_REPO = "ARTPARK-IISc/SraVaani-1.0"
KATHBATH_ZIP_URL = "https://indicwhisper.objectstore.e2enetworks.net/vistaar_benchmarks/kathbath.zip"
TARGET_SR = 16000

# folder-name candidates inside the extracted zip, in case of casing/
# naming variants across mirrors
LANG_DIR_CANDIDATES = {
    # "hindi": ["hindi"],
    # "tamil": ["tamil"],
    # "telugu": ["telugu"],
    "marathi": ["marathi"],
    # "bengali": ["bengali", "bangla"],
}
SPLIT_DIR_CANDIDATES = ["test", "test_known", "test_unknown", "valid"]
AUDIO_EXTS = {".wav", ".m4a", ".mp3", ".flac"}

# %% [markdown]
# ## 3. Set your Hugging Face token
#
# Needed only to load the gated SraVaani-1.0 model — the Kathbath zip download needs no token.

# %%
# Option A: paste your token directly (quickest for a one-off Kaggle run)
# os.environ["HF_TOKEN"] = "hf_xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx"

# Option B: Kaggle secret named HF_TOKEN (Add-ons -> Secrets), picked up automatically below

def get_hf_token():
    token = os.environ.get("HF_TOKEN")
    if token:
        return token
    try:
        from kaggle_secrets import UserSecretsClient
        token = UserSecretsClient().get_secret("HF_TOKEN")
        if token:
            return token
    except Exception:
        pass
    raise RuntimeError(
        "No HF token found. Either set os.environ['HF_TOKEN'] = 'hf_...' before running, "
        "or add it as a Kaggle secret named HF_TOKEN (Add-ons -> Secrets) and enable it for this notebook. "
        "(Needed to load the gated SraVaani-1.0 model — the Kathbath download itself needs no token.)"
    )

# %% [markdown]
# ## 4. Download + extract Kathbath (Vistaar mirror)

# %%
# ================================================================ #
# Download + extract kathbath.zip (cached)
# ================================================================ #
def download_kathbath(dest_root: Path) -> Path:
    dest_root.mkdir(parents=True, exist_ok=True)
    zip_path = dest_root / "kathbath.zip"
    extract_marker = dest_root / "kathbath" / ".extracted_ok"
    extract_dir = dest_root / "kathbath"

    if extract_marker.exists():
        print(f"Kathbath already downloaded + extracted at {extract_dir}")
        return extract_dir

    if not zip_path.exists() or zip_path.stat().st_size == 0:
        print(f"Downloading kathbath.zip from {KATHBATH_ZIP_URL} ...")
        with requests.get(KATHBATH_ZIP_URL, stream=True, timeout=60) as r:
            r.raise_for_status()
            total = int(r.headers.get("content-length", 0))
            with open(zip_path, "wb") as f, tqdm(
                total=total, unit="B", unit_scale=True, desc="kathbath.zip"
            ) as pbar:
                for chunk in r.iter_content(chunk_size=1024 * 1024):
                    if chunk:
                        f.write(chunk)
                        pbar.update(len(chunk))
    else:
        print(f"Found existing {zip_path}, skipping download.")

    print(f"Extracting to {extract_dir} ...")
    extract_dir.mkdir(parents=True, exist_ok=True)
    with zipfile.ZipFile(zip_path, "r") as zf:
        members = zf.infolist()
        for m in tqdm(members, desc="extracting", unit="file"):
            zf.extract(m, extract_dir)

    extract_marker.touch()
    print("Extraction complete.")
    return extract_dir

# %% [markdown]
# ## 5. Locate each language's test split and match audio to transcripts

# %%
def find_first_existing(base: Path, candidates):
    for c in candidates:
        p = base / c
        if p.exists():
            return p
    # fuzzy fallback: case-insensitive scan of immediate children
    if base.exists():
        lower_map = {p.name.lower(): p for p in base.iterdir() if p.is_dir()}
        for c in candidates:
            if c.lower() in lower_map:
                return lower_map[c.lower()]
    return None


def locate_language_dir(kathbath_root: Path, lang: str) -> Path:
    # the zip extracts with an extra nested "kathbath/kathbath/<lang>/" layout
    # on some mirrors, and a flat "<lang>/" layout on others -- handle both.
    search_roots = [kathbath_root, kathbath_root / "kathbath"]
    for root in search_roots:
        lang_dir = find_first_existing(root, LANG_DIR_CANDIDATES[lang])
        if lang_dir is not None:
            return lang_dir
    raise FileNotFoundError(
        f"Could not locate a folder for '{lang}' under {kathbath_root}. "
        f"Check the extracted folder layout with `!find {kathbath_root} -maxdepth 4`."
    )


# manifest.json is a NeMo-style JSONL file: one JSON object per line, each
# with (at least) "audio_filepath" and "text" -- e.g.
#   {"audio_filepath": "audio/844424933726456-...-f.wav", "duration": 4.2, "text": "..."}
MANIFEST_NAME_CANDIDATES = [
    "manifest.json",
    "test_manifest.json",
    "test_known_manifest.json",
    "test_unknown_manifest.json",
    "valid_manifest.json",
]


def find_manifest_files(lang_dir: Path):
    """Return every manifest-like JSONL file for this language. Prefers an
    explicit test/known/unknown/valid manifest if several exist; otherwise
    falls back to whatever *manifest*.json files are present (recursively,
    in case they sit inside a test/ or manifests/ subfolder)."""
    found = []
    for name in MANIFEST_NAME_CANDIDATES:
        p = lang_dir / name
        if p.exists():
            found.append(p)
    if found:
        return found
    # recursive fallback: any file whose name contains "manifest" and ends in .json
    found = sorted(lang_dir.rglob("*manifest*.json"))
    if found:
        return found
    raise FileNotFoundError(
        f"No manifest.json-style file found under {lang_dir}. "
        f"Check the folder layout with `!find {lang_dir} -maxdepth 3`."
    )


def resolve_audio_path(audio_filepath: str, manifest_path: Path, lang_dir: Path, kathbath_root: Path):
    """audio_filepath inside the manifest may be absolute, relative to the
    manifest's own folder, relative to the language folder, or relative to
    the kathbath root -- try each in turn, then fall back to a recursive
    filename search under the language folder."""
    candidates = [
        Path(audio_filepath),
        manifest_path.parent / audio_filepath,
        lang_dir / audio_filepath,
        kathbath_root / audio_filepath,
    ]
    for c in candidates:
        if c.exists():
            return c

    # last resort: search for a file with this basename anywhere under lang_dir
    target_name = Path(audio_filepath).name
    for p in lang_dir.rglob(target_name):
        return p
    return None


def load_kathbath_lang(kathbath_root: Path, lang: str, max_samples: int = -1):
    lang_dir = locate_language_dir(kathbath_root, lang)
    print(f"  -> language folder for {lang}: {lang_dir}")
    manifest_paths = find_manifest_files(lang_dir)
    print(f"  -> manifest file(s): {[str(p) for p in manifest_paths]}")

    rows = []
    n_missing_audio = 0
    for manifest_path in manifest_paths:
        with open(manifest_path, "r", encoding="utf-8") as f:
            for line_no, line in enumerate(f):
                line = line.strip()
                if not line:
                    continue
                try:
                    entry = json.loads(line)
                except json.JSONDecodeError:
                    continue

                audio_filepath = entry.get("audio_filepath") or entry.get("audio_path")
                text = entry.get("text", "")
                if not audio_filepath:
                    continue

                audio_path = resolve_audio_path(audio_filepath, manifest_path, lang_dir, kathbath_root)
                if audio_path is None:
                    n_missing_audio += 1
                    continue

                utt_id = entry.get("id") or Path(audio_filepath).stem
                # disambiguate ids across multiple manifests (e.g. test_known + test_unknown)
                utt_id = f"{manifest_path.stem}:{utt_id}"

                rows.append({"id": utt_id, "audio_path": str(audio_path), "text": str(text).strip()})

    if n_missing_audio:
        print(f"  ! {n_missing_audio} manifest entries had an audio file that could not be resolved on disk")

    if max_samples and max_samples > 0:
        rows = rows[:max_samples]

    print(f"  -> {len(rows)} (audio, text) pairs loaded for {lang}")
    return rows

# %% [markdown]
# ## 6. Text normalization + WER / CER metrics

# %%
# ================================================================ #
# Text normalization + metrics (mirrors editdistance-based WER/CER
# methodology used elsewhere in this project)
# ================================================================ #
_PUNCT_RE = re.compile(r"[^\w\s\u0900-\u0DFF]", flags=re.UNICODE)


def normalize_text(text: str) -> str:
    if text is None:
        return ""
    text = unicodedata.normalize("NFC", str(text))
    text = _PUNCT_RE.sub(" ", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text


def wer(ref: str, hyp: str) -> float:
    ref_words = ref.split()
    hyp_words = hyp.split()
    if len(ref_words) == 0:
        return 0.0 if len(hyp_words) == 0 else 1.0
    return editdistance.eval(ref_words, hyp_words) / len(ref_words)


def cer(ref: str, hyp: str) -> float:
    ref_chars = ref.replace(" ", "")
    hyp_chars = hyp.replace(" ", "")
    if len(ref_chars) == 0:
        return 0.0 if len(hyp_chars) == 0 else 1.0
    return editdistance.eval(list(ref_chars), list(hyp_chars)) / len(ref_chars)

# %% [markdown]
# ## 7. Load the SraVaani-1.0 model

# %%
def load_model(hf_token: str, device: str):
    print(f"Loading {MODEL_REPO} on {device} ...")
    model = AutoModel.from_pretrained(
        MODEL_REPO, trust_remote_code=True, token=hf_token
    ).to(device).eval()
    print("Model loaded.")
    return model


def audio_to_temp_wav(audio_path: str, tmp_dir: Path, idx: int) -> str:
    """Decodes source audio (wav/m4a/mp3/flac) to a 16kHz mono wav and
    returns its path. Falls back to librosa (ffmpeg-backed) for formats
    soundfile can't read directly, e.g. m4a."""
    out_path = tmp_dir / f"sample_{idx}.wav"
    try:
        wav, sr = sf.read(audio_path, dtype="float32")
        if wav.ndim > 1:
            wav = wav.mean(axis=1)
    except Exception:
        wav, sr = librosa.load(audio_path, sr=None, mono=True)
    if sr != TARGET_SR:
        wav = librosa.resample(wav.astype("float32"), orig_sr=sr, target_sr=TARGET_SR)
    sf.write(out_path, wav, TARGET_SR)
    return str(out_path)

# %% [markdown]
# ## 8. Checkpoint cache (resumable)

# %%
# ================================================================ #
# Checkpoint cache (resumable jsonl, one line per evaluated sample)
# ================================================================ #
def load_cache(cache_path: Path):
    done = {}
    if cache_path.exists():
        with open(cache_path, "r", encoding="utf-8") as f:
            for line in f:
                line = line.strip()
                if not line:
                    continue
                try:
                    row = json.loads(line)
                    done[row["id"]] = row
                except json.JSONDecodeError:
                    continue
    return done


def append_cache(cache_path: Path, row: dict):
    with open(cache_path, "a", encoding="utf-8") as f:
        f.write(json.dumps(row, ensure_ascii=False) + "\n")

# %% [markdown]
# ## 9. Per-language evaluation loop
#
# Prints reference / predicted text and running WER/CER every `print_every` utterances, and appends every result to a `.jsonl` checkpoint so a rerun resumes instead of restarting.

# %%
# ================================================================ #
# Per-language evaluation
# ================================================================ #
def evaluate_language(model, lang, kathbath_root, out_dir, batch_size, max_samples, print_every, device):
    print(f"\n{'=' * 70}\nEvaluating language: {lang.upper()}\n{'=' * 70}")
    rows_meta = load_kathbath_lang(kathbath_root, lang, max_samples)
    n_total = len(rows_meta)
    if n_total == 0:
        print(f"  ! no utterances found for {lang}, skipping")
        return {"language": lang, "n_utterances": 0, "wer": float("nan"), "cer": float("nan")}

    cache_path = out_dir / f"{lang}_checkpoint.jsonl"
    csv_path = out_dir / f"sravaani_kathbath_{lang}_results.csv"
    tmp_dir = out_dir / f"_tmp_wav_{lang}"
    tmp_dir.mkdir(parents=True, exist_ok=True)

    done = load_cache(cache_path)
    if done:
        print(f"  resuming from checkpoint: {len(done)}/{n_total} already done")

    pending = [r for r in rows_meta if r["id"] not in done]

    running_wer_sum, running_cer_sum, running_n = 0.0, 0.0, 0
    for r in done.values():
        running_wer_sum += r["wer"]
        running_cer_sum += r["cer"]
        running_n += 1

    pbar = tqdm(total=n_total, initial=len(done), desc=f"{lang}", unit="utt")

    batch_paths, batch_meta = [], []

    def flush_batch():
        nonlocal running_wer_sum, running_cer_sum, running_n
        if not batch_paths:
            return
        try:
            hyps = model.transcribe(batch_paths, batch_size=len(batch_paths), return_hypotheses=True)
        except TypeError:
            hyps = model.transcribe(batch_paths, return_hypotheses=True)

        for wav_path, meta, hyp in zip(batch_paths, batch_meta, hyps):
            ref_raw = meta["text"]
            pred_raw = hyp.text if hasattr(hyp, "text") else str(hyp)

            ref_norm = normalize_text(ref_raw)
            pred_norm = normalize_text(pred_raw)
            u_wer = wer(ref_norm, pred_norm)
            u_cer = cer(ref_norm, pred_norm)

            row = {
                "id": meta["id"],
                "language": lang,
                "reference": ref_raw,
                "prediction": pred_raw,
                "wer": round(u_wer, 4),
                "cer": round(u_cer, 4),
            }
            append_cache(cache_path, row)
            done[meta["id"]] = row

            running_wer_sum += u_wer
            running_cer_sum += u_cer
            running_n += 1

            if running_n % print_every == 0:
                tqdm.write(
                    f"  [{lang}] #{meta['id']} REF : {ref_raw}\n"
                    f"  [{lang}] #{meta['id']} PRED: {pred_raw}\n"
                    f"  [{lang}] running avg -> WER {running_wer_sum / running_n:.4f} | "
                    f"CER {running_cer_sum / running_n:.4f}  ({running_n}/{n_total})"
                )
            try:
                os.remove(wav_path)
            except OSError:
                pass
            pbar.update(1)
        batch_paths.clear()
        batch_meta.clear()

    for i, meta in enumerate(pending):
        wav_path = audio_to_temp_wav(meta["audio_path"], tmp_dir, i)
        batch_paths.append(wav_path)
        batch_meta.append(meta)
        if len(batch_paths) >= batch_size:
            flush_batch()
    flush_batch()
    pbar.close()

    # final CSV for this language, in original transcript order
    ordered_rows = [done[r["id"]] for r in rows_meta if r["id"] in done]
    df = pd.DataFrame(ordered_rows)
    df.to_csv(csv_path, index=False, encoding="utf-8-sig")

    lang_wer = df["wer"].mean() if len(df) else float("nan")
    lang_cer = df["cer"].mean() if len(df) else float("nan")
    print(f"  DONE {lang}: n={len(df)}  WER={lang_wer:.4f}  CER={lang_cer:.4f}")
    print(f"  -> {csv_path}")

    try:
        tmp_dir.rmdir()
    except OSError:
        pass

    gc.collect()
    if device == "cuda":
        torch.cuda.empty_cache()

    return {"language": lang, "n_utterances": len(df), "wer": lang_wer, "cer": lang_cer}

# %% [markdown]
# ## 10. Run configuration

# %%
LANGUAGES = ["marathi"]
BATCH_SIZE = 8
MAX_SAMPLES = -1       # -1 = full test set; set e.g. 50 for a quick smoke test first
PRINT_EVERY = 20
OUT_DIR = Path("/kaggle/working/sravaani_kathbath_eval")
DATA_DIR = Path("/kaggle/working/kathbath_data")

OUT_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## 11. Download data + load model

# %%
kathbath_root = download_kathbath(DATA_DIR)

hf_token = get_hf_token()
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Device: {device}")

model = load_model(hf_token, device)
# Out:
# Kathbath already downloaded + extracted at /kaggle/working/kathbath_data/kathbath
# Device: cuda
# Loading ARTPARK-IISc/SraVaani-1.0 on cuda ...
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Model loaded.

# %% [markdown]
# ## 12. Run evaluation across all languages

# %%
summary = []
t0 = time.time()
for lang in LANGUAGES:
    result = evaluate_language(
        model, lang, kathbath_root, OUT_DIR,
        batch_size=BATCH_SIZE,
        max_samples=MAX_SAMPLES,
        print_every=PRINT_EVERY,
        device=device,
    )
    summary.append(result)
    pd.DataFrame(summary).to_csv(OUT_DIR / "sravaani_kathbath_summary.csv", index=False)

elapsed = time.time() - t0
print(f"\n{'=' * 70}\nALL LANGUAGES DONE in {elapsed / 60:.1f} min\n{'=' * 70}")
summary_df = pd.DataFrame(summary)
print(summary_df.to_string(index=False))
print(f"\nPer-language CSVs + summary written to: {OUT_DIR}")
summary_df
# Out:
# ======================================================================
# Evaluating language: MARATHI
# ======================================================================
#   -> language folder for marathi: /kaggle/working/kathbath_data/kathbath/kathbath/marathi
#   -> manifest file(s): ['/kaggle/working/kathbath_data/kathbath/kathbath/marathi/manifest.json']
#   -> 1631 (audio, text) pairs loaded for marathi
# marathi:   0%|          | 0/1631 [00:00<?, ?utt/s]
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:1787: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters(). (Triggered internally at /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1480.)
#   return forward_call(*args, **kwargs)
#   [marathi] #manifest:844424931570515-236-f REF : अमेरिकेचे परराष्ट्र मंत्री माईक पॉम्पिओ यांनी नुकतीच नरेंद्र मोदी यांची भेट घेतली होती
#   [marathi] #manifest:844424931570515-236-f PRED: अमेरिकेचे परराष्ट्रमंत्री माईक पॉम्पियो यांनी नुकतीच नरेंद्र मोदी यांची भेट घेतली होती
#   [marathi] running avg -> WER 0.1102 | CER 0.0190  (20/1631)
#   [marathi] #manifest:844424931570604-236-f REF : सध्या तलाठी पदाची निवड जिल्हा निवड मंडळामार्फत केली जाते
#   [marathi] #manifest:844424931570604-236-f PRED: सध्या तलाठी पदाची निवड जिल्हा निवड मंडळामार्फत केली जाते
#   [marathi] running avg -> WER 0.1160 | CER 0.0376  (40/1631)
#   [marathi] #manifest:844424932484422-573-f REF : काहीवेळाने आशा सिंह यांच्या चालकानेही उपचार दरम्यान अखेरचा श्वास घेतला
#   [marathi] #manifest:844424932484422-573-f PRED: काही वेळाने आशा सिंह याच्या चालकानेही उपचारा दरम्यान अखेरचा श्वास घेतला
#   [marathi] running avg -> WER 0.1198 | CER 0.0317  (60/1631)
#   [marathi] #manifest:844424930557229-737-f REF : छ्ळणार्या विचारांपासून सुटका करुन घेण्याचा तो एकच मार्ग होता
#   [marathi] #manifest:844424930557229-737-f PRED: चलणाऱ्या विचारांपासून सुटका करून घेण्याचा तो एकच मार्ग होता
#   [marathi] running avg -> WER 0.1253 | CER 0.0370  (80/1631)
#   [marathi] #manifest:844424932823408-715-f REF : त्यामुळे कदाचित काहींचे घराचे स्वप्न साकार व्हायला हरकत नसावी
#   [marathi] #manifest:844424932823408-715-f PRED: त्यामुळे कदाचित काहींचे घराचे स्वप्न साकार व्हायला हरकत नसावे
#   [marathi] running avg -> WER 0.1243 | CER 0.0353  (100/1631)
#   [marathi] #manifest:844424930573363-737-f REF : तुझी काय म्हणेल असं बेधडक उत्तर देत एलियानाने त्याची बोलती बंद केली
#   [marathi] #manifest:844424930573363-737-f PRED: तुझी काय म्हणेल असं बेधडक उत्तर देत एलियानाने त्याची बोलती बंद केली
#   [marathi] running avg -> WER 0.1265 | CER 0.0347  (120/1631)
#   [marathi] #manifest:844424930573374-737-f REF : अशा आणीबाणीच्या प्रसंगीही वेळेवर आणि अचूक निर्णय करण्यात सामाजिक कार्यकर्त्यांचे आपत्ती व्यवस्थापन कौशल्य कामी येते
#   [marathi] #manifest:844424930573374-737-f PRED: अशा आणीबाणीच्या प्रसंगीही वेळेवर आणि अचूक निर्णय करण्यात सामाजिक कार्यकर्त्यांचे आपत्ती व्यवस्थापन कौशल्य कामी येते
#   [marathi] running avg -> WER 0.1251 | CER 0.0363  (140/1631)
#   [marathi] #manifest:844424930557267-737-f REF : यानंतर सुरक्षादलांनी प्रत्युत्तर देताना गोळीबार सुरू केला आणि यात एकून तीन दहशतवादी ठार झाले
#   [marathi] #manifest:844424930557267-737-f PRED: यानंतर सुरक्षा दलांनी प्रत्युत्तर देताना गोळीबार सुरू केला आणि यात एकूण तीन दहशतवादी ठार झाले
#   [marathi] running avg -> WER 0.1282 | CER 0.0377  (160/1631)
#   [marathi] #manifest:844424932262388-809-f REF : राज्यातील करोना बाधित रुग्णांची संख्या आता ५ हजारांच्या पुढं गेली आहे
#   [marathi] #manifest:844424932262388-809-f PRED: राज्यातील करोना बाधित रुग्णांची संख्या आता पाच हजारांच्या पुढे गेली आहे
#   [marathi] running avg -> WER 0.1334 | CER 0.0394  (180/1631)
#   [marathi] #manifest:844424930868434-933-f REF : परंतु बागकाम व्यवसायामुळे माळी ही नवी जात वा माळी समाजाची निर्मिती झालेली असावी
#   [marathi] #manifest:844424930868434-933-f PRED: परंतु बागकाम व्यवसायामुळे माळे ही नवीन जात वा माळी समाजाची निर्मिती झालेली असावी
#   [marathi] running avg -> WER 0.1293 | CER 0.0376  (200/1631)
#   [marathi] #manifest:844424932266686-980-f REF : १९४६ साली सिनेसृष्टीत पदार्पण केलं तेव्हा त्यांना मराठी नीट बोलता येत नव्हतं
#   [marathi] #manifest:844424932266686-980-f PRED: एकोणवीसशे छेचाळीस साली सिनेसृष्टीत पदार्पण केलं तेव्हा त्यांना मराठी नीट बोलता येत नव्हतं
#   [marathi] running avg -> WER 0.1276 | CER 0.0397  (220/1631)
#   [marathi] #manifest:844424931570561-236-f REF : रात्री जागरण करणे किंवा रात्री उशिरा झोपणे हेदेखील शरीरास अपायकारक आहे
#   [marathi] #manifest:844424931570561-236-f PRED: रात्री जागरण करणे किंवा रात्री उशिरा झोपणे हे देखील शरीरास अपायकारक आहे
#   [marathi] running avg -> WER 0.1304 | CER 0.0393  (240/1631)
#   [marathi] #manifest:844424932311895-980-f REF : संख्येने विरोधी पक्ष कमी असला तरी अखंड महाराष्ट्रवादी जनता विरोधी पक्षांच्या पाठीमागे आहे
#   [marathi] #manifest:844424932311895-980-f PRED: संख्येने विरोधी पक्ष कमी असला तरी अखंड महाराष्ट्रवादी जनता विरोधी पक्षाच्या पाठीमागे आहे
#   [marathi] running avg -> WER 0.1361 | CER 0.0415  (260/1631)
#   [marathi] #manifest:844424932823385-715-f REF : त्यावर उर्मिला मातोंडकरने सडेतोड उत्तर देत त्यांची बोलती बंद केली
#   [marathi] #manifest:844424932823385-715-f PRED: त्यावर उर्मिला मातोंडकरणे सडेतोड उत्तर देत त्यांची बोलती बंद केली
#   [marathi] running avg -> WER 0.1357 | CER 0.0423  (280/1631)
#   [marathi] #manifest:844424930557275-737-f REF : मनसेच्या कार्यकर्त्यांनी फेरीवाल्यांना मारहाण करण्यापूर्वी ठाणे महापालिकेच्या विरोधात आक्रमक होण्याची गरज असल्याचे त्यांनी स्पष्ट केले
#   [marathi] #manifest:844424930557275-737-f PRED: मनसेच्या कार्यकर्त्यांनी फेरीवाल्यांना मारहाण करण्यापूर्वी ठाणे महापालिकेच्या विरोधात आक्रमक होण्याची गरज असल्याचे त्यांनी स्पष्ट केले
#   [marathi] running avg -> WER 0.1388 | CER 0.0418  (300/1631)
#   [marathi] #manifest:844424930573298-737-f REF : इस्लामपूर पोलिसांच्या सतर्कतेमुळे हा अट्टल चोरटा जेरबंद झाला आहे
#   [marathi] #manifest:844424930573298-737-f PRED: इस्लामपूर पोलिसांच्या सतर्कतेमुळे हा अटल चोरटा जेलबंद झाला आहे
#   [marathi] running avg -> WER 0.1391 | CER 0.0411  (320/1631)
#   [marathi] #manifest:844424932337183-809-f REF : या व्हिडिओमध्ये एक कुटुंब आपल्या घरातील मृत व्यक्तीचा मृतदेह सायकलवरून नेताना दिसत आहेत
#   [marathi] #manifest:844424932337183-809-f PRED: या व्हिडिओमध्ये एक कुटुंब आपल्या घरातील मृत व्यक्तीचा मृतदेह सायकलवरून नेताना दिसत आहे
#   [marathi] running avg -> WER 0.1391 | CER 0.0405  (340/1631)
#   [marathi] #manifest:844424930875841-954-f REF : असामी खेळाडू लावलिना हिने ६९ किलो गटात भारताच्या पूजा ला मात देत विजय मिळविला
#   [marathi] #manifest:844424930875841-954-f PRED: असामी खेळाडू लावली नाईने एकूणसत्तर किलो गटात भारताच्या पूजाला मात देत विजय मिळविला
#   [marathi] running avg -> WER 0.1400 | CER 0.0402  (360/1631)
#   [marathi] #manifest:844424932372195-132-f REF : भारताला एक रन करता आला आणि ही मॅच टाय झाली
#   [marathi] #manifest:844424932372195-132-f PRED: भारताला एक रन करता आला आणि ही मॅच टाय झाली
#   [marathi] running avg -> WER 0.1387 | CER 0.0401  (380/1631)
#   [marathi] #manifest:844424932311937-980-f REF : यामध्ये चाळींचा पुर्नर विकास केल्या नंतर जेवढा विकास करण्यात आला
#   [marathi] #manifest:844424932311937-980-f PRED: त्यामध्ये चाळींचा पुनर्विकास केल्यानंतर जेवढा विकास करण्यात आला
#   [marathi] running avg -> WER 0.1377 | CER 0.0398  (400/1631)
#   [marathi] #manifest:844424930868510-933-f REF : त्यासाठी महिन्याकाठी होणारा पाच ते सहा लाख रुपयांचा खर्च अनावश्यक असल्याचे सूत्रांचे म्हणणे आहे
#   [marathi] #manifest:844424930868510-933-f PRED: त्यासाठी महिन्याकाठी होणाऱ्या पाच ते सहा लाख रुपयांचा खर्च अनावश्यक असल्याचे सुधारांचे म्हणणे आहे
#   [marathi] running avg -> WER 0.1400 | CER 0.0409  (420/1631)
#   [marathi] #manifest:844424932823362-715-f REF : राष्ट्रीय मीडिया समोर हा मोदींचा पहिला परिचय होता
#   [marathi] #manifest:844424932823362-715-f PRED: राष्ट्रीय मीडियासमोर हा मोदींचा पहिला परिचय होता
#   [marathi] running avg -> WER 0.1405 | CER 0.0407  (440/1631)
#   [marathi] #manifest:844424932484375-573-f REF : १९६५ सालापासून क्यूबामध्ये कॅस्ट्रो व त्याचा भाऊ राउल कास्त्रो ह्यांच्या नेतृत्वाखाली साम्यवादी प्रशासन अस्तित्वात आले
#   [marathi] #manifest:844424932484375-573-f PRED: एकोणीसौ पासष्ट सालापासून क्यूबामध्ये केस्ट्रो व त्यांच्या भाऊराईल केस्ट्रो यांच्या नेतृत्वाखाली साम्यवादी प्रशासन अस्तित्वात आले
#   [marathi] running avg -> WER 0.1450 | CER 0.0411  (460/1631)
#   [marathi] #manifest:844424931570546-236-f REF : या व्हिडिओ बांग्लादेशच्या खेळाडूंनी भारतीय खेळाडूंच्या समोर जाऊन गैरवर्तणूक केल्याचे दिसत आहे
#   [marathi] #manifest:844424931570546-236-f PRED: हा व्हिडिओ बांगलादेशच्या खेळाडूंनी भारतीय खेळाडूंच्या समोर जाऊन गैरवर्तणूक केल्याचे दिसत आहे
#   [marathi] running avg -> WER 0.1454 | CER 0.0418  (480/1631)
#   [marathi] #manifest:844424932484372-573-f REF : त्यामुळे इतक्या कमी कालावधीत त्यांच्याकडून ठोस निर्णय घेतले जाणे शक्य होत नाही
#   [marathi] #manifest:844424932484372-573-f PRED: त्यामुळे इतक्या कमी कालावधीत त्याच्याकडून ठोस निर्णय घेतले जाणे शक्य होत नाही
#   [marathi] running avg -> WER 0.1445 | CER 0.0421  (500/1631)
#   [marathi] #manifest:844424930875887-954-f REF : चेकोस्लोव्हाकियाच्या आक्रमणाच्या विरोधात दिग्दर्शित केलेल्या सर्वात निर्णायक कृत्यांमध्ये नतालिया गोरबनेव्हस्काया यांनी भाषण केले होते
#   [marathi] #manifest:844424930875887-954-f PRED: जेकोस्लो वाकियाच्या आक्रमणाच्या विरुद्धात दिर्गशीत केलेल्या सर्वात निर्णायक कर्तृत्वामध्ये नतालिया गोर्स्बर्न वाकियाचा यांनी भाषण केले होते
#   [marathi] running avg -> WER 0.1478 | CER 0.0439  (520/1631)
#   [marathi] #manifest:844424930875834-954-f REF : कोकण रेल्वेच्या या निर्णयामुळे पर्यटकांना मोठा दिलासा मिळणार आहे
#   [marathi] #manifest:844424930875834-954-f PRED: कोकण रेल्वेच्या या निर्णयामुळे पर्यटकांना मोठा दिलासा मिळणार आहे
#   [marathi] running avg -> WER 0.1449 | CER 0.0428  (540/1631)
#   [marathi] #manifest:844424932372211-132-f REF : १९९५ मध्ये इम्रान खान यांनी जेमिमा गोल्डस्मिथ नावाच्या ब्रिटिश पत्रकार महिलेशी विवाह केला होता
#   [marathi] #manifest:844424932372211-132-f PRED: एकोणीसशे पंच्याण्णऊमध्ये इम्रान खान यांनी जेमिमा गोल्डस्मिथ नावाच्या ब्रिटिश पत्रकार महिलेशी विवाह केला होता
#   [marathi] running avg -> WER 0.1458 | CER 0.0426  (560/1631)
#   [marathi] #manifest:844424931030047-933-f REF : मुंबई महानगरपालिकेच्या वतीनं हे औषध धारावी आणि वरळी कोळीवाड्यातील नागरिकांना देण्यात येणार आहे
#   [marathi] #manifest:844424931030047-933-f PRED: मुंबई महानगरपालिकेच्या वतीनं हे औषध धारावी आणि वरळी कोळीवाड्यातील नागरिकांना देण्यात येणार आहे
#   [marathi] running avg -> WER 0.1450 | CER 0.0423  (580/1631)
#   [marathi] #manifest:844424930557239-737-f REF : टूथपेस्ट समजून उंदराच्या विषाने दात घासल्याने एका महिलेला आपला जीव गमवावा लागला आहे
#   [marathi] #manifest:844424930557239-737-f PRED: तुप्पेत समजून उंदरांच्या विषाने दात घासल्याने एका महिलेला आपला जीव गमवावा लागला आहे
#   [marathi] running avg -> WER 0.1431 | CER 0.0416  (600/1631)
#   [marathi] #manifest:844424932266735-980-f REF : फॅन्सकडून या व्हिडीओवर कमेंट्स आणि लाइक्सचा वर्षाव होत आहे
#   [marathi] #manifest:844424932266735-980-f PRED: फॅन्सकडून या व्हिडिओवर कमेंट्स आणि लाइक्सचा वर्षा होत आहे
#   [marathi] running avg -> WER 0.1424 | CER 0.0415  (620/1631)
#   [marathi] #manifest:844424930906962-972-f REF : या धर्माला स्वतंत्र धर्म म्हणून मान्यता देण्यासाठी देशभरातील लिंगायत धर्म रस्त्यावर उतरला आहे
#   [marathi] #manifest:844424930906962-972-f PRED: या धर्माला स्वतंत्र धर्म म्हणून मान्यता देण्यासाठी देशभरातील लिंगायत धर्म रस्त्यावर उतरला आहे
#   [marathi] running avg -> WER 0.1432 | CER 0.0422  (640/1631)
#   [marathi] #manifest:844424931570544-236-f REF : काहींनी जुने दागिने मोडून नवीन दागिने तयार करून घेतले आहे
#   [marathi] #manifest:844424931570544-236-f PRED: काहींनी जुने दागिने मोडून नवीन दागिने तयार करून घेतले आहे
#   [marathi] running avg -> WER 0.1430 | CER 0.0431  (660/1631)
#   [marathi] #manifest:844424932311866-980-f REF : लेबनॉनमधील संयुक्त राष्ट्राच्या अंतरिम दलाने गुरुवारी याची पुष्टी दिली
#   [marathi] #manifest:844424932311866-980-f PRED: लेबनॉनमधील संयुक्त राष्ट्राच्या अंतरिम दलाने गुरुवारी याची पुष्टी दिली
#   [marathi] running avg -> WER 0.1432 | CER 0.0426  (680/1631)
#   [marathi] #manifest:844424930875846-954-f REF : न्यायालयाचे घटनात्मक हक्कांचे संरक्षण करणे हे कर्तव्य असल्याचे आपल्या आदेशात न्यायालयाने म्हटले आहे
#   [marathi] #manifest:844424930875846-954-f PRED: न्यायालयाचे घटनात्मक हक्काचे संरक्षण करणे हे कर्तव्य असल्याचे आपल्या आदेशात न्यायालयाने म्हटले आहे
#   [marathi] running avg -> WER 0.1446 | CER 0.0432  (700/1631)
#   [marathi] #manifest:844424930868505-933-f REF : याआधी रोहित शर्माचा दक्षिण आफ्रिकेतला सर्वाधिक स्कोअर २३ रन्स होता
#   [marathi] #manifest:844424930868505-933-f PRED: याआधी रोहित शर्माचा दक्षिण आफ्रिकेतला सर्वाधिक स्कोअर तेवीस रन्स होता
#   [marathi] running avg -> WER 0.1448 | CER 0.0430  (720/1631)
#   [marathi] #manifest:844424931570519-236-f REF : या खटल्यात देण्यात आलेल्या निकालाचा फेरविचार करण्यात यावा असे सीबीआयचे म्हणणे आहे
#   [marathi] #manifest:844424931570519-236-f PRED: या खटल्यात देण्यात आलेल्या निकालाचा फेरविचार करण्यात यावा असे सीबीआयचे म्हणणे आहे
#   [marathi] running avg -> WER 0.1436 | CER 0.0427  (740/1631)
#   [marathi] #manifest:844424931570545-236-f REF : विधानसभा निवडणुकांसाठी सकाळपासूनच मतदान करण्यासाठी विविध मतदान केंद्रांवर नागरिकांनी तुरळक गर्दी केली होती
#   [marathi] #manifest:844424931570545-236-f PRED: विधानसभा निवडणुकांसाठी सकाळपासूनच मतदान करण्यासाठी विविध मतदान केंद्रांवर नागरिकांनी तुरळक गर्दी केली होती
#   [marathi] running avg -> WER 0.1428 | CER 0.0422  (760/1631)
#   [marathi] #manifest:844424932266672-980-f REF : बुधवारी विवेक ओबेरॉयला जीवे मारण्याची धमकी आल्याची माहिती सूत्रांकडून मिळाली आहे
#   [marathi] #manifest:844424932266672-980-f PRED: बुधवारी विवेक ओबेरॉयला जेवे मारण्याची धमकी आल्याची माहिती सूत्रांकडून मिळाली आहे
#   [marathi] running avg -> WER 0.1421 | CER 0.0421  (780/1631)
#   [marathi] #manifest:844424930573324-737-f REF : समाप्ती घेतले पाच श्रेणी एक खाली ठेवले लष्करी आयडी आहे कोणताही नागरिक
#   [marathi] #manifest:844424930573324-737-f PRED: समाप्ती घेतले पाच श्रेणी एक खाली ठेवले लष्करी आयडी आहे कोणताही नागरिक
#   [marathi] running avg -> WER 0.1417 | CER 0.0419  (800/1631)
#   [marathi] #manifest:844424930649797-823-m REF : तुला हे ठाऊक आहे की मी कोणत्याही इमोशनल अत्याचाराला बळी पडणार नाही
#   [marathi] #manifest:844424930649797-823-m PRED: तुला हे ठाऊक आहे की मी कोणत्याही इमोशनल अत्याचाराला बळी पडणार नाही
#   [marathi] running avg -> WER 0.1416 | CER 0.0416  (820/1631)
#   [marathi] #manifest:844424930331400-60-m REF : या प्रकरणाची पुढील सुनावणी ३१ जानेवारी रोजी होणार आहे
#   [marathi] #manifest:844424930331400-60-m PRED: या प्रकरणाची पुढील सुनावणी एकतीस जानेवारी रोजी होणार आहेत
#   [marathi] running avg -> WER 0.1423 | CER 0.0424  (840/1631)
#   [marathi] #manifest:844424930329014-60-m REF : फुले आणि शोभेच्या झाडांच्या विविध तिच्या भरपूर कमलपुष्पाप्रमाणे आणि मासे दुर्मिळ प्रजाती एक तळे आहे
#   [marathi] #manifest:844424930329014-60-m PRED: फुले आणि शोभेच्या झाडांच्या विविधतेच्या भरपूर कलमपुष्पाप्रमाणे आणि मासे दुर्मिळ प्रजाती एक तळे आहेत
#   [marathi] running avg -> WER 0.1426 | CER 0.0427  (860/1631)
#   [marathi] #manifest:844424930323301-60-m REF : जितके शक्य असेल तितके जाणून घ्या आणि सतत प्रेरणा घ्या
#   [marathi] #manifest:844424930323301-60-m PRED: जितके शक्य असेल तितके जाणून घ्या आणि सतत प्रेरणा घ्या
#   [marathi] running avg -> WER 0.1430 | CER 0.0429  (880/1631)
#   [marathi] #manifest:844424930819840-6-m REF : योग्य वेळी त्यावर उपचार करणे हाच त्यावरचा उत्तम मार्ग आहे
#   [marathi] #manifest:844424930819840-6-m PRED: योग्य वेळी त्यावर उपचार करणे हाच त्यावरचा उत्तम मार्ग आहे
#   [marathi] running avg -> WER 0.1435 | CER 0.0428  (900/1631)
#   [marathi] #manifest:844424930649781-823-m REF : कंगनाच्या वडिलांनीही राज्यातील पोलिसांना पत्र लिहून सुरक्षा देण्याची मागणी केली
#   [marathi] #manifest:844424930649781-823-m PRED: कंगनाच्या वडिलांनीही राज्यातील पोलिसांना पत्र लिहून सुरक्षा देण्याची मागणी केली
#   [marathi] running avg -> WER 0.1436 | CER 0.0429  (920/1631)
#   [marathi] #manifest:844424930394102-60-m REF : एके दिवशी समोरच्या मुलांवर चिडलो आणि त्याच चिडलेल्या अवस्थेत रिक्षात बसलो
#   [marathi] #manifest:844424930394102-60-m PRED: एक दिवशी समोरच्या मुलांवर चिडलो आणि त्या चिडलेल्या अवस्थेत रिक्षात बसलो
#   [marathi] running avg -> WER 0.1431 | CER 0.0425  (940/1631)
#   [marathi] #manifest:844424930649770-823-m REF : विधानसभेच्या तारखा जाहीर होण्यापूर्वी राज ठाकरे संपूर्ण महाराष्ट्र दौरा करणार आहेत
#   [marathi] #manifest:844424930649770-823-m PRED: विधानसभेच्या तारखा जाहीर होण्यापूर्वी राज ठाकरे संपूर्ण महाराष्ट्र दौरा करणार आहेत
#   [marathi] running avg -> WER 0.1435 | CER 0.0423  (960/1631)
#   [marathi] #manifest:844424930344999-60-m REF : केदारनाथ या सिनेमातून ती बॉलीवूडमध्ये पदार्पण करणार असून तिच्यासोबत सुशांत सिंग राजपूतही दिसणार आहे
#   [marathi] #manifest:844424930344999-60-m PRED: केदारनाथ या सिनेमातून ती बॉलिवूडमध्ये पदार्पण करणार असून तिच्यासोबत सुशांत सिंग राजपूतही दिसणार आहेत
#   [marathi] running avg -> WER 0.1426 | CER 0.0424  (980/1631)
#   [marathi] #manifest:844424930810095-6-m REF : सहरसावर प्रत्येक रेल्वे थांबत नसली तरी इथं गाड्यांचा वेग कमी होतो
#   [marathi] #manifest:844424930810095-6-m PRED: सहरसावर प्रत्येक रेल्वे थांबत नसली तरी इथे गाड्यांचा वेग कमी होतो
#   [marathi] running avg -> WER 0.1435 | CER 0.0427  (1000/1631)
#   [marathi] #manifest:844424930746692-6-m REF : या सर्वांच्या सहाय्यानेच हा मैलाचा टप्पा आम्ही गाठू शकलो
#   [marathi] #manifest:844424930746692-6-m PRED: या सर्वांच्या साहाय्यानेच हा महिलाचा टप्पा आम्ही गाठू शकलो
#   [marathi] running avg -> WER 0.1438 | CER 0.0428  (1020/1631)
#   [marathi] #manifest:844424930328454-60-m REF : यंदाच्या निवडणुकीत पहिल्यांदाच भाजपसमोर कडवं आव्हान निर्माण झालं आहे
#   [marathi] #manifest:844424930328454-60-m PRED: यंदाच्या निवडणुकीत पहिल्यांदाच भाजपासमोर कळवा आव्हान निर्माण झाला आहे
#   [marathi] running avg -> WER 0.1434 | CER 0.0427  (1040/1631)
#   [marathi] #manifest:844424930323251-60-m REF : बँकींग प्रणाली अधिक सक्षम आणि स्वच्छ करण्याचा सरकारचा निर्धार आहे
#   [marathi] #manifest:844424930323251-60-m PRED: बँकिंग प्रणाली अधिक सक्षम आणि स्वच्छ करण्याच्या सरकारच्या निर्धारण आहेत
#   [marathi] running avg -> WER 0.1435 | CER 0.0425  (1060/1631)
#   [marathi] #manifest:844424933356052-1120-m REF : तर उद्घाटक म्हणून त्यावेळी सुप्रसिद्ध वक्तेविचारवंत दिवंगत प्रा
#   [marathi] #manifest:844424933356052-1120-m PRED: तर उद्घाटक म्हणून त्यावेळी सुप्रसिद्ध व्यक्ते विचारवंत दविंगत प्रा
#   [marathi] running avg -> WER 0.1464 | CER 0.0432  (1080/1631)
#   [marathi] #manifest:844424933394020-426-m REF : नायक वरनभात लोन्चा कोन नाय कोन्चा हा परीतोश आणि रवी अधिकारी दिग्दर्शित मराठी चित्रपट आहे
#   [marathi] #manifest:844424933394020-426-m PRED: नायक वरणभात लोणचा कोण नाय कोणचा हा परितोष आणि रवी अधिकारी दिग्दर्शित मराठी चित्रपट आहे
#   [marathi] running avg -> WER 0.1471 | CER 0.0440  (1100/1631)
#   [marathi] #manifest:844424933356046-1120-m REF : रांगोळी ही एक कला आहे आणि तिचा उगम धर्माच्या अनुबंधानेच झाला आहे असे मानले जाते
#   [marathi] #manifest:844424933356046-1120-m PRED: रांगोळी ही एक कला आहे आणि तिच्या उगम धर्माच्या अनुबंधातनेच झाला आहे असे मानले जाते
#   [marathi] running avg -> WER 0.1484 | CER 0.0449  (1120/1631)
#   [marathi] #manifest:844424933379959-487-m REF : आत्महत्या म्हणजे सहेतुकपणे स्वतःच स्वतःचे आयुष्य संपविण्याचे कृत्य होय
#   [marathi] #manifest:844424933379959-487-m PRED: आत्महत्या म्हणजे सहेतूपपणे स्वतःच स्वतःचे आयुष्य संपवण्याचे कृत्य होय
#   [marathi] running avg -> WER 0.1495 | CER 0.0455  (1140/1631)
#   [marathi] #manifest:844424933379944-487-m REF : पौराणिक दंडकारण्य या प्रदेशात तसेच रामायण व महाभारतातील रंजक कथा दंडारण्यातून सादर केल्या जातात
#   [marathi] #manifest:844424933379944-487-m PRED: पौराणिक दंडकारण्य या प्रदेशात तसेच रामायण व महाभारतातील रंजक कथा दंडारण्यातून सादर केल्या जातात
#   [marathi] running avg -> WER 0.1512 | CER 0.0475  (1160/1631)
#   [marathi] #manifest:844424933355988-1120-m REF : त्यावेळी त्या एलिफंटा वेरुळ आणि महाबलिपुरम येथील शिल्पकृती पाहण्यासाठी गेल्या
#   [marathi] #manifest:844424933355988-1120-m PRED: त्यावेळी त्या एलिफंटावेरूळ आणि महाबलीपुरम येथील शिल्पवृत्ती पाहण्यासाठी गेल्या
#   [marathi] running avg -> WER 0.1522 | CER 0.0481  (1180/1631)
#   [marathi] #manifest:844424933356016-1120-m REF : विषाणूंचा अभ्यास करणाऱ्या शाखेला विषाणुशास्त्र म्हणतात तर या शास्त्राचा अभ्यास करणाऱ्या व्यक्तींना विषाणुशास्त्रज्ञ म्हणतात
#   [marathi] #manifest:844424933356016-1120-m PRED: विषाणूंचा अभ्यास करणाऱ्या शाखेला विषाणूशास्त्र म्हणतात तर या शास्त्राचा अभ्यास करणाऱ्या व्यक्तींना विषाणूशास्त्रज्ञ म्हणतात
#   [marathi] running avg -> WER 0.1536 | CER 0.0493  (1200/1631)
#   [marathi] #manifest:844424933394047-426-m REF : जिथेउपलब्ध आहे त्यांचेकरीता एक वाजवता येणारे ध्वनि सुद्धादिली आहे
#   [marathi] #manifest:844424933394047-426-m PRED: जिथे उपलब्ध आहे त्याचेकरिता एक वाजवता येणारी ध्वनी सुद्धा दिली आहे
#   [marathi] running avg -> WER 0.1550 | CER 0.0501  (1220/1631)
#   [marathi] #manifest:844424933394024-426-m REF : उदयगिरीचा किल्ला भारताच्या तमिळनाडू राज्यातील कन्याकुमारी जिल्ह्यात असलेला एक किल्ला आहे
#   [marathi] #manifest:844424933394024-426-m PRED: उदयगिरीचा किल्ला भारताच्या तामिळनाडू राज्यातील कन्याकुमारी जिल्ह्यात असलेला एक किल्ला आहे
#   [marathi] running avg -> WER 0.1555 | CER 0.0505  (1240/1631)
#   [marathi] #manifest:844424933355994-1120-m REF : यादव आणि डॉ राजेश वत्स आदी आघाडीच्या शास्त्रज्ञ विद्यार्थ्यांना मार्गदर्शन करण्यासाठी कॉलेजांना भेटी देतात
#   [marathi] #manifest:844424933355994-1120-m PRED: यादव आणि डॉ राजेश्वस आदी आघाडीच्या शास्त्रज्ञ विद्यार्थ्यांना मार्गदर्शन करण्यासाठी कॉलेजांना भेट देतात
#   [marathi] running avg -> WER 0.1567 | CER 0.0515  (1260/1631)
#   [marathi] #manifest:844424933394849-566-m REF : राष्ट्रीय महामार्ग १ सी हा भारतातील एक छोटा राष्ट्रीय महामार्ग आहे
#   [marathi] #manifest:844424933394849-566-m PRED: राष्ट्रीय महामार्गावर एक्सी हा भारतातील एक छोटा राष्ट्रीय महामार्ग आहे
#   [marathi] running avg -> WER 0.1590 | CER 0.0527  (1280/1631)
#   [marathi] #manifest:844424933373390-962-m REF : पिंपळापूर हे भारतातील महाराष्ट्र राज्यातील यवतमाळ जिल्ह्यातील केळापूर तालुक्यातील एक गाव आहे
#   [marathi] #manifest:844424933373390-962-m PRED: पिंपळापूर हे भारतातील महाराष्ट्र राज्यातील यवतमाळ जिल्ह्यातील केळापूर तालुक्यातील एक गाव आहे
#   [marathi] running avg -> WER 0.1595 | CER 0.0529  (1300/1631)
#   [marathi] #manifest:844424933356042-1120-m REF : दिसते नासते काया माया ते अंतरी वसे ४
#   [marathi] #manifest:844424933356042-1120-m PRED: दिसते नाचते काया माया ते अंतरी वसे चार
#   [marathi] running avg -> WER 0.1603 | CER 0.0542  (1320/1631)
#   [marathi] #manifest:844424933381615-676-m REF : क्रिकेट विश्वचषक २०१९ जुलै मध्ये संपन्न झाल्यावर एशेस मालिकेला सुरुवात होईल
#   [marathi] #manifest:844424933381615-676-m PRED: क्रिकेट विश्वदेशक दोन हजार एकोणीस जुलै मध्ये संपन्न झाल्यावर आयशेष मालिकेला सुरुवात होईल
#   [marathi] running avg -> WER 0.1607 | CER 0.0547  (1340/1631)
#   [marathi] #manifest:844424933373469-962-m REF : या उपनिषदात शरीरस्थित आत्मतत्त्वाच्या आत्मदेवाच्या पूजेची व उपासनेची पद्धत समजावून दिलेली आहे
#   [marathi] #manifest:844424933373469-962-m PRED: या उपनिषदात शरीरस्त्रीत आत्मतत्वाच्या आत्मदेवाच्या पूजेची व उपासनेची पद्धत समजावून दिलेली आहे
#   [marathi] running avg -> WER 0.1609 | CER 0.0549  (1360/1631)
#   [marathi] #manifest:844424933381633-676-m REF : लंडन हीथ्रो विमानतळ हा युनायटेड किंग्डम देशामधील सर्वात मोठा व प्रमुख आंतरराष्ट्रीय विमानतळ आहे
#   [marathi] #manifest:844424933381633-676-m PRED: लंडनहिथ्रो विमानतळ हा युनायटेड किंगडम देशामधील सर्वात मोठा व प्रमुख आंतरराष्ट्रीय विमानतळ आहे
#   [marathi] running avg -> WER 0.1614 | CER 0.0550  (1380/1631)
#   [marathi] #manifest:844424933381603-676-m REF : मिरची हे उष्ण कटिबंधीय अमेरिका येथील फळ आहे असे मानले जाते
#   [marathi] #manifest:844424933381603-676-m PRED: मिरची हे उष्ण कटिबंधीय अमेरिका येथील फळ आहे असे मानले जाते
#   [marathi] running avg -> WER 0.1620 | CER 0.0553  (1400/1631)
#   [marathi] #manifest:844424933356019-1120-m REF : मालेगाव हे भारताच्या महाराष्ट्र राज्यातील पुणे जिल्ह्यातील मुळशी तालुक्यातील एक गाव आहे
#   [marathi] #manifest:844424933356019-1120-m PRED: मालेगाव हे भारताच्या महाराष्ट्र राज्यातील पुणे जिल्ह्यातील मुळशी तालुक्यातील एक गाव आहे
#   [marathi] running avg -> WER 0.1625 | CER 0.0555  (1420/1631)
#   [marathi] #manifest:844424933379937-487-m REF : या मासिकामध्ये श्रीअरविंद व श्रीमाताजी यांच्या इंग्रजी साहित्याचा अनुवाद प्रकाशित केला जातो
#   [marathi] #manifest:844424933379937-487-m PRED: या मासिकामध्ये श्रीअरविंद व श्रीमाताजी यांच्या इंग्रजी साहित्याचा अनुवाद प्रकाशित केला जातो
#   [marathi] running avg -> WER 0.1633 | CER 0.0556  (1440/1631)
#   [marathi] #manifest:844424933356056-1120-m REF : यासाठी पीएसएलव्ही सी २५ हे प्रक्षेपण अस्त्र वापरण्यात आले
#   [marathi] #manifest:844424933356056-1120-m PRED: यासाठी पी एस एल व्ही सी ट्वेंटी फाय हे प्रक्षेपण अस्त्र वापरण्यात आले
#   [marathi] running avg -> WER 0.1644 | CER 0.0563  (1460/1631)
#   [marathi] #manifest:844424933280434-817-m REF : दुसऱ्या महायुद्धात नाझी जर्मनीचा पाडाव झाल्यानंतर नाझी पक्ष नष्ट पावला
#   [marathi] #manifest:844424933280434-817-m PRED: दुसऱ्या महायुद्धात नाझी जर्मनीचा पाढाव झाल्यानंतर नाझी पक्ष नष्ट पावला
#   [marathi] running avg -> WER 0.1641 | CER 0.0566  (1480/1631)
#   [marathi] #manifest:844424933379905-487-m REF : मध्य युगातले कुठलेही नाणे त्यांना दाखवले की ते तत्काळ त्याची माहिती सांगत
#   [marathi] #manifest:844424933379905-487-m PRED: मध्ययुगातले कुठलेही नाणे त्यांना दाखवले की ते तत्काळ त्याची माहिती सांगत
#   [marathi] running avg -> WER 0.1652 | CER 0.0575  (1500/1631)
#   [marathi] #manifest:844424933379935-487-m REF : पंचक्रोशीतील व बाहेरगावी कामधंद्यासाठी गेलेले लोक या दिवशी गावात येतात
#   [marathi] #manifest:844424933379935-487-m PRED: पंचक्रोशीतील व बाहेरगावी कामधंद्यासाठी गेलेले लोक या दिवशी गावात येतात
#   [marathi] running avg -> WER 0.1662 | CER 0.0581  (1520/1631)
#   [marathi] #manifest:844424933373423-962-m REF : हा रस्ता पुन्हा केव्हा व कसा सुरू होईल याबद्दल साशंकता आहे
#   [marathi] #manifest:844424933373423-962-m PRED: हा रस्ता पुन्हा केव्हा व कसा सुरू होईल याबद्दल असा शंका आहे
#   [marathi] running avg -> WER 0.1667 | CER 0.0593  (1540/1631)
#   [marathi] #manifest:844424933379933-487-m REF : पण या नौका फ्लेचरच्या मुख्य तांड्याचा भाग नव्हत्याच
#   [marathi] #manifest:844424933379933-487-m PRED: पण या नौका फ्लेचरच्या मुख्य तांड्यांच्या भाग नव्हत्याच
#   [marathi] running avg -> WER 0.1682 | CER 0.0599  (1560/1631)
#   [marathi] #manifest:844424933356041-1120-m REF : तर न्यायाची योग्य ती तत्त्वे ज्यांचे सर्वोत्तम परिणाम होतात त्या असतात
#   [marathi] #manifest:844424933356041-1120-m PRED: तर न्यायाची योग्य ती तत्त्वे त्यांचे सर्वोत्तम परिणाम होतात त्यास असतात
#   [marathi] running avg -> WER 0.1684 | CER 0.0606  (1580/1631)
#   [marathi] #manifest:844424933373429-962-m REF : ग्राहकांच्या मागणीशिवाय उत्पादकांना उत्पादित करण्याच्या मुख्य हेतूंपैकी एक नसण्याची शक्यता असते ग्राहकांना विक्री करणे
#   [marathi] #manifest:844424933373429-962-m PRED: ग्राहकांच्या मागणीशिवाय उत्पादकांना उत्पादित करण्याच्या मुख्य हेतूपैकी एक नसण्याची शक्यता असणे ग्राहकांना विक्री करणे
#   [marathi] running avg -> WER 0.1695 | CER 0.0611  (1600/1631)
#   [marathi] #manifest:844424933379924-487-m REF : पुणे जिल्हातील शिवगंगागुंजवणी खोऱ्यात दारूबंदी आंदोलनाद्वारे ग्रामीण शक्तीचे संघटन सुरू झाले
#   [marathi] #manifest:844424933379924-487-m PRED: पुणे जिल्ह्यातील शिवगंगागुंजवणी खोऱ्यात दारूबंदी आंदोलनाद्वारे ग्रामीण शक्तीचे संघटन सुरू झाले
#   [marathi] running avg -> WER 0.1699 | CER 0.0618  (1620/1631)
#   DONE marathi: n=1631  WER=0.1702  CER=0.0620
#   -> /kaggle/working/sravaani_kathbath_eval/sravaani_kathbath_marathi_results.csv
#
# ======================================================================
# ALL LANGUAGES DONE in 2.1 min
# ======================================================================
# language  n_utterances      wer      cer
#  marathi          1631 0.170212 0.061994
#
# Per-language CSVs + summary written to: /kaggle/working/sravaani_kathbath_eval
#   language  n_utterances       wer       cer
# 0  marathi          1631  0.170212  0.061994

# %% [markdown]
# ## 13. Inspect a results CSV

# %%
# e.g. inspect Marathi results
pd.read_csv(OUT_DIR / "sravaani_kathbath_marathi_results.csv").head(20)
# Out:
#                                 id language  \
# 0   manifest:844424932828564-933-f  marathi
# 1   manifest:844424932266749-980-f  marathi
# 2   manifest:844424932372222-132-f  marathi
# 3   manifest:844424932262362-809-f  marathi
# 4   manifest:844424932330066-980-f  marathi
# 5   manifest:844424932372246-132-f  marathi
# 6   manifest:844424931570565-236-f  marathi
# 7   manifest:844424930875888-954-f  marathi
# 8   manifest:844424931130704-933-f  marathi
# 9   manifest:844424930906986-972-f  marathi
# 10  manifest:844424930875832-954-f  marathi
# 11  manifest:844424932311883-980-f  marathi
# 12  manifest:844424932311872-980-f  marathi
# 13  manifest:844424931130726-933-f  marathi
# 14  manifest:844424932337151-809-f  marathi
# 15  manifest:844424932311898-980-f  marathi
# 16  manifest:844424930557238-737-f  marathi
# 17  manifest:844424932266694-980-f  marathi
# 18  manifest:844424932311908-980-f  marathi
# 19  manifest:844424931570515-236-f  marathi
#
#                                             reference  \
# 0   १३ वर्षाची असताना तिला मिनी राष्ट्रीय बॅडमिंटन...
# 1   त्यामुळे रिक्षा चालकाने थेट नवी मुंबई पोलीस आय...
# 2   हा चित्रपट वास्तववादी आणि त्याचबरोबर व्यावसायि...
# 3   राने तयार असल्याने आता केवळ टोकण करण्याचे काम ...
# 4   दीर्घ पल्ल्याचे आलाप घेण्याची क्षमता यामुळे त्...
# 5   वेलिंग्टन कसोटीत भारताच्या खेळाडूंना वाऱ्यामु...
# 6   दर अर्ध्या तासाने मुलांना डोळ्याचे व्यायाम करा...
# 7   अशा सर्व परिस्थितीत केंद्राने आता महानगरपालिके...
# 8   पण लथीशाला शिक्षणाची खूप आवड होती आणि तिच्यात ...
# 9   भालचंद्र कानगो त्याचे उद्घाटन करणार असून अध्यक...
# 10  एखाद्या कलेचं परीक्षण करण्यासाठी त्या कलेची जा...
# 11  गर्भारपणात यकृताचे आजार का व कसे होऊ शकतात ते ...
# 12  जेणेकरून एक आशादायक सुरुवात होऊन लोकांचे तसेच ...
# 13  भाजपचे नेते आणि खासदार गोपीनाथ मुंडे यांना निव...
# 14  गुढीच्या माध्यमातून स्वाती जोशी यांना सोलार एन...
# 15  या वर्षी जानेवरी महिन्यात ताजिमा यांना हॉस्पिट...
# 16  त्यामुळे अशा प्रकारच्या तुलनेमुळे शिवरायांवर प...
# 17  या स्पर्धेत पृथ्वी साव हा सातत्याने दमदार फलंद...
# 18  मुंबईतील सर्वाधिक गजबजलेल्या स्थानकात छत्रपती ...
# 19  अमेरिकेचे परराष्ट्र मंत्री माईक पॉम्पिओ यांनी ...
#
#                                            prediction     wer     cer
# 0   तेरा वर्षाची असताना तिला मिनी राष्ट्रीय बॅडमिं...  0.1000  0.0656
# 1   त्यामुळे रिक्षाचालकाने थेट नवी मुंबई पोलीस आयु...  0.1818  0.0000
# 2   हा चित्रपट वास्तववादी आणि त्याचबरोबर व्यावसायि...  0.0000  0.0000
# 3   राणे तयार असल्याने आता केवळ टोकन करण्याचे काम ...  0.2727  0.0755
# 4   दीर्घपल्ल्यांची आलाप घेण्याची क्षमता यामुळे त्...  0.1818  0.0282
# 5   वेलिंग्टन कचोटीत भारतातच्या खेळाडूंना वाऱ्यामु...  0.1538  0.0235
# 6   दर अर्ध्या तासाने मुलांना डोळ्याचे व्यायाम करा...  0.0000  0.0000
# 7   अशा सर्व परिस्थितीत केंद्राने आता महानगरपालिके...  0.0000  0.0000
# 8   पण लथीशाला शिक्षणाची खूप आवड होती आणि तिच्या श...  0.0909  0.0179
# 9   भालचंद्र कानगो त्यांचे उद्घाटन करणार असून अध्य...  0.3846  0.0588
# 10  एखाद्या कलेचं परीक्षण करण्यासाठी त्या कलेचं जा...  0.0769  0.0122
# 11  गर्भारपणात यकृताचे आजार का व कसे होऊ शकतात ते ...  0.0000  0.0000
# 12  जेणेकरून एक आशादायक सुरुवात होऊन लोकांचे तसेच ...  0.0000  0.0000
# 13  भाजपचे नेते आणि खासदार गोपीनाथ मुंडे यांना निव...  0.0000  0.0000
# 14  गुढीच्या माध्यमातून स्वाती जोशी यांना सोलर एनर...  0.1667  0.0405
# 15  यावर्षी जानेवारी महिन्यात ताझिमा यांना हॉस्पिट...  0.3636  0.0312
# 16  त्यामुळे अशा प्रकारच्या तुलनेमुळे शिवरायांवर प...  0.0000  0.0000
# 17  या स्पर्धेत पृथ्वी साव हा सातत्याने दमदार फलंद...  0.0000  0.0000
# 18  मुंबईतील सर्वाधिक गजबजलेल्या स्थानकात छत्रपती ...  0.0000  0.0000
# 19  अमेरिकेचे परराष्ट्रमंत्री माईक पॉम्पियो यांनी ...  0.2308  0.0270
