# %% [markdown]
# # IndicWhisper Evaluation on Kathbath-Marathi
# ### Accelerator = GPU T4

# %% [markdown]
# # Cell 1: Install dependencies

# %%
# !pip install editdistance -q
# !pip install joblib tqdm librosa soundfile indicnlp indic-nlp-library -q
# !pip install git+https://github.com/anoopkunchukuttan/indic_nlp_library.git -q
# !pip install git+https://github.com/huggingface/transformers -q
# !pip install git+https://github.com/huggingface/datasets -q
# !pip install evaluate accelerate -q
# !sudo apt install ffmpeg -y -q
print("All dependencies installed!")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 102.9 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 8.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 516.0/516.0 kB 23.6 MB/s eta 0:00:00
#   Building wheel for transformers (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for datasets (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 107.9 MB/s eta 0:00:0000:010:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cudf-cu12 26.2.1 requires numba-cuda[cu12]<0.23.0,>=0.22.2, but you have numba-cuda 0.30.2 which is incompatible.
# Reading package lists...
# Building dependency tree...
# Reading state information...
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 141 not upgraded.
# All dependencies installed!

# %% [markdown]
# # Cell 2: Clone vistaar repo

# %%
import os

if not os.path.exists('/kaggle/working/vistaar'):
    # !git clone https://github.com/AI4Bharat/vistaar.git /kaggle/working/vistaar
    print("Cloned!")
else:
    print("Already cloned, skipping.")

# %cd /kaggle/working/vistaar
# Out:
# Cloning into '/kaggle/working/vistaar'...
# remote: Enumerating objects: 166, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 166 (delta 10), reused 0 (delta 0), pack-reused 145 (from 1)
# Receiving objects: 100% (166/166), 61.78 KiB | 10.30 MiB/s, done.
# Resolving deltas: 100% (95/95), done.
# Cloned!
# /kaggle/working/vistaar

# %% [markdown]
# # Cell 3: Write fixed evaluation.py

# %%
fixed_eval = '''
import argparse
from transformers import pipeline
import editdistance
from joblib import Parallel, delayed
from tqdm import tqdm
import json
import soundfile as sf
from torch.utils.data import Dataset
from indicnlp.normalize.indic_normalize import IndicNormalizerFactory
import os
import string
import re
import time
import torch

from transformers import (
    AutoConfig,
    AutoFeatureExtractor,
    AutoModelForSpeechSeq2Seq,
    AutoProcessor,
    AutoTokenizer,
)

lang_to_code = {
    "hindi": "hi",
    "sanskrit": "sa",
    "bengali": "bn",
    "tamil": "ta",
    "telugu": "te",
    "gujarati": "gu",
    "kannada": "kn",
    "malayalam": "ml",
    "marathi": "mr",
    "odia": "or",
    "punjabi": "pa",
    "urdu": "ur",
}


def normalize_sentence(sentence, lang_code):
    factory = IndicNormalizerFactory()
    normalizer = factory.get_normalizer(lang_code)
    return normalizer.normalize(sentence)


def compute_cer(refs, hyps):
    """Character Error Rate using editdistance (no rapidfuzz dependency)"""
    total_chars = 0
    total_edits = 0
    for r, h in zip(refs, hyps):
        total_edits += editdistance.eval(r, h)
        total_chars += len(r)
    return total_edits / total_chars if total_chars > 0 else 0.0


def compute_wer(refs, hyps):
    """Word Error Rate using editdistance (no rapidfuzz dependency)"""
    total_words = 0
    total_edits = 0
    for r, h in zip(refs, hyps):
        r_words = r.split()
        h_words = h.split()
        total_edits += editdistance.eval(r_words, h_words)
        total_words += len(r_words)
    return total_edits / total_words if total_words > 0 else 0.0


class eval_dataset(Dataset):
    def __init__(self):
        self.audios = []
        self.sents = []

    def __len__(self):
        return len(self.audios)

    def __getitem__(self, i):
        return {
            "raw": self.audios[i]["array"],
            "sampling_rate": self.audios[i]["sampling_rate"],
            "reference": self.sents[i],
            "path": self.audios[i]["path"],
            "duration": self.audios[i]["duration"],
        }

    def fill_data(self, aud, sent):
        self.audios.append(aud)
        self.sents.append(sent)


def get_data(split):
    js_data = json.loads(split)
    aud = {}
    # Use audio_filepath directly from manifest (no hardcoded path replacement)
    aud["path"] = js_data["audio_filepath"]
    y, sr = sf.read(aud["path"])
    aud["duration"] = js_data["duration"]
    aud["array"] = y
    aud["sampling_rate"] = sr
    return (aud, js_data["text"])


def main(args):
    with open(args.manifest_path, "r") as f:
        data = f.read()
        splits = data.split("\\n")
        if splits[-1] == "":
            splits = splits[:-1]

    da = Parallel(n_jobs=4)(delayed(get_data)(split) for split in tqdm(splits))

    dataset = eval_dataset()
    for d in da:
        dataset.fill_data(d[0], d[1])

    whisper_asr = pipeline(
        "automatic-speech-recognition",
        model=args.model_path,
        device=args.device,
    )

    if args.lang_code == "or":
        whisper_asr.model.config.forced_decoder_ids = (
            whisper_asr.tokenizer.get_decoder_prompt_ids(
                language=None, task="transcribe"
            )
        )
    else:
        whisper_asr.model.config.forced_decoder_ids = (
            whisper_asr.tokenizer.get_decoder_prompt_ids(
                language=args.lang_code, task="transcribe"
            )
        )

    hypothesis = []
    ground_truth = []

    os.makedirs(dir_path + "/predictions", exist_ok=True)
    out_name = (
        args.model_path.rsplit("/", 1)[-1]
        + "_"
        + args.manifest_name
        + "_predictions.json"
    )
    open(dir_path + "/predictions/" + out_name, "w").close()

    st = time.time()

    for out in tqdm(whisper_asr(dataset, batch_size=args.batch_size), total=len(dataset)):
        hyp = out["text"]
        ref = out["reference"][0]
        hyp = hyp.translate(str.maketrans("", "", string.punctuation + "\u0964\u06d4\u2019-\u0965"))
        ref = ref.translate(str.maketrans("", "", string.punctuation + "\u0964\u06d4\u2019-\u0965"))
        if args.lang_code[:2] != "ur":
            hyp = normalize_sentence(hyp, args.lang_code[:2])
            ref = normalize_sentence(ref, args.lang_code[:2])
        hyp = re.sub(" +", " ", hyp).strip()
        ref = re.sub(" +", " ", ref).strip()
        if ref == "":
            ref = "<empty>"
        hypothesis.append(hyp)
        ground_truth.append(ref)
        res = {
            "audio_filepath": out["path"][0],
            "duration": out["duration"][0],
            "text": ref,
            "pred_text": hyp,
        }
        with open(dir_path + "/predictions/" + out_name, "a") as f:
            json.dump(res, f, ensure_ascii=False)
            f.write("\\n")

    et = time.time()

    result = {}
    result["model"] = args.model_path
    result["dataset"] = args.manifest_name
    result["language"] = args.lang_code
    result["cer"] = compute_cer(ground_truth, hypothesis)
    result["wer"] = compute_wer(ground_truth, hypothesis)
    result["time_minutes"] = round((et - st) / 60, 2)
    result["batch_size"] = args.batch_size

    print("\\n===== RESULTS =====")
    for k, v in result.items():
        print(f"  {k}: {v}")

    with open(dir_path + "/results.csv", "a") as results_fp:
        print(",".join([str(v) for v in result.values()]), file=results_fp)


if __name__ == "__main__":
    dir_path = os.path.dirname(os.path.realpath(__file__))
    parser = argparse.ArgumentParser()
    parser.add_argument("--model_path", type=str, required=True)
    parser.add_argument("--manifest_path", type=str, required=True)
    parser.add_argument("--manifest_name", type=str, required=True)
    parser.add_argument("--device", type=int, default=-1)
    parser.add_argument("--batch_size", type=int, default=32)
    parser.add_argument("--language", type=str, required=True)
    args = parser.parse_args()

    if len(args.language) == 2:
        args.lang_code = args.language.lower()
    else:
        args.lang_code = lang_to_code[args.language.lower()]

    main(args)
'''

with open('/kaggle/working/vistaar/evaluation.py', 'w') as f:
    f.write(fixed_eval)

print("evaluation.py written successfully!")
# !grep -n 'compute_cer\|compute_wer\|audio_filepath\|editdistance' /kaggle/working/vistaar/evaluation.py
# Out:
# evaluation.py written successfully!
# 4:import editdistance
# 47:def compute_cer(refs, hyps):
# 48:    """Character Error Rate using editdistance (no rapidfuzz dependency)"""
# 52:        total_edits += editdistance.eval(r, h)
# 57:def compute_wer(refs, hyps):
# 58:    """Word Error Rate using editdistance (no rapidfuzz dependency)"""
# 64:        total_edits += editdistance.eval(r_words, h_words)
# 94:    # Use audio_filepath directly from manifest (no hardcoded path replacement)
# 95:    aud["path"] = js_data["audio_filepath"]
# 164:            "audio_filepath": out["path"][0],
# 179:    result["cer"] = compute_cer(ground_truth, hypothesis)
# 180:    result["wer"] = compute_wer(ground_truth, hypothesis)

# %% [markdown]
# # Cell 4: Create FULL manifest

# %%
import json, os

BASE = "/kaggle/input/datasets/monuj007/kathbath-benchmarks-marathi"
IN_MANIFEST = f"{BASE}/kathbath/marathi/manifest.json"
OUT_MANIFEST = "/kaggle/working/manifest_marathi_full.json"

count = 0
with open(IN_MANIFEST) as f, open(OUT_MANIFEST, "w") as out:
    for line in f:
        line = line.strip()
        if not line:
            continue
        entry = json.loads(line)
        filename = os.path.basename(entry["audio_filepath"])
        entry["audio_filepath"] = f"{BASE}/kathbath/marathi/wavs/wavs/{filename}"
        out.write(json.dumps(entry, ensure_ascii=False) + "\n")
        count += 1

print(f"Created full manifest with {count} samples: {OUT_MANIFEST}")
# Out:
# Created full manifest with 1631 samples: /kaggle/working/manifest_marathi_full.json

# %% [markdown]
# # Cell 5: Download Marathi Model

# %%
# !wget -q https://indicwhisper.objectstore.e2enetworks.net/marathi_models.zip -O /kaggle/working/vistaar/marathi_models.zip
# !unzip -q /kaggle/working/vistaar/marathi_models.zip -d /kaggle/working/vistaar/
# !ls /kaggle/working/vistaar/marathi_models/
# Out:
# whisper-medium-mr_alldata_multigpu

# %% [markdown]
# # Cell 6: Run evaluation (OOM-safe)

# %%
import os, torch

# Free GPU memory before starting
torch.cuda.empty_cache()
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"Free memory: {torch.cuda.mem_get_info()[0]/1024**3:.2f} GB")

# %cd /kaggle/working/vistaar

# Set env var to reduce memory fragmentation
import os
os.environ["PYTORCH_ALLOC_CONF"] = "expandable_segments:True"

# !PYTORCH_ALLOC_CONF=expandable_segments:True python evaluation.py \
    --model_path="marathi_models/whisper-medium-mr_alldata_multigpu" \
    --manifest_path="/kaggle/working/manifest_marathi_full.json" \
    --manifest_name="kathbath" \
    --device=0 \
    --batch_size=4 \
    --language="mr"
# Out:
# GPU: Tesla T4
# Free memory: 14.46 GB
# /kaggle/working/vistaar
# 100%|██████████████████████████████████████| 1631/1631 [00:04<00:00, 364.68it/s]
# Loading weights: 100%|█████████████████████| 947/947 [00:00<00:00, 18386.36it/s]
#   0%|                                                  | 0/1631 [00:00<?, ?it/s][transformers] Using custom `forced_decoder_ids` from the (generation) config. This is deprecated in favor of the `task` and `language` flags/config options.
# [transformers] Transcription using a multilingual Whisper will default to language detection followed by transcription instead of translation to English. This might be a breaking change for your use case. If you want to instead always translate your audio to English, make sure to pass `language='en'`. See https://github.com/huggingface/transformers/pull/28687 for more details.
# [transformers] A custom logits processor of type <class 'transformers.generation.logits_process.SuppressTokensLogitsProcessor'> has been passed to `.generate()`, but it was also created in `.generate()`, given its parameterization. The custom <class 'transformers.generation.logits_process.SuppressTokensLogitsProcessor'> will take precedence. Please check the docstring of <class 'transformers.generation.logits_process.SuppressTokensLogitsProcessor'> to see related `.generate()` flags.
# [transformers] A custom logits processor of type <class 'transformers.generation.logits_process.SuppressTokensAtBeginLogitsProcessor'> has been passed to `.generate()`, but it was also created in `.generate()`, given its parameterization. The custom <class 'transformers.generation.logits_process.SuppressTokensAtBeginLogitsProcessor'> will take precedence. Please check the docstring of <class 'transformers.generation.logits_process.SuppressTokensAtBeginLogitsProcessor'> to see related `.generate()` flags.
# 100%|█████████████████████████████████████| 1631/1631 [1:04:16<00:00,  2.36s/it]
#
# ===== RESULTS =====
#   model: marathi_models/whisper-medium-mr_alldata_multigpu
#   dataset: kathbath
#   language: mr
#   cer: 0.06529411764705882
#   wer: 0.20251366120218578
#   time_minutes: 64.27
#   batch_size: 4

# %% [markdown]
# # Cell 7: View results

# %%
# ── ──────────────────────────────────────────────────────
print("=== Results CSV ===")
# !cat /kaggle/working/vistaar/results.csv

print("\n=== Predictions ===")
# !cat /kaggle/working/vistaar/predictions/whisper-medium-mr_alldata_multigpu_kathbath_predictions.json
# Out:
# === Results CSV ===
# marathi_models/whisper-medium-mr_alldata_multigpu,kathbath,mr,0.06529411764705882,0.20251366120218578,64.27,4
#
# === Predictions ===
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-marathi/kathbath/marathi/wavs/wavs/844424
"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-marathi/kathbath/marathi/wavs/wavs/844424932372181-132-f.wav", "duration": 7.082125, "text": "कधी कोणत्या ना कोणत्या कारणावरून तिला खावा लागणारा ओरडाही तिचं मन दुखावणाराच असू शकतो", "pred_text": "कधी कोणत्या ना कोणत्या कारणावरून तिला खावा लागणारा ओरडाही तिचं मन दुखवणाराच असू शकतो"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-marathi/kathbath/marathi/wavs/wavs/844424932330020-980-f.wav", "duration": 5.108375, "text": "पुणे जिल्हय़ातील दौंड व इंदापूरमध्ये अवकाळी पावसामुळे पिकांचे नुकसान झाले आहे", "pred_text": "पुणे जिल्ह्यातील दौंड व इंदापूरमध्ये अवकाळी पावसामुळे पिकांचे नुकसान झाले आहे"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-marathi/kathbath/marathi/wavs/wavs/844424931130682-933-f.wav", "duration": 4.945875, "text": "पोलीस कडे तोडून ते एकमेकांच्या अंगावर धावून जाण्याचे प्रयत्न सुरू होते", "pred_text": "पोलिसकडे तोडून ते एकमेकांच्या अंगावर धावून जाण्याचे प्रयत्न सुरू होते"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-marathi/kathbath/marathi/wavs/wavs/844424932372163-132-f.wav", "duration": 5.78175, "text": "या व्यतिरिक्त पवारांनी मराठा आरक्षणावर काहीच भाष्य केलं नाही", "pred_text": "या व्यतिरिक्त पवारांनी मराठा आरक्षणावर काहीच भाष्य केले नाही"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-marathi/kathbath/marathi/wavs/wavs/844424930557199-737-f.wav", "duration": 5.8746875, "text": "रणबीर या शोमध्ये आला तर त्याची ही छोट्या पडद्यावरील पहिलीच एंट्री असेल", "pred_text": "रणबीर या शोमध्ये आला तर त्याची ही छोटा पडद्यावरील पहिली सेंट्री असेल"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-marathi/kathbath/marathi/wavs/wavs/844424932484370-573-f.wav", "duration": 7.244625, "text": "मिळणाऱ्या संधी उपलब्ध करणे आणि त्यात सुधार आणण्याची प्रत्यक्षात गरज असल्याचेही त्यांनी स्पष्ट केले", "pred_text": "मिळण्याच्या संधी उपलब्ध करणे आणि त्यात सुधार आणण्याची प्रत्यक्षता गरज असल्याचेही त्यांनी स्पष्ट केले"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-marathi/kathbath/marathi/wavs/wavs/844424931218208-933-f.wav", "duration": 6.014, "text": "राजनीतीच्या सशक्त कथेमुळेच हा चित्रपट स्वीकारल्याचे कतरीनाचे म्हणणे आहे", "pred_text": "राजनीतीच्या सशक्त कथेमुळेच हा चित्रपट स्वीकारल्याचे कतरिनाचे म्हणणे आहे"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-marathi/kathbath/marathi/wavs/wavs/844424931570556-236-f.wav", "duration": 6.501625, "text": "याने त्रस्त होऊन हे शेतकरी आता कंपनीच्या दारातच आंदोलनाला बसले आहेत", "pred_text": "याने त्रस्त होऊन हे शेतकरी आता कंपनीच्या दारातच आंदोलनाला बसले आहेत"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-marathi/kathbath/marathi/wavs/wavs/844424932828578-933-f.wav", "duration": 6.1765, "text": "या हेअर पॅकचा नियमित योग्य वापर केल्यास टाळूला येणारी खाज आणि अन्य समस्या दूर होतील", "pred_text": "या हेअरपॅकचा नियमित योग्य वापर केल्यास टाळूला येणारी खाज आणि अन्य समस्या दूर होतील"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-marathi/kathbath/marathi/wavs/wavs/844424930557228-737-f.wav", "duration": 6.1300625, "text": "बुवाचे वाठार येथील महादेव सखाराम चौगुले यांना दीड एकर शेतजमीन आहे", "pred_text": "बुवाचे वाठार येथील महादेव सखलम चौगुले यांना दीड एक शेतजमीन आहे"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-marathi/kathbath/marathi/wavs/wavs/844424932
ते"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-marathi/kathbath/marathi/wavs/wavs/844424932311847-980-f.wav", "duration": 8.7075, "text": "इटलीतील तोरिनो प्रांतातील उसास्को कम्यूनमधून आलेल्या आंतोनिओ आगू या इटालियनाने उसास्को शहराची स्थापना केली", "pred_text": "इटलीतील तोरिनो प्रांतातील उसास्को कम्यूनमधून आलेल्या आंतोनिओ आगो या इटालियनाने उसास्को शहराची स्थापना केली"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-marathi/kathbath/marathi/wavs/wavs/844424932484374-573-f.wav", "duration": 9.5201875, "text": "त्यांची स्थिती काय आहे यावर लक्ष ठेवण्यासाठी उच्च न्यायालयाने पर्यावरणप्रेमींच्या मागणीवरून एक वृक्ष समिती नेमली", "pred_text": "त्याची स्थिती काय आहे यावर लक्ष ठेवण्यासाठी उच्च न्यायालयाने पर्यावरण प्रेमीच्या मागणीवरून एक वृक्ष समिती नेमली"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-marathi/kathbath/marathi/wavs/wavs/844424931570594-236-f.wav", "duration": 6.1533125, "text": "काही आठवड्यांपर्यंत हे जाग येणे चालू राहिले आणि मी काही कारणास्तव उदास होऊ लागलो", "pred_text": "काही आठवड्यापर्यंत हे जाग येणे चालू राहिले आणि मी काही कारणास्तव उदास होऊ लागलो"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-marathi/kathbath/marathi/wavs/wavs/844424930875869-954-f.wav", "duration": 6.757, "text": "याआधी रघुराम राजन यांनीही आंतरराष्ट्रीय नाणेनिधीचे प्रमुखपद भूषवले आहे", "pred_text": "याआधी रघुराम राजन यांनीही आंतरराष्ट्रीय नानेनिधीचे प्रमुख पद भूषवले आहे"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-marathi/kathbath/marathi/wavs/wavs/844424931218201-933-f.wav", "duration": 7.15175, "text": "जर बोर्डवर अगदी थोडा फोड दिसला तर ते नवीनमध्ये बदलले पाहिजेत", "pred_text": "जर बोर्डावर अगदी थोडा फोड दिसला तर ते नवीनमध्ये बदलले पाहिजेत"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-marathi/kathbath/marathi/wavs/wavs/844424930902745-715-f.wav", "duration": 5.7353125, "text": "तसेच दोघंही आपल्या कामामधून वेळात वेळ काढून मुलांना देखील पुरेसा वेळ देतात", "pred_text": "तसेच दोघंही आपल्या कामामधून वेळात वेळ काढून मुलांना देखील पुरेसा वेळ देतात"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-marathi/kathbath/marathi/wavs/wavs/844424932266741-980-f.wav", "duration": 6.292625, "text": "मात्र आता विधेयक आजच सभागृहात मांडलं जाणार असल्याचं विनोद तावडे यांनी स्पष्ट केलंय", "pred_text": "मात्र आता विधेयक आजच सभागृहात मांडलं जाणार असल्याचं विनोद तावडे यांनी स्पष्ट केलंय"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-marathi/kathbath/marathi/wavs/wavs/844424932330028-980-f.wav", "duration": 4.156375, "text": "शाळा आपल्याला भेटायला आणि आपल्या मुलाची मुलाखत हवी आहे", "pred_text": "शाळा आपल्याला भेटायला आणि आपल्या मुलाची मुलाखत हवी आहे"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-marathi/kathbath/marathi/wavs/wavs/844424931570577-236-f.wav", "duration": 7.1285625, "text": "सहकार क्षेत्राकडे ग्रामीण तसेच कष्टकरी शेतकरी व व्यावसायिक आणि उद्योजक जोडले जातात", "pred_text": "सहकार क्षेत्राकडे ग्रामी तसेच कष्टकरी शेतकरी व व्यावसायिक आणि उद्योजक जोडले जातात"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-marathi/kathbath/marathi/wavs/wavs/844424932266698-980-f.wav", "duration": 8.196625, "text": "चलनी नोटांप्रमाणे दिसणार्या त्या नोटा बनावट असल्याचे समोर आल्यानंतर सांगली पोलिसांनी कारवाईचा फास आवळला", "pred_text": "चलनी नोटांप्रमाणे दिसणाऱ्या त्या नोटा बनावट असल्याचे समोर आल्यानंतर सांगली पोलिसांनी कारवाईचा फास आवडला"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-marathi/kathbath/marathi/wavs/wavs/844424932
हे"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-marathi/kathbath/marathi/wavs/wavs/844424933379972-487-m.wav", "duration": 7.73225, "text": "प्रत्येक हिंदूची रामचरितमानसवर अनन्य श्रद्धा आहे आणि तो हिंदूंचा पवित्र ग्रंथ आहे", "pred_text": "प्रत्येक हिंदूची रामचरित मानसवर अनन्य श्रद्धा आहे आणि तो हिंदूचा पवित्र ग्रंथ आहे"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-marathi/kathbath/marathi/wavs/wavs/844424933379961-487-m.wav", "duration": 5.4566875, "text": "शिवांगी पद्मिनी आणि तेजस्विनी या पंढरीनाथ कोल्हापुरे यांच्या तीन मुली आहेत", "pred_text": "शिवांगी पद्दिनी आणि तेजस्विनी या पंढरीनाथ कोल्हापुरे यांच्या तीन मुली आहेत"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-marathi/kathbath/marathi/wavs/wavs/844424933379902-487-m.wav", "duration": 9.009375, "text": "त्यानंतर अमेरिकन पत्रकार स्टॅन्लेने लिहिलेल्या प्रवासवर्णनाने युरोपियन लोकांच्या मनात आफ्रिकेविषयी आकर्षण निर्माण झाले", "pred_text": "त्यानंतर अमेरिकन पत्रकार स्टॅलेंडने लिहिलेल्या प्रवास वर्णनाने युरोपियन लोकांच्या मनात आफ्रिकेविषयी आकर्षण निर्माण झाले"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-marathi/kathbath/marathi/wavs/wavs/844424933393999-426-m.wav", "duration": 6.873125, "text": "मात्र चैत्र महिना हा अधिक मास असण्याचे प्रसंग फार थोडे आहेत", "pred_text": "मात्र चेत्र महिना हा अधिक मास असण्याचे प्रसंग फार थोडे आहेत"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-marathi/kathbath/marathi/wavs/wavs/844424933393992-426-m.wav", "duration": 8.010875, "text": "मुख्य कर्णधार कार्लोस ब्रेथवेटने दौऱ्यास सुरक्षेचे कारण सांगून जाण्याच नकार दिला", "pred_text": "मुख्य कर्णधार कॉर्लस ब्रेथवेटने दौऱ्या सुरक्षेचे कारण सांगून जाण्यास नकार दिला"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-marathi/kathbath/marathi/wavs/wavs/844424933355966-1120-m.wav", "duration": 5.4799375, "text": "महादेवनगर हे भारताच्या महाराष्ट्र राज्यातील नाशिक जिल्ह्यातील निफाड तालुक्यातील एक गाव आहे", "pred_text": "महादेवनगर हे भारताच्या महाराष्ट्र राज्यातील नाशिक जिल्ह्यातील नेपाड तालुक्यातील एक गाव आहे"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-marathi/kathbath/marathi/wavs/wavs/844424933379900-487-m.wav", "duration": 5.317375, "text": "लेखक शास्त्रज्ञ शिक्षण म्हणुन सकनी मोहन कारुपाईल प्रसिद्ध आहेत", "pred_text": "लेखकशास्त्रज्ञ शिक्षण म्हणून सखनी मोहन कारू पाईल प्रसिद्ध आहे"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-marathi/kathbath/marathi/wavs/wavs/844424933356036-1120-m.wav", "duration": 6.478375, "text": "इ स १९४८ मध्ये संघावर गांधीहत्या प्रकरणामुळे बंदी घालण्यात आली होती", "pred_text": "इ स एक हजार नऊ शे अठ्ठेचाळीस मध्ये संघावर गांधी हत्या प्रकरणामुळे बंदी घालवण्यात आली होती"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-marathi/kathbath/marathi/wavs/wavs/844424933379979-487-m.wav", "duration": 5.8746875, "text": "या कामासाठी रॉयल जिओग्राफीकल सोसायटीने सुवर्णपदक देऊन त्याचा सन्मान केला", "pred_text": "या कामासाठी रॉयल जिओग्राफिकल सोसायटीने सुवर्णपदक देऊन त्याचा सन्मान केला"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-marathi/kathbath/marathi/wavs/wavs/844424933393994-426-m.wav", "duration": 11.61, "text": "बाबासाहेब आंबेडकरांनी इ स १९३५३६ या कालावधी दरम्यान लिहिलेले २० पानी आत्मचरित्र आहे", "pred_text": "बाबासाहेब आंबेडकरांनी इ स एक हजार नऊ शे पस्तीस शून्य या कालावधी दरम्यान लिहिलेले वीसवानी आत्मचारित्रिय आहे"}
