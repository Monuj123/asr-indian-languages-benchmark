# %% [markdown]
# # IndicWhisper Evaluation on Kathbath-Hindi
# ### Accelerator = GPU T4

# %% [markdown]
# # Cell 1: Install dependencies

# %%
# !pip install editdistance -q
# !pip install joblib tqdm librosa soundfile indicnlp indic-nlp-library -q
# !pip install git+https://github.com/anoopkunchukuttan/indic_nlp_library.git -q
# !pip install git+https://github.com/huggingface/transformers -q
# !pip install git+https://github.com/huggingface/datasets -q
# !pip install evaluate accelerate -q
# !sudo apt install ffmpeg -y -q
print("All dependencies installed!")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 61.9 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 8.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 516.0/516.0 kB 10.1 MB/s eta 0:00:00a 0:00:01
#   Building wheel for transformers (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for datasets (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 106.6 MB/s eta 0:00:0000:010:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cudf-cu12 26.2.1 requires numba-cuda[cu12]<0.23.0,>=0.22.2, but you have numba-cuda 0.30.2 which is incompatible.
# Reading package lists...
# Building dependency tree...
# Reading state information...
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 141 not upgraded.
# All dependencies installed!

# %%
from huggingface_hub import login

hf_token = "your_token_here"

login(token=hf_token)
print("Successfully logged into Hugging Face Hub!")
# Out:
# Successfully logged into Hugging Face Hub!

# %% [markdown]
# # Cell 2: Clone vistaar repo

# %%
import os

if not os.path.exists('/kaggle/working/vistaar'):
    # !git clone https://github.com/AI4Bharat/vistaar.git /kaggle/working/vistaar
    print("Cloned!")
else:
    print("Already cloned, skipping.")

# %cd /kaggle/working/vistaar
# Out:
# Cloning into '/kaggle/working/vistaar'...
# remote: Enumerating objects: 166, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 166 (delta 10), reused 0 (delta 0), pack-reused 145 (from 1)
# Receiving objects: 100% (166/166), 61.78 KiB | 1.54 MiB/s, done.
# Resolving deltas: 100% (95/95), done.
# Cloned!
# /kaggle/working/vistaar

# %% [markdown]
# # Cell 3: Write fixed evaluation.py

# %%
fixed_eval = '''
import argparse
from transformers import pipeline
import editdistance
from joblib import Parallel, delayed
from tqdm import tqdm
import json
import soundfile as sf
from torch.utils.data import Dataset
from indicnlp.normalize.indic_normalize import IndicNormalizerFactory
import os
import string
import re
import time
import torch

from transformers import (
    AutoConfig,
    AutoFeatureExtractor,
    AutoModelForSpeechSeq2Seq,
    AutoProcessor,
    AutoTokenizer,
)

lang_to_code = {
    "hindi": "hi",
    "sanskrit": "sa",
    "bengali": "bn",
    "tamil": "ta",
    "telugu": "te",
    "gujarati": "gu",
    "kannada": "kn",
    "malayalam": "ml",
    "marathi": "mr",
    "odia": "or",
    "punjabi": "pa",
    "urdu": "ur",
}


def normalize_sentence(sentence, lang_code):
    factory = IndicNormalizerFactory()
    normalizer = factory.get_normalizer(lang_code)
    return normalizer.normalize(sentence)


def compute_cer(refs, hyps):
    """Character Error Rate using editdistance (no rapidfuzz dependency)"""
    total_chars = 0
    total_edits = 0
    for r, h in zip(refs, hyps):
        total_edits += editdistance.eval(r, h)
        total_chars += len(r)
    return total_edits / total_chars if total_chars > 0 else 0.0


def compute_wer(refs, hyps):
    """Word Error Rate using editdistance (no rapidfuzz dependency)"""
    total_words = 0
    total_edits = 0
    for r, h in zip(refs, hyps):
        r_words = r.split()
        h_words = h.split()
        total_edits += editdistance.eval(r_words, h_words)
        total_words += len(r_words)
    return total_edits / total_words if total_words > 0 else 0.0


class eval_dataset(Dataset):
    def __init__(self):
        self.audios = []
        self.sents = []

    def __len__(self):
        return len(self.audios)

    def __getitem__(self, i):
        return {
            "raw": self.audios[i]["array"],
            "sampling_rate": self.audios[i]["sampling_rate"],
            "reference": self.sents[i],
            "path": self.audios[i]["path"],
            "duration": self.audios[i]["duration"],
        }

    def fill_data(self, aud, sent):
        self.audios.append(aud)
        self.sents.append(sent)


def get_data(split):
    js_data = json.loads(split)
    aud = {}
    # Use audio_filepath directly from manifest (no hardcoded path replacement)
    aud["path"] = js_data["audio_filepath"]
    y, sr = sf.read(aud["path"])
    aud["duration"] = js_data["duration"]
    aud["array"] = y
    aud["sampling_rate"] = sr
    return (aud, js_data["text"])


def main(args):
    with open(args.manifest_path, "r") as f:
        data = f.read()
        splits = data.split("\\n")
        if splits[-1] == "":
            splits = splits[:-1]

    da = Parallel(n_jobs=4)(delayed(get_data)(split) for split in tqdm(splits))

    dataset = eval_dataset()
    for d in da:
        dataset.fill_data(d[0], d[1])

    whisper_asr = pipeline(
        "automatic-speech-recognition",
        model=args.model_path,
        device=args.device,
    )

    if args.lang_code == "or":
        whisper_asr.model.config.forced_decoder_ids = (
            whisper_asr.tokenizer.get_decoder_prompt_ids(
                language=None, task="transcribe"
            )
        )
    else:
        whisper_asr.model.config.forced_decoder_ids = (
            whisper_asr.tokenizer.get_decoder_prompt_ids(
                language=args.lang_code, task="transcribe"
            )
        )

    hypothesis = []
    ground_truth = []

    os.makedirs(dir_path + "/predictions", exist_ok=True)
    out_name = (
        args.model_path.rsplit("/", 1)[-1]
        + "_"
        + args.manifest_name
        + "_predictions.json"
    )
    open(dir_path + "/predictions/" + out_name, "w").close()

    st = time.time()

    for out in tqdm(whisper_asr(dataset, batch_size=args.batch_size), total=len(dataset)):
        hyp = out["text"]
        ref = out["reference"][0]
        hyp = hyp.translate(str.maketrans("", "", string.punctuation + "\u0964\u06d4\u2019-\u0965"))
        ref = ref.translate(str.maketrans("", "", string.punctuation + "\u0964\u06d4\u2019-\u0965"))
        if args.lang_code[:2] != "ur":
            hyp = normalize_sentence(hyp, args.lang_code[:2])
            ref = normalize_sentence(ref, args.lang_code[:2])
        hyp = re.sub(" +", " ", hyp).strip()
        ref = re.sub(" +", " ", ref).strip()
        if ref == "":
            ref = "<empty>"
        hypothesis.append(hyp)
        ground_truth.append(ref)
        res = {
            "audio_filepath": out["path"][0],
            "duration": out["duration"][0],
            "text": ref,
            "pred_text": hyp,
        }
        with open(dir_path + "/predictions/" + out_name, "a") as f:
            json.dump(res, f, ensure_ascii=False)
            f.write("\\n")

    et = time.time()

    result = {}
    result["model"] = args.model_path
    result["dataset"] = args.manifest_name
    result["language"] = args.lang_code
    result["cer"] = compute_cer(ground_truth, hypothesis)
    result["wer"] = compute_wer(ground_truth, hypothesis)
    result["time_minutes"] = round((et - st) / 60, 2)
    result["batch_size"] = args.batch_size

    print("\\n===== RESULTS =====")
    for k, v in result.items():
        print(f"  {k}: {v}")

    with open(dir_path + "/results.csv", "a") as results_fp:
        print(",".join([str(v) for v in result.values()]), file=results_fp)


if __name__ == "__main__":
    dir_path = os.path.dirname(os.path.realpath(__file__))
    parser = argparse.ArgumentParser()
    parser.add_argument("--model_path", type=str, required=True)
    parser.add_argument("--manifest_path", type=str, required=True)
    parser.add_argument("--manifest_name", type=str, required=True)
    parser.add_argument("--device", type=int, default=-1)
    parser.add_argument("--batch_size", type=int, default=32)
    parser.add_argument("--language", type=str, required=True)
    args = parser.parse_args()

    if len(args.language) == 2:
        args.lang_code = args.language.lower()
    else:
        args.lang_code = lang_to_code[args.language.lower()]

    main(args)
'''

with open('/kaggle/working/vistaar/evaluation.py', 'w') as f:
    f.write(fixed_eval)

print("evaluation.py written successfully!")
# !grep -n 'compute_cer\|compute_wer\|audio_filepath\|editdistance' /kaggle/working/vistaar/evaluation.py
# Out:
# evaluation.py written successfully!
# 4:import editdistance
# 47:def compute_cer(refs, hyps):
# 48:    """Character Error Rate using editdistance (no rapidfuzz dependency)"""
# 52:        total_edits += editdistance.eval(r, h)
# 57:def compute_wer(refs, hyps):
# 58:    """Word Error Rate using editdistance (no rapidfuzz dependency)"""
# 64:        total_edits += editdistance.eval(r_words, h_words)
# 94:    # Use audio_filepath directly from manifest (no hardcoded path replacement)
# 95:    aud["path"] = js_data["audio_filepath"]
# 164:            "audio_filepath": out["path"][0],
# 179:    result["cer"] = compute_cer(ground_truth, hypothesis)
# 180:    result["wer"] = compute_wer(ground_truth, hypothesis)

# %% [markdown]
# # Cell 4: Create FULL manifest

# %%
import json, os

BASE = "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi"
IN_MANIFEST = f"{BASE}/kathbath/hindi/manifest.json"
OUT_MANIFEST = "/kaggle/working/manifest_hindi_full.json"

count = 0
with open(IN_MANIFEST) as f, open(OUT_MANIFEST, "w") as out:
    for line in f:
        line = line.strip()
        if not line:
            continue
        entry = json.loads(line)
        filename = os.path.basename(entry["audio_filepath"])
        entry["audio_filepath"] = f"{BASE}/kathbath/hindi/wavs/wavs/{filename}"
        out.write(json.dumps(entry, ensure_ascii=False) + "\n")
        count += 1

print(f"Created full manifest with {count} samples: {OUT_MANIFEST}")
# Out:
# Created full manifest with 1929 samples: /kaggle/working/manifest_hindi_full.json

# %% [markdown]
# # Cell 5: Download Bengali Model

# %%
# !wget -q https://indicwhisper.objectstore.e2enetworks.net/hindi_models.zip -O /kaggle/working/vistaar/hindi_models.zip
# !unzip -q /kaggle/working/vistaar/hindi_models.zip -d /kaggle/working/vistaar/
# !ls /kaggle/working/vistaar/hindi_models/
# Out:
# whisper-large-hi-noldcil  whisper-medium-hi_alldata_multigpu

# %% [markdown]
# # Cell 6: Run evaluation (OOM-safe)

# %%
import os, torch

# Free GPU memory before starting
torch.cuda.empty_cache()
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"Free memory: {torch.cuda.mem_get_info()[0]/1024**3:.2f} GB")

# %cd /kaggle/working/vistaar

# Set env var to reduce memory fragmentation
import os
os.environ["PYTORCH_ALLOC_CONF"] = "expandable_segments:True"

# !PYTORCH_ALLOC_CONF=expandable_segments:True python evaluation.py \
    --model_path="hindi_models/whisper-medium-hi_alldata_multigpu" \
    --manifest_path="/kaggle/working/manifest_hindi_full.json" \
    --manifest_name="kathbath" \
    --device=0 \
    --batch_size=4 \
    --language="hi"
# Out:
# GPU: Tesla T4
# Free memory: 14.46 GB
# /kaggle/working/vistaar
# 100%|██████████████████████████████████████| 1929/1929 [00:07<00:00, 272.05it/s]
# Loading weights: 100%|█████████████████████| 947/947 [00:00<00:00, 15703.85it/s]
#   0%|                                                  | 0/1929 [00:00<?, ?it/s][transformers] Using custom `forced_decoder_ids` from the (generation) config. This is deprecated in favor of the `task` and `language` flags/config options.
# [transformers] Transcription using a multilingual Whisper will default to language detection followed by transcription instead of translation to English. This might be a breaking change for your use case. If you want to instead always translate your audio to English, make sure to pass `language='en'`. See https://github.com/huggingface/transformers/pull/28687 for more details.
# [transformers] A custom logits processor of type <class 'transformers.generation.logits_process.SuppressTokensLogitsProcessor'> has been passed to `.generate()`, but it was also created in `.generate()`, given its parameterization. The custom <class 'transformers.generation.logits_process.SuppressTokensLogitsProcessor'> will take precedence. Please check the docstring of <class 'transformers.generation.logits_process.SuppressTokensLogitsProcessor'> to see related `.generate()` flags.
# [transformers] A custom logits processor of type <class 'transformers.generation.logits_process.SuppressTokensAtBeginLogitsProcessor'> has been passed to `.generate()`, but it was also created in `.generate()`, given its parameterization. The custom <class 'transformers.generation.logits_process.SuppressTokensAtBeginLogitsProcessor'> will take precedence. Please check the docstring of <class 'transformers.generation.logits_process.SuppressTokensAtBeginLogitsProcessor'> to see related `.generate()` flags.
# 100%|███████████████████████████████████████| 1929/1929 [54:38<00:00,  1.70s/it]
#
# ===== RESULTS =====
#   model: hindi_models/whisper-medium-hi_alldata_multigpu
#   dataset: kathbath
#   language: hi
#   cer: 0.03652684925598447
#   wer: 0.10235419063633949
#   time_minutes: 54.64
#   batch_size: 4

# %% [markdown]
# # Cell 7: View results

# %%
print("=== Results CSV ===")
# !cat /kaggle/working/vistaar/results.csv

print("\n=== Predictions ===")
# !cat /kaggle/working/vistaar/predictions/whisper-medium-hi_alldata_multigpu_kathbath_predictions.json
# Out:
# === Results CSV ===
# hindi_models/whisper-medium-hi_alldata_multigpu,kathbath,hi,0.03652684925598447,0.10235419063633949,54.64,4
#
# === Predictions ===
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932919645-1202-f.wav", "duration": 5.7585625, "text": "सुधीर मिश्रा की ये फिल्म लेखक शरत चंद्र चट्टोपाध्याय के उपन्यास देवदास पर आधारित होगी", "pred_text": "सुधीर मिश्रा की यह फिल्म लेखक शरद चंद्र चटुपाध्या के उपन्यास देवीदास पर आधारित होगी"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932410060-267-f.wav", "duration": 4.644, "text": "खोज कम मांग के लिए इंजन में वेबसाइट पदोन्नति", "pred_text": "खोज कम मांग के लिए इंजन में वेबसाइट पदोन्नति"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930954560-564-f.wav", "duration": 5.7585625, "text": "ट्रेन लक्ष्मीबाई नगर भी नहीं पहुंचती कि लोगों का बतियाना बन्द हो जाता है", "pred_text": "ट्रेन लक्ष्मीबाई नगर भी नहीं पहुंचती कि लोगों का बतियाना बंद हो जाता है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930627604-153-f.wav", "duration": 8.6610625, "text": "नई पॉलिसी के तहत एक्सट्रा चार्ज देकर ज्यादा एफएआर भी लिया जा सकता है", "pred_text": "नई पॉलिसी के तहत एक्स्ट्रा चार्ज देकर ज्यादा एफआईआर भी लिया जा सकता है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930966728-564-f.wav", "duration": 4.9923125, "text": "उन्होंने वन मुख्यालय से प्रस्ताव पर अनुमति प्रदान करने का आग्रह किया है", "pred_text": "उन्होंने वन मुख्यालय से प्रस्ताव पर अनुमति प्रदान करने का आग्रह किया है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932410065-267-f.wav", "duration": 4.5975625, "text": "उषा ने ऑटो चालक को बताया कि उसे भिंड जाना है", "pred_text": "उषा ने ऑटो चालक को बताया कि उसे भिंड जाना है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932574148-221-f.wav", "duration": 6.873125, "text": "देश की जनता अपने आप अन्ना की टीम के सवालों का जवाब चुनावों में देगी", "pred_text": "देश की जनता अपने आप अन्ना की टीम के सवालों का जवाब चुनावों में देगी"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930759178-153-f.wav", "duration": 4.8994375, "text": "शासन द्वारा मंजूरी मिलते ही ओपन जेल का निर्माण कार्य शुरू हो गया", "pred_text": "शासन द्वारा मंजूरी मिलते ही ओपन जेल का निर्माण कार्य शुरू हो गया"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930929569-1190-f.wav", "duration": 7.082125, "text": "इसके अलावा गुजरात के अहमदाबाद में आज जगन्नाथ यात्रा निकाली जाएगी", "pred_text": "इसके अलावा गुजरात के अहमदाबाद में आज जगरनाथ यात्रा निकाली जाएगी"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930918882-564-f.wav", "duration": 4.5743125, "text": "अभी यह साफ नहीं है कि किरण नई पार्टी बनाएंगे अथवा नहीं", "pred_text": "अभी यह साफ नहीं है कि किरण नई पार्टी बनाएंगे अथवा नहीं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930966776-564-f.wav", "duration": 4.179625, "text": "लोग रो रहे थे तो कोई उन्हें ढाढस बंधा रहा था", "pred_text": "लोग रो रहे थे तो कोई उन्हें ढांढस बँगा रहा था"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930898388-574-f.wav", "duration": 8.68425, "text": "स्वतंत्रता सेनानी अमरनाथ डोगरा को पुलिस के जवानों ने उन्हें अंतिम विदाई दी", "pred_text": "स्वतंत्रता सेनानी अमरनाथ डोगरा को पुलिस के जवानों ने उन्हें अंतिम विदाई दी"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932919598-1202-f.wav", "duration": 3.5294375, "text": "उन फोटोज में कपिल एक प्यारी सी बच्ची को थामे हुए थे", "pred_text": "उन फोटोज में कपिल एक प्यारी सी बच्ची को थामे हुए थे"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930927709-574-f.wav", "duration": 4.945875, "text": "होली के आठ दिन बाद होती है शीतला माता की पूजा", "pred_text": "होली के आठ दिन बाद होती है शीतला माता की पूजा"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930570555-160-f.wav", "duration": 5.340625, "text": "आस्था के केंद्र इस मंदिर में लोग प्रतिदिन पूजा करते हैं", "pred_text": "आस्था के केंद्र इस मंदिर में लोग प्रतिदिन पूजा करते हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930570589-160-f.wav", "duration": 7.0124375, "text": "धोनी ने मैदान पर आते ही आक्रामक अंदाज में बल्लेबाजी करनी शुरू कर दी", "pred_text": "धोनी ने मैदान पर आते ही आक्रामक अंदाज में बल्लेबाजी करनी शुरू कर दी"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930918888-564-f.wav", "duration": 4.6208125, "text": "जिसके लिए उनका देहान्त के बाद तर्पण किया जाता है", "pred_text": "जिसके लिए उनका देहांत के बाद तर्पण किया जाता है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930560836-620-f.wav", "duration": 7.3375, "text": "सूर्योदय से पहले उठकर स्नान से निवृत्त होकर पीले रंग के वस्त्र पहनने चाहिए", "pred_text": "सूर्योदय से पहले उठकर स्नान से निवृत्त होकर पीले रंग के वस्त्र पहनने चाहिए"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930547215-497-f.wav", "duration": 5.6656875, "text": "परिणामस्वरूप लोगों को मतदान के प्रति जागरूक करना एक सामाजिक कार्य है", "pred_text": "परिणामस्वरूप लोगों को मतदान के प्रति जागरूक करना एक सामाजिक कार्य है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930708001-153-f.wav", "duration": 5.688875, "text": "चोर स्टेज से ले उड़ा नोटों से भरा हुआ बैग", "pred_text": "चोर स्टेज से ले उड़ा नोटों से भरा हुआ बैग"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930927688-574-f.wav", "duration": 5.921125, "text": "दूसरी ओर गर्म मौसम के चलते पेयजल पर भी काफी असर पड़ता है", "pred_text": "दूसरी ओर गर्म मौसम के चलते पेयजल पर भी काफी असर पड़ता है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932574081-221-f.wav", "duration": 6.94275, "text": "बस वह दो विकल्पों पर अब भी ताला लगाए हुए है", "pred_text": "बस वह दो विकल्पों पर अब भी ताला लगाए हुए हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930627659-153-f.wav", "duration": 7.244625, "text": "उन्होने श्री चौहान को ताइवान आने का आमंत्रण दिया", "pred_text": "उन्होंने श्री चौहान को ताइवान आने का आमंत्रण दिया"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930627606-153-f.wav", "duration": 6.873125, "text": "इन भाषाई विभाजनों को चुनौती भी नहीं दी जा सकती है", "pred_text": "इन भाषाई विभाजनों को चुनौती भी नहीं दी जा सकती है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930927681-574-f.wav", "duration": 5.3638125, "text": "इसलिए भी कि इसके सिवाय मैं कुछ और कर नहीं सकता", "pred_text": "इसलिए भी कि इसके सिवाय मैं कुछ और कर नहीं सकता"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932919565-1202-f.wav", "duration": 4.6208125, "text": "विभाग अनुदेशकों के भर्ती एवं पदोन्नति नियम बनाने में भी असफल रहा है", "pred_text": "विभाग अनुदेशकों के भर्ती एवं पदोन्नति नियम बनाने में भी असफल रहा है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930325529-497-f.wav", "duration": 4.7833125, "text": "धर्मशाला में पुरुष खिलाडि़यों के लिए अकोमोडेशन की आवश्यकता है", "pred_text": "धर्मशाला में पुरुष खिलाड़ियों के लिए अकोमोडेशन की आवश्यकता है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930637326-620-f.wav", "duration": 6.014, "text": "इसके बाद ही चार वर्षीय बीएससी फोरेस्ट्री का कोर्स किया जा सकता है", "pred_text": "इसके बाद ही चार वर्षीय बीएससी फॉरेस्ट्री का कोर्स किया जा सकता है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932919589-1202-f.wav", "duration": 4.435, "text": "निगम कार्यालय में कांग्रेसियों द्वारा किए गए उत्पात के बाद का दृश्य", "pred_text": "निगम कार्यालय में कांग्रेसियों द्वारा किए गए उत्पाद के बाद का दृश्य"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930966750-564-f.wav", "duration": 6.501625, "text": "उनका कहना है कि जीत के बाद उनकी प्राथमिकता क्षेत्र का समग्र विकास करवाना है", "pred_text": "उनका कहना है कि जीत के बाद उनकी प्राथमिकता क्षेत्र का समग्र विकास करवाना है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932919556-1202-f.wav", "duration": 3.692, "text": "वहां से मंजूरी के बाद इसे लागू कर दिया जाएगा", "pred_text": "वहां से मंजूरी के बाद इसे लागू कर दिया जाएगा"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930929612-1190-f.wav", "duration": 10.541875, "text": "यदि आपके पास समर्पित कसरत कक्ष नहीं है तो एक फोल्डिंग ट्रेडमिल बहुत अच्छा है", "pred_text": "यदि आपके पास समर्पित कसरत कक्ष नहीं है तो एक फोल्डिंग ट्रेडमिल बहुत अच्छा है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930547250-497-f.wav", "duration": 4.435, "text": "आइपीएल के आधिकारिक ट्विटर अकाउंट पर इसकी जानकारी दी गई है", "pred_text": "आईपीएल के अधिकारी ट्विटर अकाउंट पर इसकी जानकारी दी गई है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930929538-1190-f.wav", "duration": 10.1935625, "text": "डोकलाम के समय सभी नॉर्म को धता बताकर वह चीनी राजदूत से मिले", "pred_text": "डोकलाम के समय सभी नार्म को घता बताकर वह चीनी राजदूत से मिले"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930929603-1190-f.wav", "duration": 6.6176875, "text": "बच्चों में स्क्रब टाइफस के लक्षण दिखने के बाद डॉक्टर अलर्ट पर हैं", "pred_text": "बच्चों में स्क्रब टायफस के लक्षण दिखने के बाद डॉक्टर अलर्ट पर हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930966742-564-f.wav", "duration": 4.9690625, "text": "एनफील्ड के साथ मेरी कुछ और भी यादें जुड़ी हुई हैं", "pred_text": "एनफ़ील्ड के साथ मेरी कुछ और भी भी यादें जुड़ी हुई हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930966772-564-f.wav", "duration": 5.2245, "text": "क्योंकि फेशवॉश आपकी त्वचा का तेल तो गहराई से साफ कर देता है", "pred_text": "क्योंकि फेस वॉश आपकी त्वचा का तेल तो गहराई से साफ कर देता है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930966741-564-f.wav", "duration": 5.4799375, "text": "सुषमा ने विदेश मंत्रालय तक लोगों की पहुँच को बनाया था आसान", "pred_text": "सुषमा ने विदेश मंत्रालय तक लोगों की पहुंच को बनाया था आसान"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932410149-267-f.wav", "duration": 4.8994375, "text": "फिल्टर के गंदे होने पर इंजन को पर्याप्त हवा नहीं मिलती है", "pred_text": "फिल्टर के गंदे होने पर इंजन को पर्याप्त हवा नहीं मिलती है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930927636-574-f.wav", "duration": 6.2461875, "text": "कई सारे परिवार आज रात अपने प्रियजनों के लिए शोक मनाएंगे", "pred_text": "कई सारे परिवार आज रात अपने प्रियजनों के लिए शोक मनाएंगे"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930954539-564-f.wav", "duration": 6.757, "text": "प्रभाव केवल लंबे समय तक और व्यवस्थित पाठ्यक्रम उपचार के साथ ध्यान देने योग्य होगा", "pred_text": "प्रभाव केवल लंबे समय तक और व्यवस्थित पाठ्यक्रम उपचार के साथ ध्यान देने योग्य होगा"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930898447-574-f.wav", "duration": 5.0851875, "text": "इस शो में वह कई हस्तियों का इंटरव्यू लेते हैं", "pred_text": "इस शो में वह कई हस्तियों का इंटरव्यू लेते हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930929579-1190-f.wav", "duration": 8.3591875, "text": "फिल्म के निर्देशक शमास सिद्दीकी जो कि लीड एक्टर नवाजुद्दीन सिद्दीकी के भाई हैं", "pred_text": "फिल्म के निर्देशक शमांस सिद्दीकी जोकि लीड एक्टर नवाजुद्दीन सिद्दीकी के भाई हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930966825-564-f.wav", "duration": 4.9923125, "text": "माघ पूर्णिमा को शुभ मुहूर्त में इस डण्डे की स्थापना की जाती है", "pred_text": "माघ पूर्णिमा को सुबहोर्त में इस डंडे की स्थापना की जाती है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930560865-620-f.wav", "duration": 4.6208125, "text": "हो सकता है कि उसे भी किसी ने धक्का दिया हो", "pred_text": "हो सकता है कि उसे भी किसी ने धक्का दिया हो"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930918913-564-f.wav", "duration": 5.4566875, "text": "परिणाम तक पहुंचाने के लिए इसे प्रेत शक्ति से संपन्न किया जाता है", "pred_text": "परिणाम तक पहुंचाने के लिए इसे प्रेत शक्ति से संपन्न किया जाता है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930759145-153-f.wav", "duration": 6.3390625, "text": "जवानों की जान बचाने पर इंडियन आर्मी ने किया कश्मीरी युवकों का शुक्रिया", "pred_text": "जवानों की जान बचाने के लिए इंडियन आर्मी ने किया कश्मीरी युवाओं का शुक्रिया"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930918924-564-f.wav", "duration": 4.5743125, "text": "अश्लीलता का यह कार्यक्रम काफी देर तक चलता रहा", "pred_text": "आज रलीलता का यह कार्यक्रम काफी देर तक चलता रहा"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930929529-1190-f.wav", "duration": 11.8189375, "text": "दक्षिणी सुमात्रा और जावा द्वीपों के बीच स्थित सुंडा द्वीप में यह ज्वालामुखी फटा है", "pred_text": "दक्षिणी सुमात्रा और जावा द्वीपों के बीच स्थित सुंडा द्वीप में यह ज्वालामुखी फटा है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930570514-160-f.wav", "duration": 5.7353125, "text": "बताया जा रहा है कि टूरिस्ट की हत्या तीर मारकर की गई है", "pred_text": "बताया जा रहा है कि टूरिस्ट की हत्या तेर मारकर की गई है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930918861-564-f.wav", "duration": 6.1765, "text": "देवेंद्र फडणवीस ने कहा कि इसके बाद मैं राजभवन जाऊंगा और अपना इस्तीफा दूंगा", "pred_text": "देवेंद्र फेडेनविश ने कहा कि इसके बाद मैं राजभवन जाऊंगा और अपना इस्तीफा दूंगा"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930707995-153-f.wav", "duration": 7.662625, "text": "ये सनसनीखेज घटना ओल्ड भोपाल के अशोका गार्डन थाना इलाके की है", "pred_text": "ये सनसनीखेज घटना ओल्ड भोपाल के अशोका गार्डन थाना इलाके की है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932919562-1202-f.wav", "duration": 4.4814375, "text": "निर्धन जनता भारी दामों पर निजी मेडिकल स्टोर से दवाइयां खरीदने को विवश हैं", "pred_text": "निर्धन जनता भारी दामों पर निजी मेडिकल स्टोर्स से दवाइयां खरीदने को विवश है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930898425-574-f.wav", "duration": 5.131625, "text": "अब एक अलग तरह से आंदोलन शुरू करना चाहती हूं", "pred_text": "अब एक अलग तरह से आंदोलन शुरू करना चाहती हूं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930570560-160-f.wav", "duration": 5.317375, "text": "बाकी फिल्म इस कहानी के बारे में आगे बताती है", "pred_text": "बाकी फिल्म इस कहानी के बारे में आगे बताती है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930929595-1190-f.wav", "duration": 5.4335, "text": "आपके शरीर में इम्यूनिटी होना काफी जरूरी होता है", "pred_text": "आपके शरीर में इम्यूनिटी होना काफी जरूरी होता है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930325481-497-f.wav", "duration": 4.3189375, "text": "यहां पर हनुमान जी को महाराजाधिराज के नाम से भी पुकारा जाता है", "pred_text": "यहां पर हनुमान जी को महाराजा धीराज के नाम से भी पुकारा जाता है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930637364-620-f.wav", "duration": 4.9923125, "text": "मुर्गियों के बीच ओर्लोव झपट्टा आम तौर पर बहुत छोटे हैं", "pred_text": "मुर्गियों के बीच औरलोफ झपट्टा आम तौर पर बहुत छोटे हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930898444-574-f.wav", "duration": 5.6656875, "text": "लेकिन उन्होंने इन अटकलों को खारिज कर दिया था", "pred_text": "लेकिन उन्होंने इन अटकलों को खारिज कर दिया था"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930954617-564-f.wav", "duration": 5.24775, "text": "कैंप में झड़प बाद फैली हिंसा से अमरनाथ यात्रा रोकी गई", "pred_text": "कैंप में झड़प बात फैली हिंसा से अमरनाथ यात्रा रोकी गई"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930929572-1190-f.wav", "duration": 6.7105625, "text": "लुटेरों ने कार की डिग्गी से रुपयों से भरा बैग निकाल लिया", "pred_text": "लुटेरों ने कार की डिग्गी से रुपयों से भरा बैग निकाल लिया"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930570549-160-f.wav", "duration": 7.2910625, "text": "छोटी बालों वाली बिल्लियों का संयोजन बहुत कम उत्पादन करने के लिए पर्याप्त है", "pred_text": "छोटी बालों वाली बिल्लियों का संयोजन बहुत कम उत्पादन करने के लिए पर्याप्त है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930547227-497-f.wav", "duration": 3.6455625, "text": "युवक पर काबू पाते हुए उसे खंभे से बांध दिया", "pred_text": "युवक पर काबू पाते हुए उसे खम्बे से बांध दिया"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930927673-574-f.wav", "duration": 7.0124375, "text": "हसीन का आरोप है कि शमी दूसरी लड़कियों से अंतरंग चैट करते हैं", "pred_text": "हसीन का आरोप है कि शमी दूसरी लड़कियों से अतरंग चैट करते हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930918829-564-f.wav", "duration": 5.78175, "text": "अब कांच के लिए फिल्म देते हैं और मिलीमीटर सख्ती से समायोजित करें", "pred_text": "अब कांच के लिए फिल्म देते हैं और मिलीमीटर शक्ति से समायोजित करें"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932574085-221-f.wav", "duration": 9.0558125, "text": "वित्त मंत्रालय ने नियम इसलिए बनाया है ताकि कैश निकालना कम हो सके", "pred_text": "वित्त मंत्रालय ने नियम इसलिए बनाया है ताकि कैश निकालना कम हो सके"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932410150-267-f.wav", "duration": 6.4319375, "text": "अकादमी की स्वीकृत और अधिकृत योजनाओं की स्पष्टतः कुछ आधारभूत विशेषताएं हैं", "pred_text": "अकादमी की स्वीकृत और अधिकृत योजनाओं की स्पर्शता कुछ आधारभूत विशेषताएं हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930954594-564-f.wav", "duration": 5.131625, "text": "जामिया के शोधकर्ताओं ने बनाई सलाइवा आधारित कोरोना जांच किट", "pred_text": "जामिया के शोधकर्ताओं ने बनाई सलाइवा आधारित कोरोना जांच किट"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930707961-153-f.wav", "duration": 7.4768125, "text": "भुगतान न किए जाने को लेकर वित्त एवं लेखाधिकारी और शिक्षक नेताओं में नोकझोंक हुई", "pred_text": "भुगतान न किए जाने को लेकर वित्त एवं लेखाधिकारी और शिक्षक नेताओं में नोकझोंक हुए"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930570562-160-f.wav", "duration": 5.1780625, "text": "जान बूझकर अभिनव रुबीना ने कविता को किया टारगेट", "pred_text": "जानबूझकर अभिनव रूबीना ने कविता को किया टारकेट"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930627681-153-f.wav", "duration": 5.5495625, "text": "हम किसी के दबाव में काम नहीं कर रहे हैं", "pred_text": "हम किसी के दबाव में काम नहीं कर रहे हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930627646-153-f.wav", "duration": 9.4040625, "text": "चोरी की तीनों घटनाओं में अपराधियों की हरकत सीसीटीवी कैमरे में कैद है", "pred_text": "चोरी की तीनों घटनाओं में अपराधियों की हरकत सीसीटीवी कैमरे में कैद है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930570571-160-f.wav", "duration": 5.131625, "text": "क्योंकि वो बस किसी तरह पार्टी में शामिल होना चाहती थीं", "pred_text": "क्योंकि वो बस किसी तरह पार्टी में शामिल होना चाहती थीं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932574109-221-f.wav", "duration": 7.244625, "text": "उनके सिय्योन के गीतों को ऊंचा कर दिया गया था", "pred_text": "उनके सियोन के गीतों को ऊंचा कर दिया गया था"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932919574-1202-f.wav", "duration": 2.5774375, "text": "यह एक खेल की तरह हो चुका है", "pred_text": "यह एक खेल की तरह हो चुका है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930634223-620-f.wav", "duration": 3.50625, "text": "अब दूसरे चरण का काम शुरू हो गया है", "pred_text": "अब दूसरे चरण का काम शुरू हो गया है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930547202-497-f.wav", "duration": 4.7833125, "text": "मिथुन राशि के लोग आलस्य का परित्याग करें और अपने कर्म पथ पे चलें", "pred_text": "मिथुन राशि के लोग आलस्य का परिताज्ञ करें और अपने कर्मपथ पे चलें"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930927726-574-f.wav", "duration": 6.9891875, "text": "इस मिशन के मद्देनजर इको फ्रैंडली बप्पा मुंबई में जमकर उभरे हैं", "pred_text": "इस मिशन के मद्देनजर इको फ्रेंडली बप्पा मुंबई में जमकर उभरे हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930570539-160-f.wav", "duration": 7.3839375, "text": "ड्रीम गर्ल के इलाके में पूरे नहीं हुए वादे तो मतदाताओं ने किया चुनाव बहिष्कार", "pred_text": "ड्रीम गर्ल के इलाके में पूरे नहीं हुए वादे तो मतदाताओं ने किया चुनाव बहिष्कार"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930547282-497-f.wav", "duration": 4.08675, "text": "यह योजना आत्मनिर्भर भारत आर्थिक पैकेज का हिस्सा है", "pred_text": "यह योजना आत्मनिर्भर भारत पार्थिक पैकेज का हिस्सा है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930627621-153-f.wav", "duration": 6.292625, "text": "अब वाईएस जगन मोहन रेड्डी के बारे में पुस्तक लिखा है", "pred_text": "अब वाईएस जगनमोहन रेड्डी के बारे में पुस्तक लिखा है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932574127-221-f.wav", "duration": 8.1734375, "text": "यह अक्सर एंटीसेप्टिक और एंटीबायोटिक समाधान और सपोजिटरी निर्धारित है", "pred_text": "यह अक्सर एंटीसेप्टिक और एंटीबायोटिक समाधान और स्पोजिटरी निर्धारित है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930927705-574-f.wav", "duration": 5.2709375, "text": "और इस फिल्म के लिए करिश्मा को नेशनल अवार्ड मिल गया", "pred_text": "और इस फिल्म के लिए करिश्मा को नेशनल अवॉर्ड मिल गया"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930325523-497-f.wav", "duration": 4.551125, "text": "वह बहुत अच्छे इंसान हैं और घमंड उनमें जरा भी नहीं है", "pred_text": "वह बहुत अच्छे इंसान हैं और घमंड उनमें जरा भी नहीं हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930707952-153-f.wav", "duration": 7.36075, "text": "ग्रामीण क्षेात्रों से अपने परीक्षा केन्द्र तक छात्र कैसे पहुंचेंगे", "pred_text": "ग्रामीण क्षेत्रों से अपनी परीक्षा केंद्र तक छात्र कैसे पहुंचेंगे"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932410090-267-f.wav", "duration": 6.19975, "text": "उनकी टीम में भिवानी की महिला खिलाड़ी गीता व विनेश भी शामिल हैं", "pred_text": "उनकी टीम में भिवानी की महिला खिलाड़ी गीता व विनेश भी शामिल हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932410087-267-f.wav", "duration": 4.179625, "text": "इन लोगों को मुख्य तंत्र के काम की निगरानी करेगा", "pred_text": "इन लोगों को मुख्य तंत्र के काम की निगरानी करेगा"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930954540-564-f.wav", "duration": 5.03875, "text": "गिद्दा डालने के बाद महिलाओं ने शोभायात्रा में भी भाग लिया", "pred_text": "गिद्दा डालने के बाद महिलाओं ने शोभायात्रा में भी भाग लिया"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930759131-153-f.wav", "duration": 5.805, "text": "पीरिड्स के समय शरीर में बहुत अधिक दर्द होता है", "pred_text": "पिरेड्स के समय शरीर में बहुत अधिक दर्द होता है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930621990-620-f.wav", "duration": 4.45825, "text": "फिर न कोई रावण इस धरती पर जिंदा रहे", "pred_text": "फिर न कोई रावण इस धरती पर जिंदा रहे"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932410143-267-f.wav", "duration": 4.342125, "text": "विशेषज्ञों द्वारा इसका कारण बढ़ता तनाव बताया जा रहा है", "pred_text": "विशेषज्ञों द्वारा इसका कारण बढ़तातरा बताया जा रहा है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932919561-1202-f.wav", "duration": 4.4814375, "text": "मशहूर बिड़ला प्रौद्योगिकी एवं विज्ञान संस्थान यहीं पर स्थित है", "pred_text": "मशहूर बिड़ला प्रौद्योगिकी एवं विज्ञान संस्थान यहीं पर स्थित है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930929559-1190-f.wav", "duration": 7.9644375, "text": "हिमाचल प्रदेश के कांगड़ा में ये दर्दनाक बस हादसा ढ़लियारा गांव का है", "pred_text": "हिमाचल प्रदेश के कांगड़ा में ये दर्दनाक बस हादसा ढलियारा गांव का है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930621925-620-f.wav", "duration": 5.4566875, "text": "उसके बाद अनीता अपनी मंझली बहन और मां के साथ वहां रहती थीं", "pred_text": "उसके बाद अनीता अपनी मंझली बहन और मां के साथ वहां रहते थे"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932410127-267-f.wav", "duration": 5.108375, "text": "एकाउंट नंबर एवं ऑनलाइन ट्रांजेक्शन नंबर सार्वजनिक कर दिया है", "pred_text": "एकाउंट नंबर एवं ऑनलाइन ट्रांजेक्शन नंबर सार्वजनिक कर दिया है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930927639-574-f.wav", "duration": 4.760125, "text": "रंग चावल के साथ पके हुए लाल सेम से है", "pred_text": "रमचावल के साथ पके हुए लाल सैम से हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930954531-564-f.wav", "duration": 4.644, "text": "मंदिर का सभामंडप किले के अन्य इमारतों का समकालीन है", "pred_text": "मंदिर का सभा मंडप किले के अन्य इमारतों का समकालीन है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932919577-1202-f.wav", "duration": 3.7151875, "text": "मरीजों का परीक्षण इलाके के वरिष्ठ डाक्टरों द्वारा किया जाएगा", "pred_text": "मरीजों का परीक्षण इलाके के वरिष्ठ डॉक्टरों द्वारा किया जाएगा"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930918883-564-f.wav", "duration": 3.9009375, "text": "अब तक हनीप्रीत का कोई सुराग नहीं मिला है", "pred_text": "अब तक हनीप्रीत का कोई सुराग नहीं मिला है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930918838-564-f.wav", "duration": 5.131625, "text": "कोई मोदी का तो कोई राहुल का पोस्टर पहन लेती हैं", "pred_text": "कोई मोदी का तो कोई राउण्ड का पोस्टर पहन लेती हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932919620-1202-f.wav", "duration": 3.3436875, "text": "लेकिन यथार्थ परिस्थिति उनकी हत्या करने पर तुली है", "pred_text": "लेकिन निदार्थ परिस्थिति उनके हत्या करने पर तुली है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932919624-1202-f.wav", "duration": 4.5975625, "text": "उन्होंने बताया कि स्कूल प्रबंधन चाहता है कि बच्चे स्वस्थ्य रहें और सर्वांगीण विकास करें", "pred_text": "उन्होंने बताया कि स्कूल प्रबंधन चाहता है कि बच्चे स्वस्थ रहें और सर्वांगीण विकास करें"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930637297-620-f.wav", "duration": 6.1533125, "text": "जिसके बाद भदभदा विश्राम घाट पर हिन्दु रीति रिवाज से अंतिम संस्कार किया गया", "pred_text": "जिसके बाद भटभदा विश्राम घाट पर हिंदू रीति रिवाज से अंतिम संस्कार किया गया"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930547246-497-f.wav", "duration": 5.99075, "text": "इस फिल्म में कृति के साथ सुशांत सिंह राजपूत मुख्य किरदार निभाते हुए नजर आएंगे", "pred_text": "इस फिल्म में कृति के साथ सुशांत सिंहराज बूथ मुख्य किरदार निभाते हुए नजर आएंगे"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930707958-153-f.wav", "duration": 7.0124375, "text": "इस अवसर पर आई हुई संगत के लिए अटूट लंगर का भी आयोजन किया गया", "pred_text": "इस अवसर पर आई हुई संगत के लिए अटूट लंगर का भी आयोजन किया गया"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930707966-153-f.wav", "duration": 8.196625, "text": "पत्रकारों द्वारा पूछे गए मुख्य विषय को अलग रखनेवाले प्रश्न", "pred_text": "पत्रकारों द्वारा पूछे गए मुख्य विषय को अलग रखने वाले प्रश्न"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932410119-267-f.wav", "duration": 3.9241875, "text": "क्या श्रमिकों का दर्द उन्हें दिखाई नहीं दे रहा है", "pred_text": "क्या श्रमिकों का दर्द उन्हें दिखाई नहीं दे रहा है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930898417-574-f.wav", "duration": 6.9195625, "text": "अंतरराष्ट्रीय योग दिवस पर योगगुरु बाबा रामदेव बनाएंगे वर्ल्ड रिकॉर्ड", "pred_text": "अंतरराष्ट्रीय योग दिवस पर योग गुरु बाबा रामदेव बनाएंगे वर्ल्ड रिकॉर्ड"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930929550-1190-f.wav", "duration": 5.3638125, "text": "इस दौरान उनका बड़ा बेटा घर पर अकेले खेल रहा था", "pred_text": "इस दौरान उनका बड़ा बेटा घर पर अकेले खेल रहा था"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930918870-564-f.wav", "duration": 5.7353125, "text": "जले हुए ट्रासर्फामर प्राथमिकता से बदलने की व्यवस्था सुनिश्चित हो", "pred_text": "जले हुए ट्रांसफार्मर प्राथमिकता से बदलने की व्यवस्था सुनिश्चित हो"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930570532-160-f.wav", "duration": 7.082125, "text": "इस डांस नंबर को परफेक्ट करने के लिए दीपिका ने पूरा जोर लगा दिया", "pred_text": "इस डांस नंबर को परफेक्ट करने के लिए दीपिका ने पूरा जोर लगा दिया"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930325552-497-f.wav", "duration": 5.03875, "text": "उनके पास अमेरिका से मिले तमाम तरह के अत्याधुनिक हथियार थे", "pred_text": "उसके पास अमेरिका से मिले तमाम तरह के अत्याधुनिक हथियार थे"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932574103-221-f.wav", "duration": 7.7786875, "text": "यह भी चिकन या मछली की शोरबा के आधार पर तैयार किया जा सकता है", "pred_text": "यह भी चिकन या मछली की शोरबा के आधार पर तैयार किया जा सकता है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930570530-160-f.wav", "duration": 7.0124375, "text": "राहुल से मीटिंग से पहले वनमंत्री उमंग सिंघार को अचानक दिल्ली बुला लिया गया", "pred_text": "राहुल से मीटिंग से पहले वन मंत्री उमंग सिंघार को अचानक दिल्ली बुला लिया गया"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930918890-564-f.wav", "duration": 4.2725, "text": "वो उनकी आने वाली दोनों फिल्मों में काम करने वाली है", "pred_text": "वो उनकी आने वाली दोनों फिल्मों में काम करने वाली हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930929551-1190-f.wav", "duration": 5.41025, "text": "दोनों हार्ट को पांच जगहों से कनेक्ट किया गया", "pred_text": "दोनों हार्ट को पांच जगहों से कनेक्ट किया गया"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930954529-564-f.wav", "duration": 5.8746875, "text": "कार्यक्रम का आरंभ प्रधानाचार्य मथुरा दास भारती ने स्काउट ध्वजारोहण करके किया", "pred_text": "कार्यक्रम का आरंभ प्रधान आचार्य मथुरादास भारती ने स्काउट ध्वजारोहण करके किया"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930929622-1190-f.wav", "duration": 7.7555, "text": "न ही हर कोई आपके विजेट के विनिर्माण विवरण जानना चाहता है", "pred_text": "न ही हर कोई आपके विजेट के विनिर्माण विवरण जानना चाहता है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930918848-564-f.wav", "duration": 3.5526875, "text": "अब जान से मारने की धमकी मिल रही है", "pred_text": "अब जान से मारने की धमकी मिल रही है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930570531-160-f.wav", "duration": 5.131625, "text": "मृतकों की संख्या में इजाफा होने की आशंका है", "pred_text": "मृतकों की संख्या में इजाफा होने की आशंका है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930929565-1190-f.wav", "duration": 9.4040625, "text": "इसी तरह पैरा टीचरों को भी चरणबद्ध तरीके से नियमित किए जाने का प्रस्ताव है", "pred_text": "इस तरह पैराटीचर को भी चरणबद्ध तरीके से नियमित किए जाने का प्रस्ताव है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930927675-574-f.wav", "duration": 6.19975, "text": "बैठक में आसपास की पंचायतों के दर्जनों भक्तों ने भाग लिया", "pred_text": "बैठक में आसपास की पंचायतों के दर्जनों भक्तों ने भाग लिया"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932410146-267-f.wav", "duration": 5.4566875, "text": "पौने चार फुट के पव्वा ने हथेली पर गुदा हुआ गर्लफ्रेंड का नाम दिखाया", "pred_text": "पौने चार फुट के पव्वा ने हथेली पर गुदा हुआ गर्लफ्रेंड का नाम दिखाया"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932410122-267-f.wav", "duration": 4.6904375, "text": "बदमाशों की पूरी करतूत घर में लगे सीसीटीवी में कैद हो गई है", "pred_text": "बदमाशों की पूरी करतूत घर में लगे सीसीटीवी में कैद हो गई है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930966761-564-f.wav", "duration": 5.20125, "text": "उन्होंने यह भी बताया कि इस दिशा में निर्णायक बातचीत चल रही है", "pred_text": "उन्होंने यह भी बताया कि इस दिशा में निर्णायक बातचीत चल रही है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932919569-1202-f.wav", "duration": 3.390125, "text": "ऐसे में निश्चित रूप से हमारी बाजार हिस्सेदारी भी बढ़ेगी", "pred_text": "ऐसे में निश्चित रूप से हमारी बाजार हिस्सेदारी भी बढ़ेगी"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930570550-160-f.wav", "duration": 6.36225, "text": "उनके पिता गुजराती और मां फरिदा हाफ ब्रिटिश हैं", "pred_text": "उनके पिता गुजराती और मां फरीदा हाफ ब्रिटिश हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932410106-267-f.wav", "duration": 5.82825, "text": "रिपोर्ट मिलने के बाद मामले की समीक्षा की जाएगी और जरूरी कार्रवाई भी की जाएगी", "pred_text": "रिपोर्ट मिलने के बाद मामले की समीक्षा की जाएगी और जरूरी कार्रवाई भी की जाएगी"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930898433-574-f.wav", "duration": 6.687375, "text": "इस मौके पर देश की जनता को नई संसद की इमारत सौगात में मिल जाएगी", "pred_text": "इस मौके पर देश की जनता को नई संसद की इमारत सौगात में मिल जाएगी"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930759114-153-f.wav", "duration": 5.3870625, "text": "वह इतने इमोशनल हुए कि उन्होंने महिला को गले लगा लिया", "pred_text": "वहां इतने इमोशनल हुए कि उन्होंने महिला को गले लगा लिया"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930918884-564-f.wav", "duration": 4.7136875, "text": "उनसे प्रत्यक्ष मिल कर उन्हें भेट वस्तु भी दी गयी थी", "pred_text": "उनसे प्रत्यक्ष्य मिलकर उन्हें भेंट वस्तु भी दी गई थी"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930547287-497-f.wav", "duration": 5.897875, "text": "हालांकि फिल्म अभी रिलीज होने को है लेकिन इसकी कई स्पेशल स्क्रीनिंग हो चुकी हैं", "pred_text": "हालांकि फिल्म अभी रिलीज होने को है लेकिन इसकी कई स्पेशल स्क्रीनिंग हो चुकी हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930570572-160-f.wav", "duration": 5.0851875, "text": "यहां केवल कला व वाणिज्य की पढ़ाई की सुविधा है", "pred_text": "यहाँ केवल कला व वाणिज्य की पढ़ाई की सुविधा है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932919559-1202-f.wav", "duration": 4.4814375, "text": "ज्योतिष गणना के अनुसार भगवान श्रीकृष्ण का जन्मोत्सव तीन दिनों तक रहेगा", "pred_text": "ज्योतिष गणना के अनुसार भगवान श्रीकृष्ण का जन्मोत्सव तीन दिनों तक रहेगा"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930966784-564-f.wav", "duration": 5.8514375, "text": "इसमें चीन की कंपनियों के साथ संयुक्त उपक्रम बनाने वाली कंपनियां भी शामिल होंगी", "pred_text": "इसमें चीन की कंपनियों के साथ संयुक्त उपक्रम बनाने वाली कंपनियां भी शामिल होंगी"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932574114-221-f.wav", "duration": 6.3855, "text": "यूजर्स के हिसाब से दुनिया का यह सबसे बड़ा मैसेजिंग एप्प है", "pred_text": "यूजर्स के हिसाब से दुनिया का यह सबसे बड़ा मैसेजिंग ऐप है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932919607-1202-f.wav", "duration": 2.7399375, "text": "दीया मिर्जा के घर गूंजी बेटे की किलकारी", "pred_text": "दीया मिर्जा के घनगुंजी बेटे के खिलकारे"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932919612-1202-f.wav", "duration": 3.5294375, "text": "शो के जरिए करीना लगातार फैंस को एंटरटेन कर रही हैं", "pred_text": "शो के जरिए करीना लगातार फैंस को एंटरटेन कर रही हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930325546-497-f.wav", "duration": 4.760125, "text": "घर की स्ट्रांग कंटेस्टेंट अर्शी खान घर से बेघर हो गई हैं", "pred_text": "घर की स्ट्रांग कंटेस्टेंट अर्शी खान घर से भी घर हो गई"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930637303-620-f.wav", "duration": 5.131625, "text": "भाजपा विधायक अनंत ओझा को धमकी देने के मामले में गिरफ्तार", "pred_text": "भाजपा विधायक अनंत ओझा को धमकी देने के मामले में गिरफ्तार"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930927696-574-f.wav", "duration": 7.8715625, "text": "प्रचंड बहुमत होने के बाद भी एनटी रामाराव को बर्खास्त कर दिया गया था", "pred_text": "प्रचंड बहुमत होने के बाद भी एंटी रामाराव को बर्खास्त कर दिया गया था"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930918843-564-f.wav", "duration": 5.1780625, "text": "ये सभी कृषि यंत्र किसानों को ड्रॉ द्वारा दिए जाएंगे", "pred_text": "ये सभी कृषि यंत्र किसानों को ड्रो द्वारा दिए जाएंगे"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930325510-497-f.wav", "duration": 5.131625, "text": "यह भावुक पल था क्योंकि मैं उनके अंतिम संस्कार के समय नहीं था", "pred_text": "यह भावुक पल था क्योंकि मैं उनके अंतिम संस्कार के समय नहीं था"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930927721-574-f.wav", "duration": 7.430375, "text": "ऐसे में इस बड़े टूर्नामेंट को जीतने के लिए हर टीम पसीना बहा रही है", "pred_text": "ऐसे में इस बड़े टूर्नामेंट को जीतने के लिए हर टीम पसीना बहा रही है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930898390-574-f.wav", "duration": 6.687375, "text": "कारोबारी ऋण के मामले में भारत की स्थिति उतनी बुरी नहीं दिखती", "pred_text": "कारोबारी ऋण के मामले में भारत की स्थिति उतनी बुरी नहीं दिखती"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932410128-267-f.wav", "duration": 5.61925, "text": "गांगुली ने उम्मीद जताई कि एक दिन वह भी कहानी का अपना पक्ष बता पाएंगे", "pred_text": "गांगुलियों ने उम्मीद जताई कि एक दिन वह भी कहानी का अपना पक्ष बता पाएंगे"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930547194-497-f.wav", "duration": 3.204375, "text": "इस फोटो में नेहरू सिगरेट पीते हुए दिख रहे हैं", "pred_text": "इस फोटो में नेहरू सिगरेट पीते हुए दिख रहे हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930898398-574-f.wav", "duration": 6.0371875, "text": "फिल्म में सुशांत सिंह राजपूत मुख्य किरदार में हैं", "pred_text": "फिल्म में सुशांत सिंह राजपूत मुख्य किरदार में हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930918923-564-f.wav", "duration": 5.1780625, "text": "यह कुछ ऐसी स्थिति है जैसे कि घर में अनचाहे मेहमान आ गए हों", "pred_text": "यहां कुछ ऐसी ऐसी स्थिति है जैसे कि घर में अनचाहे मेहमान आ गए हों"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930918912-564-f.wav", "duration": 4.4814375, "text": "तोते का प्रश्न सुनते ही गुरुदेव बेहोश होकर गिर पड़े", "pred_text": "तोते का प्रश्न सुनते ही गुरुदेव बेहोश होकर गिर पड़े"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930918889-564-f.wav", "duration": 5.78175, "text": "लेकिन एक दिन बाद महावीर यादव को पीआर बांड पर छोड़ दिया गया", "pred_text": "लेकिन एक दिन बाद महावीर यादव को पीआर बांड पर छोड़ दिया गया"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930627642-153-f.wav", "duration": 6.5480625, "text": "इसे बारे में मुझे मेरी मां ने बताया है", "pred_text": "इसे बारे में मुझे मेरी मां ने बताया है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932919643-1202-f.wav", "duration": 4.2725, "text": "लाजमी हैं उन्ही का मार्गदर्शन पाकर तो हम और आप यहां तक पहुंचें हैं", "pred_text": "लाज़मी है उन्हीं का मार्गदर्शन पाकर तो हम और आप यहां तक पहुंचे"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932410074-267-f.wav", "duration": 6.1765, "text": "उनकी ठौड़ी पर चोट के निशान मिले और नाक से खून निकल रहा था", "pred_text": "उनकी ठोड़ी पर चोट के निशान मिले और नाक से खून निकल रहा था"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930966808-564-f.wav", "duration": 5.24775, "text": "इससे ही मेटाबोलिक एक्टिविटी और शरीर का विकास प्रभावित होता है", "pred_text": "इससे ही मेटाबॉलिक एक्टिविटी और शरीर का विकास प्रभावित होता है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930927714-574-f.wav", "duration": 5.0155, "text": "आगे सूत जी ने शिव के अनेक रूपों का वर्णन किया है", "pred_text": "आगे सूदजी ने शिवजी के अनेक रूपों का वर्णन किया है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930547237-497-f.wav", "duration": 2.6703125, "text": "एक मामले में मरीज दूसरे देश में चला गया", "pred_text": "एक मामले में मरीज दूसरे देश में चला गया"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930927723-574-f.wav", "duration": 9.2415625, "text": "फलदार व औषधीय पौधे लगाकर महंत समाज में पर्यावरण सरंक्षण का संदेश दे रहे हैं", "pred_text": "फलदार व औषधीय पौधे लगाकर महंत समाज में पर्यावरण संरक्षण का संदेश दे रहे हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424930898401-574-f.wav", "duration": 5.805, "text": "टैंक टॉप की जगह टर्टलनेक वाली ड्रेस ले लेती है", "pred_text": "टैंकटॉप की जगह टर्टल नेक वाली ड्रेस ले लेती है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424932410152-267-f.wav", "duration": 5.41025, "text": "उन्होंने बिल्डरों को जल्द से जल्द प्रोजेक्ट पूरा करने का आदेश दिया है", "pred_text": "उन्होंने बिल्डरों को जल्द से जल्द प्रोजेक्ट पूरा करने का आज निर्देश दिया है"}
# ...
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933456111-312-m.wav", "duration": 4.853, "text": "भारत में सबसे प्रसिद्ध और सबसे प्रतिष्ठित पार्श्व गायकों में से एक", "pred_text": "भारत में सबसे प्रसिद्ध और प्रतिष्ठित पार्श्व गायकों में एक"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933454753-288-m.wav", "duration": 5.2709375, "text": "विशिष्टाद्वैत में ज्ञान की अपेक्षा भक्ति को प्रधान माना गया है", "pred_text": "विशिष्टादैत्व में ज्ञान की अपेक्षा भक्ति को प्रधान माना गया है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933261565-1183-m.wav", "duration": 4.527875, "text": "वो लगातार नगर बदलते हैं जिससे पुलिस उनका पिछा न कर सके", "pred_text": "वो लगातार नगर बदलते हैं जिससे पुलिस उनका पीछा न कर सके"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933481746-288-m.wav", "duration": 5.108375, "text": "पोंगल के दौरान पुरुषों का मंदिर में प्रवेश वर्जित होता है", "pred_text": "पोंगल के दौरान पुरुषों का मंदिर प्रवेश वर्जित होता है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933474121-540-m.wav", "duration": 4.2725, "text": "है तो यह बच्चों के लिये लेकिन बड़ों को भी पसंद आती है", "pred_text": "है तो यह बच्चों के लिए लेकिन बड़ों को भी पसंद आती है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933261639-1183-m.wav", "duration": 6.5480625, "text": "का राजवाड़े कोशकार वामन शिवराम आप्टे आर एन दांडेकर संगीतकार विष्णु नारायण भातखंडे न्याय", "pred_text": "का राजवाणे कोशिकार वामन शिवराम आप्टे आर एन दंडिकार संगीतकार विष्णु नारायण भारतखण्ड न्याय"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933507453-540-m.wav", "duration": 8.4520625, "text": "प्रस्तावित पोर्टोविगो हाईस्पीड रेल लाइन हवाई अड्डे के माध्यम से बनाई जाएगी", "pred_text": "प्रस्तावित पेट्रोबीगो हाईस्पीड रेललाइन हवाई अड़े के माध्यम से बनाई जाएगी"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933456087-312-m.wav", "duration": 4.6904375, "text": "यहाँ पर कपास अनुसंधान केंद्र भी स्थित है", "pred_text": "यहाँ पर कपास अनुसंधान केन्द्र भी स्थित है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933474100-540-m.wav", "duration": 3.6223125, "text": "इस से बाहर वाले क्षेत्र को दिचान कला कहते हैं", "pred_text": "इसे से बाहर वाले क्षेत्र को द्विचानकल कहते हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933474155-540-m.wav", "duration": 4.365375, "text": "वो पूर्व प्रधानमंत्री इंदिरा गांधी के पौत्र हैं", "pred_text": "वे पूर्ण प्रधानमंत्री इंदिरा गांधी का पौत्र हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933456096-312-m.wav", "duration": 6.2461875, "text": "भारत की जनगणना २००१ के अनुसार डेह की आबादी ७५६६ है", "pred_text": "भारत की जनगणना दो हज़ार एक के अनुसार डे की आबादी पचहत्तर सौ छयासठ है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933454664-288-m.wav", "duration": 3.599125, "text": "प्रदान करने के ललए अंगूठे और एक तु", "pred_text": "प्रदान करने के ललय अंगूठे और एक तू"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933471299-312-m.wav", "duration": 7.3375, "text": "रोडीओ काउबॉय का पहनावा शहरी श्रमिक काउबॉयों से बहुत अलग नहीं है", "pred_text": "रोडियो काऊबाओं का पहनावा शहरी श्रमिक काऊबाओं से बहुत अलग नहीं है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933261589-1183-m.wav", "duration": 4.4814375, "text": "पूर्ण ऊंचाई सीधे नीचे जमीन से ऊपर की दूरी के संदर्भ में ऊंचाई", "pred_text": "पुन ऊँचाई सीधे नीचे ज़मीन से ऊपर की दूरी के संदर्भ में ऊँचाई"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933481696-288-m.wav", "duration": 5.78175, "text": "तिब्बत में यह नदी लंगचेन त्संगपो के नाम से जानी जाती है", "pred_text": "तिब्बत में यह नदीलंगचैंत संगपों के नाम से जानी जाती है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933469959-312-m.wav", "duration": 3.1115, "text": "एक वर्ष के बारह मासों के नाम ये हैं", "pred_text": "एक वर्ष के बारह मासों के इनाम ये हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933474126-540-m.wav", "duration": 6.1300625, "text": "प्रसिद्ध फिल्मकार प्रकाश झाइसी विधालय के विधार्थी रह चुके है", "pred_text": "प्रसिद्ध फिल्मकार प्रकाश झाई श्री सिंह विद्यालय के विद्यार्थी रह चुके हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933474125-540-m.wav", "duration": 7.1981875, "text": "इनमें भारतीय तटरक्षक और मित्र देशों के अफसरप्रशिक्षु शामिल हैं", "pred_text": "इनमें भारतीय तटरक्षक और मित्र देशों के अफसर प्रशिक्षु शामिल हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933469994-312-m.wav", "duration": 3.4598125, "text": "यह वृक्ष सभी जीवधारियों का रक्षण करता है", "pred_text": "यह वृक्ष सभी जीवधारियों का रक्षण करता है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933261586-1183-m.wav", "duration": 4.6904375, "text": "एक सैन्य विंग एक राजनीतिक विंग और एक वित्त को बढाने वाला विंग", "pred_text": "एक सैन्य विंग एक राजनीतिक विंग और एक वीथ को बढ़ाने वाला विंग"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933474091-540-m.wav", "duration": 5.0155, "text": "प्रस्तुत घटना को प्रमाणित करनेवाली कोई प्रामाणिक या लिखित सामग्री नहीं मिलती", "pred_text": "प्रस्तुत घटना को प्रमाणित करने वाली कोई प्रमाणिक या लिखित सामग्री नहीं मिलती"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933454712-288-m.wav", "duration": 4.1099375, "text": "विद्यालयों के दलों के लिये रियायत उपलब्ध है", "pred_text": "विद्यालयों के दलों के लिए रियायत उपलब्ध हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933454622-288-m.wav", "duration": 6.1765, "text": "कणाद कृत वैशेषिकसूत्रों में ईश्वर का स्पष्टोल्लेख नहीं हुआ है", "pred_text": "कणाधिकृत वैसे शिख सूत्रों में ईश्वर का स्पष्टोल्येख नहीं हुआ है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933261595-1183-m.wav", "duration": 4.179625, "text": "धारावाहिक में एक आम आदमी भगवानदास की कहानी है", "pred_text": "धारावाहिक में एक आम आदमी भगवान दास की कहानी है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933261616-1183-m.wav", "duration": 3.784875, "text": "जी एस सिंघवी भारत के सर्वोच्च न्यायालय के न्यायाधीश हैं", "pred_text": "जीएस सिंधवी भारत के सर्वोच्च न्यायालय के न्यायाधीश हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933454727-288-m.wav", "duration": 4.2956875, "text": "आपका यह पुत्र कुल का नाश करने वाला होगा", "pred_text": "आपका यह पुत्र कुल का नाश करने वाला होगा"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933261621-1183-m.wav", "duration": 5.596, "text": "माज़े पहले द्वार से बाहर था और शुभ मार्ग पर सबसे अच्छा सुबह तैनात था", "pred_text": "माझे पहले द्वार से बाहर था और शुभ मार्ग पर सबसे अच्छा शुभः तैनात था"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933474119-540-m.wav", "duration": 5.712125, "text": "कभी उन्हें पल्हाव कभी शक देश से आया हुआ बताया जाता है", "pred_text": "कभी उन्हें पल्लुहाओ कभी शक देश से आया हुआ बताया जाता है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933471285-312-m.wav", "duration": 4.4118125, "text": "अस्थियों से अनेक प्रकार की आवश्यक वस्तुएँ बनती हैं", "pred_text": "अस्तियों से अनेक प्रकार की आवश्यक वस्तुएँ बनती हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933471251-312-m.wav", "duration": 6.8034375, "text": "तब पिघले हुए शोधित और विधिवत् निर्मित मिश्र धातु की सिलें ढाल ली जाती हैं", "pred_text": "तब पिछले हुए शोषित और विविध निर्मित मिश्र धातुओं की सीलें डाल ली जाती हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933261626-1183-m.wav", "duration": 2.832875, "text": "इसमें मुख्य भूमिका जया बच्चन ने की है", "pred_text": "इसमें मुख्य भूमिका जया बच्चन ने की है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933454706-288-m.wav", "duration": 5.503125, "text": "अलखिया सम्प्रदाय मध्यकालीन भारत का एक हिंदू संप्रदाय है", "pred_text": "अल्किया संप्रदाय मध्यकालीन भारत का एक हिन्दू संप्रदाय है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933456086-312-m.wav", "duration": 3.5294375, "text": "यह बहुत तेज बीट पर किया जाता है", "pred_text": "यह बहुत तेज बिट पर किया जाता है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933469949-312-m.wav", "duration": 5.03875, "text": "राज्य और प्रजा कि उन पर अपनी रक्छा की आशा", "pred_text": "राज्य और प्रजा के उन पर अपनी रक्षा की आशा"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933261576-1183-m.wav", "duration": 4.3189375, "text": "महाकवि केशव ने अलंकारों को काव्य का अपेक्षित गुण माना है", "pred_text": "महाकवि केशव ने अलंकारों को काव्य का अपेक्षित गुण माना है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933472390-312-m.wav", "duration": 4.922625, "text": "१४ साल की उम्र में उनका परिवार वापस न्यूजीलैंड लौट आया", "pred_text": "चौदह साल की उम्र में उनका परिवार वापस न्यूजीलैंड लौट आया"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933471275-312-m.wav", "duration": 8.5449375, "text": "मंदिर के उत्खनन से पूजापात्र थालियांघड़े खप्पर नाचते हुए पक्षी धूपदान आदि मिले हैं", "pred_text": "मंदिर के उत्खनन से पूजा पात्र थालियांगड़े खप्पर नाचते हुए पंछी धूप दान आदि मिले हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933481723-288-m.wav", "duration": 5.2709375, "text": "इसलिए कर केवल जनता द्वारा सरकार को किया गया भुगतान है", "pred_text": "इसलिए कर केवल जनता द्वारा सरकार को किया गया भुगतान है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933474180-540-m.wav", "duration": 5.340625, "text": "इनका साम्राज्य मध्य प्रदेश के बड़े भूभाग पर फैला हुआ था", "pred_text": "इनका साम्राज्य मध्यप्रदेश के बड़े भूभाग पर फैला हुआ था"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933469964-312-m.wav", "duration": 4.24925, "text": "कुतुबपुर पुनपुन पटना बिहार स्थित एक गाँव है", "pred_text": "कुतुबपुर पुनपुन पटना बिहार स्थित एक गाँव है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933454757-288-m.wav", "duration": 7.3375, "text": "शहर की अनेक मस्जिद मकबर महल और किले पर्यटकों को खासे आकर्षित करते हैं", "pred_text": "शहर की अनेक मस्जिद मकबरमहल और किले पर्यटकों को खासे आकर्षित करते हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933471305-312-m.wav", "duration": 6.269375, "text": "वह जान जाती है की वह साहिल से प्यार करने लगी है", "pred_text": "वह जान जाती है कि वह साहिल से प्यार करने लगी है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933474150-540-m.wav", "duration": 6.4086875, "text": "नवरात्र पर्व के दूसरे दिन माँ ब्रह्मचारिणी की पूजाअर्चना की जाती है", "pred_text": "नवरात्र पर्व के दूसरे दिन मां ब्रह्मचारिणी की पूजा अर्चना की जाती है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933474127-540-m.wav", "duration": 3.483, "text": "पैरों के निशान की जासूसी कार्य में सहायता", "pred_text": "पैरों के निशान की जातूती कार्य में सहायता"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933469919-312-m.wav", "duration": 5.5495625, "text": "तीन ई एफ़ और जी वासयोग्य क्षेत्र में परिक्रमा कर रहे हैं", "pred_text": "तीन ईएफ़ और जी वास्य योग क्षेत्र में प्रक्रिमा कर रहे हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933507457-540-m.wav", "duration": 3.7151875, "text": "पानी का स्तर हर दिन घट रहे हैं", "pred_text": "पानी का अस्तर हर दिन घाट रहे हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933481752-288-m.wav", "duration": 6.083625, "text": "मुख्य कल्पना मानवज्ञान की जीवंत शक्ति और प्रमुख माध्यम होती है", "pred_text": "मुख्य कल्पना मानवविज्ञान की जीवन्त शक्ति और प्रमुख माध्यम होती है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933469923-312-m.wav", "duration": 5.4566875, "text": "विशेषाधिकार और सामंती नियम का संहिता में कोई स्थान नहीं था", "pred_text": "विशेषाधिकार और समानती नियम का संहिता में कोई अस्थास्था नहीं है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933454642-288-m.wav", "duration": 4.6208125, "text": "पर्दा कर ल्यूंगा अपनी आधी साडी मन्ने दिए तू", "pred_text": "परदा कर लूँगा अपनी आँधी साड़ी मंत्रे दिये तू"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933481721-288-m.wav", "duration": 6.4319375, "text": "लुंगी नगिदी क्योंकि एक पेट की चोट की वनडे सीरीज से बाहर हो गए", "pred_text": "लुंगीनगीदी क्योंकि एक पेट की चोट की वनडे सीरीज से बाहर हो गए"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933507454-540-m.wav", "duration": 4.4118125, "text": "वे इसके लिए कार्यशालाएं भी आयोजित करते हैं", "pred_text": "वे इसके लिए कार्याशालाएँ भी आयोजित करते हैं"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933474107-540-m.wav", "duration": 3.6223125, "text": "नर की बिना बालों वाली पूंछ होती है", "pred_text": "नर के बिना बालों वाली पूछ होती है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933481727-288-m.wav", "duration": 5.340625, "text": "रहुघाट पर पन बिजली परियोजना प्रस्तावित की गई है", "pred_text": "रघु घाट पर पनबिजली परियोजना प्रस्तावित की गई है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933454608-288-m.wav", "duration": 5.99075, "text": "विधिक कहावत यह है कि कानून के प्रति अनभिज्ञता कोई बचाव नहीं है", "pred_text": "वैधिक कहावत यह है कि कानून के प्रति अनवैधता कोई बचाव नहीं है"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-hindi/kathbath/hindi/wavs/wavs/844424933456097-312-m.wav", "duration": 6.6409375, "text": "अजीत चंदिला जन्म ०५ दिसंबर १९८३ हरियाणा भारत से एक ऑफ स्पिन गेंदबाज है", "pred_text": "अजीत चाँदिला जन्म चार दिसम्बर एक हज़ार नौ सौ तैंतीस से शून्य भारत से"}
