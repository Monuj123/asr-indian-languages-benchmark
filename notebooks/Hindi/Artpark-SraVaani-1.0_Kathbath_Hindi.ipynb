# %% [markdown]
# # SraVaani-1.0 — Kathbath ASR evaluation (Hindi / Tamil / Telugu / Marathi / Bengali)
#
# Evaluates [`ARTPARK-IISc/SraVaani-1.0`](https://huggingface.co/ARTPARK-IISc/SraVaani-1.0) on the Kathbath test sets, downloaded automatically from the public Vistaar-benchmark mirror:
#
# ```
# https://indicwhisper.objectstore.e2enetworks.net/vistaar_benchmarks/kathbath.zip
# ```
#
# **What this notebook does**
# 1. Downloads + extracts `kathbath.zip` (cached — reruns skip this).
# 2. Locates each language's `test/` folder (`audio/` + `transcript.txt`), indexing audio files recursively to route around nested subfolders.
# 3. Loads SraVaani-1.0 (`trust_remote_code=True`) — **gated**, needs an HF token with accepted terms on the model page.
# 4. Runs inference in batches, printing reference / predicted text and running WER/CER as it goes.
# 5. Checkpoints every sample to a resumable `.jsonl` cache per language, so a Kaggle session timeout doesn't lose progress.
# 6. Writes one CSV per language (`id, reference, prediction, wer, cer`) plus a combined summary CSV.
#
# **Before running:** accept the gated-access terms at https://huggingface.co/ARTPARK-IISc/SraVaani-1.0, then add an HF token as a Kaggle secret named `HF_TOKEN` (Add-ons → Secrets) and enable it for this notebook — or set it directly in the cell below.

# %% [markdown]
# ## 1. Install dependencies

# %%
import os, sys

def _ensure(pkg_import, pip_name=None):
    try:
        __import__(pkg_import)
    except ImportError:
        os.system(f"{sys.executable} -m pip install -q {pip_name or pkg_import}")

for mod, pip_name in [
    ("editdistance", "editdistance"),
    ("soundfile", "soundfile"),
    ("librosa", "librosa"),
    ("tqdm", "tqdm"),
    ("requests", "requests"),
]:
    _ensure(mod, pip_name)

print("Dependencies ready.")
# Out:
# Dependencies ready.

# %% [markdown]
# ## 2. Imports and config

# %%
import gc
import json
import re
import time
import unicodedata
import zipfile
from pathlib import Path

import pandas as pd
import editdistance
import requests
import soundfile as sf
import librosa
import torch
from tqdm.auto import tqdm
from transformers import AutoModel

MODEL_REPO = "ARTPARK-IISc/SraVaani-1.0"
KATHBATH_ZIP_URL = "https://indicwhisper.objectstore.e2enetworks.net/vistaar_benchmarks/kathbath.zip"
TARGET_SR = 16000

# folder-name candidates inside the extracted zip, in case of casing/
# naming variants across mirrors
LANG_DIR_CANDIDATES = {
    "hindi": ["hindi"],
    # "tamil": ["tamil"],
    # "telugu": ["telugu"],
    # "marathi": ["marathi"],
    # "bengali": ["bengali", "bangla"],
}
SPLIT_DIR_CANDIDATES = ["test", "test_known", "test_unknown", "valid"]
AUDIO_EXTS = {".wav", ".m4a", ".mp3", ".flac"}

# %% [markdown]
# ## 3. Set your Hugging Face token
#
# Needed only to load the gated SraVaani-1.0 model — the Kathbath zip download needs no token.

# %%
# Option A: paste your token directly (quickest for a one-off Kaggle run)
# os.environ["HF_TOKEN"] = "hf_xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx"

# Option B: Kaggle secret named HF_TOKEN (Add-ons -> Secrets), picked up automatically below

def get_hf_token():
    token = os.environ.get("HF_TOKEN")
    if token:
        return token
    try:
        from kaggle_secrets import UserSecretsClient
        token = UserSecretsClient().get_secret("HF_TOKEN")
        if token:
            return token
    except Exception:
        pass
    raise RuntimeError(
        "No HF token found. Either set os.environ['HF_TOKEN'] = 'hf_...' before running, "
        "or add it as a Kaggle secret named HF_TOKEN (Add-ons -> Secrets) and enable it for this notebook. "
        "(Needed to load the gated SraVaani-1.0 model — the Kathbath download itself needs no token.)"
    )

# %% [markdown]
# ## 4. Download + extract Kathbath (Vistaar mirror)

# %%
# ================================================================ #
# Download + extract kathbath.zip (cached)
# ================================================================ #
def download_kathbath(dest_root: Path) -> Path:
    dest_root.mkdir(parents=True, exist_ok=True)
    zip_path = dest_root / "kathbath.zip"
    extract_marker = dest_root / "kathbath" / ".extracted_ok"
    extract_dir = dest_root / "kathbath"

    if extract_marker.exists():
        print(f"Kathbath already downloaded + extracted at {extract_dir}")
        return extract_dir

    if not zip_path.exists() or zip_path.stat().st_size == 0:
        print(f"Downloading kathbath.zip from {KATHBATH_ZIP_URL} ...")
        with requests.get(KATHBATH_ZIP_URL, stream=True, timeout=60) as r:
            r.raise_for_status()
            total = int(r.headers.get("content-length", 0))
            with open(zip_path, "wb") as f, tqdm(
                total=total, unit="B", unit_scale=True, desc="kathbath.zip"
            ) as pbar:
                for chunk in r.iter_content(chunk_size=1024 * 1024):
                    if chunk:
                        f.write(chunk)
                        pbar.update(len(chunk))
    else:
        print(f"Found existing {zip_path}, skipping download.")

    print(f"Extracting to {extract_dir} ...")
    extract_dir.mkdir(parents=True, exist_ok=True)
    with zipfile.ZipFile(zip_path, "r") as zf:
        members = zf.infolist()
        for m in tqdm(members, desc="extracting", unit="file"):
            zf.extract(m, extract_dir)

    extract_marker.touch()
    print("Extraction complete.")
    return extract_dir

# %% [markdown]
# ## 5. Locate each language's test split and match audio to transcripts

# %%
def find_first_existing(base: Path, candidates):
    for c in candidates:
        p = base / c
        if p.exists():
            return p
    # fuzzy fallback: case-insensitive scan of immediate children
    if base.exists():
        lower_map = {p.name.lower(): p for p in base.iterdir() if p.is_dir()}
        for c in candidates:
            if c.lower() in lower_map:
                return lower_map[c.lower()]
    return None


def locate_language_dir(kathbath_root: Path, lang: str) -> Path:
    # the zip extracts with an extra nested "kathbath/kathbath/<lang>/" layout
    # on some mirrors, and a flat "<lang>/" layout on others -- handle both.
    search_roots = [kathbath_root, kathbath_root / "kathbath"]
    for root in search_roots:
        lang_dir = find_first_existing(root, LANG_DIR_CANDIDATES[lang])
        if lang_dir is not None:
            return lang_dir
    raise FileNotFoundError(
        f"Could not locate a folder for '{lang}' under {kathbath_root}. "
        f"Check the extracted folder layout with `!find {kathbath_root} -maxdepth 4`."
    )


# manifest.json is a NeMo-style JSONL file: one JSON object per line, each
# with (at least) "audio_filepath" and "text" -- e.g.
#   {"audio_filepath": "audio/844424933726456-...-f.wav", "duration": 4.2, "text": "..."}
MANIFEST_NAME_CANDIDATES = [
    "manifest.json",
    "test_manifest.json",
    "test_known_manifest.json",
    "test_unknown_manifest.json",
    "valid_manifest.json",
]


def find_manifest_files(lang_dir: Path):
    """Return every manifest-like JSONL file for this language. Prefers an
    explicit test/known/unknown/valid manifest if several exist; otherwise
    falls back to whatever *manifest*.json files are present (recursively,
    in case they sit inside a test/ or manifests/ subfolder)."""
    found = []
    for name in MANIFEST_NAME_CANDIDATES:
        p = lang_dir / name
        if p.exists():
            found.append(p)
    if found:
        return found
    # recursive fallback: any file whose name contains "manifest" and ends in .json
    found = sorted(lang_dir.rglob("*manifest*.json"))
    if found:
        return found
    raise FileNotFoundError(
        f"No manifest.json-style file found under {lang_dir}. "
        f"Check the folder layout with `!find {lang_dir} -maxdepth 3`."
    )


def resolve_audio_path(audio_filepath: str, manifest_path: Path, lang_dir: Path, kathbath_root: Path):
    """audio_filepath inside the manifest may be absolute, relative to the
    manifest's own folder, relative to the language folder, or relative to
    the kathbath root -- try each in turn, then fall back to a recursive
    filename search under the language folder."""
    candidates = [
        Path(audio_filepath),
        manifest_path.parent / audio_filepath,
        lang_dir / audio_filepath,
        kathbath_root / audio_filepath,
    ]
    for c in candidates:
        if c.exists():
            return c

    # last resort: search for a file with this basename anywhere under lang_dir
    target_name = Path(audio_filepath).name
    for p in lang_dir.rglob(target_name):
        return p
    return None


def load_kathbath_lang(kathbath_root: Path, lang: str, max_samples: int = -1):
    lang_dir = locate_language_dir(kathbath_root, lang)
    print(f"  -> language folder for {lang}: {lang_dir}")
    manifest_paths = find_manifest_files(lang_dir)
    print(f"  -> manifest file(s): {[str(p) for p in manifest_paths]}")

    rows = []
    n_missing_audio = 0
    for manifest_path in manifest_paths:
        with open(manifest_path, "r", encoding="utf-8") as f:
            for line_no, line in enumerate(f):
                line = line.strip()
                if not line:
                    continue
                try:
                    entry = json.loads(line)
                except json.JSONDecodeError:
                    continue

                audio_filepath = entry.get("audio_filepath") or entry.get("audio_path")
                text = entry.get("text", "")
                if not audio_filepath:
                    continue

                audio_path = resolve_audio_path(audio_filepath, manifest_path, lang_dir, kathbath_root)
                if audio_path is None:
                    n_missing_audio += 1
                    continue

                utt_id = entry.get("id") or Path(audio_filepath).stem
                # disambiguate ids across multiple manifests (e.g. test_known + test_unknown)
                utt_id = f"{manifest_path.stem}:{utt_id}"

                rows.append({"id": utt_id, "audio_path": str(audio_path), "text": str(text).strip()})

    if n_missing_audio:
        print(f"  ! {n_missing_audio} manifest entries had an audio file that could not be resolved on disk")

    if max_samples and max_samples > 0:
        rows = rows[:max_samples]

    print(f"  -> {len(rows)} (audio, text) pairs loaded for {lang}")
    return rows

# %% [markdown]
# ## 6. Text normalization + WER / CER metrics

# %%
# ================================================================ #
# Text normalization + metrics (mirrors editdistance-based WER/CER
# methodology used elsewhere in this project)
# ================================================================ #
_PUNCT_RE = re.compile(r"[^\w\s\u0900-\u0DFF]", flags=re.UNICODE)


def normalize_text(text: str) -> str:
    if text is None:
        return ""
    text = unicodedata.normalize("NFC", str(text))
    text = _PUNCT_RE.sub(" ", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text


def wer(ref: str, hyp: str) -> float:
    ref_words = ref.split()
    hyp_words = hyp.split()
    if len(ref_words) == 0:
        return 0.0 if len(hyp_words) == 0 else 1.0
    return editdistance.eval(ref_words, hyp_words) / len(ref_words)


def cer(ref: str, hyp: str) -> float:
    ref_chars = ref.replace(" ", "")
    hyp_chars = hyp.replace(" ", "")
    if len(ref_chars) == 0:
        return 0.0 if len(hyp_chars) == 0 else 1.0
    return editdistance.eval(list(ref_chars), list(hyp_chars)) / len(ref_chars)

# %% [markdown]
# ## 7. Load the SraVaani-1.0 model

# %%
def load_model(hf_token: str, device: str):
    print(f"Loading {MODEL_REPO} on {device} ...")
    model = AutoModel.from_pretrained(
        MODEL_REPO, trust_remote_code=True, token=hf_token
    ).to(device).eval()
    print("Model loaded.")
    return model


def audio_to_temp_wav(audio_path: str, tmp_dir: Path, idx: int) -> str:
    """Decodes source audio (wav/m4a/mp3/flac) to a 16kHz mono wav and
    returns its path. Falls back to librosa (ffmpeg-backed) for formats
    soundfile can't read directly, e.g. m4a."""
    out_path = tmp_dir / f"sample_{idx}.wav"
    try:
        wav, sr = sf.read(audio_path, dtype="float32")
        if wav.ndim > 1:
            wav = wav.mean(axis=1)
    except Exception:
        wav, sr = librosa.load(audio_path, sr=None, mono=True)
    if sr != TARGET_SR:
        wav = librosa.resample(wav.astype("float32"), orig_sr=sr, target_sr=TARGET_SR)
    sf.write(out_path, wav, TARGET_SR)
    return str(out_path)

# %% [markdown]
# ## 8. Checkpoint cache (resumable)

# %%
# ================================================================ #
# Checkpoint cache (resumable jsonl, one line per evaluated sample)
# ================================================================ #
def load_cache(cache_path: Path):
    done = {}
    if cache_path.exists():
        with open(cache_path, "r", encoding="utf-8") as f:
            for line in f:
                line = line.strip()
                if not line:
                    continue
                try:
                    row = json.loads(line)
                    done[row["id"]] = row
                except json.JSONDecodeError:
                    continue
    return done


def append_cache(cache_path: Path, row: dict):
    with open(cache_path, "a", encoding="utf-8") as f:
        f.write(json.dumps(row, ensure_ascii=False) + "\n")

# %% [markdown]
# ## 9. Per-language evaluation loop
#
# Prints reference / predicted text and running WER/CER every `print_every` utterances, and appends every result to a `.jsonl` checkpoint so a rerun resumes instead of restarting.

# %%
# ================================================================ #
# Per-language evaluation
# ================================================================ #
def evaluate_language(model, lang, kathbath_root, out_dir, batch_size, max_samples, print_every, device):
    print(f"\n{'=' * 70}\nEvaluating language: {lang.upper()}\n{'=' * 70}")
    rows_meta = load_kathbath_lang(kathbath_root, lang, max_samples)
    n_total = len(rows_meta)
    if n_total == 0:
        print(f"  ! no utterances found for {lang}, skipping")
        return {"language": lang, "n_utterances": 0, "wer": float("nan"), "cer": float("nan")}

    cache_path = out_dir / f"{lang}_checkpoint.jsonl"
    csv_path = out_dir / f"sravaani_kathbath_{lang}_results.csv"
    tmp_dir = out_dir / f"_tmp_wav_{lang}"
    tmp_dir.mkdir(parents=True, exist_ok=True)

    done = load_cache(cache_path)
    if done:
        print(f"  resuming from checkpoint: {len(done)}/{n_total} already done")

    pending = [r for r in rows_meta if r["id"] not in done]

    running_wer_sum, running_cer_sum, running_n = 0.0, 0.0, 0
    for r in done.values():
        running_wer_sum += r["wer"]
        running_cer_sum += r["cer"]
        running_n += 1

    pbar = tqdm(total=n_total, initial=len(done), desc=f"{lang}", unit="utt")

    batch_paths, batch_meta = [], []

    def flush_batch():
        nonlocal running_wer_sum, running_cer_sum, running_n
        if not batch_paths:
            return
        try:
            hyps = model.transcribe(batch_paths, batch_size=len(batch_paths), return_hypotheses=True)
        except TypeError:
            hyps = model.transcribe(batch_paths, return_hypotheses=True)

        for wav_path, meta, hyp in zip(batch_paths, batch_meta, hyps):
            ref_raw = meta["text"]
            pred_raw = hyp.text if hasattr(hyp, "text") else str(hyp)

            ref_norm = normalize_text(ref_raw)
            pred_norm = normalize_text(pred_raw)
            u_wer = wer(ref_norm, pred_norm)
            u_cer = cer(ref_norm, pred_norm)

            row = {
                "id": meta["id"],
                "language": lang,
                "reference": ref_raw,
                "prediction": pred_raw,
                "wer": round(u_wer, 4),
                "cer": round(u_cer, 4),
            }
            append_cache(cache_path, row)
            done[meta["id"]] = row

            running_wer_sum += u_wer
            running_cer_sum += u_cer
            running_n += 1

            if running_n % print_every == 0:
                tqdm.write(
                    f"  [{lang}] #{meta['id']} REF : {ref_raw}\n"
                    f"  [{lang}] #{meta['id']} PRED: {pred_raw}\n"
                    f"  [{lang}] running avg -> WER {running_wer_sum / running_n:.4f} | "
                    f"CER {running_cer_sum / running_n:.4f}  ({running_n}/{n_total})"
                )
            try:
                os.remove(wav_path)
            except OSError:
                pass
            pbar.update(1)
        batch_paths.clear()
        batch_meta.clear()

    for i, meta in enumerate(pending):
        wav_path = audio_to_temp_wav(meta["audio_path"], tmp_dir, i)
        batch_paths.append(wav_path)
        batch_meta.append(meta)
        if len(batch_paths) >= batch_size:
            flush_batch()
    flush_batch()
    pbar.close()

    # final CSV for this language, in original transcript order
    ordered_rows = [done[r["id"]] for r in rows_meta if r["id"] in done]
    df = pd.DataFrame(ordered_rows)
    df.to_csv(csv_path, index=False, encoding="utf-8-sig")

    lang_wer = df["wer"].mean() if len(df) else float("nan")
    lang_cer = df["cer"].mean() if len(df) else float("nan")
    print(f"  DONE {lang}: n={len(df)}  WER={lang_wer:.4f}  CER={lang_cer:.4f}")
    print(f"  -> {csv_path}")

    try:
        tmp_dir.rmdir()
    except OSError:
        pass

    gc.collect()
    if device == "cuda":
        torch.cuda.empty_cache()

    return {"language": lang, "n_utterances": len(df), "wer": lang_wer, "cer": lang_cer}

# %% [markdown]
# ## 10. Run configuration

# %%
LANGUAGES = ["hindi"]
BATCH_SIZE = 8
MAX_SAMPLES = -1       # -1 = full test set; set e.g. 50 for a quick smoke test first
PRINT_EVERY = 20
OUT_DIR = Path("/kaggle/working/sravaani_kathbath_eval")
DATA_DIR = Path("/kaggle/working/kathbath_data")

OUT_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## 11. Download data + load model

# %%
kathbath_root = download_kathbath(DATA_DIR)

hf_token = get_hf_token()
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Device: {device}")

model = load_model(hf_token, device)
# Out:
# Kathbath already downloaded + extracted at /kaggle/working/kathbath_data/kathbath
# Device: cuda
# Loading ARTPARK-IISc/SraVaani-1.0 on cuda ...
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Model loaded.

# %% [markdown]
# ## 12. Run evaluation across all languages

# %%
summary = []
t0 = time.time()
for lang in LANGUAGES:
    result = evaluate_language(
        model, lang, kathbath_root, OUT_DIR,
        batch_size=BATCH_SIZE,
        max_samples=MAX_SAMPLES,
        print_every=PRINT_EVERY,
        device=device,
    )
    summary.append(result)
    pd.DataFrame(summary).to_csv(OUT_DIR / "sravaani_kathbath_summary.csv", index=False)

elapsed = time.time() - t0
print(f"\n{'=' * 70}\nALL LANGUAGES DONE in {elapsed / 60:.1f} min\n{'=' * 70}")
summary_df = pd.DataFrame(summary)
print(summary_df.to_string(index=False))
print(f"\nPer-language CSVs + summary written to: {OUT_DIR}")
summary_df
# Out:
# ======================================================================
# Evaluating language: HINDI
# ======================================================================
#   -> language folder for hindi: /kaggle/working/kathbath_data/kathbath/kathbath/hindi
#   -> manifest file(s): ['/kaggle/working/kathbath_data/kathbath/kathbath/hindi/manifest.json']
#   -> 1929 (audio, text) pairs loaded for hindi
# hindi:   0%|          | 0/1929 [00:00<?, ?utt/s]
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:1787: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters(). (Triggered internally at /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1480.)
#   return forward_call(*args, **kwargs)
#   [hindi] #manifest:844424930708001-153-f REF : चोर स्टेज से ले उड़ा नोटों से भरा हुआ बैग
#   [hindi] #manifest:844424930708001-153-f PRED: चोर स्टेज से ले उड़ा नोटों से भरा हुआ बैग
#   [hindi] running avg -> WER 0.0369 | CER 0.0120  (20/1929)
#   [hindi] #manifest:844424930927636-574-f REF : कई सारे परिवार आज रात अपने प्रियजनों के लिए शोक मनाएंगे
#   [hindi] #manifest:844424930927636-574-f PRED: कई सारे परिवार आज रात अपने प्रियजनों के लिए शोक मनाएंगे
#   [hindi] running avg -> WER 0.0464 | CER 0.0158  (40/1929)
#   [hindi] #manifest:844424930954617-564-f REF : कैंप में झड़प बाद फैली हिंसा से अमरनाथ यात्रा रोकी गई
#   [hindi] #manifest:844424930954617-564-f PRED: कैंप में झड़पबात फैली हिंसा से अमरनाथ यात्रा रोकी गई
#   [hindi] running avg -> WER 0.0520 | CER 0.0173  (60/1929)
#   [hindi] #manifest:844424930547282-497-f REF : यह योजना आत्मनिर्भर भारत आर्थिक पैकेज का हिस्सा है
#   [hindi] #manifest:844424930547282-497-f PRED: यह योजना आत्मनिर्भर भारत आर्थिक पैकेज का हिस्सा है
#   [hindi] running avg -> WER 0.0512 | CER 0.0155  (80/1929)
#   [hindi] #manifest:844424930918838-564-f REF : कोई मोदी का तो कोई राहुल का पोस्टर पहन लेती हैं
#   [hindi] #manifest:844424930918838-564-f PRED: कोई मोदी का तो कोई राउट का पोस्टर पहन लेती हैं
#   [hindi] running avg -> WER 0.0592 | CER 0.0183  (100/1929)
#   [hindi] #manifest:844424930570531-160-f REF : मृतकों की संख्या में इजाफा होने की आशंका है
#   [hindi] #manifest:844424930570531-160-f PRED: मृतकों की संख्या में इजाफा होने की आशंका है
#   [hindi] running avg -> WER 0.0640 | CER 0.0181  (120/1929)
#   [hindi] #manifest:844424930637303-620-f REF : भाजपा विधायक अनंत ओझा को धमकी देने के मामले में गिरफ्तार
#   [hindi] #manifest:844424930637303-620-f PRED: भाजपा विधायक अनंत ओझा को धमकी देने के मामले में गिरफ्तार
#   [hindi] running avg -> WER 0.0690 | CER 0.0193  (140/1929)
#   [hindi] #manifest:844424932410152-267-f REF : उन्होंने बिल्डरों को जल्द से जल्द प्रोजेक्ट पूरा करने का आदेश दिया है
#   [hindi] #manifest:844424932410152-267-f PRED: उन्होंने बिल्डरों को जल्द से जल्द प्रोजेक्ट पूरा करने का आदेश दिया है
#   [hindi] running avg -> WER 0.0697 | CER 0.0191  (160/1929)
#   [hindi] #manifest:844424930954547-564-f REF : इस ड्राइव की वजह से भी आपात स्थिति है
#   [hindi] #manifest:844424930954547-564-f PRED: इस ड्राइव की वजह से भी आपात स्थिति है
#   [hindi] running avg -> WER 0.0685 | CER 0.0197  (180/1929)
#   [hindi] #manifest:844424930627645-153-f REF : सरेआम फायरिंग का मामला सामने आया तो पुलिस हरकत में आई
#   [hindi] #manifest:844424930627645-153-f PRED: सरेआम फायरिंग का मामला सामने आया तो पुलिस हरकत में आई
#   [hindi] running avg -> WER 0.0651 | CER 0.0182  (200/1929)
#   [hindi] #manifest:844424930570578-160-f REF : बंगाल में दशहरा दुर्गा से जुड़ा है तो कर्नाटक में चामुंडी से
#   [hindi] #manifest:844424930570578-160-f PRED: बंगाल में दशहरा दुर्गा से जुड़ा है तो कर्नाटक में चामुंडी से
#   [hindi] running avg -> WER 0.0677 | CER 0.0200  (220/1929)
#   [hindi] #manifest:844424932919628-1202-f REF : घटना की सूचने मिलते ही कई थानों की पुलिस के साथ अधिकारी मौके पर पहुंचे
#   [hindi] #manifest:844424932919628-1202-f PRED: घटना की सूचने मिलते ही कई थानों की पुलिस के साथ अधिकारी मौके पर पहुंचे
#   [hindi] running avg -> WER 0.0674 | CER 0.0201  (240/1929)
#   [hindi] #manifest:844424930898409-574-f REF : दोपहर में सचिन जब ऑफिस पहुंचे तो उन्हें रामपाल नहीं मिला
#   [hindi] #manifest:844424930898409-574-f PRED: दोपहर में सचिन जब ऑफिस पहुंचे तो उन्हें रामपाल नहीं मिला
#   [hindi] running avg -> WER 0.0682 | CER 0.0199  (260/1929)
#   [hindi] #manifest:844424930707954-153-f REF : खेल के मैदान में अनचाहा खंबा हटाने के लिए स्वीकृत किए
#   [hindi] #manifest:844424930707954-153-f PRED: खेल के मैदान में अनचाहा खंभा हटाने के लिए स्वीकृत किए
#   [hindi] running avg -> WER 0.0700 | CER 0.0209  (280/1929)
#   [hindi] #manifest:844424930954537-564-f REF : खास तौर पर दक्षिण और दक्षिणपूर्वी एशिया में भारत की स्थिति मजबूत हुई है
#   [hindi] #manifest:844424930954537-564-f PRED: खासतौर पर दक्षिण और दक्षिण पूर्वी एशिया में भारत की स्थिति मजबूत हुई है
#   [hindi] running avg -> WER 0.0677 | CER 0.0200  (300/1929)
#   [hindi] #manifest:844424932410086-267-f REF : घरेलू जीवन में कलह के आसार बन रहे हैं
#   [hindi] #manifest:844424932410086-267-f PRED: घरेलू जीवन में कला के आसार बन रहे हैं
#   [hindi] running avg -> WER 0.0687 | CER 0.0200  (320/1929)
#   [hindi] #manifest:844424930927720-574-f REF : महिला इवांग शेरपा को प्रधान तथा टिनले शेरपा को संघ का उपप्रधान नियुक्त किया गया
#   [hindi] #manifest:844424930927720-574-f PRED: महिला इवांग शेरपा को प्रधान तथा टिनले शेरपा को संघ का उपधान नियुक्त किया गया
#   [hindi] running avg -> WER 0.0681 | CER 0.0200  (340/1929)
#   [hindi] #manifest:844424932919634-1202-f REF : बढ़ती आबादी के कारण पानी की आवश्यकता बढ़ी है
#   [hindi] #manifest:844424932919634-1202-f PRED: बढ़ती आबादी के कारण पानी की आवश्यकता बढ़ी है
#   [hindi] running avg -> WER 0.0669 | CER 0.0195  (360/1929)
#   [hindi] #manifest:844424930966809-564-f REF : लेकिन कर्मचारी व संसाधनों की संख्या नहीं बढ़ रही है
#   [hindi] #manifest:844424930966809-564-f PRED: लेकिन कर्मचारी व संसाधनों की संख्या नहीं बढ़ रही है
#   [hindi] running avg -> WER 0.0674 | CER 0.0198  (380/1929)
#   [hindi] #manifest:844424930898379-574-f REF : लेकिन भाजपा प्रतिनिधिमंडल ने बिहार को सिर्फ विशेष सहायता देने की मांग रखी
#   [hindi] #manifest:844424930898379-574-f PRED: लेकिन भाजपा प्रतिनिधिमंडल ने बिहार को सिर्फ विशेष सहायता देने की मांग रखी
#   [hindi] running avg -> WER 0.0677 | CER 0.0196  (400/1929)
#   [hindi] #manifest:844424930325521-497-f REF : चर्चित अभिनेता अमन वर्मा ने टेलीविजन अभिनेत्री वंदना लालवानी से दिल्ली में सगाई की है
#   [hindi] #manifest:844424930325521-497-f PRED: चर्चित अभिनेता अमन वर्मा ने टेलीविजन अभिनेत्री वंदना लालवानी से दिल्ली में सगाई की है
#   [hindi] running avg -> WER 0.0673 | CER 0.0195  (420/1929)
#   [hindi] #manifest:844424930570495-160-f REF : एक बेल्ट जो आपके मोबाइल की बैटरी को हर समय चार्ज रखेगी
#   [hindi] #manifest:844424930570495-160-f PRED: एक बिल्ट जो आपके मोबाइल की बैटरी को हर समय चार्ज रखेगी
#   [hindi] running avg -> WER 0.0682 | CER 0.0195  (440/1929)
#   [hindi] #manifest:844424930570568-160-f REF : गांव में बिजली पहुंचने से ग्रामीण बहुत खुश हैं
#   [hindi] #manifest:844424930570568-160-f PRED: गांव में बिजली पहुंचने से ग्रामीण बहुत खुश हैं
#   [hindi] running avg -> WER 0.0677 | CER 0.0198  (460/1929)
#   [hindi] #manifest:844424932919633-1202-f REF : कई राज्यों में क्षतिपूर्ति मामलों के राजनीतीकरण की भी खबरें आई हैं
#   [hindi] #manifest:844424932919633-1202-f PRED: कई राज्यों में क्षतिपूर्ति मामलों के राजनीतिकरण की भी खबरें आई हैं
#   [hindi] running avg -> WER 0.0663 | CER 0.0193  (480/1929)
#   [hindi] #manifest:844424932410072-267-f REF : इससे निपटने के लिए प्रधानमंत्री नरेंद्र मोदी ने कमर कस ली है
#   [hindi] #manifest:844424932410072-267-f PRED: इससे निपटने के लिए प्रधानमंत्री नरेंद्र मोदी ने कमर कस ली है
#   [hindi] running avg -> WER 0.0649 | CER 0.0188  (500/1929)
#   [hindi] #manifest:844424930898378-574-f REF : बता दें कि साध्वी प्रज्ञा सिंह ठाकुर का भाजपा में भारी विरोध है
#   [hindi] #manifest:844424930898378-574-f PRED: बता दें कि साध्वी प्रज्ञा सिंह ठाकुर का भाजपा में भारी विरोध है
#   [hindi] running avg -> WER 0.0652 | CER 0.0187  (520/1929)
#   [hindi] #manifest:844424930954620-564-f REF : कोरोना के कारण सोशल डिस्टेसिंग का कड़ाई से पालन होगा
#   [hindi] #manifest:844424930954620-564-f PRED: कोरोना के कारण सोशल डिस्टेंसिंग का कड़ाई से पालन होगा
#   [hindi] running avg -> WER 0.0642 | CER 0.0185  (540/1929)
#   [hindi] #manifest:844424930759102-153-f REF : अब तीन साल बाद फिर से विधायक निधि को बढ़ाने की चर्चा चल पड़ी है
#   [hindi] #manifest:844424930759102-153-f PRED: अब तीन साल बाद फिर से विधायक निधि को बढ़ाने की चर्चा चल पड़ी है
#   [hindi] running avg -> WER 0.0649 | CER 0.0188  (560/1929)
#   [hindi] #manifest:844424930918891-564-f REF : यह कई मिशनों को अंजाम देने में सक्षम है
#   [hindi] #manifest:844424930918891-564-f PRED: यह कई मिशनों को अंजाम देने में सक्षम है
#   [hindi] running avg -> WER 0.0649 | CER 0.0185  (580/1929)
#   [hindi] #manifest:844424930898431-574-f REF : जानकारी के अनुसार इन योजनाओं को बजट आने के एकदम बाद लागू कर दिया जाएगा
#   [hindi] #manifest:844424930898431-574-f PRED: जानकारी के अनुसार इन योजनाओं को बजट आने के एकदम बाद लागू कर दिया जाएगा
#   [hindi] running avg -> WER 0.0654 | CER 0.0188  (600/1929)
#   [hindi] #manifest:844424930325467-497-f REF : इन स्कीमों को लागू करने में यहां कोई बिचौलिया नहीं है
#   [hindi] #manifest:844424930325467-497-f PRED: इन स्कीमों को लागू करने में यहां कोई बिचौलिया नहीं है
#   [hindi] running avg -> WER 0.0654 | CER 0.0185  (620/1929)
#   [hindi] #manifest:844424930927700-574-f REF : साथ ही पीयूष गोयल ने फिल्म की तारीफ की
#   [hindi] #manifest:844424930927700-574-f PRED: साथ ही पीयूष गोयल ने फिल्म की तारीफ की
#   [hindi] running avg -> WER 0.0649 | CER 0.0182  (640/1929)
#   [hindi] #manifest:844424932410089-267-f REF : कंगना ने कहा कि यह फिल्म बॉलिवुड की पारंपरिक लव स्टोरीज़ से बिल्कुल अलग है
#   [hindi] #manifest:844424932410089-267-f PRED: कंगना ने कहा कि यह फिल्म बॉलीवुड की पारंपरिक लव स्टोरीज से बिल्कुल अलग है
#   [hindi] running avg -> WER 0.0663 | CER 0.0185  (660/1929)
#   [hindi] #manifest:844424930634237-620-f REF : वह आरती शुरू होने के थोड़ी देर बाद वहाँ पहुँचे
#   [hindi] #manifest:844424930634237-620-f PRED: वह आरती शुरू होने के थोड़ी देर बाद वहां पहुंचे
#   [hindi] running avg -> WER 0.0666 | CER 0.0191  (680/1929)
#   [hindi] #manifest:844424930927677-574-f REF : इसे तमिलनाडु में फिलहाल लोकसभा की सात सीटें और राज्यसभा की एक सीट मिली है
#   [hindi] #manifest:844424930927677-574-f PRED: इसे तमिलनाडु में फिलहाल लोकसभा की सात सीटें और राज्यसभा की एक सीट मिली है
#   [hindi] running avg -> WER 0.0667 | CER 0.0191  (700/1929)
#   [hindi] #manifest:844424930547217-497-f REF : सलमान खान ने इस बार अपना बर्थडे काफी अनोखे तरीके से मनाया है
#   [hindi] #manifest:844424930547217-497-f PRED: सलमान खान ने इस बार अपना बर्थडे काफी अनोखे तरीके से मनाया है
#   [hindi] running avg -> WER 0.0664 | CER 0.0190  (720/1929)
#   [hindi] #manifest:844424930547229-497-f REF : उरी के बाद इसे पहला इतना बड़ा हमला माना जा रहा है
#   [hindi] #manifest:844424930547229-497-f PRED: उरी के बाद इसे पहला इतना बड़ा हमला माना जा रहा है
#   [hindi] running avg -> WER 0.0672 | CER 0.0196  (740/1929)
#   [hindi] #manifest:844424930966806-564-f REF : मीन का स्वामी गुरु तथा चंद्रमा का संयोग धन का आगमन कराएगा
#   [hindi] #manifest:844424930966806-564-f PRED: मीन का स्वामी गुरु तथा चन्द्रमा का सहयोग धन का आगमन करायेगा
#   [hindi] running avg -> WER 0.0677 | CER 0.0198  (760/1929)
#   [hindi] #manifest:844424932410151-267-f REF : उसकी दो संचालिकाएं भी गिरफ्तार करके कोर्ट में पेश की गईं
#   [hindi] #manifest:844424932410151-267-f PRED: उसकी दो संचालिकाएं भी गिरफ्तार करके कोर्ट में पेश की गईं
#   [hindi] running avg -> WER 0.0684 | CER 0.0202  (780/1929)
#   [hindi] #manifest:844424930898436-574-f REF : वे कई गाड़ियों के काफिले के साथ विकास यात्रा में पहुंचे
#   [hindi] #manifest:844424930898436-574-f PRED: वे कई गाड़िय़ों के काफिले के साथ विकास यात्रा में पहुंचे
#   [hindi] running avg -> WER 0.0684 | CER 0.0202  (800/1929)
#   [hindi] #manifest:844424930621948-620-f REF : सप्ताह के उतर्राध में शुक्र का परिवर्तन सुख भाव में होगा
#   [hindi] #manifest:844424930621948-620-f PRED: सप्ताह के उत्तरार्ध में शुक्र का परिवर्तन सुख भाव में होगा
#   [hindi] running avg -> WER 0.0677 | CER 0.0202  (820/1929)
#   [hindi] #manifest:844424930929591-1190-f REF : राकेश टिकैत एवं उनके साथ के लोगों के साथ पुलिस लाठियां चला रही है
#   [hindi] #manifest:844424930929591-1190-f PRED: राकेश टिकैत एवं उनके साथ के लोगों के साथ पुलिस लाठियां चला रही हैं
#   [hindi] running avg -> WER 0.0669 | CER 0.0200  (840/1929)
#   [hindi] #manifest:844424930898365-574-f REF : हेमा मालिनी ने ट्वीट किया है कि आज अंतरराष्ट्रीय योग दिवस है
#   [hindi] #manifest:844424930898365-574-f PRED: हेमा मालिनी ने ट्वीट किया है कि आज अंतरराष्ट्रीय योग दिवस है
#   [hindi] running avg -> WER 0.0663 | CER 0.0198  (860/1929)
#   [hindi] #manifest:844424930621922-620-f REF : तहसीलदार ने जमीनों की रिपोर्ट तैयार कर कलेक्टर के पास भेज दी है
#   [hindi] #manifest:844424930621922-620-f PRED: तहसीलदार ने जमीनों की रिपोर्ट तैयार कर कलेक्टर के पास भेज दी है
#   [hindi] running avg -> WER 0.0660 | CER 0.0197  (880/1929)
#   [hindi] #manifest:844424932410141-267-f REF : यह विचार समता मंच हरियाणा के प्रधान एवं समाजिक कार्यकत्र्ता देशबंधु ने व्यक्त किए
#   [hindi] #manifest:844424932410141-267-f PRED: यह विचार समता मंच हरियाणा के प्रधान एवं सामाजिक कार्यकर्ता देशभंतू ने व्यक्त किए
#   [hindi] running avg -> WER 0.0657 | CER 0.0195  (900/1929)
#   [hindi] #manifest:844424930759155-153-f REF : एलजी ने मंगलवार को नई दिल्ली में एलसीडी टीवी की नई रेंज पेश की
#   [hindi] #manifest:844424930759155-153-f PRED: एलजी ने मंगलवार को नई दिल्ली में एलसीडी टीवी की नई रेंज पेश की
#   [hindi] running avg -> WER 0.0662 | CER 0.0197  (920/1929)
#   [hindi] #manifest:844424930325530-497-f REF : पाकिस्तानी अदालतों पर टिप्पणी करते उन्होंने कहा किअफसोस है कि यह कहना पड़ता है
#   [hindi] #manifest:844424930325530-497-f PRED: पाकिस्तानी अदालतों पर टिप्पणी करते उन्होंने कहा कि अफसोस है कि यह कहना पड़ता है
#   [hindi] running avg -> WER 0.0665 | CER 0.0198  (940/1929)
#   [hindi] #manifest:844424932410148-267-f REF : इसी लीक पर आज के ज्यादातर हिंदी फिल्मकार चल रहे हैं
#   [hindi] #manifest:844424932410148-267-f PRED: इसी लीग पर आज के ज्यादातर हिंदी फिल्मकार चल रहे हैं
#   [hindi] running avg -> WER 0.0665 | CER 0.0199  (960/1929)
#   [hindi] #manifest:844424932314901-730-m REF : अब चुनाव के समय वोट बटोरने के लिए कार्यकर्ता याद आ रहे हैं
#   [hindi] #manifest:844424932314901-730-m PRED: अब चुनाव के समय वोट बटोरने के लिए कार्यकर्ता याद आ रहे हैं
#   [hindi] running avg -> WER 0.0671 | CER 0.0203  (980/1929)
#   [hindi] #manifest:844424930324598-536-m REF : भारत दुनिया का तीसरा सबसे बड़ा अंडा उत्पादक है
#   [hindi] #manifest:844424930324598-536-m PRED: भारत दुनिया का तीसरा सबसे बड़ा अंडा उत्पादक है
#   [hindi] running avg -> WER 0.0668 | CER 0.0202  (1000/1929)
#   [hindi] #manifest:844424932406217-532-m REF : फिलहाल इस मुद्दे पर कैंप में बड़े स्तर पर चर्चा जारी है
#   [hindi] #manifest:844424932406217-532-m PRED: फिलहाल इस मुद्दे पर कैम्प में बड़े स्तर पर चर्चा जारी है
#   [hindi] running avg -> WER 0.0672 | CER 0.0208  (1020/1929)
#   [hindi] #manifest:844424932563140-769-m REF : आज हम आपको विवस्वान सूर्य मंदिर के दर्शन करा रहे हैं
#   [hindi] #manifest:844424932563140-769-m PRED: आज हम आपको विविश्वान सूर्य मंदिर के दर्शन करवा रहे हैं
#   [hindi] running avg -> WER 0.0673 | CER 0.0208  (1040/1929)
#   [hindi] #manifest:844424932563113-769-m REF : पालोक बसु उन्हें समय देते हुए नेक्स्ट केस की सुनवाई पर आ गए
#   [hindi] #manifest:844424932563113-769-m PRED: पालोक बसु उन्हें समय देते हुए नेक्स्ट केस की सुनवाई पर आ गए
#   [hindi] running avg -> WER 0.0666 | CER 0.0207  (1060/1929)
#   [hindi] #manifest:844424930324604-536-m REF : आखिरकार कभी न कभी तो समझौता होना ही है
#   [hindi] #manifest:844424930324604-536-m PRED: आखिरकार कभी न कभी तो समझौता होना ही है
#   [hindi] running avg -> WER 0.0666 | CER 0.0207  (1080/1929)
#   [hindi] #manifest:844424930331291-536-m REF : वे लंबे समय तक बीबीसी में अपनी सेवाएं दे चुके हैं
#   [hindi] #manifest:844424930331291-536-m PRED: वे लंबे समय तक बीबीसी में अपनी सेवाएं दे चुके हैं
#   [hindi] running avg -> WER 0.0658 | CER 0.0206  (1100/1929)
#   [hindi] #manifest:844424932406183-532-m REF : ये सभी लोग कोरोना संक्रमित व्यक्तियों के प्राथमिक संपर्क के कारण पॉजिटिव निकले हैं
#   [hindi] #manifest:844424932406183-532-m PRED: ये सभी लोग कोरोना संक्रमित व्यक्तियों के प्राथमिक संपर्क के कारण पॉजिटिव निकले हैं
#   [hindi] running avg -> WER 0.0654 | CER 0.0204  (1120/1929)
#   [hindi] #manifest:844424930324591-536-m REF : मनसे के विवेक भोईर ने भी मनसे पार्टी में अपनी एक पहचान रखते है
#   [hindi] #manifest:844424930324591-536-m PRED: मनसे के विवेक भोहिर ने भी मनसे पार्टी में अपनी एक पहचान रखते हैं
#   [hindi] running avg -> WER 0.0652 | CER 0.0204  (1140/1929)
#   [hindi] #manifest:844424932406221-532-m REF : हालांकि शासन ने अब तक रिपोर्ट को सार्वजनिक नहीं किया है
#   [hindi] #manifest:844424932406221-532-m PRED: हालांकि शासन ने अब तक रिपोर्ट को सार्वजनिक नहीं किया है
#   [hindi] running avg -> WER 0.0655 | CER 0.0205  (1160/1929)
#   [hindi] #manifest:844424930324580-536-m REF : फैन्स आधिकारिक टिकट वेबसाइट जूंगा पर ऑनलाइन टिकट हासिल कर सकते हैं
#   [hindi] #manifest:844424930324580-536-m PRED: फैन्स आधिकारिक टिकट वेबसाइट जूंगा पर ऑनलाइन टिकट हासिल कर सकते हैं
#   [hindi] running avg -> WER 0.0649 | CER 0.0204  (1180/1929)
#   [hindi] #manifest:844424932406072-866-m REF : उन्होंने लगता है कि बीमारी से तंग आकर जगराम ने अपनी जान दे दी
#   [hindi] #manifest:844424932406072-866-m PRED: उन्होंने लगता है कि बीमारी से तंग आकर जगराम ने अपनी जान दे दी
#   [hindi] running avg -> WER 0.0646 | CER 0.0203  (1200/1929)
#   [hindi] #manifest:844424930324627-536-m REF : तय हुआ कि भरद्वाज इन्द्र से रोग दूर करने की जानकारी करें
#   [hindi] #manifest:844424930324627-536-m PRED: तय हुआ कि भरद्वाज इंद्र से रोग दूर करने की जानकारी करें
#   [hindi] running avg -> WER 0.0645 | CER 0.0202  (1220/1929)
#   [hindi] #manifest:844424932314894-730-m REF : हालांकि कारोबारियों के पास ऑनलाइन एडवांस टैक्स भरने का विकल्प है
#   [hindi] #manifest:844424932314894-730-m PRED: हालांकि कारोबारियों के पास ऑनलाइन एडवांस टैक्स भरने का विकल्प है
#   [hindi] running avg -> WER 0.0640 | CER 0.0200  (1240/1929)
#   [hindi] #manifest:844424932563153-769-m REF : इससे पहले गृहमंत्री सिंह के आवास पर मीटिंग हुई
#   [hindi] #manifest:844424932563153-769-m PRED: इससे पहले गृहमंत्री सिंह के आवास पर मीटिंग हुई
#   [hindi] running avg -> WER 0.0640 | CER 0.0200  (1260/1929)
#   [hindi] #manifest:844424932406160-532-m REF : पर्यटकों को गुजरात दौरे के दौरान लॉर्ड्स होटल्स एंड रिसॉर्ट्स की सुविधा दी जाती है
#   [hindi] #manifest:844424932406160-532-m PRED: पर्यटकों को गुजरात दौरे के दौरान लाइट्स होटल्स एंड रिसॉर्ट्स की सुविधा दी जाती है
#   [hindi] running avg -> WER 0.0643 | CER 0.0202  (1280/1929)
#   [hindi] #manifest:844424932314925-730-m REF : इंडिया के एक के बाद एक विकेट गिर रहे थे
#   [hindi] #manifest:844424932314925-730-m PRED: इंडिया के एक के बाद एक विकेट गिर रहे थे
#   [hindi] running avg -> WER 0.0637 | CER 0.0201  (1300/1929)
#   [hindi] #manifest:844424932406156-532-m REF : जब आप संदेश लिखने के बाद आपको अपने वीडियो गैलरी से वीडियो चुनना है
#   [hindi] #manifest:844424932406156-532-m PRED: जब आप संदेश लिखने के बाद आपको अपनी वीडियो गैलरी से वीडियो चुनना है
#   [hindi] running avg -> WER 0.0640 | CER 0.0201  (1320/1929)
#   [hindi] #manifest:844424930331283-536-m REF : रक्षा मंत्री मनोहर पर्रिकर भी ट्विटर पर ज्यादा सक्रिय नहीं हैं
#   [hindi] #manifest:844424930331283-536-m PRED: रक्षा मंत्री मनोहर पर्रिकर भी ट्विटर पर ज्यादा सक्रिय नहीं है
#   [hindi] running avg -> WER 0.0637 | CER 0.0200  (1340/1929)
#   [hindi] #manifest:844424932563083-769-m REF : विभाग के अधिकारियों ने उस कनेक्शन को बीते दिन ठीक कर दिया
#   [hindi] #manifest:844424932563083-769-m PRED: विभाग के कर्मचारियों ने उस कनेक्शन को बीते दिन ठीक कर दिया
#   [hindi] running avg -> WER 0.0634 | CER 0.0200  (1360/1929)
#   [hindi] #manifest:844424931190261-526-m REF : वैसे बॉलीवुड हस्तियों के बीच इस फिल्म को काफी पसंद किया जा रहा है
#   [hindi] #manifest:844424931190261-526-m PRED: वैसे बॉलीवुड हस्तियों के बीच इस फिल्म को काफी पसंद किया जा रहा है
#   [hindi] running avg -> WER 0.0633 | CER 0.0200  (1380/1929)
#   [hindi] #manifest:844424930331319-536-m REF : प्रार्थना करने से दिल से खुशी महसूस होती है
#   [hindi] #manifest:844424930331319-536-m PRED: प्रार्थना करने से दिल से खुशी महसूस होती है
#   [hindi] running avg -> WER 0.0632 | CER 0.0200  (1400/1929)
#   [hindi] #manifest:844424932314891-730-m REF : मेहनत के बाद भी नतीजे फेवर में नहीं रहेंगे
#   [hindi] #manifest:844424932314891-730-m PRED: मेहनत के बाद भी नतीजे फेवर में नहीं रहेंगे
#   [hindi] running avg -> WER 0.0640 | CER 0.0207  (1420/1929)
#   [hindi] #manifest:844424932563144-769-m REF : अब वे सरस्वती समाज से भी जुडे हुए है
#   [hindi] #manifest:844424932563144-769-m PRED: अब वे सरस्वती समाज से भी जुड़े हुए हैं
#   [hindi] running avg -> WER 0.0646 | CER 0.0210  (1440/1929)
#   [hindi] #manifest:844424933456127-312-m REF : वर्तमान में कुल ५० संपर्क क्रांति गाड़ियां उपलब्ध हैं
#   [hindi] #manifest:844424933456127-312-m PRED: वर्तमान में कुल पचास संपर्क क्रांति गाड़ियाँ उपलब्ध हैं
#   [hindi] running avg -> WER 0.0649 | CER 0.0212  (1460/1929)
#   [hindi] #manifest:844424933456113-312-m REF : उन्के पुरस्कारो ने उन्हे साख और स्वतनत्र जीने के लिये पैसे सुसज्जित किये
#   [hindi] #manifest:844424933456113-312-m PRED: उनके पुरस्कारों ने शाक और स्वतंत्र जीने के लिए पैसे सुसज्जित किए
#   [hindi] running avg -> WER 0.0661 | CER 0.0215  (1480/1929)
#   [hindi] #manifest:844424933474152-540-m REF : इस नाम क़ो बराबर पढ़ने से भगवान् की कृपा होती है
#   [hindi] #manifest:844424933474152-540-m PRED: इस नाम को बराबर पड़ने से भगवान की कृपा होती है
#   [hindi] running avg -> WER 0.0677 | CER 0.0223  (1500/1929)
#   [hindi] #manifest:844424933454624-288-m REF : नाम वह धागा है जो निरंजन के साथ सम्पर्क या सम्बन्ध स्थापित करता है
#   [hindi] #manifest:844424933454624-288-m PRED: नाम वह धागा है जो निरंजन के साथ संपर्क या संबंध स्थापित करता है
#   [hindi] running avg -> WER 0.0692 | CER 0.0231  (1520/1929)
#   [hindi] #manifest:844424933474098-540-m REF : राजा घोड़े से कूदे और उस सिंह की तलाश करने लगे
#   [hindi] #manifest:844424933474098-540-m PRED: राजा घोड़े से कूदे अरसिंह की तलाश करने लगे
#   [hindi] running avg -> WER 0.0703 | CER 0.0236  (1540/1929)
#   [hindi] #manifest:844424933454626-288-m REF : वह राजा हिरण्य धनु नामक निषाद के पुत्र थे
#   [hindi] #manifest:844424933454626-288-m PRED: वह राजा हिरण्य धनु नामक निषाद के पुत्र थे
#   [hindi] running avg -> WER 0.0719 | CER 0.0243  (1560/1929)
#   [hindi] #manifest:844424933471261-312-m REF : वे दोनों दंडित होकर अमर हो जाना चाहते हैं
#   [hindi] #manifest:844424933471261-312-m PRED: वे दोनों दंडित होकर अमर हो जाना चाहते हैं
#   [hindi] running avg -> WER 0.0733 | CER 0.0249  (1580/1929)
#   [hindi] #manifest:844424933454704-288-m REF : इसके बाद इस समुदाय की बिजली और पानी की आपूर्ति काट दी गयी
#   [hindi] #manifest:844424933454704-288-m PRED: इसके बाद इस समुदाय की बिजली और पानी की आपूर्ति काट दी गई
#   [hindi] running avg -> WER 0.0747 | CER 0.0252  (1600/1929)
#   [hindi] #manifest:844424933454648-288-m REF : यहां जन्मास्टमी और होली पर भव्य कार्यक्रम आयोजित होते हैं
#   [hindi] #manifest:844424933454648-288-m PRED: यहाँ जन्माष्टमी और होली पर भव्य कार्यक्रम आयोजित होते हैं
#   [hindi] running avg -> WER 0.0757 | CER 0.0257  (1620/1929)
#   [hindi] #manifest:844424933474143-540-m REF : आमतौर पर मृत रोमनों को दफ़नाने के स्थान पर उनका दाह संस्कार किया जाता था
#   [hindi] #manifest:844424933474143-540-m PRED: आमतौर पर मृतरामणों को दफ़नाने के स्थान पर उनका दाह संस्कार किया जाता था
#   [hindi] running avg -> WER 0.0764 | CER 0.0262  (1640/1929)
#   [hindi] #manifest:844424933474156-540-m REF : बाँस गीत के गायक मुख्यत राऊत या अहीर जाति के लोग हैं
#   [hindi] #manifest:844424933474156-540-m PRED: बांस गीत का गायक मुख्य राउत या बाहिर जाति के लोग हैं
#   [hindi] running avg -> WER 0.0771 | CER 0.0264  (1660/1929)
#   [hindi] #manifest:844424933474146-540-m REF : कोलकाता पत्तन में एक आधिनिक कम्प्यूटारीकृत कंटेनर टर्मिनल भी है
#   [hindi] #manifest:844424933474146-540-m PRED: कोलकाता पत्तन में एक आधुनिक कंप्यूटरीकृति कंटेनर टर्मिनल भी है
#   [hindi] running avg -> WER 0.0778 | CER 0.0265  (1680/1929)
#   [hindi] #manifest:844424933469999-312-m REF : प्रसिद्ध मदन कामदेव गुवाहाटी से ३० कि मी १९ मील दूर है
#   [hindi] #manifest:844424933469999-312-m PRED: प्रसिद्ध मदन कामदेव गुहाटी से तीस किमी उन्नीस मील दूर है
#   [hindi] running avg -> WER 0.0783 | CER 0.0269  (1700/1929)
#   [hindi] #manifest:844424933261647-1183-m REF : विश्व में सर्वाधिक लोग क्रिश्चियनईसाई रिलिजन को मानते हैं
#   [hindi] #manifest:844424933261647-1183-m PRED: विश्व में सर्वाधिक लोग क्रिश्चियन ईसाई रिलीजन को मानते हैं
#   [hindi] running avg -> WER 0.0793 | CER 0.0272  (1720/1929)
#   [hindi] #manifest:844424933469954-312-m REF : वह कुछ दिनों वहीं जंगल में एकांतवास में रहे
#   [hindi] #manifest:844424933469954-312-m PRED: वह कुछ दिनों वहीं जंगल में एकांतवास में रहे
#   [hindi] running avg -> WER 0.0797 | CER 0.0271  (1740/1929)
#   [hindi] #manifest:844424933454765-288-m REF : दीर्घायु व्यक्ति के लिए वह आस्थगित जीवन भृति दी जाए जिसमें मृत्युपरांत कुछ न मिले
#   [hindi] #manifest:844424933454765-288-m PRED: दीर्घायु व्यक्ति के लिए वह अस्तगति जीवन वृत्ति दी जाए जिसमें मृत्युप्रांत कुछ न मिले
#   [hindi] running avg -> WER 0.0812 | CER 0.0279  (1760/1929)
#   [hindi] #manifest:844424933261651-1183-m REF : इसका निर्देशन निर्माण और लेखन का कार्य देव आनन्द ने किया है
#   [hindi] #manifest:844424933261651-1183-m PRED: इसका निर्देशन निर्माण और लेखन का कार्य देव आनंद ने किया है
#   [hindi] running avg -> WER 0.0816 | CER 0.0280  (1780/1929)
#   [hindi] #manifest:844424933454617-288-m REF : जब ये आठवीं में पहुंचीं तब इनके पिता दिल्ली चले आये
#   [hindi] #manifest:844424933454617-288-m PRED: जब ये आठवीं में पहुंची तब इनके पिता दिल्ली चले आए
#   [hindi] running avg -> WER 0.0828 | CER 0.0285  (1800/1929)
#   [hindi] #manifest:844424933469917-312-m REF : संगठन के मुखिया को मान्यजन कहा जाता था
#   [hindi] #manifest:844424933469917-312-m PRED: संगठन के मुखिया को मान्यजन कहा जाता था
#   [hindi] running avg -> WER 0.0843 | CER 0.0295  (1820/1929)
#   [hindi] #manifest:844424933261648-1183-m REF : आवश्यकतानुसार एक या इससे अधिक डोल एक साथ भरे जा सकते हैं
#   [hindi] #manifest:844424933261648-1183-m PRED: आवश्यकता अनुसार एक या इससे अधिक डोल एक साथ भरे जा सकते हैं
#   [hindi] running avg -> WER 0.0851 | CER 0.0300  (1840/1929)
#   [hindi] #manifest:844424933454771-288-m REF : जुलाई के दौरान कैलिफोर्निया विश्वविद्यालय लॉस एंजिल्स में फ़िल्मांकन किया गया
#   [hindi] #manifest:844424933454771-288-m PRED: जुलाई के दौरान कैलिफोर्निया विश्वविद्यालय लॉस एंजिल्स में फिल्मांकान किया गया
#   [hindi] running avg -> WER 0.0861 | CER 0.0303  (1860/1929)
#   [hindi] #manifest:844424933261639-1183-m REF : का राजवाड़े कोशकार वामन शिवराम आप्टे आर एन दांडेकर संगीतकार विष्णु नारायण भातखंडे न्याय
#   [hindi] #manifest:844424933261639-1183-m PRED: गारजवाडे कोस्कार वामन शिवराम आपटे आर एन्दांडिकार संगीतकार विष्णुनारायण भातखंडे न्याय
#   [hindi] running avg -> WER 0.0873 | CER 0.0306  (1880/1929)
#   [hindi] #manifest:844424933454727-288-m REF : आपका यह पुत्र कुल का नाश करने वाला होगा
#   [hindi] #manifest:844424933454727-288-m PRED: आपका यह पुत्र कुल का नाश करने वाला होगा
#   [hindi] running avg -> WER 0.0885 | CER 0.0312  (1900/1929)
#   [hindi] #manifest:844424933507457-540-m REF : पानी का स्तर हर दिन घट रहे हैं
#   [hindi] #manifest:844424933507457-540-m PRED: पानी का स्तर हर दिन घट रहे हैं
#   [hindi] running avg -> WER 0.0887 | CER 0.0314  (1920/1929)
#   DONE hindi: n=1929  WER=0.0896  CER=0.0319
#   -> /kaggle/working/sravaani_kathbath_eval/sravaani_kathbath_hindi_results.csv
#
# ======================================================================
# ALL LANGUAGES DONE in 2.2 min
# ======================================================================
# language  n_utterances      wer     cer
#    hindi          1929 0.089595 0.03192
#
# Per-language CSVs + summary written to: /kaggle/working/sravaani_kathbath_eval
#   language  n_utterances       wer      cer
# 0    hindi          1929  0.089595  0.03192

# %% [markdown]
# ## 13. Inspect a results CSV

# %%
# e.g. inspect Hindi results
pd.read_csv(OUT_DIR / "sravaani_kathbath_hindi_results.csv").head(20)
# Out:
#                                  id language  \
# 0   manifest:844424932919645-1202-f    hindi
# 1    manifest:844424932410060-267-f    hindi
# 2    manifest:844424930954560-564-f    hindi
# 3    manifest:844424930627604-153-f    hindi
# 4    manifest:844424930966728-564-f    hindi
# 5    manifest:844424932410065-267-f    hindi
# 6    manifest:844424932574148-221-f    hindi
# 7    manifest:844424930759178-153-f    hindi
# 8   manifest:844424930929569-1190-f    hindi
# 9    manifest:844424930918882-564-f    hindi
# 10   manifest:844424930966776-564-f    hindi
# 11   manifest:844424930898388-574-f    hindi
# 12  manifest:844424932919598-1202-f    hindi
# 13   manifest:844424930927709-574-f    hindi
# 14   manifest:844424930570555-160-f    hindi
# 15   manifest:844424930570589-160-f    hindi
# 16   manifest:844424930918888-564-f    hindi
# 17   manifest:844424930560836-620-f    hindi
# 18   manifest:844424930547215-497-f    hindi
# 19   manifest:844424930708001-153-f    hindi
#
#                                             reference  \
# 0   सुधीर मिश्रा की ये फिल्म लेखक शरत चंद्र चट्टोप...
# 1        खोज कम मांग के लिए इंजन में वेबसाइट पदोन्नति
# 2   ट्रेन लक्ष्मीबाई नगर भी नहीं पहुंचती कि लोगों ...
# 3   नई पॉलिसी के तहत एक्सट्रा चार्ज देकर ज्यादा एफ...
# 4   उन्होंने वन मुख्यालय से प्रस्ताव पर अनुमति प्र...
# 5        उषा ने ऑटो चालक को बताया कि उसे भिंड जाना है
# 6   देश की जनता अपने आप अन्ना की टीम के सवालों का ...
# 7   शासन द्वारा मंजूरी मिलते ही ओपन जेल का निर्माण...
# 8   इसके अलावा गुजरात के अहमदाबाद में आज जगन्नाथ य...
# 9   अभी यह साफ नहीं है कि किरण नई पार्टी बनाएंगे अ...
# 10       लोग रो रहे थे तो कोई उन्हें ढाढस बंधा रहा था
# 11  स्वतंत्रता सेनानी अमरनाथ डोगरा को पुलिस के जवा...
# 12  उन फोटोज में कपिल एक प्यारी सी बच्ची को थामे ह...
# 13      होली के आठ दिन बाद होती है शीतला माता की पूजा
# 14  आस्था के केंद्र इस मंदिर में लोग प्रतिदिन पूजा...
# 15  धोनी ने मैदान पर आते ही आक्रामक अंदाज में बल्ल...
# 16   जिसके लिए उनका देहान्त के बाद तर्पण किया जाता है
# 17  सूर्योदय से पहले उठकर स्नान से निवृत्त होकर पी...
# 18  परिणामस्वरूप लोगों को मतदान के प्रति जागरूक कर...
# 19          चोर स्टेज से ले उड़ा नोटों से भरा हुआ बैग
#
#                                            prediction     wer     cer
# 0   सुधीर मिश्रा की ये फिल्म लेखिक शरदचंद्र चट्टोप...  0.3333  0.0704
# 1        खोज कम मांग के लिए इंजन में वेबसाइट पदोन्नति  0.0000  0.0000
# 2   ट्रेन लक्ष्मीबाई नगर भी नहीं पहुंचती कि लोगों ...  0.0714  0.0339
# 3   नई पॉलिसी के तहत एक्स्ट्रा चार्ज देकर ज्यादा ए...  0.1429  0.0545
# 4   उन्होंने वन मुख्यालय से प्रस्ताव पर अनुमति प्र...  0.0000  0.0000
# 5        उषा ने ऑटो चालक को बताया कि उसे भिंड जाना है  0.0000  0.0000
# 6   देश की जनता अपने आप अन्ना की टीम के सवालों का ...  0.0000  0.0000
# 7   शासन द्वारा मंजूरी मिलते ही ओपन जेल का निर्माण...  0.0000  0.0000
# 8   इसके अलावा गुजरात के अहमदाबाद में आज जगन्नाथ य...  0.0000  0.0000
# 9   अभी यह साफ नहीं है कि किरण नई पार्टी बनाएंगे अ...  0.0000  0.0000
# 10      लोग रो रहे थे तो कोई उन्हें ढांढस बंधा रहा था  0.0909  0.0294
# 11  स्वतंत्रता सेनानी अमरनाथ डोगरा को पुलिस के जवा...  0.0000  0.0000
# 12  उन फोटोज में कपिल एक प्यारी सी बच्ची को थामे ह...  0.0000  0.0000
# 13      होली के आठ दिन बाद होती है शीतला माता की पूजा  0.0000  0.0000
# 14  आस्था के केंद्र इस मंदिर में लोग प्रतिदिन पूजा...  0.0000  0.0000
# 15  धोनी ने मैदान पर आते ही आक्रामक अंदाज में बल्ल...  0.0000  0.0000
# 16    जिसके लिए उनका देहांत के बाद तर्पण किया जाता है  0.1000  0.0513
# 17  सूर्योदय से पहले उठकर स्नान से निवृत्त होकर पी...  0.0000  0.0000
# 18  परिणामस्वरूप लोगों को मतदान के प्रति जागरूक कर...  0.0000  0.0000
# 19          चोर स्टेज से ले उड़ा नोटों से भरा हुआ बैग  0.0000  0.0000
