# %% [markdown]
# # IndicWhisper Evaluation on Kathbath-Hindi
# ### Accelerator = GPU T4

# %% [markdown]
# # Cell 1: Install dependencies

# %%
# !pip install editdistance -q
# !pip install joblib tqdm librosa soundfile indicnlp indic-nlp-library -q
# !pip install git+https://github.com/anoopkunchukuttan/indic_nlp_library.git -q
# !pip install git+https://github.com/huggingface/transformers -q
# !pip install git+https://github.com/huggingface/datasets -q
# !pip install evaluate accelerate -q
# !sudo apt install ffmpeg -y -q
print("All dependencies installed!")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 53.0 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 6.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 516.0/516.0 kB 9.1 MB/s eta 0:00:00ta 0:00:01
#   Building wheel for transformers (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for datasets (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 1.9 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 87.0 MB/s eta 0:00:00:00:0100:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cudf-cu12 26.2.1 requires numba-cuda[cu12]<0.23.0,>=0.22.2, but you have numba-cuda 0.30.2 which is incompatible.
# Reading package lists...
# Building dependency tree...
# Reading state information...
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 141 not upgraded.
# All dependencies installed!

# %%
from huggingface_hub import login

hf_token = "your_token_here"

login(token=hf_token)
print("Successfully logged into Hugging Face Hub!")
# Out:
# Successfully logged into Hugging Face Hub!

# %% [markdown]
# # Cell 2: Clone vistaar repo

# %%
import os

if not os.path.exists('/kaggle/working/vistaar'):
    # !git clone https://github.com/AI4Bharat/vistaar.git /kaggle/working/vistaar
    print("Cloned!")
else:
    print("Already cloned, skipping.")

# %cd /kaggle/working/vistaar
# Out:
# Cloning into '/kaggle/working/vistaar'...
# remote: Enumerating objects: 166, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 166 (delta 10), reused 0 (delta 0), pack-reused 145 (from 1)
# Receiving objects: 100% (166/166), 61.78 KiB | 2.21 MiB/s, done.
# Resolving deltas: 100% (95/95), done.
# Cloned!
# /kaggle/working/vistaar

# %% [markdown]
# # Cell 3: Write fixed evaluation.py

# %%
fixed_eval = '''
import argparse
from transformers import pipeline
import editdistance
from joblib import Parallel, delayed
from tqdm import tqdm
import json
import soundfile as sf
from torch.utils.data import Dataset
from indicnlp.normalize.indic_normalize import IndicNormalizerFactory
import os
import string
import re
import time
import torch

from transformers import (
    AutoConfig,
    AutoFeatureExtractor,
    AutoModelForSpeechSeq2Seq,
    AutoProcessor,
    AutoTokenizer,
)

lang_to_code = {
    "hindi": "hi",
    "sanskrit": "sa",
    "bengali": "bn",
    "tamil": "ta",
    "telugu": "te",
    "gujarati": "gu",
    "kannada": "kn",
    "malayalam": "ml",
    "marathi": "mr",
    "odia": "or",
    "punjabi": "pa",
    "urdu": "ur",
}


def normalize_sentence(sentence, lang_code):
    factory = IndicNormalizerFactory()
    normalizer = factory.get_normalizer(lang_code)
    return normalizer.normalize(sentence)


def compute_cer(refs, hyps):
    """Character Error Rate using editdistance (no rapidfuzz dependency)"""
    total_chars = 0
    total_edits = 0
    for r, h in zip(refs, hyps):
        total_edits += editdistance.eval(r, h)
        total_chars += len(r)
    return total_edits / total_chars if total_chars > 0 else 0.0


def compute_wer(refs, hyps):
    """Word Error Rate using editdistance (no rapidfuzz dependency)"""
    total_words = 0
    total_edits = 0
    for r, h in zip(refs, hyps):
        r_words = r.split()
        h_words = h.split()
        total_edits += editdistance.eval(r_words, h_words)
        total_words += len(r_words)
    return total_edits / total_words if total_words > 0 else 0.0


class eval_dataset(Dataset):
    def __init__(self):
        self.audios = []
        self.sents = []

    def __len__(self):
        return len(self.audios)

    def __getitem__(self, i):
        return {
            "raw": self.audios[i]["array"],
            "sampling_rate": self.audios[i]["sampling_rate"],
            "reference": self.sents[i],
            "path": self.audios[i]["path"],
            "duration": self.audios[i]["duration"],
        }

    def fill_data(self, aud, sent):
        self.audios.append(aud)
        self.sents.append(sent)


def get_data(split):
    js_data = json.loads(split)
    aud = {}
    # Use audio_filepath directly from manifest (no hardcoded path replacement)
    aud["path"] = js_data["audio_filepath"]
    y, sr = sf.read(aud["path"])
    aud["duration"] = js_data["duration"]
    aud["array"] = y
    aud["sampling_rate"] = sr
    return (aud, js_data["text"])


def main(args):
    with open(args.manifest_path, "r") as f:
        data = f.read()
        splits = data.split("\\n")
        if splits[-1] == "":
            splits = splits[:-1]

    da = Parallel(n_jobs=4)(delayed(get_data)(split) for split in tqdm(splits))

    dataset = eval_dataset()
    for d in da:
        dataset.fill_data(d[0], d[1])

    whisper_asr = pipeline(
        "automatic-speech-recognition",
        model=args.model_path,
        device=args.device,
    )

    if args.lang_code == "or":
        whisper_asr.model.config.forced_decoder_ids = (
            whisper_asr.tokenizer.get_decoder_prompt_ids(
                language=None, task="transcribe"
            )
        )
    else:
        whisper_asr.model.config.forced_decoder_ids = (
            whisper_asr.tokenizer.get_decoder_prompt_ids(
                language=args.lang_code, task="transcribe"
            )
        )

    hypothesis = []
    ground_truth = []

    os.makedirs(dir_path + "/predictions", exist_ok=True)
    out_name = (
        args.model_path.rsplit("/", 1)[-1]
        + "_"
        + args.manifest_name
        + "_predictions.json"
    )
    open(dir_path + "/predictions/" + out_name, "w").close()

    st = time.time()

    for out in tqdm(whisper_asr(dataset, batch_size=args.batch_size), total=len(dataset)):
        hyp = out["text"]
        ref = out["reference"][0]
        hyp = hyp.translate(str.maketrans("", "", string.punctuation + "\u0964\u06d4\u2019-\u0965"))
        ref = ref.translate(str.maketrans("", "", string.punctuation + "\u0964\u06d4\u2019-\u0965"))
        if args.lang_code[:2] != "ur":
            hyp = normalize_sentence(hyp, args.lang_code[:2])
            ref = normalize_sentence(ref, args.lang_code[:2])
        hyp = re.sub(" +", " ", hyp).strip()
        ref = re.sub(" +", " ", ref).strip()
        if ref == "":
            ref = "<empty>"
        hypothesis.append(hyp)
        ground_truth.append(ref)
        res = {
            "audio_filepath": out["path"][0],
            "duration": out["duration"][0],
            "text": ref,
            "pred_text": hyp,
        }
        with open(dir_path + "/predictions/" + out_name, "a") as f:
            json.dump(res, f, ensure_ascii=False)
            f.write("\\n")

    et = time.time()

    result = {}
    result["model"] = args.model_path
    result["dataset"] = args.manifest_name
    result["language"] = args.lang_code
    result["cer"] = compute_cer(ground_truth, hypothesis)
    result["wer"] = compute_wer(ground_truth, hypothesis)
    result["time_minutes"] = round((et - st) / 60, 2)
    result["batch_size"] = args.batch_size

    print("\\n===== RESULTS =====")
    for k, v in result.items():
        print(f"  {k}: {v}")

    with open(dir_path + "/results.csv", "a") as results_fp:
        print(",".join([str(v) for v in result.values()]), file=results_fp)


if __name__ == "__main__":
    dir_path = os.path.dirname(os.path.realpath(__file__))
    parser = argparse.ArgumentParser()
    parser.add_argument("--model_path", type=str, required=True)
    parser.add_argument("--manifest_path", type=str, required=True)
    parser.add_argument("--manifest_name", type=str, required=True)
    parser.add_argument("--device", type=int, default=-1)
    parser.add_argument("--batch_size", type=int, default=32)
    parser.add_argument("--language", type=str, required=True)
    args = parser.parse_args()

    if len(args.language) == 2:
        args.lang_code = args.language.lower()
    else:
        args.lang_code = lang_to_code[args.language.lower()]

    main(args)
'''

with open('/kaggle/working/vistaar/evaluation.py', 'w') as f:
    f.write(fixed_eval)

print("evaluation.py written successfully!")
# !grep -n 'compute_cer\|compute_wer\|audio_filepath\|editdistance' /kaggle/working/vistaar/evaluation.py
# Out:
# evaluation.py written successfully!
# 4:import editdistance
# 47:def compute_cer(refs, hyps):
# 48:    """Character Error Rate using editdistance (no rapidfuzz dependency)"""
# 52:        total_edits += editdistance.eval(r, h)
# 57:def compute_wer(refs, hyps):
# 58:    """Word Error Rate using editdistance (no rapidfuzz dependency)"""
# 64:        total_edits += editdistance.eval(r_words, h_words)
# 94:    # Use audio_filepath directly from manifest (no hardcoded path replacement)
# 95:    aud["path"] = js_data["audio_filepath"]
# 164:            "audio_filepath": out["path"][0],
# 179:    result["cer"] = compute_cer(ground_truth, hypothesis)
# 180:    result["wer"] = compute_wer(ground_truth, hypothesis)

# %% [markdown]
# # Cell 4: Create FULL manifest

# %%
import json, os

BASE = "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu"
IN_MANIFEST = f"{BASE}/kathbath/telugu/manifest.json"
OUT_MANIFEST = "/kaggle/working/manifest_telugu_full.json"

count = 0
with open(IN_MANIFEST) as f, open(OUT_MANIFEST, "w") as out:
    for line in f:
        line = line.strip()
        if not line:
            continue
        entry = json.loads(line)
        filename = os.path.basename(entry["audio_filepath"])
        entry["audio_filepath"] = f"{BASE}/kathbath/telugu/wavs/wavs/{filename}"
        out.write(json.dumps(entry, ensure_ascii=False) + "\n")
        count += 1

print(f"Created full manifest with {count} samples: {OUT_MANIFEST}")
# Out:
# Created full manifest with 1492 samples: /kaggle/working/manifest_telugu_full.json

# %% [markdown]
# # Cell 5: Download Bengali Model

# %%
# !wget -q https://indicwhisper.objectstore.e2enetworks.net/telugu_models.zip -O /kaggle/working/vistaar/telugu_models.zip
# !unzip -q /kaggle/working/vistaar/telugu_models.zip -d /kaggle/working/vistaar/
# !ls /kaggle/working/vistaar/telugu_models/
# Out:
# whisper-medium-te_alldata_multigpu

# %% [markdown]
# # Cell 6: Run evaluation (OOM-safe)

# %%
import os, torch

# Free GPU memory before starting
torch.cuda.empty_cache()
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"Free memory: {torch.cuda.mem_get_info()[0]/1024**3:.2f} GB")

# %cd /kaggle/working/vistaar

# Set env var to reduce memory fragmentation
import os
os.environ["PYTORCH_ALLOC_CONF"] = "expandable_segments:True"

# !PYTORCH_ALLOC_CONF=expandable_segments:True python evaluation.py \
    --model_path="telugu_models/whisper-medium-te_alldata_multigpu" \
    --manifest_path="/kaggle/working/manifest_telugu_full.json" \
    --manifest_name="kathbath" \
    --device=0 \
    --batch_size=4 \
    --language="te"
# Out:
# GPU: Tesla T4
# Free memory: 14.46 GB
# /kaggle/working/vistaar
# 100%|██████████████████████████████████████| 1492/1492 [00:07<00:00, 204.71it/s]
# Loading weights: 100%|█████████████████████| 947/947 [00:00<00:00, 13133.68it/s]
#   0%|                                                  | 0/1492 [00:00<?, ?it/s][transformers] Using custom `forced_decoder_ids` from the (generation) config. This is deprecated in favor of the `task` and `language` flags/config options.
# [transformers] Transcription using a multilingual Whisper will default to language detection followed by transcription instead of translation to English. This might be a breaking change for your use case. If you want to instead always translate your audio to English, make sure to pass `language='en'`. See https://github.com/huggingface/transformers/pull/28687 for more details.
# [transformers] A custom logits processor of type <class 'transformers.generation.logits_process.SuppressTokensLogitsProcessor'> has been passed to `.generate()`, but it was also created in `.generate()`, given its parameterization. The custom <class 'transformers.generation.logits_process.SuppressTokensLogitsProcessor'> will take precedence. Please check the docstring of <class 'transformers.generation.logits_process.SuppressTokensLogitsProcessor'> to see related `.generate()` flags.
# [transformers] A custom logits processor of type <class 'transformers.generation.logits_process.SuppressTokensAtBeginLogitsProcessor'> has been passed to `.generate()`, but it was also created in `.generate()`, given its parameterization. The custom <class 'transformers.generation.logits_process.SuppressTokensAtBeginLogitsProcessor'> will take precedence. Please check the docstring of <class 'transformers.generation.logits_process.SuppressTokensAtBeginLogitsProcessor'> to see related `.generate()` flags.
# 100%|█████████████████████████████████████| 1492/1492 [1:38:41<00:00,  3.97s/it]
#
# ===== RESULTS =====
#   model: telugu_models/whisper-medium-te_alldata_multigpu
#   dataset: kathbath
#   language: te
#   cer: 0.12949168797953964
#   wer: 0.3697248848499938
#   time_minutes: 98.69
#   batch_size: 4

# %% [markdown]
# # Cell 7: View results

# %%
print("=== Results CSV ===")
# !cat /kaggle/working/vistaar/results.csv

print("\n=== Predictions ===")  
# !cat /kaggle/working/vistaar/predictions/whisper-medium-te_alldata_multigpu_kathbath_predictions.json
# Out:
# === Results CSV ===
# telugu_models/whisper-medium-te_alldata_multigpu,kathbath,te,0.12949168797953964,0.3697248848499938,98.69,4
#
# === Predictions ===
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932651824-944-f.wav", "duration": 8.9165, "text": "అయితే ప్రియాంక ఎంత ఫ్రీ షో ఇచ్చినా కానీ బేవాచ్ చిత్రానికి అది హెల్ప్ కాలేదు", "pred_text": "అయితే ప్రియాంక ఎంత ఫ్రీ షో ఇచ్చినా గానీ భ్యవత్ చిత్రానికి అది హెల్ప్ కాలేదు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932537159-1154-f.wav", "duration": 7.8948125, "text": "అయితే కారులో ఉన్నవారికి ఎలాంటి గాయాలు కాకపోవడంతో అంతా ఊపిరి పీల్చుకున్నారు", "pred_text": "అయితే కారులో ఉన్న వారికి ఎలాంటి గాయాలు కాకపోవడంతో అంతా ఊపిరి పీల్చుకున్నారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931156864-213-f.wav", "duration": 6.1300625, "text": "ఉప్పల్ నియోజకవర్గంలో రెండు వేల రెండు వందల కోట్లతో అభివృద్ధి పనులు చేశామన్నారు", "pred_text": "ఉప్పల్ నియోజకవర్గంలో రెండు వేల రెండు వందల కోట్లతో అభివృద్ధి పనులు చేశామన్నారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931358649-879-f.wav", "duration": 5.317375, "text": "వాస్తవానికి ఇక్కడ ఇస్లాం మతం మినహా మరే ఇతర మతాన్ని అనుసరించడం నిషేధం", "pred_text": "Sejumlahnya di sini Islam ialah minasih minasih dan sebagainya lainnya ialah nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilయ విగ్ర ప్యూటిగాలు విగ్గాలు ప్యూటీకు ప్యూటీకు ప్యుటీటీటీటీటీటీటీటీటీటీటీటీటీటీటీటీటీటీటీటీటీటీటీటీటీటీటీ�"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424930603374-860-f.wav", "duration": 5.6656875, "text": "రెండేళ్ల క్రితం హాత్ వే నుంచి బయటకొచ్చిన ఆయన ఎగ్జయిటైల్ అనే కంపెనీలో చేరారు", "pred_text": "రెండేళ్ల క్రితం హాత్వే నుంచి బయటకొచ్చిన ఆయన ఎగ్సైటల్ అనే కంపెనీలో చేరారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932537226-1154-f.wav", "duration": 7.5696875, "text": "ఈ పరీక్షించని మోడ్స్ అని ఒక ప్రమాదం ఉంది లేదు అని పేర్కొంది విలువ", "pred_text": "ఈ పరీక్షించని మోర్స్ అని ఒక ప్రమాదం ఉంది లేదు అని పేర్కొంది విలువ"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932537203-1154-f.wav", "duration": 8.8700625, "text": "మొత్తానికి తన హాట్ పెర్ఫామెన్స్తో బిగ్ బాస్ హౌస్ని హీటెక్కించింది హారిక", "pred_text": "మొత్తానికి తన హార్ట్ పెర్ఫార్మెన్స్ తో బిగ్ బాస్ హౌస్ ని హీటెక్కించింది హారిక"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932651858-944-f.wav", "duration": 6.2461875, "text": "భూ సంస్కరణలు సరిగ్గా అమలు కాకపోవడం వల్లే భూమిలేని పేదరైతులు కౌలుదారులుగా మారారు", "pred_text": "భూ సంస్కరణలు సరిగ్గా అమలు కాకపోవడం వల్లే భూమి లేని పేద రైతులు కౌలు ధరలుగా మారారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932737147-944-f.wav", "duration": 4.736875, "text": "అట్లాంటిక్ ప్రవాహం వలన బారెంట్స్ సముద్రం యొక్క నైరుతి పడటం లేదు", "pred_text": "అట్లాంటిక్ ప్రవాహం వలన బ్యారెన్జ్ సముద్రం యొక్క నైరుతి పడటం లేదు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932652117-822-f.wav", "duration": 7.36075, "text": "నిజానికి ఈ కొన్ని గ్రహాలు నిజానికి అలాంటి ఒక గ్రహం యొక్క కక్ష్య తెలిసిన లేకపోతే", "pred_text": "నిజానికి ఈ కొన్ని గ్రహాలు నిజానికి అలాంటి ఒక గ్రహం యొక్క కక్ష్య తెలిసిన లేకపోతే"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931241469-860-f.wav", "duration": 8.5449375, "text": "పంచాయతీ అధికారి తో ప్రజాప్రతినిధులు ప్రణాళికలకు రూపకల్పన చేసుకోవాలని అధికారులకు సూచించారు", "pred_text": "పంచాయతీ అధికారితో ప్రజాప్రతినిధులు ప్రణాళికలకు రూపకల్పన చేసుకోవాలని అధికారులకు సూచించారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932651921-944-f.wav", "duration": 6.2461875, "text": "కాగా ఈ చిత్రం ట్రైలర్ను స్వాతంత్ర్య దినోత్సవం సందర్భంగా విడుదల చేశారు", "pred_text": "కాగా ఈ చిత్రం ట్రైలర్ను స్వాతంత్ర్య దినోత్సవం సందర్భంగా విడుదల చేశారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931189566-76-f.wav", "duration": 9.8685, "text": "ఇప్పుడు ఎన్నికలు దగ్గరపడ్డ నేపథ్యంలో కేంద్రం నుంచి సాధ్యమైన్ని నిధులు రాబట్టేందుకు రాష్ట్రం అన్ని ప్రయత్నాలు చేసింది", "pred_text": "ఇప్పుడు ఎన్నికలు దగ్గరపడ్డ నేపథ్యంలో కేంద్రం నుంచి సాధ్యమైన నిధులు రాబట్టేందుకు రాష్ట్రం అన్ని ప్రయత్నాలు చేసింది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931279383-194-f.wav", "duration": 8.5449375, "text": "ఇంట్లోనే సులభంగా ఎలా వ్యాయామం చేయాలో ఈ వీడియో ద్వారా చెప్పుకొచ్చిందీ ఫిట్నెస్ ఫ్రీక్", "pred_text": "ఇంట్లోనే సులభంగా ఎలా వ్యాయాయం చేయాలో ఈ వీడియో ద్వారా చెప్పుకొచ్చింది ఫిట్నెస్ ఫ్రీక్"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932537181-1154-f.wav", "duration": 9.9845625, "text": "నలుగురు వ్యక్తులు దౌర్జన్యంగా ఇంట్లోకి ప్రవేశించి తల్లి తలకు తుపాకీ చూపించి అత్యాచారయత్నం చేశారు", "pred_text": "4 orang orang yang dihidapkan sejumlahan sekepulauan dalam rumah mereka telah mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mulaid mడి తెలి తలకు తుపాకీ చూపించి అత్యాచారాయత్నం చేశారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932537174-1154-f.wav", "duration": 10.4721875, "text": "త్వరలో నావిక్ సిగ్నల్స్ మొబైల్ ఫోన్లకు అందుబాటులోకి తెచ్చే ప్రయత్నాలు ముమ్మరంగా జరుగుతున్నాయని తెలిపారు", "pred_text": "త్వరలో నావిక్ సిగ్నల్స్ మొబైల్ ఫోన్లకు అందుబాటులోకి తెచ్చే ప్రయత్నాలు ముమ్మరంగా జరుగుతున్నాయని తెలిపారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931189548-76-f.wav", "duration": 8.4985, "text": "అలాగే ఈ రెండు ఫోన్లలోనూ హానర్ సూపర్ చార్జ్ ఫాస్ట్ చార్జింగ్ వంటి అద్భుత ఫీచర్ను అందిస్తున్నారు", "pred_text": "అలాగే ఈ రెండు ఫోన్లలోనూ హానర్ సూపర్ ఛార్జ్ ఫాస్ట్ ఛార్జింగ్ వెంటి అద్భుత ఫీచర్ను అందిస్తున్నారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931140354-213-f.wav", "duration": 7.848375, "text": "మరియు ఒక భారీ నిర్వాహక తరగతి సృష్టించడానికి సంస్థలు యొక్క పనితీరు మరియు సహకారం మెరుగుపరచడానికి", "pred_text": "మరియు ఒక భారీ నిర్వాహక తరగతి సృష్టించడానికి సంస్థలు యొక్క పనితీరు మరియు సహకారం మెరుగుపరచడానికి"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932651859-944-f.wav", "duration": 6.9195625, "text": "టీడీపీ అవిశ్వాస తీర్మానం పెట్టడంతో గత శుక్రవారం నాడు రాహుల్ ఈ సందర్భంలో హగ్ ఇచ్చారు", "pred_text": "TDP అవిశ్వాస తీర్మానం పెట్టడంతో గత శుక్రవారం నాడు రాహుల్ ఈ సందర్భంలో హక్కు ఇచ్చారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932652060-822-f.wav", "duration": 7.5696875, "text": "కొంతకాలంగా టీడీపీ నుంచి కొందరు ఎమ్మెల్యేలు బయటకు వెళ్లిపోతారనే ప్రచారం జోరుగా సాగుతోంది", "pred_text": "కొంత కాలంగా టీడీపీ నుంచి కొందరు ఎమ్మెల్యేలు బయటకు వెళ్తారని ప్రచారం జోరుగా సాగుతోంది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932652071-822-f.wav", "duration": 6.3390625, "text": "సౌమ్య కు మటుకు తను చేసిన తప్పు గుర్తుకు వస్తూనే ఉంటుంది", "pred_text": "సోమ్యకు మాటుకు తాను చేసిన తప్పు గుర్తుకు వస్తూనే ఉంటుంది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932651877-944-f.wav", "duration": 6.7105625, "text": "పవన్పై తమకున్న అభిమానం కొద్దీ తమ సినిమాల ఆడియో ఫంక్షన్లకు పవన్ను ఆహ్వానిస్తుంటారు", "pred_text": "పవన్ పై తముకున్న అభిమానం కొద్దీ తమ సినిమాల ఆడియో ఫంక్షన్లకు పవన్ ను ఆహ్వానిస్తుంటారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932537192-1154-f.wav", "duration": 7.244625, "text": "మరి రాఖీ సావంత్ సవాలుకు సన్నీ లియోన్ ఎలా స్పందిస్తుందో చూడాలి", "pred_text": "మరి రాకీ సవాంత్ సవాల్ కు సన్నీలియన్ ఎలా స్పందించిందో చూడాలి"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931156810-213-f.wav", "duration": 8.5449375, "text": "వివిధ ప్రాంతాల నుండి భక్తులు తిరుమలకు వాహనాల్లో రెండు కనుమార్గాల్లో పయనిస్తుంటే చీమలదండును తలపించింది", "pred_text": "వివిధ ప్రాంతాల నుండి భక్తులు తిరుమలకు వాహనాల్లో రెండు కనుమార్గాల్లో పయనిస్తుంటే చేమలదండ్రును తలపించింది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932537162-1154-f.wav", "duration": 11.3545625, "text": "వీరిలో కనిగిరి నుండి గెలిచిన కదిరి బాబురావుకు హిందుపురం ఎమ్మెల్యే నందమూరి బాలకృష్ణ అండదండలు పుష్కలంగా ఉన్నాయి", "pred_text": "వీరిలో కనిగిరి నుండి గెలిచిన కదిరి బాబూరావుకు హిందూపురం ఎమ్మెల్యే నందమూరి బాలకృష్ణ అండదండలు పుష్కలంగా ఉన్నాయి"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932651922-944-f.wav", "duration": 6.269375, "text": "ఆస్ట్రేలియాతో జరిగిన మూడవ వన్డేలో భారత బ్యాట్స్మెన్ విరాట్ కోహ్లీ సెంచరీ సాధించాడు", "pred_text": "Australia తో జరిగిన మూడవ వన్డేలో భారత బ్యాట్స్ మెన్ విరాట్ కోహ్లీ సెంచరీ సాధించాడు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931140412-213-f.wav", "duration": 7.1285625, "text": "ముందస్తుకు వెళ్తే నాలుగేళ్ల టీఆర్ఎస్ పాలనను ప్రజలు తిప్పి కొడతారని జోస్యం చెప్పారు", "pred_text": "ముందస్తుకు వెళ్తే నాలుగేళ్ల టీఆర్ఎస్ పాలనను ప్రజలు తిప్పి కొడతారని జోస్యన్ చెప్పారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932542945-377-f.wav", "duration": 8.591375, "text": "షెడ్యూల్ ప్రకారం మార్చి నెలలో ఇరు జట్ల మధ్య మూడు మ్యాచ్ల టెస్ట్ సిరీస్ జరగాల్సి ఉంది", "pred_text": "షెడ్యూల్ ప్రకారం మార్చినెలలో ఇరువురు జట్ల మధ్య మూడు మ్యాచ్ల టెస్ట్ సీరీస్ జరగాల్సి ఉంది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932737124-944-f.wav", "duration": 6.757, "text": "చివరి దశ ఎన్నికల్లో భాగంగా ఎనిమిది రాష్ట్రాల్లో ఇవాళ ఉదయం నుండి పోలింగ్ జరుగుతున్న విషయం తెలిసిందే", "pred_text": "చివరి దశ ఎన్నికల్లో భాగంగా ఎనిమిది రాష్ట్రాల్లో ఇవాళ ఉదయం నుండి పోలింగ్ జరుగుతున్న విషయం తెలిసిందే"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932737182-944-f.wav", "duration": 5.897875, "text": "ఇసుక లేదా హ్యూమస్ తో హ్యూమస్ మిశ్రమంతో నింపిన చిన్న కుండలలో ఇది ఉత్తమం", "pred_text": "ఇసుక లేదా హ్యూమస్ తో హ్యూమస్ మిశ్రమంతో నింపిన చిన్న కుండలలో ఇది ఉత్తమం"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931241434-860-f.wav", "duration": 6.0371875, "text": "చైనాకు చెందిన ప్రముఖ స్మార్ట్ ఫోన్ బ్రాండ్ రియల్ మీ ఒక హెచ్చరికను జారీ చేసింది", "pred_text": "చైనాకు చెందిన ప్రముఖ స్మార్ట్ ఫోన్ బ్రాండ్ రియెల్ మీ ఒక హైచ్చరికను జారీ చేసింది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932651906-944-f.wav", "duration": 7.15175, "text": "వాస్కో నూనెజ్ డి బల్బోయా పసిఫిక్ మహాసముద్రంలో చేరుకున్న మొట్టమొదటి యూరోపియన్గా మారింది", "pred_text": "వాస్కో నూనెజ్ డి బాల్బోయ్ పెసిఫిక్ మహాసముద్రంలో చేరుకున్న మొట్టమొదటి యూరోపియన్ గా మారింది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931140371-213-f.wav", "duration": 7.36075, "text": "ఆ పరిస్థితుల్లో వేరే అబ్బాయితో నిశ్చితార్థం జరిగిన నందుతో ప్రేమలో పడతాడు వెంకీ", "pred_text": "ఆ పరిస్థితుల్లో వేరే అబ్బాయితో నిశితార్థం జరిగిన నందుతో ప్రేమలో పడతాడు వెంకీ"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931279458-194-f.wav", "duration": 9.4273125, "text": "సినిమా అన్ని చోట్ల నుండి పాజిటివ్ టాక్ సొంతం చేసుకుని కలక్షన్స్ లో కూడా అదరగొడుతుంది", "pred_text": "సినిమా అన్ని చోట్ల నుండి పాజిటివ్ టాక్స్ అంతం చేసుకుని కలెక్షన్స్ లో కూడా అదరగొడుతుంది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932737107-944-f.wav", "duration": 8.2895625, "text": "నాగ్పూర్లోని ఆర్ఎస్ఎస్ కేంద్ర కార్యాలయంలో దాదాపు రెండు గంటలపాటు చంద్రబాబు నాయుడు మోహన్ భగవత్తో భేటీ అయ్యారు", "pred_text": "నాగ్పూర్లోని ఆర్ఎస్ఎస్ కేంద్ర కార్యాలయంలో దాదాపు రెండు గంటల పాటు చంద్రబాబు నాయుడు మోహన్ భగవత్ తో భేటీ అయ్యారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931241389-860-f.wav", "duration": 9.938125, "text": "దీంతోపాటు హైదరా బాద్లోని మరో ప్రధానమైన జూబ్లీ బస్స్టేషన్లోనూ ఈ వైఫై సేవలు అందుబాటులోకి తీసుకువస్తున్నట్లు తెలి పారు", "pred_text": "దీనితో పాటు హైదరాబాద్ లోని మరో ప్రధానమైన జూబ్లీ బస్ స్టేషన్ లోనూ ఈ వైఫై సేవలు అందుబాటులోకి తీసుకు వస్తున్నట్లు తెలిపారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932537152-1154-f.wav", "duration": 9.1254375, "text": "సంబంధిత వివరాలు తెలుసుకుని సొంతంగా డీల్ చేయగలమనుకుంటే బ్యాంకుల ద్వారా పాలసీ తీసుకోవచ్చు", "pred_text": "Tidak paham dengan nilainilai nilainilai nilainilai nilainilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilగో సంక్యోగోగోగోగోగోగోగోగోగోగోగోగోగోగోగోగోగోగోగోగోగోగోగోగోగోగోగోగోగోగోగోగోగోగోగోగోగోగోగోగోగ"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931241425-860-f.wav", "duration": 8.7306875, "text": "కృష్ణానదికి చేరువనే నిర్మిస్తున్న అమరావతి విషయంలో జలగండం రాదన్న గ్యారంటీ ఇవ్వాల్సిన అవసరం ఎంతైనా ఉంది", "pred_text": "కృష్ణా నదికి చేరువని నిర్మిస్తున్న అమరావతి విషయంలో జలగృండం రాధన్న గ్యారెంటీ ఇవ్వాల్సిన అవసరం ఎంతైనా ఉంది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931156853-213-f.wav", "duration": 7.5929375, "text": "రెగ్యులర్ కమర్షియల్ సినిమాలకు అలవాటుపడిన తెలుగు ప్రేక్షకులకు కొత్త తరహా అనుభూతిని పంచే చిత్రమిది", "pred_text": "రెగ్యులర్ కమెర్షియల్ సినిమాలకు అలవాటుపడిన తెలుగు ప్రేక్షకులకు కొత్త తరహా అనుభూతిని పెంచే చిత్రం ఇదే"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932652107-822-f.wav", "duration": 8.9629375, "text": "సంజయ్ రావత్ మొదటి నుంచీ బీజేపీ పట్ల ఒకింత విమర్శనాత్మకంగానే వ్యవహరిస్తున్నారు", "pred_text": "సంజయ్ రావత్ మొదట్టి నుంచి బీజేపీ పట్ల ఒక్కిత విమర్శనాత్మకంగానే వ్యవహరిస్తున్నారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931210892-213-f.wav", "duration": 7.15175, "text": "అంటే శివాజీ హిందూ మతాభిమాని కాబట్టి విజయం సాధించాడన్న మాట నిజం కాదు", "pred_text": "అంటే శివాజీ హిందూ మతాభీమాని కాబట్టి విజయం సాధించాడన్న మాట నిజం కాదు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932737189-944-f.wav", "duration": 5.41025, "text": "రెండు దేశల మధ్య గతంలో చర్చలు జరిగినా అర్ధాంతరంగా నిలిచిపోయిన సందర్భాలు ఉన్నాయి", "pred_text": "రెండు దేశాల మధ్య గతంలో చర్చలు జరిగినా అర్ధంత్రంగా నిలిచిపోయిన సందర్భాలు ఉన్నాయి"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931189560-76-f.wav", "duration": 9.589875, "text": "ఇతరులు కుటుంబం ఆర్కైవ్ అందమైన మరియు అసలు ఫోటోలు ఉంచబడిన కేవలం ఒక ఫోటో సెషన్ కోసం ఏర్పాట్లు", "pred_text": "ఇతరులు కుటుంబం ఆర్కైవ్ అందమైన మరియు అసలు ఫోటోలు ఉంచబడిన కేవలం ఒక ఫోటో సెషన్ కోసం ఏర్పాట్లు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932651891-944-f.wav", "duration": 7.4071875, "text": "చాలా మంది అభిమానులు ఎల్లప్పుడూ వారి విగ్రహాల గురించి కొన్ని వ్యక్తిగత సమాచారం తెలిసిన ఆసక్తి", "pred_text": "Banyak orang penghormat telah selalu menjelaskan imam mereka mengenai beberapa makhluk yang telah mereka telah menjelaskan"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932651861-944-f.wav", "duration": 8.777125, "text": "సుదీర్ఘ రాజకీయానుభవం కలిగిన చంద్రబాబు రాజకీయ అవగాహన లేని రాహుల్ గాంధీ నాయకత్వంలో నడవాలనుకోవడం దారుణమన్నారు", "pred_text": "సుదీర్ఘ రాజకీయ అనుభవం కలిగిన చంద్రబాబు రాజకీయ అవగాహన లేని రాహుల్ గాంధీ నాయకత్వంలో నడవాలనుకోవడం దారుణమన్నారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931210911-213-f.wav", "duration": 8.591375, "text": "అంతర్గత మౌంటు కాంక్రీటు బేస్ లోకి చిత్తు చేశాడు మరియు మద్దతు జోడించే ఒక స్టడ్ అందిస్తుంది", "pred_text": "అంతర్గత మౌంట్ కాంక్రీట్ బేస్ లోకి చిత్తు చేశాడు మరియు మద్దతు జోడించే ఒక స్టర్ట్ అందిస్తుంది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931358618-879-f.wav", "duration": 7.058875, "text": "మెటాస్టాటిక్ రొమ్ము క్యాన్సర్కు ఉపయోగించే కెమోథెరపీ మందులు కూడా సాధారణంగా జుట్టు నష్టం కలిగిస్తాయి", "pred_text": "మోటార్ స్టాటిక్ రోమ్ క్యాన్సర్కు ఉపయోగించే కైమోథెర్ఫీ మందులు కూడా సాధారణంగా జుట్టు నష్టం కలిగిస్తాయి"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931140350-213-f.wav", "duration": 10.26325, "text": "స్థానికంగా కలకలం క్రియేట్ చేసిన ఈ సంఘటన ఆంధ్రపద్రేశ్ రాష్ట్రంలో శ్రీకాకుళం జిల్లా వీరఘట్టం గ్రామ సమీపంలో వెలుగుచూసింది", "pred_text": "స్థానికంగా కలకలం క్రియేట్ చేసిన ఈ సంఘటన ఆంధ్రప్రదేశ్ రాష్ట్రంలో శ్రీకాకులం జిల్లా వీరఘట్టం గ్రామ సమీపంలో వెలుగు చూసింది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424930596028-860-f.wav", "duration": 6.4551875, "text": "వారికి మొదటి సారి ఫ్లైట్ ఎక్స్ పీరియన్స్ చూపించాలని ఇలా చేశారట", "pred_text": "వారికి మొదటిసారి ఫ్లైట్ ఎక్స్పీరెన్స్ చూపించాలని ఇలా చేశారట"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931156843-213-f.wav", "duration": 7.8948125, "text": "దీనితో సౌమ్య అక్కడికక్కడే కుప్పకూలాగా మరో చేతిలో ఉన్న పెట్రోల్ తీసి ఆమె పై పోసి నిప్పు అంటించాడు", "pred_text": "దీనితో సౌమ్య అక్కడిక్కక్కడే కుప్పకూలగా మరో జేతిలో ఉన్న పెట్రోల్ తీసి ఆమెపై పోసి నిప్పు అట్టించాడు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932662495-108-f.wav", "duration": 6.2461875, "text": "లంగర్హౌస్ త్రివేణీ సంగమాన్ని దక్షిణ కాశి అని కూడా అంటారు", "pred_text": "లంగర్ హౌస్ త్రివే అని సంగమాన్ని దక్షిణ కాశీ అని కూడా అంటారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931358705-879-f.wav", "duration": 5.99075, "text": "గాయం తర్వాత ఎంట్రీ ఇస్తున్న రోహిత్ శర్మ భారీగా పరుగులు చేయాలనే కోరికతో ఉంటాడు", "pred_text": "గాయన్ తర్వాత ఎంట్రీ ఇస్తున్న రోహిత్ శర్మ భారీగా పరుగులు చేయాలనే కోరికతో ఉంటాడు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931156827-213-f.wav", "duration": 7.825125, "text": "పాత పద్ధతిలో రిజిస్ట్రేషన్లు అమలు కావడం లేదని పిటీషనర్ తరపు న్యాయవాది కోర్టులో వాధించారు", "pred_text": "పాత పద్ధతిలో రిజిస్ట్రేషన్లు అమలు కావడం లేదని పిటిషనరు తరఫు న్యాయవాది కోర్టులో వాదించారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931210949-213-f.wav", "duration": 7.267875, "text": "బాధతో రక్తపు మడుగులో పడి కొట్టుమిట్టాడుతున్న బాధితుడ్ని స్థానికులు ఆస్పత్రికి తరలించారు", "pred_text": "భాగతో రక్తపు మడుగులో పడి కొట్టుమిట్టాడుతున్న బాధితుడిని స్థానికులు ఆసుపత్రికి తరలించారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424930603377-860-f.wav", "duration": 7.0124375, "text": "భారత్లో విధ్వంసానికి పాకిస్తాన్ కుట్ర చేస్తోందని ఇప్పటికే నిఘా వర్గాలు హెచ్చరించాయి", "pred_text": "భారత్ లో విధం సానికి పాకిస్తాన్ కుట్ర చేస్తోందని ఇప్పటికే నిఘా వర్గాలు హెచ్చరించాయి"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932737167-944-f.wav", "duration": 6.1300625, "text": "వారితో శాండ్విచ్లు మరియు కేకులను తయారు చేసేందుకు ఒక పిక్నిక్లో పని చేయడానికి పాన్కేక్లు తీసుకోవచ్చు", "pred_text": "dengan mereka kuihsandwich dan kek yang dikorekkan untuk dipasarkan untuk dipasarkan dalam piknik yang dikorekkan untuk dipasarkan pula papankek yang dikorekkan pula papankek yang dikorekkan pula papankek yang dikorekkan pula papankek yg dikorekkan pula papankek yg dikorekkan pula papankek yg dikorekkan pula papankek yg dikorekkan pula papankek yg dikorekkan pula papankek yg dikorekkan pula papankek yg dikorekkan pula papankek yg dikorekకిలో వేసుకున్నారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932537207-1154-f.wav", "duration": 10.031, "text": "కళంకితులను ఉన్నత పదవుల్లో కూర్చోబెట్టడం ఒక దుష్ట సంప్రదాయాన్ని ప్రవేశపెట్టడమేనని వ్యాఖ్యానించారు", "pred_text": "కలంకితులను ఉన్నత పదవుల్లో కూర్చోబెట్టడం ఒక దుష్ట సాంప్రదాయాన్ని ప్రవేశపెట్టడమేనని వ్యాఖ్యానించారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931156818-213-f.wav", "duration": 7.3839375, "text": "ఘటనపై పూర్తి నివేదిక సమర్పించాలని రక్షణ మంత్రి నిర్మలా సీతారామన్ సైన్యాన్ని ఆదేశించారు", "pred_text": "ఘటనపై పూర్తి నివేదిక సమర్పించాలని రక్షణ మంత్రి నిర్మలా సీతారామన్ సైన్యాన్ని ఆదేశించారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932537208-1154-f.wav", "duration": 9.009375, "text": "తాము అధికారంలోకి వస్తే కేంద్రంలో ఎవరితోనూ కలిసేది లేదని స్పష్టం చేశారు", "pred_text": "తాము అధికారంలోకి వస్తే కేంద్రంలో ఎవరితోనూ కలిసేది లేదని స్పష్టం చేశారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931358624-879-f.wav", "duration": 5.7585625, "text": "కలకత్తాకు చెందిన ఈమె ఈ మధ్యే టాలీవుడ్ లో స్టైలిస్ట్ గా బాగా పాపులర్ అయింది", "pred_text": "కలకత్తాకు చెందిన ఈ మే ఈ మధ్య టాలీవుడ్ లో స్టైలిస్ట్ గా బాగా పాపులర్ అయింది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932651902-944-f.wav", "duration": 6.7338125, "text": "అవినీతిని ప్రశ్నిస్తున్నందుకే ఆయనపై హత్య చేసి చంపేశారు అని బండి సంజయ్ అన్నారు", "pred_text": "అవినీతిని ప్రశ్నిస్తున్నందుకే ఆయనపై హత్య చేసి చంపేశారని బండి సంజయ్ అన్నారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932737156-944-f.wav", "duration": 7.3375, "text": "హుడ్ గణనీయంగా అంతర్గత భాగాలు మరియు శక్తి దళాలకు ప్రాప్తిని డ్రైవర్లు మరియు ఆటో మెకానిక్ సులభతరం చేస్తుంది", "pred_text": "హుడ్ గణనీయంగా అంతర్గత భాగాలు మరియు శక్తి దళాలకు ప్రాప్తిని డ్రైవర్లు మరియు ఆటోమెకానిక్ సులభతరం చేస్తుంది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932542955-377-f.wav", "duration": 7.5696875, "text": "తెహ్రీ ఘర్వాల్ అంటే త్రికరణాలతో చేసే పాపాలను హరించే కోట అని అర్ధం", "pred_text": "తెహ్పీ గర్వాల్ అంటే త్రికరణలతో చేసే పాపాలను హరించే కోట అని అర్థం"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931241448-860-f.wav", "duration": 6.8034375, "text": "దీనితోపాటు తమిళ చిత్ర పరిశ్రమలో మీ టూ ఉద్యమంలో చిన్మయి పాత్ర చాలా చురుకైనది", "pred_text": "దీనితో పాటు తంపుల చిత్ర పరిశ్రమలు మీ టూ ఉద్యమంలో సిన్మై పాత్ర చాలా చురుకైనది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931189515-76-f.wav", "duration": 8.4753125, "text": "ప్రస్తుత తెరాస సిట్టింగ్ ఎంపీ జితేందర్రెడ్డి సైతం బుధవారం రాత్రి భాజపాలో చేరారు", "pred_text": "ప్రస్తుత తెరాస సిట్టింగ్ ఎంపీ జితేంద్ర రెడ్డి సైతం బుధవారం రాత్రి భాజపాలో చేరారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931156806-213-f.wav", "duration": 9.3111875, "text": "రేవంత్ నియోజకవర్గమైన కొడంగల్ లో కొందరు నేతలు టిడిపి వీడి టిఆర్ఎస్ లో చేరేందుకు రెడీ అవుతున్నారు", "pred_text": "రేవంత్ నియోజకవర్గమైన కొండగల్లో కొందరు నేతలు టీడీపీ వీడి టీఆర్ఎస్లో చేరేందకు రెడీ అవుతున్నారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932737194-944-f.wav", "duration": 5.7585625, "text": "తన బిడ్డకు తెలివైన మరియు విద్యావంతులైన వ్యక్తి కావాలని తల్లి ఏమీ కోరుకోలేదు", "pred_text": "తన బిడ్డకు తెలివైన మరియు విద్యావంతులైన వ్యక్తి కావాలని తల్లి ఏమీ కోరుకోలేదు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931358595-879-f.wav", "duration": 5.9443125, "text": "గతంలో ఎప్పుడు లేని విధంగా మొదటి సారి విజయ్ సినిమా కోసం నిర్మాతలు భారీగా ఖర్చు చేశారు", "pred_text": "గతంలో ఎప్పూడూ లేని విధంగా మొదటిసారి విజయ్ సినిమా కోసం నిర్మాతలు భారీగా ఖర్చు చేశారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932737139-944-f.wav", "duration": 8.89325, "text": "ఈ నేపథ్యంలో ఎంఐఎం వైఖరికి వ్యతిరేకంగా పలువురు మస్లిం మహిళలు రోడ్డెక్కి నిరసన వ్యక్తం చేశారు", "pred_text": "ఈ నేపథ్యంలో ఎంఐఎం వైఖరికి వ్యతిరేకంగా పలువురు ముస్లిం మహిళలు రోడ్డీకి నిరసనత్ వ్యక్తం చేశారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932537161-1154-f.wav", "duration": 7.15175, "text": "ఈ క్రమంలో బుధవారం ఉదయం పెట్రోల్ బాటిల్తో ఖలీల్ ఇంటికి చేరుకుంది", "pred_text": "ఈ క్రమంలో బుధవారం ఉదయం పెట్రోల్ బాటిల్ తో కలీల్ ఇంటికి చేరుకుంది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931358616-879-f.wav", "duration": 8.7539375, "text": "దేశంలో మొదటిసారి నలుగురు సుప్రీంకోర్టు న్యాయమూర్తులు బయటికొచ్చి ప్రజాస్వామ్యం ప్రమాదంలో పడినట్టు ప్రెస్ కాన్ఫరెన్స్ పెట్టి చెప్పారు", "pred_text": "దేశంలో మొదటిసారి నలుగురు సుప్రీంకోర్టు న్యాయమూర్తులు బయటికొచ్చి ప్రజాస్వామ్యం ప్రమాదంలో పడినట్లు ప్రెస్ కాన్ఫరెన్స్ పెట్టి చెప్పారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931156874-213-f.wav", "duration": 5.2709375, "text": "పేదరికం అనే ఆలోచన నుంచి విముక్తి పొందడానికి భారీ ప్రణాళికలు అవసరం", "pred_text": "పేదరికం అనే ఆలోచన నుంచి వైముక్తి పొందడానికి భారీ ప్రణాళికలు అవసరం"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932737198-944-f.wav", "duration": 6.4086875, "text": "బాలీవుడ్ మీడియాలో వస్తున్న వార్తల ప్రకారం సాహూ చిత్ర యూనిట్ ఆమెని సంప్రదించినట్లు తెలుస్తోంది", "pred_text": "బాలీవుడ్ మీడియాలో వస్తున్న వార్తల ప్రకారం సాహూ చిత్ర యూనిట్ ఆమెను సంప్రదించినట్లు తెలుస్తోంది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931210921-213-f.wav", "duration": 7.5000625, "text": "ముఖ్యంగా పసుపులో యాంటీ ఇన్ఫ్లమేటరీ మరియు బ్లడ్ థిన్నింగ్ లక్షణాలు పుష్కలంగా ఉన్నాయి", "pred_text": "ముఖ్యంగా పసుపులు యాంటీ ఇన్ఫోలిమేటరీ మరియు బ్లడ్ దిన్నింగ్ లక్షణాలు పుష్కలంగా ఉన్నాయి"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931189518-76-f.wav", "duration": 8.5449375, "text": "గుహలోని సహజంగా ఏర్పడిన శిల్పాకృతుల గురించే మాట్లాడుకుంటూ కటికి జలపాతానికి పయనమవుతారు", "pred_text": "గుహలోని సహజంగా ఏర్పడిన శిల్పాకృతుల గురించే మాట్లాడుకుంటూ కటికి జలపాతానికి పయనమవుతారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931358532-879-f.wav", "duration": 5.0619375, "text": "ఈ పోరాట ఆటలో కనిపిస్తుంది మరియు చాలా తాజా పోషిస్తుంది ఎందుకంటే", "pred_text": "ఈ పోరాట ఆటలో కనిపిస్తుంది మరియు చాలా తాజా పోషిస్తుంది ఎందుకంటే"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931358612-879-f.wav", "duration": 6.269375, "text": "మాజీ మంత్రి హరిరామ జోగయ్య తన ఆత్మకథ ద్వారా రంగా హత్యోదంతాన్ని చర్చనీయాంశం చేశారు", "pred_text": "మాజీ మంత్రి హరిరామ జోగుయ్య తన ఆత్మకథ ద్వారా రంగ హత్యోతంతాన్ని చర్చనీయాంశం చేశారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932652091-822-f.wav", "duration": 6.57125, "text": "ఈ సందర్భంగా మంత్రి మాట్లాడుతూ మీకు ఏం కాదు నేనున్నాను అంటూ బాధితులకు భరోసా కల్పించారు", "pred_text": "ఈ సందర్భంగా మంత్రి మాట్లాడుతూ మీకు ఏమీ కాదు నేను ఉన్నాను అంటూ బాధ్యతులకు భరోసా కల్పించారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931241430-860-f.wav", "duration": 10.05425, "text": "గతంలో లాగా బీసీసీఐకి ఇప్పుడు ఆదాయం లేనందున క్రికెటర్లు తమ వేతనాల్లో కోత విధించుకోవాలని మల్హోత్రా సూచించారు", "pred_text": "గతంలో లాగా బీసీసీఐకి ఇప్పుడు ఆదాయం లేనందుకు క్రికెటర్లు తమ వేతనాల్లో కోత విధించుకోవాలని మల్హోత్రా సూచించారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424930603381-860-f.wav", "duration": 5.8514375, "text": "కర్నాటక రాష్ట్రంలోని పడమటి భాగంలో దాగి వున్న చరిత్ర గడగ్ పట్టణం", "pred_text": "కర్ణాటక రాష్ట్రంలోని పడమట భాగంలో దాగి ఉన్న చరిత్ర గడగ్ పట్టణం"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932537228-1154-f.wav", "duration": 9.84525, "text": "మునుగోడు ఎమ్మెల్యే కోమటిరెడ్డి రాజగోపాల్రెడ్డి సీపీఎం కార్యకర్తలను అడ్డుకోవడంతో పరిస్థితి ఉద్రిక్తంగా మారింది", "pred_text": "మునుగోడు ఎమ్మెల్యే కోమటిరెడ్డి రాజగోపాల్ రెడ్డి సీఎం కార్యకర్తలను అడ్డుకోవడంతో పరిస్థితి ఉద్రిక్తంగా మారింది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931156835-213-f.wav", "duration": 10.6115, "text": "అంతేకాకుండా పవర్ స్టార్ పవన్ కళ్యాణ్ మలయాళ చిత్రం అయ్యప్పనుమ్ కోషియుమ్ రీమేక్ చిత్రంలో కూడా నటించబోతోంది", "pred_text": "అంతే కాకుండా పవర్ స్టార్ పవన్ కళ్యాన్ మలయాళ్ చిత్రం అయ్యప్పన్నం కోషియం రీమేక్ చిత్రంలో కూడా నటించబోతోంది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931189556-76-f.wav", "duration": 6.9195625, "text": "అట్లు చేసినప్పుడు చాలమందికి పద్య సాహిత్యములో ఆసక్తి కలుగుతుందని నా భావన", "pred_text": "అట్లు చేసినప్పుడు చాలా మందికి పద్య సాహిత్యంలో ఆసక్తి కలుగుతుందని నా భావన"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932662458-108-f.wav", "duration": 7.453625, "text": "ఈ నేపథ్యంలో ఏపీ బీజేపీ నేతలకు అమిత్ షా క్లారిటీ ఇచ్చారని తెలుస్తోంది", "pred_text": "ఈ నేపథ్యంలో ఏపీ బీజేపీ నేతలకు అమిత్ షా క్రాటీ ఇచ్చారని తెలుస్తోంది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931358608-879-f.wav", "duration": 7.94125, "text": "పురాతన సంప్రదాయాలను ప్రతిబింబించేలా ఈ సాధువులు కాషాయ వస్త్రధారులై వొళ్ళంతా విబూది రాసుకుని కనిపిస్తారు", "pred_text": "పురాతన సంప్రదాయాలను ప్రతిబింబించేలా ఈ సాధువులు కాషాయ వస్త్రాలై వొల్లంతా విభూతి రాసుకుని కనిపిస్తారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931210919-213-f.wav", "duration": 11.3778125, "text": "మొత్తం విద్యుత్ ప్లాంట్ స్వయంచాలకంగా రోటర్ వేగం మరియు శక్తి వ్యవస్థ సమకాలీకరణ స్థిరీకరణ నియంత్రించబడుతుంది పని", "pred_text": "మొత్తం విడ్జ్ ప్లాంట్ స్వయంచాలకంగా రోటర్ వేగం మరియు శక్తి వ్యవస్థ సమకాలీకరణ స్థిరీకరణ నియంత్రపడుతుంది పని"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932537165-1154-f.wav", "duration": 8.3591875, "text": "ఎన్నో విశిష్టతలు ఉన్నాయి కాబట్టే ఈ పండుగను పెద్ద పండుగ అని గర్వంగా చెప్పుకుంటారు", "pred_text": "ఎన్నో విశిష్టతలు ఉన్నాయి కాబట్టే ఈ పండగను పెద్ద పండగ అని గర్వంగా చెప్పుకుంటున్నారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931156846-213-f.wav", "duration": 5.5728125, "text": "యూఎస్ కాంగ్రెస్ లో ఇండో అమెరికన్లు కొత్త చరిత్ర సృష్టించారు", "pred_text": "యు ఎస్ కాంగ్రెస్ లో ఇండో అమెరికన్లు కొత్త చరిత్ర సృష్టించారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932537138-1154-f.wav", "duration": 6.5480625, "text": "ఎమ్మెల్యే వద్ద వైద్య సేవ యొక్క పరిహారం కోసం సుంకాలు అమర్చే రూల్స్", "pred_text": "ఎమ్మెల్యే వద్ద వైద్య సేవ యొక్క పరిహారం కోసం సుంకాలం అమర్చే రూల్స్"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932542959-377-f.wav", "duration": 10.1935625, "text": "వైయస్సార్ కాంగ్రెసు పార్టీ పట్ల ప్రజల్లో ఉన్న నమ్మకానికి ఇటీవల జరిగిన ఉప ఎన్నికలలోని ఫలితాలే నిదర్శనం అన్నారు", "pred_text": "వైఎస్సార్ కాంగ్రెస్ పార్టీ పట్ల ప్రజల్లో ఉన్న నమ్మకానికి ఇటీవల జరిగిన ఉప ఎన్నికల్లోని ఫలితాలే నిదర్శనం అన్నారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424930603316-860-f.wav", "duration": 8.034125, "text": "దాన్ని మరింత ద్రవ సాస్ వేడెక్కేలా తక్కువ సమయం మరియు అతన్ని తీవ్రంగా కొట్టారు గమనించాలి", "pred_text": "దాన్ని మరింత ద్రవ సాస వేడెక్కేలా తక్కువ సమయం మరియు అతన్ని తీవ్రంగా కొట్టారు గమనించాలి"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931358541-879-f.wav", "duration": 6.9195625, "text": "బీఎండబ్ల్యూ కారు చోరీకి గురైందని తెలిసిన వెంటనే తమ బృందంతో పోలీసు అధికారులు ఘటనా స్ధలానికి చేరుకున్నారు", "pred_text": "Bmw కారు చోరికి గురైందని తెలిసిన వెంటనే తమ బృందంతో పోలీసు అధికారులు ఘటనా స్థలానికి చేరుకున్నారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931189555-76-f.wav", "duration": 8.2895625, "text": "చేతి వృత్తుల కళాకారుల నైపుణ్యాన్ని పెంచేందుకు ప్రధాని మోదీ కృషి చేస్తున్నారని ఆయన తెలిపారు", "pred_text": "చేతి వృత్తుల కళాకారుల నైపుణ్యాన్ని పెంచేందుకు ప్రధాని మోదీ కృషి చేస్తున్నారని ఆయన తెలిపారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931210929-213-f.wav", "duration": 8.31275, "text": "ఎస్సై ప్రభాకర్ రెడ్డి ఆత్మహత్యకు పాల్పడితే సిసిటివి ఫుటేజీలో తప్పకుండా రికార్టు అవుతుందని అంటున్నారు", "pred_text": "ఎస్ఐ ప్రభాకర్ రెడ్డి ఆత్మహత్యకు పాల్పడితే సీసీటీవీ పుటేజీలో తప్పకుండా రికార్డ్ అవుతుందని అంటున్నారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931358526-879-f.wav", "duration": 4.736875, "text": "ఈ విషయం బయట పడటంతో ఆల్ఫోన్సో గర్ల్ఫ్రెండ్ అతడికి బ్రేకప్ చెప్పే సింది", "pred_text": "ఈ విషయం బయట పడడంతో అల్ఫాన్సోం గర్ల్ఫ్రెండ్ అతడికి బ్రేకప్ చెప్పేసింది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424930603296-860-f.wav", "duration": 7.2214375, "text": "దొంగఓట్లు వేయకుండా కట్టడి చేసేందుకు సిరా గుర్తు పద్ధతి సత్ఫలితాలను ఇచ్చింది", "pred_text": "తుంగ ఊట్లు వేయకుండా కట్టడి చేసేందుకు సీరా గుర్తు పద్ధతి సత్ఫలితాలను ఇచ్చింది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932652087-822-f.wav", "duration": 5.4335, "text": "అయితే మార్గం మద్యలో అతను పోలీసులకు ఏమి మాయ చేశాడో తెలియదు", "pred_text": "అయితే మార్గం మధ్యలో అతను పోలీసులకు ఏమీ మాయి చేశాడో తెలియదు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931156844-213-f.wav", "duration": 6.2229375, "text": "ఒకరోజు రాత్రి అనుకోకుండా ఈ సీక్వెల్ కి సంబంధించిన కథ ఏమిటనేది తట్టింది", "pred_text": "ఒక్క రోజు రాత్రి అనుకోకుండా ఈ సీక్వెల్ కి సంబంధించిన కథ ఏమిటనేదే తట్టింది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932652121-822-f.wav", "duration": 5.688875, "text": "అంతా ఆన్లైన్ వ్యవహారం కాబట్టి ఎలాంటి ఆర్థికసంస్థల ప్రమేయం లేకుండా ముందుకు సాగవచ్చు", "pred_text": "అంతా ఆన్లైన్ వ్యవహారం కాబట్టి ఎలాంటి ఆర్థిక సంస్థలు ప్రమేయం లేకుండా ముందుకు సాగవచ్చు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931189497-76-f.wav", "duration": 8.10375, "text": "లేదా వాటిపై మేం తీసిన వీడియోలను మా వెబ్సైట్ ఇన్స్టాగ్రామ్ అకౌంటులో చూడండి", "pred_text": "లేదా వాటిపై మేం తీసిన వీడియోలను మా వెబ్ సైట్ ఇన్స్టాగ్రామ్ అకౌంట్లో చూడండి"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931241402-860-f.wav", "duration": 6.8266875, "text": "హైదరాబాద్లో వైరస్ వ్యాప్తి ఎక్కువగా ఉండటమే దీనికి కారణమని వైద్యులు చెబుతున్నారు", "pred_text": "హైదరాబాద్ లో వైరస్ వ్యాప్తి ఎక్కువగా ఉండటమే దీనికి కారణం అని వైద్యులు చెబుతున్నారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932651884-944-f.wav", "duration": 7.7090625, "text": "క్లోరిన్ పరిశ్రమ మరియు వైద్యంలో ఎంతో అవసరం దీనిలో హైడ్రోక్లోరిక్ యాసిడ్ ఉత్పత్తి ఉపయోగిస్తారు", "pred_text": "chlorine పరిశ్రమ మరియు వైద్యంలో ఎంతో అవసరం దీనిలో హైడ్రోక్లోరిక్ యాసిడ్ ఉత్పత్తి ఉపయోగిస్తారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931189490-76-f.wav", "duration": 10.7740625, "text": "వారిలో ఒకరికి లైంగిక వాంఛ కలిగితే మరొకరు తమను తాము ప్రేరేపించుకుని ఆ క్షణాన్ని ఆస్వాధించేందుకు ఆరాటపడుతుంటారు", "pred_text": "వారిలో ఒకరికి లైంగిక వాంఛ కలిగితే మరొకరు తమను తాము ప్రేరేపించుకుని ఆ క్షణాన్ని ఆస్వాదించేందుకు ఆరాటపడుతుంటారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932652058-822-f.wav", "duration": 9.171875, "text": "ప్రచారంలో బాగంగా డిప్యూటీ సీఎం మహమూద్ ఆలీ సిద్దిపేటలో మైనారిటీల ఆధ్వర్యంలో నిర్వహించిన సభకు హాజరయ్యారు", "pred_text": "Pembicaraan terakhir kala pembayaran diputuskan oleh Deputy CM Mohammed Mohamad Ali Siddiwabdipet utk rakyat minoritauh wabarakat nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilai nilగా పిగా ప్రోక్ కు కు ప్రోక్ తుగించిందుతునునునునునునునునునునునునునునునునునునునునున"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932651904-944-f.wav", "duration": 7.1285625, "text": "రైతులకు న్యాయం జరిగేలా బిల్లు ఆమోదం ఆమోదించారన్నారు కెసిఆర్ కు కతజ్ఞతలు తెలిపారు", "pred_text": "రైతులకు న్యాయం జరిగేలా బిల్లు ఆమోదం ఆమోదించారన్నారు కేసీఆర్ కు కృతజ్ఞతులు తెలిపారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932651912-944-f.wav", "duration": 7.082125, "text": "కేసుల నుంచి బయటపడేందుకే ఆ పార్టీ అధ్యక్షుడు జగన్ బీజేపీతో చేతులు కలిపారన్నారు", "pred_text": "కేసుల నుంచి బయట పడేందుకే ఆ పార్టీ అధ్యక్షుడు జగన్ విజపెత్తు చేత్తులు కలిపారన్నారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932537185-1154-f.wav", "duration": 8.777125, "text": "మళ్లీ ఆ పార్టీల నేతలనే తమ పార్టీలో చేర్చుకుని కొత్త పాలన అందిస్తామంటూ టీఆర్ఎస్ మభ్యపెడుతోంది", "pred_text": "మళ్లీ ఆ పార్టీల నేతలను తమ పార్టీలో చేర్చుకుని కొత్త పాలను అందిస్తామంటూ టీఆర్ఎస్ మభ్య పెడుతోంది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931241395-860-f.wav", "duration": 6.269375, "text": "అమెరికాలో ప్రతిష్టాత్మకంగా నిర్వహించే స్పెల్లింగ్ బీ షోలో తన ప్రతిభను కనబరచాడు", "pred_text": "అమెరికాలో ప్రతిష్టాత్మకంగా నిర్వహించే స్పెల్లింగ్ బీ షోలో తన ప్రతిభను కనుబరించాడు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931358681-879-f.wav", "duration": 8.9629375, "text": "ఈ లేఅవుట్లో అత్యంత భారీ బహుళ అంతస్థులతో కూడిన భవనాల నిర్మాణానికి వీలుగా లేఅవుట్ను అభివృద్ధి చేయాలని భావిస్తున్నట్టు సమాచారం", "pred_text": "ఈ లేఅవుట్లో అత్యంత భారీ బహుళ అంతస్తులతో కూడిన భవనాల నిర్మాణానికి వీలుగా లేఅవుట్ను అభివృద్ధి చేయాలని భావిస్తున్నట్టు సమాచారం"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424930596029-860-f.wav", "duration": 10.8669375, "text": "చరమాంకంలో సహచరిణిని ఏర్పాటు చేసుకున్న వాళ్లందరి ఆస్తిపాస్తులూ యిలాటి వివాదాల్లో చిక్కుకున్నాయి", "pred_text": "చరమాంకంలో సహచరినిని ఏర్పాటు చేసుకున్న వాళ్లందరి ఆస్తిపాస్తులు ఇలాంటి వివాదాలలో చిక్కుకున్నాయి"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931241408-860-f.wav", "duration": 11.493875, "text": "సంవత్సరాల జంట కోసం బ్యాంక్ సేవల సంఖ్యను గణనీయంగా పెరిగింది మరియు వారు ఇకపై మాత్రమే రుణాలు జారీ పరిమితం", "pred_text": "సంవత్రాల జంట కోసం బ్యాంకు సేవల సంఖ్యను గమనీయంగా పెరిగింది మరియు వారి ఇకపై మాత్రమే రుణాలు జారే పరిమితం"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931210887-213-f.wav", "duration": 8.6610625, "text": "అక్కడ నిర్మాణం సంపాదించింది మీడియం యొక్క ఆమ్లత్వం బట్టి మారుతూ సామర్థ్యం విధిస్తారు", "pred_text": "అక్కడ నిర్మాణం సంపాదించింది మీడియం యొక్క ఆమ్లత్వం బట్టి మారుతూ సామగ్రం విధిస్తారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931189526-76-f.wav", "duration": 7.9876875, "text": "ఇతరులు మీ ఆధీనంలో ఉన్నారని మీకు తెలిసినప్పుడు మీరు మరింత శక్తిమంతులుగా అయిపోతారు", "pred_text": "ఇతరులు మీ ఆధీనంలో ఉన్నారని మీకు తెలిసినప్పుడు మీరు మరింత శక్తిమంతులుగా అయిపోతారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931241379-860-f.wav", "duration": 7.2910625, "text": "ఈ సందర్భంగా ఇరువురు గంట పాటు ప్రత్యేక హోదాతో పాటు వివిధ అంశాలపై చర్చించారు", "pred_text": "ఈ సందర్భంగా ఇరువురు గంటస్పాటు ప్రత్యేక హోదాతో పాటు వివిధ అంశాలపై చర్చించారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932737114-944-f.wav", "duration": 6.94275, "text": "జీన్స్ యొక్క సాంప్రదాయ రంగు క్రీడా శైలి మరియు స్ట్రిప్ రెండింటికీ పరిపూర్ణ సామరస్యంగా ఉంది", "pred_text": "జీన్స్ యొక్క సాంప్రదయ రంగు క్రీడా శైలి మరియు స్ట్రీప్ రెండింటికీ పరిపూర్ణ సామరస్యంగా ఉంది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931358625-879-f.wav", "duration": 6.478375, "text": "దాంతో ఇది అల్లు అర్జున్ కి సెకండ్ హానీమూన్ అని అతని సన్నిహితులు సరదాకా వ్యాఖ్యానిస్తున్నారు", "pred_text": "దాంతో ఇది అల్లూ అర్జున్ కీ సెకెండ్ హనీమున్ అని అతని స్నేహితులు సరదాగా వ్యాఖ్యానిస్తున్నాడు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931358621-879-f.wav", "duration": 6.478375, "text": "కానీ తాను నక్కిన మూలనుండి బయటపడేసరికే ఆ మనిషి తన పొట్టను చీల్చేస్తాడు", "pred_text": "కానీ తాను నక్కిన మూల నుండి బయటపడే సరికి ఆ మనిష్యీ తన పుట్టను చేర్చేస్తాడు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931358659-879-f.wav", "duration": 5.6656875, "text": "హేమంత్ అనే వ్యక్తి కొన్నిరోజులుగా తన ఇంట్లో ఓ రామచిలుకను పెంచుకుంటున్నాడు", "pred_text": "హేమంత్ అనే వ్యక్తి కొన్ని రోజులుగా తన ఇంట్లో ఓ రామచిల్లి కను పెంచుకుంటున్నాడు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424930596037-860-f.wav", "duration": 6.269375, "text": "ప్రముఖ స్మార్ట్ ఫోన్ బ్రాండ్ ఒప్పో మనదేశంలో కొత్త ఫోన్ లాంచ్ చేయనుంది", "pred_text": "ప్రముఖ స్మార్ట్ ఫోన్ బ్రాండ్ ఒపో మన దేశంలో కొత్త ఫోన్ లాంజ్ చేయనుంది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932542939-377-f.wav", "duration": 7.1053125, "text": "ఈ సినిమాతో ఎన్టీఆర్ హ్యాట్రిక్కొడితే చూడాలని ఆయన అభిమానులు ఆశ పడుతున్నారు", "pred_text": "ఈ సినిమాతో ఎన్టీఆర్ యాట్రిక్ కొడితే చూడాలని ఆయన అభిమానులు ఆశ పడుతున్నారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931156821-213-f.wav", "duration": 8.3591875, "text": "దేశీయంగా మందగమన పరిస్థితులు తీవ్రతరం అవుతున్న నేపథ్యంలో ఉద్యోగాల్లో కోతలు విధిస్తున్నారు", "pred_text": "దేశీయంగా మందగమన పరిస్థితులు తీవ్రతరం అవుతున్న నేపథ్యంలో ఉజ్జాగాల్లో కోతలు విధిస్తున్నారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932537189-1154-f.wav", "duration": 10.4954375, "text": "కాని దేశ వ్యాప్తంగా అనేక చోట్ల పెన్షన్దార్లు డబ్బు తీసుకోవడానికి బ్యాంకుల వద్ద క్యూ లలో పడిగాపులు కాస్తూనే ఉన్నారు", "pred_text": "tetapi di seluruh negara di mana pun ada tempat untuk penjabat pencegah jauhkan walaupun walaupun walaupun walaupun walaupun walaupun walaupun walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao walao wala��్పపల్పలులులులులులులులులు�"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424931189568-76-f.wav", "duration": 12.283375, "text": "ఈ పాయింట్ ని ఆధారంగా చేసుకొని కొత్త సీఎం అభ్యర్థిని బీజేపీ తెరపైకి తీసుకు వస్తుంది అంటూ విశ్లేషకులు అభిప్రాయపడుతున్నారు", "pred_text": "ఈ పాయింట్ని ఆధారంగా చేసుకుని కొత్త సీఎం అభ్యర్థిని బీజేపీ తెరపైకి తీసుకు వస్తుంది అంటూ విశ్లేషకులు అభిప్రాయపడుతున్నారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932651893-944-f.wav", "duration": 6.106875, "text": "పుష్పాలు వివిధ రకాల ప్రకాశవంతమైన రంగులతో కంటికి ఎంతో ఆనందం కలిగిస్తాయి", "pred_text": "Pusat pulao pulao pulao pulao pulao pulao pulao pulao pulao pulao pulao pulao pulao pulao pulao pulao pulao pulao pulao pulao pulao pulao pulao pulao pulao pulao pulao పుష్పాలు వివిధ రకాల ప్రకాశవంతమైన రంగులతో కంటికి ఎంతో ఆనందం కలిగిస్తాయి"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424932737133-944-f.wav", "duration": 5.0155, "text": "మధ్యాహ్నం ఒంటిగంటకు హస్తిన నుంచి ఆయన హైదరాబాద్కు తిరుగుముఖం పడతారు", "pred_text": "Madhyaహాను ఒంటి గంటకు హస్తిన నుంచి ఆయన హైదరాబాద్ కు తిరుగుముఖం పడతారు"}
# ...
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933323955-406-m.wav", "duration": 5.8746875, "text": "అశోక్ ఇప్పుడు ఏదైనా సురక్షితమైన ప్రదేశానికి వెళ్లి బాగా డబ్బు సంపాదించాలని నిర్ణయించుకున్నాడు", "pred_text": "అశోక్ ఇప్పుడు ఏదైనా సురక్షితమైన ప్రదేశానికి వెళ్లి బాగా డబ్బు సంపాదించాలని నిర్ణయించుకున్నాడు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933277367-192-m.wav", "duration": 6.292625, "text": "ఈ సభ ద్వారా చైతన్యవంతమైన ప్రజలు వెట్టిచాకిరిపై తిరుగుబాటు చేశారు", "pred_text": "ఈ సభ ద్వారా చైతన్యవంతమైన ప్రజలు వెట్టిచాకిరిపై తిరుగుబాటు చేశారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933340283-1150-m.wav", "duration": 13.6765625, "text": "ఆయన స్వరంలోని మాధుర్యం రామాయణ భారత భాగవతాలపై ఆయనకున్న పట్టు కారణంగా పురాణప్రవచన ప్రముఖులలో ఆయన ప్రత్యేకతను సంతరించుకున్నారు", "pred_text": "ఆయన స్వరంలోని మాధుర్యం రామాయణ భారత భాగవతాలపై ఆయనకున్న పట్టు కారణంగా పురాణ ప్రవచన ప్రముఖులలో ఆయన ప్రత్యేకతను సంతరించుకున్నారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933277355-192-m.wav", "duration": 7.175, "text": "పెద్ద భవనాలకు విశాలమైన గోపురాలను నిర్మించటానికి గణితము లో పట్టు సాధించవలసి వచ్చింది", "pred_text": "పెద భవనాలకు విశాలమైన గోపురావులను నిర్మించటానికి గణితములో పట్టు సాధించవలసి వచ్చింది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933277363-192-m.wav", "duration": 8.1734375, "text": "అదేవిధంగా అభినయాలకు స్వభావానుగుణంగా తేల్చడానికి వాద్యాలు కూడా ప్రధాన భూమికను నిర్వహిస్తాయి", "pred_text": "అదేవిధంగా అభినయాలకు స్వభావాను గుణంగా తేల్చడానికి వాద్యాలు కూడా ప్రధాన భూమికను నిర్వహిస్తాయి"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933323909-406-m.wav", "duration": 6.3855, "text": "కానీ జాతీయ రక్షణ సంస్థ ఏర్పాటు తరువాత జాయింట్ ఇంటలిజెన్స్ సంస్థ దానిలో విలీనం అయ్యింది", "pred_text": "కానీ జాతీయ రక్షణ సంస్థ ఏర్పాటు తర్వాత జాయింట్ ఇంటెలిజెన్స్ సంస్థ దానిలో విలీనం అయ్యింది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933352921-1150-m.wav", "duration": 9.1254375, "text": "వారూ అక్కడనుండి తప్పించుకోవడం ద్వారా ఆ బాలుడు తాను పుట్టిన ఐదేళ్ళ తరువాత మొదటిసారి బాహ్య ప్రపంచాన్ని చూస్తాడు", "pred_text": "వారు అక్కడ నుండి తప్పించుకోవడం ద్వారా ఆ బాలుడు తాను పుట్టిన ఐదేళ్ల తర్వాత మొదటిసారి బాహ్య ప్రపంచాన్ని చూస్తాడు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933327808-772-m.wav", "duration": 5.317375, "text": "ఆకాశం భూమి కలిసే చోటు ఎప్పటికీ కంటి వద్దే ఉండాలి", "pred_text": "ఆకాశం భూమి కలిసే చోటు ఇప్పటికీ కంటి వద్దే ఉండాలి"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933311437-1113-m.wav", "duration": 7.0124375, "text": "ఇక్కడ రాళ్ళు ప్రధానంగా ఉన్న లైంస్టోన్ పొరలు షాలె ఇసుకరాయి ఉన్నాయి", "pred_text": "ఇక్కడ రాళ్ళు ప్రధానంగా ఉన్న లైన్స్టోన్ పొరలు షాలే ఇసుకరాయి ఉన్నాయి"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933276820-192-m.wav", "duration": 6.687375, "text": "ఇచటనే ఆసూరి కేశవాచార్యులవారు పుత్రకామేష్ఠి చేసి భగవద్రామానుజులను పుత్రునిగా పొందిరి", "pred_text": "ఇచ్చటనే ఆసూరి కేశవాచార్యులు వారు పుత్ర కామెస్టు చేసి భగువ ద్రామాండుజులను పుత్రినిగా పొందిరి"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933323972-406-m.wav", "duration": 3.9938125, "text": "ఓ పనిమీద పల్లెటూరికి వచ్చి జయలక్ష్మి మాధవి తో ప్రేమలో పడతాడు", "pred_text": "ఓ పనిమీద పల్లెటూరికి వచ్చి జయలక్ష్మీ మాధవితో ప్రేమలో పడతాడు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933324199-119-m.wav", "duration": 6.6176875, "text": "కానీ హేబియాస్ కార్పస్ ఒక మినహాయింపు ఖైదీ తరపున ఎవరైనా పిటిషన్ దాఖలు చేయవచ్చు", "pred_text": "కానీ హెబియాస్ కర్పాస్ ఒక మినహాయింపు ఖైదీ తరపున ఎవరైనా పిటిషన్ దాఖలు చేయవచ్చు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933323957-406-m.wav", "duration": 4.1099375, "text": "సెయింట్ పౌల్ నగరం వంపులు తిరిగిన ఇరుకైన వీధులతో ఉంటుంది", "pred_text": "సెయింట్ ఫౌల్ నగరం వంపులు తిరిగిన ఇరుకైన వీధులతో ఉంటుంది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933276812-192-m.wav", "duration": 7.5696875, "text": "పరిపాలన సౌలభ్యం కొరకు హైదరాబాదు సంస్థానం పదహారు జిల్లాలుగా ఆ జిల్లాలను నాలుగు విభాగాలుగా చేసారు", "pred_text": "పరిపాలన సౌలభ్యం కొరకు హైదరాబాద్ సంస్థానం పదహారు జిల్లాలుగా ఆ జిల్లాలు నాలుగు విభాగాలుగా చేశారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933327866-772-m.wav", "duration": 8.5449375, "text": "వీరపునాయునిపల్లెలో నేతాజీ ప్రాథమిక పాఠశాల నెలకొల్పిన చెన్నారెడ్డి అక్కడే ఉపాధ్యాయుడిగా పనిచేశాడు", "pred_text": "వీరపు నాయునిపల్లెలో నేతాజీ ప్రాథమిక పాఠశాల నేలకొల్పిన చిన్నారెడ్డి అక్కడి ఉపాధ్యాయుడుగా పనిచేశాడు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933324216-119-m.wav", "duration": 8.428875, "text": "చిన్నస్థాయి స్వతంత్ర ప్రొవైడర్లు ఆకస్మికంగా ఉద్భవించడం ప్రభుత్వ అధికారులు ప్రోత్సహించడం వల్ల ఈ విజయం సాధ్యమైంది", "pred_text": "చిన్న స్థాయి స్వాతంతర్ ప్రొవైడర్లు ఆకస్మికంగా ఉద్భవించడం ప్రభుత్వ అధికారులు ప్రోత్తగించడం వల్ల ఈ విజయం సాధ్యమైంది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933323973-406-m.wav", "duration": 6.1300625, "text": "కేవలం పాపులు మాత్రమే చనిపోయిన పిమ్మట ఈ ద్వారం గుండా లోనికి వస్తారని ఇందులో పేర్కొన బడింది", "pred_text": "కేవలం పాములు మాత్రమే చనిపోయిన పిమ్మట ఈ ద్వారం గుండా లోనికి వస్తారని ఇందులో పేర్కొనబడింది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933324213-119-m.wav", "duration": 6.5480625, "text": "ఈ గ్రామానికి సమీపంలో చిన్న అవుటపల్లి అజ్జంపూడి గన్నవరం కేసరపల్లి తెన్నేరు గ్రామాలు ఉన్నాయి", "pred_text": "ఈ గ్రామానికి సమీపంలో చిన అవటపల్లి అంజంపూడి గన్నవరం కేసరవల్లి తెన్నేరు గ్రామాలు ఉన్నాయి"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933311411-1113-m.wav", "duration": 11.0295, "text": "అనగా మొదటి మూడవ దశలో ఘన ఇంధనాన్ని చోదక మొటారులలో వాడగా రెండవనాల్గవదశ మోటరులలో ద్రవఇంధనాన్ని వాడారు", "pred_text": "అనగా మొదటి మూడవ దశలో ఘన ఇంధనాన్ని చొదక మోటార్లలో వాడగా రెండవ నాల్గవ దశ మోటార్లలో ద్రవేంద్రాన్ని వాడతారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933324221-119-m.wav", "duration": 4.66725, "text": "కొయ్యేటిపాడు పశ్చిమ గోదావరి జిల్లా పెనుమంట్ర మండలానికి చెందిన గ్రామం", "pred_text": "కొయ్యేటిపాడు పశ్చిమ గోదావరి జిల్లా పెనుమంట్ర మండలానికి చెందిన గ్రామం"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933323920-406-m.wav", "duration": 6.4319375, "text": "సాంఘిక సమస్యలపై సాహసోపేతంగా తీసిన సినిమాగా తెలుగు సినిమా రంగంలో ప్రత్యేక స్థానం ఇచ్చారు", "pred_text": "సాంకిక సమస్యలపై సహోపేతంగా తీసిన సినిమాగా తెలుగు సినిమా రంగంలో ప్రత్యేక స్థానం ఇచ్చారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933327884-772-m.wav", "duration": 6.757, "text": "ఊరివారందరినీ సమాధాన పరిచి హేమని హరిబాబుతో పంపడం సినిమా ముగింపు", "pred_text": "ఊరివారందర్నీ సమాధానపరిచి ఏమానీ హరిబాబుతో పంపడం సినిమా ముగింపు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933276866-192-m.wav", "duration": 4.342125, "text": "అక్కడ కొద్దికాలం ఉండి తన భార్యను తీసుకొని మద్రాసు వెళతాడు", "pred_text": "అక్కడ కొద్దికాలం ఉండీ తన భారీని తీసుకుని మద్రాసు వెళతాడు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933324244-119-m.wav", "duration": 8.2895625, "text": "రొమాంటిక్ కవి మిహై ఏమినేస్కు రచయిత అయాన్ క్రేంగా లు అత్యుత్తమ ప్రభావము కలిగిన రోమేనియన్ భాష కళాకారులు", "pred_text": "రొమాంటిక్ కవి మీహై ఎయిమీనేస్ కు రచయిత అయాంక్రేంగలు అత్యుత్తమ ప్రభావం కలిగిన రోమేనియన్ బాషా కళాకారులు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933323937-406-m.wav", "duration": 6.478375, "text": "ప్లాంటులు మూసివేసి వారి ఉద్యోగాల నుండి వైదొలిగారు పి డి వి ఎస్ ఎ రిఫైనరీలు దాదాపు మూతబడ్డాయి", "pred_text": "ప్లాంటులు మూచివేసి వారు ఉద్యోగాల నుండి వైదులుగారు పీడీవీఎస్ఏ రీఫైనరేలు దాదాపు మూతబడ్డాయి"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933311393-1113-m.wav", "duration": 9.6130625, "text": "ప్రపంచంలో మనం చూసే ప్రతి దానికీ కారణమంటూ ఉంటుందనీ దానికి దేవుడు కాక సైన్సు ఆధారమనీ ఆ పుస్తకం చెప్తుంది", "pred_text": "ప్రపంచంలో మనం చూసే ప్రతీదానికి కారణం అంటూ ఉంటాదని దానికి దేవుడు కాక సైన్స్ ఆధారమని ఆ పుస్తకం చెప్పుతుంది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933276857-192-m.wav", "duration": 9.079, "text": "ప్రత్యామ్నాయంగా కొండ జాతులు సంచార ప్రాంతాలలో సంచారజాతుల ముట్టడి కారణంగా వర్తకం పతనం నీటిపారుదల విధానాల నిర్లక్ష్యతకు దారితీసాయి", "pred_text": "ప్రత్యామ్నాయంగా కొండజాతులు సంచార ప్రాంతాలలో సంచార జాతులు ముట్టడి కారణంగా వర్తకం పతనం నీటి పారుదల విధానాల నిర్లక్షతకు దారితీశాయి"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933352938-1150-m.wav", "duration": 7.7090625, "text": "గచ్చకాయలు చింత బిచ్చల సంఖ్య కూడా ఒక్కో ప్రాంతంలో ఒక్కో విధంగా ఉండటాన్ని గమనించ వచ్చు", "pred_text": "గచ్చకయాలు చింతబిచ్చల సంఖ్య కూడా ఒక్కో ప్రాంతంలో ఒక్కో విధంగా ఉండటాన్ని గమనించవచ్చు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933323967-406-m.wav", "duration": 7.1285625, "text": "ఇంద్రుడు దేవతలు పరమనీచులు కాకపోతే నా తమ్ములకు ద్రౌపదికి ఇలాంటి నరకబాధలు అనుభవించ వలసిన అగత్యము ఏమిటి", "pred_text": "ఇంద్రుడు దేవతలు పరమ నీచులు కాకపోతే నా తమ్ముళ్లకు ద్రౌపదికి ఇలాంటి నరక బాధలు అనుభవించవలసిన ఆగత్యం ఏమిటి"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933340305-1150-m.wav", "duration": 5.688875, "text": "క్యాంపస్ అనే ఇంగ్లీషు మాటే తెలుగు లోనూ ప్రాచుర్యంలో ఉంది", "pred_text": "క్యాంపజ్ అనేమే ఇంగ్లీషు మాట తెలుగులోనూ ప్రాచుర్యంలో ఉంది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933324894-810-m.wav", "duration": 7.175, "text": "టోనీని చంపడానికి అంగీకరించడమంటే ప్రపంచానికి తప్పుడు సంకేతాలు పంపడమేనంటూ వాదించింది", "pred_text": "టోనీని చంపడానికి అంగీకరించమంటే ప్రపంచానికి తప్పుడు సంకేతాలు పంపడమేనంటూ వాదించింది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933324207-119-m.wav", "duration": 5.5728125, "text": "ఉల్లివేర్లు కత్తిరించి తీసేసి మిగిలిన కాడల్ని శుభ్రంగా కడిగి సన్నగా తరగాలి", "pred_text": "ఇళ్లి వేళ్లు కత్తిరించి తీసేసి మిగిలిన కాడల్ని శుభ్రంగా కడిగి సన్నగా తరగాలి"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933352942-1150-m.wav", "duration": 10.05425, "text": "చాలక్కాయమార్గం వడిపెరియారు మార్గం ఏర్పడి తరువాత పంబా ప్రాజెక్టు నిర్మాణంలో శబరిమలకు వచ్చే భక్తుల రద్దీ పెరిగింది", "pred_text": "చాలకాయ మార్గం వరిపెరియారు మార్గం ఏర్పడి తర్వాత పంబా ప్రాజెక్టు నిర్మాణంలో శబ్రమలకు వచ్చే భక్తుల రద్దీ పెరిగింది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933324901-810-m.wav", "duration": 5.317375, "text": "పవిత్రమైన నదులలో మానవులు స్నానం చేసి వారి పాపాలను పోగొట్టుకొంటున్నారు", "pred_text": "పవిత్రమైన నదుల్లో మానవును స్నానం చేసి వారి పాపాలను పోగొట్టుకుంటున్నారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933277342-192-m.wav", "duration": 8.68425, "text": "కిలో అంటే వెయ్యి కాబట్టి కిలోమీటరు అంటే వెయ్యి మీటర్లు కిలోగ్రాము అంటే వెయ్యి గ్రాములు అని అర్థం చేసుకుంటున్నాం", "pred_text": "కిలో అంటే వెయ్యి కాబట్టి కిలోమేటరు అంటే వెయ్యి మీటర్లు కిలోగ్రామ్ అంటే వెయ్యి గ్రాములు అని అర్థం చేసుకుంటున్నాం"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933327823-772-m.wav", "duration": 11.1688125, "text": "గుప్తులు మగధలో బలబంతులైనాక పాండులు క్షీణిస్తున్న సమయంలో గుహుడు పాండులనుంచి వీడి స్వతంత్ర రాజ్యం చేసినాడు", "pred_text": "గుప్తులు మగధలో బలబంతులైనాక పాండులు క్షీణిస్తున్న సమయంలో గుహుడు పాండుల నుంచి వీరి స్వాతంత్ర్య రాజ్యం చేసినాడు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933324200-119-m.wav", "duration": 4.551125, "text": "ఈ ప్రసారాలలో నాణ్యత ధ్వనిలో స్వచ్ఛత మధ్య రకంగా ఉంటుంది", "pred_text": "ఈ ప్రసారాలలో నాణ్యత ధ్వనిలో స్వచ్ఛత మధ్య రకంగా ఉంటుంది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933340337-1150-m.wav", "duration": 7.5465, "text": "అన్ని ప్రధాన నగరాల నుండి రహదారి ద్వారా హాఫ్లాంగ్ కు రవాణా సౌకర్యం ఉంది", "pred_text": "అన్ని ప్రధాన నగరాల నుండి రహదారి ద్వారా హాఫ్ లాంగ్ కు రవాణా సౌకర్యం ఉంది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933327805-772-m.wav", "duration": 5.5728125, "text": "వేగంగా ప్రవహించే గల్వాన్ నది సమీపంలో ఈ ఘర్షణ జరిగింది", "pred_text": "వేగంగా ప్రవహించే గాల్వన్ నది సమీపంలో ఈ ఘర్షణ జరిగింది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933323893-406-m.wav", "duration": 10.4954375, "text": "ఈఇతిహాసం ఆకలితో అలమటించే భారతీయుల చేత భూమిలేని నిరుపేదలచేత దోచుకోబడుతున్న కార్మికులచేత పురోగామిశక్తుల చేత రచింపబడుతుందని ప్రకటించారు", "pred_text": "ఈ ఈతిహాసం ఆఖలితో అలుమటించే భారతీయుల చేత భూమిలేని నిరుపేదల చేత దోచుకోబడుతున్న కార్మికుల చేత పురోగమి శక్తుల చేత రచింపబడుతుందని ప్రకటించారు"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933323952-406-m.wav", "duration": 6.3390625, "text": "సమీప జూనియర్ కళాశాల రౌతులపూడిలోను ప్రభుత్వ ఆర్ట్స్ సైన్స్ డిగ్రీ కళాశాల అన్నవరంలోనూ ఉన్నాయి", "pred_text": "సమీప జూనియర్ కళాశాల రౌతులపూడిలోను ప్రభుత్వ ఆర్ట్స్ సైత్ డిగ్రీ కళాశాల అండవరంలోనూ ఉన్నాయి"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933323948-406-m.wav", "duration": 5.108375, "text": "ది కుయామక మౌంటెంస్ లాగునా మౌంటెన్లు నగరానికి తూర్పున ఉన్నాయి", "pred_text": "దీ కుయామాక మౌంటేజ్ లాగున మౌంట్ లేన్లు నగరానికి తూర్పున ఉన్నాయి"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933324890-810-m.wav", "duration": 9.2183125, "text": "దేవకి వాసుదేవులకి శ్రీకృష్ణుడు జన్మించిన ఈ ప్రదేశం ప్రముఖ పవిత్రాలయంగా విరాజిల్లుతూ పర్యాటకులను ఆకర్షిస్తుంది", "pred_text": "దేవక్యీ వసుదేవులకు శ్రీకృష్ణును జన్మించిన ఈ ప్రదేశం ప్రాముఖ్య పవిత్రాలయంగా విరజిల్లుతూ పర్యాటకులను ఆకర్షిస్తుంది"}
# {"audio_filepath": "/kaggle/input/datasets/monuj007/kathbath-benchmarks-telugu/kathbath/telugu/wavs/wavs/844424933277323-192-m.wav", "duration": 8.4753125, "text": "ప్రతి విద్యార్థి స్థానిక సామగ్రిని స్థానిక సాంకేతిక నిపుణులను ఉపయోగించి తన సొంత పరికరాలను రూపొందించాలని పట్టుబట్టాడు", "pred_text": "ప్రతి విద్యార్థి స్థానిక సామగిరి స్థానిక సాంకేతిక నిపుణులను ఉపయోగించి తన సొంత పరికరాలను రూపొందించాలని పట్టుబట్టాడు"}
