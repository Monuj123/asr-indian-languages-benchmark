# %% [markdown]
# # SraVaani-1.0 — Kathbath ASR evaluation (Hindi / Tamil / Telugu / Marathi / Bengali)
#
# Evaluates [`ARTPARK-IISc/SraVaani-1.0`](https://huggingface.co/ARTPARK-IISc/SraVaani-1.0) on the Kathbath test sets, downloaded automatically from the public Vistaar-benchmark mirror:
#
# ```
# https://indicwhisper.objectstore.e2enetworks.net/vistaar_benchmarks/kathbath.zip
# ```
#
# **What this notebook does**
# 1. Downloads + extracts `kathbath.zip` (cached — reruns skip this).
# 2. Locates each language's `test/` folder (`audio/` + `transcript.txt`), indexing audio files recursively to route around nested subfolders.
# 3. Loads SraVaani-1.0 (`trust_remote_code=True`) — **gated**, needs an HF token with accepted terms on the model page.
# 4. Runs inference in batches, printing reference / predicted text and running WER/CER as it goes.
# 5. Checkpoints every sample to a resumable `.jsonl` cache per language, so a Kaggle session timeout doesn't lose progress.
# 6. Writes one CSV per language (`id, reference, prediction, wer, cer`) plus a combined summary CSV.
#
# **Before running:** accept the gated-access terms at https://huggingface.co/ARTPARK-IISc/SraVaani-1.0, then add an HF token as a Kaggle secret named `HF_TOKEN` (Add-ons → Secrets) and enable it for this notebook — or set it directly in the cell below.

# %% [markdown]
# ## 1. Install dependencies

# %%
import os, sys

def _ensure(pkg_import, pip_name=None):
    try:
        __import__(pkg_import)
    except ImportError:
        os.system(f"{sys.executable} -m pip install -q {pip_name or pkg_import}")

for mod, pip_name in [
    ("editdistance", "editdistance"),
    ("soundfile", "soundfile"),
    ("librosa", "librosa"),
    ("tqdm", "tqdm"),
    ("requests", "requests"),
]:
    _ensure(mod, pip_name)

print("Dependencies ready.")
# Out:
# Dependencies ready.

# %% [markdown]
# ## 2. Imports and config

# %%
import gc
import json
import re
import time
import unicodedata
import zipfile
from pathlib import Path

import pandas as pd
import editdistance
import requests
import soundfile as sf
import librosa
import torch
from tqdm.auto import tqdm
from transformers import AutoModel

MODEL_REPO = "ARTPARK-IISc/SraVaani-1.0"
KATHBATH_ZIP_URL = "https://indicwhisper.objectstore.e2enetworks.net/vistaar_benchmarks/kathbath.zip"
TARGET_SR = 16000

# folder-name candidates inside the extracted zip, in case of casing/
# naming variants across mirrors
LANG_DIR_CANDIDATES = {
    # "hindi": ["hindi"],
    # "tamil": ["tamil"],
    "telugu": ["telugu"],
    # "marathi": ["marathi"],
    # "bengali": ["bengali", "bangla"],
}
SPLIT_DIR_CANDIDATES = ["test", "test_known", "test_unknown", "valid"]
AUDIO_EXTS = {".wav", ".m4a", ".mp3", ".flac"}

# %% [markdown]
# ## 3. Set your Hugging Face token
#
# Needed only to load the gated SraVaani-1.0 model — the Kathbath zip download needs no token.

# %%
# Option A: paste your token directly (quickest for a one-off Kaggle run)
# os.environ["HF_TOKEN"] = "hf_xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx"

# Option B: Kaggle secret named HF_TOKEN (Add-ons -> Secrets), picked up automatically below

def get_hf_token():
    token = os.environ.get("HF_TOKEN")
    if token:
        return token
    try:
        from kaggle_secrets import UserSecretsClient
        token = UserSecretsClient().get_secret("HF_TOKEN")
        if token:
            return token
    except Exception:
        pass
    raise RuntimeError(
        "No HF token found. Either set os.environ['HF_TOKEN'] = 'hf_...' before running, "
        "or add it as a Kaggle secret named HF_TOKEN (Add-ons -> Secrets) and enable it for this notebook. "
        "(Needed to load the gated SraVaani-1.0 model — the Kathbath download itself needs no token.)"
    )

# %% [markdown]
# ## 4. Download + extract Kathbath (Vistaar mirror)

# %%
# ================================================================ #
# Download + extract kathbath.zip (cached)
# ================================================================ #
def download_kathbath(dest_root: Path) -> Path:
    dest_root.mkdir(parents=True, exist_ok=True)
    zip_path = dest_root / "kathbath.zip"
    extract_marker = dest_root / "kathbath" / ".extracted_ok"
    extract_dir = dest_root / "kathbath"

    if extract_marker.exists():
        print(f"Kathbath already downloaded + extracted at {extract_dir}")
        return extract_dir

    if not zip_path.exists() or zip_path.stat().st_size == 0:
        print(f"Downloading kathbath.zip from {KATHBATH_ZIP_URL} ...")
        with requests.get(KATHBATH_ZIP_URL, stream=True, timeout=60) as r:
            r.raise_for_status()
            total = int(r.headers.get("content-length", 0))
            with open(zip_path, "wb") as f, tqdm(
                total=total, unit="B", unit_scale=True, desc="kathbath.zip"
            ) as pbar:
                for chunk in r.iter_content(chunk_size=1024 * 1024):
                    if chunk:
                        f.write(chunk)
                        pbar.update(len(chunk))
    else:
        print(f"Found existing {zip_path}, skipping download.")

    print(f"Extracting to {extract_dir} ...")
    extract_dir.mkdir(parents=True, exist_ok=True)
    with zipfile.ZipFile(zip_path, "r") as zf:
        members = zf.infolist()
        for m in tqdm(members, desc="extracting", unit="file"):
            zf.extract(m, extract_dir)

    extract_marker.touch()
    print("Extraction complete.")
    return extract_dir

# %% [markdown]
# ## 5. Locate each language's test split and match audio to transcripts

# %%
def find_first_existing(base: Path, candidates):
    for c in candidates:
        p = base / c
        if p.exists():
            return p
    # fuzzy fallback: case-insensitive scan of immediate children
    if base.exists():
        lower_map = {p.name.lower(): p for p in base.iterdir() if p.is_dir()}
        for c in candidates:
            if c.lower() in lower_map:
                return lower_map[c.lower()]
    return None


def locate_language_dir(kathbath_root: Path, lang: str) -> Path:
    # the zip extracts with an extra nested "kathbath/kathbath/<lang>/" layout
    # on some mirrors, and a flat "<lang>/" layout on others -- handle both.
    search_roots = [kathbath_root, kathbath_root / "kathbath"]
    for root in search_roots:
        lang_dir = find_first_existing(root, LANG_DIR_CANDIDATES[lang])
        if lang_dir is not None:
            return lang_dir
    raise FileNotFoundError(
        f"Could not locate a folder for '{lang}' under {kathbath_root}. "
        f"Check the extracted folder layout with `!find {kathbath_root} -maxdepth 4`."
    )


# manifest.json is a NeMo-style JSONL file: one JSON object per line, each
# with (at least) "audio_filepath" and "text" -- e.g.
#   {"audio_filepath": "audio/844424933726456-...-f.wav", "duration": 4.2, "text": "..."}
MANIFEST_NAME_CANDIDATES = [
    "manifest.json",
    "test_manifest.json",
    "test_known_manifest.json",
    "test_unknown_manifest.json",
    "valid_manifest.json",
]


def find_manifest_files(lang_dir: Path):
    """Return every manifest-like JSONL file for this language. Prefers an
    explicit test/known/unknown/valid manifest if several exist; otherwise
    falls back to whatever *manifest*.json files are present (recursively,
    in case they sit inside a test/ or manifests/ subfolder)."""
    found = []
    for name in MANIFEST_NAME_CANDIDATES:
        p = lang_dir / name
        if p.exists():
            found.append(p)
    if found:
        return found
    # recursive fallback: any file whose name contains "manifest" and ends in .json
    found = sorted(lang_dir.rglob("*manifest*.json"))
    if found:
        return found
    raise FileNotFoundError(
        f"No manifest.json-style file found under {lang_dir}. "
        f"Check the folder layout with `!find {lang_dir} -maxdepth 3`."
    )


def resolve_audio_path(audio_filepath: str, manifest_path: Path, lang_dir: Path, kathbath_root: Path):
    """audio_filepath inside the manifest may be absolute, relative to the
    manifest's own folder, relative to the language folder, or relative to
    the kathbath root -- try each in turn, then fall back to a recursive
    filename search under the language folder."""
    candidates = [
        Path(audio_filepath),
        manifest_path.parent / audio_filepath,
        lang_dir / audio_filepath,
        kathbath_root / audio_filepath,
    ]
    for c in candidates:
        if c.exists():
            return c

    # last resort: search for a file with this basename anywhere under lang_dir
    target_name = Path(audio_filepath).name
    for p in lang_dir.rglob(target_name):
        return p
    return None


def load_kathbath_lang(kathbath_root: Path, lang: str, max_samples: int = -1):
    lang_dir = locate_language_dir(kathbath_root, lang)
    print(f"  -> language folder for {lang}: {lang_dir}")
    manifest_paths = find_manifest_files(lang_dir)
    print(f"  -> manifest file(s): {[str(p) for p in manifest_paths]}")

    rows = []
    n_missing_audio = 0
    for manifest_path in manifest_paths:
        with open(manifest_path, "r", encoding="utf-8") as f:
            for line_no, line in enumerate(f):
                line = line.strip()
                if not line:
                    continue
                try:
                    entry = json.loads(line)
                except json.JSONDecodeError:
                    continue

                audio_filepath = entry.get("audio_filepath") or entry.get("audio_path")
                text = entry.get("text", "")
                if not audio_filepath:
                    continue

                audio_path = resolve_audio_path(audio_filepath, manifest_path, lang_dir, kathbath_root)
                if audio_path is None:
                    n_missing_audio += 1
                    continue

                utt_id = entry.get("id") or Path(audio_filepath).stem
                # disambiguate ids across multiple manifests (e.g. test_known + test_unknown)
                utt_id = f"{manifest_path.stem}:{utt_id}"

                rows.append({"id": utt_id, "audio_path": str(audio_path), "text": str(text).strip()})

    if n_missing_audio:
        print(f"  ! {n_missing_audio} manifest entries had an audio file that could not be resolved on disk")

    if max_samples and max_samples > 0:
        rows = rows[:max_samples]

    print(f"  -> {len(rows)} (audio, text) pairs loaded for {lang}")
    return rows

# %% [markdown]
# ## 6. Text normalization + WER / CER metrics

# %%
# ================================================================ #
# Text normalization + metrics (mirrors editdistance-based WER/CER
# methodology used elsewhere in this project)
# ================================================================ #
_PUNCT_RE = re.compile(r"[^\w\s\u0900-\u0DFF]", flags=re.UNICODE)


def normalize_text(text: str) -> str:
    if text is None:
        return ""
    text = unicodedata.normalize("NFC", str(text))
    text = _PUNCT_RE.sub(" ", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text


def wer(ref: str, hyp: str) -> float:
    ref_words = ref.split()
    hyp_words = hyp.split()
    if len(ref_words) == 0:
        return 0.0 if len(hyp_words) == 0 else 1.0
    return editdistance.eval(ref_words, hyp_words) / len(ref_words)


def cer(ref: str, hyp: str) -> float:
    ref_chars = ref.replace(" ", "")
    hyp_chars = hyp.replace(" ", "")
    if len(ref_chars) == 0:
        return 0.0 if len(hyp_chars) == 0 else 1.0
    return editdistance.eval(list(ref_chars), list(hyp_chars)) / len(ref_chars)

# %% [markdown]
# ## 7. Load the SraVaani-1.0 model

# %%
def load_model(hf_token: str, device: str):
    print(f"Loading {MODEL_REPO} on {device} ...")
    model = AutoModel.from_pretrained(
        MODEL_REPO, trust_remote_code=True, token=hf_token
    ).to(device).eval()
    print("Model loaded.")
    return model


def audio_to_temp_wav(audio_path: str, tmp_dir: Path, idx: int) -> str:
    """Decodes source audio (wav/m4a/mp3/flac) to a 16kHz mono wav and
    returns its path. Falls back to librosa (ffmpeg-backed) for formats
    soundfile can't read directly, e.g. m4a."""
    out_path = tmp_dir / f"sample_{idx}.wav"
    try:
        wav, sr = sf.read(audio_path, dtype="float32")
        if wav.ndim > 1:
            wav = wav.mean(axis=1)
    except Exception:
        wav, sr = librosa.load(audio_path, sr=None, mono=True)
    if sr != TARGET_SR:
        wav = librosa.resample(wav.astype("float32"), orig_sr=sr, target_sr=TARGET_SR)
    sf.write(out_path, wav, TARGET_SR)
    return str(out_path)

# %% [markdown]
# ## 8. Checkpoint cache (resumable)

# %%
# ================================================================ #
# Checkpoint cache (resumable jsonl, one line per evaluated sample)
# ================================================================ #
def load_cache(cache_path: Path):
    done = {}
    if cache_path.exists():
        with open(cache_path, "r", encoding="utf-8") as f:
            for line in f:
                line = line.strip()
                if not line:
                    continue
                try:
                    row = json.loads(line)
                    done[row["id"]] = row
                except json.JSONDecodeError:
                    continue
    return done


def append_cache(cache_path: Path, row: dict):
    with open(cache_path, "a", encoding="utf-8") as f:
        f.write(json.dumps(row, ensure_ascii=False) + "\n")

# %% [markdown]
# ## 9. Per-language evaluation loop
#
# Prints reference / predicted text and running WER/CER every `print_every` utterances, and appends every result to a `.jsonl` checkpoint so a rerun resumes instead of restarting.

# %%
# ================================================================ #
# Per-language evaluation
# ================================================================ #
def evaluate_language(model, lang, kathbath_root, out_dir, batch_size, max_samples, print_every, device):
    print(f"\n{'=' * 70}\nEvaluating language: {lang.upper()}\n{'=' * 70}")
    rows_meta = load_kathbath_lang(kathbath_root, lang, max_samples)
    n_total = len(rows_meta)
    if n_total == 0:
        print(f"  ! no utterances found for {lang}, skipping")
        return {"language": lang, "n_utterances": 0, "wer": float("nan"), "cer": float("nan")}

    cache_path = out_dir / f"{lang}_checkpoint.jsonl"
    csv_path = out_dir / f"sravaani_kathbath_{lang}_results.csv"
    tmp_dir = out_dir / f"_tmp_wav_{lang}"
    tmp_dir.mkdir(parents=True, exist_ok=True)

    done = load_cache(cache_path)
    if done:
        print(f"  resuming from checkpoint: {len(done)}/{n_total} already done")

    pending = [r for r in rows_meta if r["id"] not in done]

    running_wer_sum, running_cer_sum, running_n = 0.0, 0.0, 0
    for r in done.values():
        running_wer_sum += r["wer"]
        running_cer_sum += r["cer"]
        running_n += 1

    pbar = tqdm(total=n_total, initial=len(done), desc=f"{lang}", unit="utt")

    batch_paths, batch_meta = [], []

    def flush_batch():
        nonlocal running_wer_sum, running_cer_sum, running_n
        if not batch_paths:
            return
        try:
            hyps = model.transcribe(batch_paths, batch_size=len(batch_paths), return_hypotheses=True)
        except TypeError:
            hyps = model.transcribe(batch_paths, return_hypotheses=True)

        for wav_path, meta, hyp in zip(batch_paths, batch_meta, hyps):
            ref_raw = meta["text"]
            pred_raw = hyp.text if hasattr(hyp, "text") else str(hyp)

            ref_norm = normalize_text(ref_raw)
            pred_norm = normalize_text(pred_raw)
            u_wer = wer(ref_norm, pred_norm)
            u_cer = cer(ref_norm, pred_norm)

            row = {
                "id": meta["id"],
                "language": lang,
                "reference": ref_raw,
                "prediction": pred_raw,
                "wer": round(u_wer, 4),
                "cer": round(u_cer, 4),
            }
            append_cache(cache_path, row)
            done[meta["id"]] = row

            running_wer_sum += u_wer
            running_cer_sum += u_cer
            running_n += 1

            if running_n % print_every == 0:
                tqdm.write(
                    f"  [{lang}] #{meta['id']} REF : {ref_raw}\n"
                    f"  [{lang}] #{meta['id']} PRED: {pred_raw}\n"
                    f"  [{lang}] running avg -> WER {running_wer_sum / running_n:.4f} | "
                    f"CER {running_cer_sum / running_n:.4f}  ({running_n}/{n_total})"
                )
            try:
                os.remove(wav_path)
            except OSError:
                pass
            pbar.update(1)
        batch_paths.clear()
        batch_meta.clear()

    for i, meta in enumerate(pending):
        wav_path = audio_to_temp_wav(meta["audio_path"], tmp_dir, i)
        batch_paths.append(wav_path)
        batch_meta.append(meta)
        if len(batch_paths) >= batch_size:
            flush_batch()
    flush_batch()
    pbar.close()

    # final CSV for this language, in original transcript order
    ordered_rows = [done[r["id"]] for r in rows_meta if r["id"] in done]
    df = pd.DataFrame(ordered_rows)
    df.to_csv(csv_path, index=False, encoding="utf-8-sig")

    lang_wer = df["wer"].mean() if len(df) else float("nan")
    lang_cer = df["cer"].mean() if len(df) else float("nan")
    print(f"  DONE {lang}: n={len(df)}  WER={lang_wer:.4f}  CER={lang_cer:.4f}")
    print(f"  -> {csv_path}")

    try:
        tmp_dir.rmdir()
    except OSError:
        pass

    gc.collect()
    if device == "cuda":
        torch.cuda.empty_cache()

    return {"language": lang, "n_utterances": len(df), "wer": lang_wer, "cer": lang_cer}

# %% [markdown]
# ## 10. Run configuration

# %%
LANGUAGES = ["telugu"]
BATCH_SIZE = 8
MAX_SAMPLES = -1       # -1 = full test set; set e.g. 50 for a quick smoke test first
PRINT_EVERY = 20
OUT_DIR = Path("/kaggle/working/sravaani_kathbath_eval")
DATA_DIR = Path("/kaggle/working/kathbath_data")

OUT_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## 11. Download data + load model

# %%
kathbath_root = download_kathbath(DATA_DIR)

hf_token = get_hf_token()
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Device: {device}")

model = load_model(hf_token, device)
# Out:
# Kathbath already downloaded + extracted at /kaggle/working/kathbath_data/kathbath
# Device: cuda
# Loading ARTPARK-IISc/SraVaani-1.0 on cuda ...
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Model loaded.

# %% [markdown]
# ## 12. Run evaluation across all languages

# %%
summary = []
t0 = time.time()
for lang in LANGUAGES:
    result = evaluate_language(
        model, lang, kathbath_root, OUT_DIR,
        batch_size=BATCH_SIZE,
        max_samples=MAX_SAMPLES,
        print_every=PRINT_EVERY,
        device=device,
    )
    summary.append(result)
    pd.DataFrame(summary).to_csv(OUT_DIR / "sravaani_kathbath_summary.csv", index=False)

elapsed = time.time() - t0
print(f"\n{'=' * 70}\nALL LANGUAGES DONE in {elapsed / 60:.1f} min\n{'=' * 70}")
summary_df = pd.DataFrame(summary)
print(summary_df.to_string(index=False))
print(f"\nPer-language CSVs + summary written to: {OUT_DIR}")
summary_df
# Out:
# ======================================================================
# Evaluating language: TELUGU
# ======================================================================
#   -> language folder for telugu: /kaggle/working/kathbath_data/kathbath/kathbath/telugu
#   -> manifest file(s): ['/kaggle/working/kathbath_data/kathbath/kathbath/telugu/manifest.json']
#   -> 1492 (audio, text) pairs loaded for telugu
# telugu:   0%|          | 0/1492 [00:00<?, ?utt/s]
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:1787: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters(). (Triggered internally at /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1480.)
#   return forward_call(*args, **kwargs)
#   [telugu] #manifest:844424932652060-822-f REF : కొంతకాలంగా టీడీపీ నుంచి కొందరు ఎమ్మెల్యేలు బయటకు వెళ్లిపోతారనే ప్రచారం జోరుగా సాగుతోంది
#   [telugu] #manifest:844424932652060-822-f PRED: కొంతకాలంగా టీడీపీ నుంచి కొందరు ఎమ్మెల్యేలు బయటకు వెళ్తారనే ప్రచారం జోరుగా సాగుతోంది
#   [telugu] running avg -> WER 0.1155 | CER 0.0191  (20/1492)
#   [telugu] #manifest:844424932652107-822-f REF : సంజయ్ రావత్ మొదటి నుంచీ బీజేపీ పట్ల ఒకింత విమర్శనాత్మకంగానే వ్యవహరిస్తున్నారు
#   [telugu] #manifest:844424932652107-822-f PRED: సంజయ్ రావత్ మొదటి నుంచి బీజేపీ పట్ల వంకిత విమర్శనాత్మకంగానే వ్యవహరిస్తున్నారు
#   [telugu] running avg -> WER 0.1881 | CER 0.0273  (40/1492)
#   [telugu] #manifest:844424931358624-879-f REF : కలకత్తాకు చెందిన ఈమె ఈ మధ్యే టాలీవుడ్ లో స్టైలిస్ట్ గా బాగా పాపులర్ అయింది
#   [telugu] #manifest:844424931358624-879-f PRED: కలకత్తాకు చెందిన ఈమె ఈ మధ్య టాలీవుడ్ లో స్టైలిస్ట్ గా బాగా పాపులర్ అయింది
#   [telugu] running avg -> WER 0.1798 | CER 0.0237  (60/1492)
#   [telugu] #manifest:844424930603381-860-f REF : కర్నాటక రాష్ట్రంలోని పడమటి భాగంలో దాగి వున్న చరిత్ర గడగ్ పట్టణం
#   [telugu] #manifest:844424930603381-860-f PRED: కర్ణాటక రాష్ట్రంలోని పడమట భాగంలో దాగి ఉన్న చరిత్ర గడగ్ పట్టణం
#   [telugu] running avg -> WER 0.1757 | CER 0.0242  (80/1492)
#   [telugu] #manifest:844424931189497-76-f REF : లేదా వాటిపై మేం తీసిన వీడియోలను మా వెబ్సైట్ ఇన్స్టాగ్రామ్ అకౌంటులో చూడండి
#   [telugu] #manifest:844424931189497-76-f PRED: లేదా వాటిపై మేం తీసిన వీడియోలను మా వెబ్సైట్ ఇన్స్టాగ్రామ్ అకౌంట్ లో చూడండి
#   [telugu] running avg -> WER 0.1800 | CER 0.0254  (100/1492)
#   [telugu] #manifest:844424932542939-377-f REF : ఈ సినిమాతో ఎన్టీఆర్ హ్యాట్రిక్కొడితే చూడాలని ఆయన అభిమానులు ఆశ పడుతున్నారు
#   [telugu] #manifest:844424932542939-377-f PRED: ఈ సినిమాతో ఎన్టీఆర్ హ్యాట్రిక్ కొడితే చూడాలని ఆయన అభిమానులు ఆశపడుతున్నారు
#   [telugu] running avg -> WER 0.1773 | CER 0.0244  (120/1492)
#   [telugu] #manifest:844424931156804-213-f REF : ఒడిశా సీఎం ముఖ్యమంత్రి నవీన్ పట్నాయక్ ఆధ్వర్యంలో ఇదే విషయం కేంద్రానికి కూడా విజ్ఞప్తి చేశామన్నారు
#   [telugu] #manifest:844424931156804-213-f PRED: ఒడిశా సీఎం ముఖ్యమంత్రి నవీన్ పట్నాయక్ ఆధ్వర్యంలో ఇదే విషయం కేంద్రానికి కూడా విజ్ఞప్తి చేశామన్నారు
#   [telugu] running avg -> WER 0.1775 | CER 0.0229  (140/1492)
#   [telugu] #manifest:844424930596090-860-f REF : ఇప్పుడు సాయి ధరమ్ తేజ సినిమా డేట్ హుష్ కాకి అయిపోయింది
#   [telugu] #manifest:844424930596090-860-f PRED: ఇప్పుడు సాయి ధరమ్ తేజ్ సినిమా డేట్ పుష్ కాకీ అయిపోయింది
#   [telugu] running avg -> WER 0.1813 | CER 0.0231  (160/1492)
#   [telugu] #manifest:844424931156799-213-f REF : అంతకముందు కచ్చులూరలో బోటు ప్రమాదస్థలిలో సీఎం వైఎస్ జగన్ ఏరియల్ సర్వే నిర్వహించారు
#   [telugu] #manifest:844424931156799-213-f PRED: అంతకు ముందు కచ్చులూరలో బోటు ప్రమాదస్థలిలో సీఎం వైఎస్ జగన్ ఏరియల్ సర్వే నిర్వహించారు
#   [telugu] running avg -> WER 0.1787 | CER 0.0229  (180/1492)
#   [telugu] #manifest:844424932651831-944-f REF : అలాగే బ్లాక్ బస్టర్ అయితే సినిమా నాలుగు వారాలు కనీసం థియేటర్లలో వుంటుంది
#   [telugu] #manifest:844424932651831-944-f PRED: అలాగే బ్లాక్ బస్టర్ అయితే సినిమా నాలుగు వారాల కనీసం థియేటర్లోనే ఉంటుంది
#   [telugu] running avg -> WER 0.1802 | CER 0.0234  (200/1492)
#   [telugu] #manifest:844424931358711-879-f REF : తాజాగా బయటపడిన వీడియోకాన్ గ్రూప్నకు ఇచ్చిన రుణాల కేటాయింపు అవకతవకలతో ఐసిఐసిఐ బ్యాంకు విశ్వసనీయత మసకబారిందని బిజినెస్ అనలిస్ట్లు అభిప్రాయపడుతున్నారు
#   [telugu] #manifest:844424931358711-879-f PRED: తాజాగా బయటపడిన వీడియోకాన్ గ్రూప్కు ఇచ్చిన రుణాల కేటాయింపు అవకతవకలతో ఐసీఐసీ బ్యాంకు విశ్వసనీయత మశకబారిందని బిజినెస్ అనలిస్టులు అభిప్రాయపడుతున్నారు
#   [telugu] running avg -> WER 0.1788 | CER 0.0233  (220/1492)
#   [telugu] #manifest:844424930603365-860-f REF : దీని కోర్సులు ఒక వ్యక్తి జీవితంలో పొందవలసిన సహాయపడే ప్రధాన అడ్డంకులు అధిగమించి లక్ష్యంగా ఉంటాయి
#   [telugu] #manifest:844424930603365-860-f PRED: దీని కోర్సులు ఒక వ్యక్తి జీవితంలో పొందవలసిన సహాయపడే ప్రధాన అడ్డంకులు అధిగమించి లక్ష్యంగా ఉంటాయి
#   [telugu] running avg -> WER 0.1744 | CER 0.0226  (240/1492)
#   [telugu] #manifest:844424932537224-1154-f REF : లైంగిక సంపర్కం తరువాత కూడా మూత్ర విసర్జన చేసి జననాంగాల్ని ఎక్కువ నీటితో శుభ్రపరచుకోవాలి
#   [telugu] #manifest:844424932537224-1154-f PRED: లైంగిక సంపర్కం తర్వాత కూడా మూత్ర విసర్జన చేసి జననాంగాన్ని ఎక్కువ నీటితో శుభ్రపరుచుకోవాలి
#   [telugu] running avg -> WER 0.1737 | CER 0.0228  (260/1492)
#   [telugu] #manifest:844424932737150-944-f REF : ఇప్పుడు మనం పాకిస్తాన్ను అదుపు చేసేందుకు ఎలాంటి చర్యకు దిగినా చైనా జోక్యం చేసుకునే పరిస్థితులు నెలకొన్నాయి
#   [telugu] #manifest:844424932737150-944-f PRED: ఇప్పుడు మనం పాకిస్తాన్ను అదుపు చేసేందుకు ఎలాంటి చర్యకు దిగినా చైనా జోక్యం చేసుకునే పరిస్థితులు నెలకొన్నాయి
#   [telugu] running avg -> WER 0.1744 | CER 0.0234  (280/1492)
#   [telugu] #manifest:844424931140366-213-f REF : నాసిరకం శానిటైజర్లు తయారు చేస్తున్న కంపెనీలపై అక్కడి ఆరోగ్య శాఖా మంత్రి అనిల్ విజ్ ఆగ్రహం వ్యక్తం చేశారు
#   [telugu] #manifest:844424931140366-213-f PRED: నాసిరకం శానిటైజర్లు తయారు చేస్తున్న కంపెనీలపై అక్కడి ఆరోగ్య శాఖ మంత్రి అనిల్ విజ్ ఆగ్రహం వ్యక్తం చేశారు
#   [telugu] running avg -> WER 0.1711 | CER 0.0230  (300/1492)
#   [telugu] #manifest:844424932537198-1154-f REF : అలాంటి దానికి భిన్నంగా బుధవారం నిర్వహించిన మీడియా సమావేశంలో సీను కనిపించింది
#   [telugu] #manifest:844424932537198-1154-f PRED: అలాంటి దానికి భిన్నంగా బుధవారం నిర్వహించిన మీడియా సమావేశంలో సీను కనిపించింది
#   [telugu] running avg -> WER 0.1710 | CER 0.0227  (320/1492)
#   [telugu] #manifest:844424931358578-879-f REF : బండి ఆపి అలవాటైన ఇల్లే కావటంతో హడావుడి లేకుండానే గుమ్మం లోపలికి వచ్చేసాడు ఆద్విక్
#   [telugu] #manifest:844424931358578-879-f PRED: బండియాపి అలవాటైన ఇళ్లే కావడంతో హడావుడి లేకుండానే గుమ్మం లోపలికి వచ్చేశాడు ఆద్విక్
#   [telugu] running avg -> WER 0.1744 | CER 0.0233  (340/1492)
#   [telugu] #manifest:844424931358660-879-f REF : దివంగత నేత సుష్మా స్వరాజ్ సైతం ఆజంఖాన్ వ్యాఖ్యలపై మండిపడుతూ ఉండేవారు
#   [telugu] #manifest:844424931358660-879-f PRED: దివంగత నేత సుష్మా స్వరాజ్ సైతం అజంకాన్ వ్యాఖ్యలపై మండిపడుతూ ఉండేవారు
#   [telugu] running avg -> WER 0.1730 | CER 0.0235  (360/1492)
#   [telugu] #manifest:844424931210897-213-f REF : పెరటి పక్షి జాతులు విస్తృతమైన విభిన్న పక్షి జాతులకు తమ పెంపుడు జంతువులను ఆకర్షణీయంగా చేసుకోవటానికి అనేక దశలను తీసుకుంటాయి
#   [telugu] #manifest:844424931210897-213-f PRED: పెరటి పక్షిజాతులు విస్తృతమైన విభిన్న పక్షిజాతులకు తమ పెంపుడు జంతువులను ఆకర్షణీయంగా చేసుకోవడానికి అనేక దశలను తీసుకుంటాయి
#   [telugu] running avg -> WER 0.1768 | CER 0.0239  (380/1492)
#   [telugu] #manifest:844424931189549-76-f REF : హర్యానా వెర్సస్ భజన్లాల్ కేసులో సుప్రీంకోర్టు మార్గదర్శకాలకు విరుద్ధంగా పోలీసులు తనపై కేసులు పెట్టారని రవిప్రకాశ్ పేర్కొన్నారు
#   [telugu] #manifest:844424931189549-76-f PRED: హర్యానా వర్సెస్ భజన్లాల్ కేసులో సుప్రీంకోర్టు మార్గదర్శకాలకు విరుద్ధంగా పోలీసులు తనపై కేసు పెట్టారని రవిప్రకాష్ పేర్కొన్నారు
#   [telugu] running avg -> WER 0.1780 | CER 0.0242  (400/1492)
#   [telugu] #manifest:844424931189525-76-f REF : ఈ కేసులో ముందస్తు బెయిల్ కోసం చిదంబరం తాజాగా అప్పీల్ చేసుకున్నారు
#   [telugu] #manifest:844424931189525-76-f PRED: ఈ కేసులో ముందస్తు బెయిల్ కోసం చిదంబరం తాజాగా అప్పీల్ చేసుకున్నారు
#   [telugu] running avg -> WER 0.1762 | CER 0.0240  (420/1492)
#   [telugu] #manifest:844424932652077-822-f REF : ట్రేప్జాయిడ్ ఆకారంలో అత్యంత ప్రజాదరణ పొందిన వేసవి దుస్తులలో ఒకటి నార మరియు పత్తి ఉత్పత్తులు
#   [telugu] #manifest:844424932652077-822-f PRED: ట్రేస్పాయిడ్ ఆకారంలో అత్యంత ప్రజాదరణ పొందిన వేసవి దుస్తులలో ఒకటి నార మరియు పత్తి ఉత్పత్తులు
#   [telugu] running avg -> WER 0.1754 | CER 0.0238  (440/1492)
#   [telugu] #manifest:844424931189491-76-f REF : దీంతో రాఫెల్ ఒప్పందంపై సీబీఐ విచారణ జరుగకూడదన్న అభిప్రాయంతో తెరవెనుక ఎవరో వున్నట్లు స్పష్టమవుతోంది
#   [telugu] #manifest:844424931189491-76-f PRED: దీంతో రాఫెల్ ఒప్పందంపై సీబీఐ విచారణ జరగకూడదన్న అభిప్రాయంతో తెర వెనుక ఎవరో ఉన్నట్లు స్పష్టమవుతోంది
#   [telugu] running avg -> WER 0.1775 | CER 0.0242  (460/1492)
#   [telugu] #manifest:844424932651908-944-f REF : ఈ దేశాలను సందర్శించటానికి యుక్రెయిన్ పౌరులు వీసా జారీ చేయాలి
#   [telugu] #manifest:844424932651908-944-f PRED: ఈ దేశాలను సందర్శించటానికి యూక్రెన్ పౌరులు వీసా జారీ చేయాలి
#   [telugu] running avg -> WER 0.1780 | CER 0.0245  (480/1492)
#   [telugu] #manifest:844424930603331-860-f REF : లెర్నింగ్ లైసెన్స్ తో కార్ డ్రైవింగ్ చేస్తూ రోడ్ పైకి వచ్చింది ఒక మహిళ
#   [telugu] #manifest:844424930603331-860-f PRED: లర్నింగ్ లైసెన్స్ తో కార్ డ్రైవింగ్ చేస్తూ రోడ్డుపైకి వచ్చింది ఒక మహిళ
#   [telugu] running avg -> WER 0.1783 | CER 0.0244  (500/1492)
#   [telugu] #manifest:844424932652027-822-f REF : ఇక్కడ రిహన్న తన వక్షోజాలను దాచడానికి మొసలి చర్మపు రంగుని ఆ ప్రదేశంలో పూసుకుంది
#   [telugu] #manifest:844424932652027-822-f PRED: ఇక్కడ రిహాన్ తన వాక్షజాలాలను దాచడానికి ముసలి చర్మపు రంగును ఆ ప్రదేశంలో పూసుకుంది
#   [telugu] running avg -> WER 0.1796 | CER 0.0250  (520/1492)
#   [telugu] #manifest:844424931241422-860-f REF : అందుకని అతను పార్మేనియన్ స్థానములో ఉన్న అవకాశమున్నట్లయితే అతను కూడా ఈ ప్రతిపాదనను అంగీకరించినట్లు అతను ప్రత్యుత్తరమిచ్చాడు
#   [telugu] #manifest:844424931241422-860-f PRED: అందుకని అతను పార్మానేనియా స్థానంలో ఉన్న అవకాశం ఉన్నట్లయితే అతను కూడా ఆ ప్రతిపాదనను అంగీకరించినట్లు అతను ప్రత్యుత్తరమిచ్చాడు
#   [telugu] running avg -> WER 0.1790 | CER 0.0249  (540/1492)
#   [telugu] #manifest:844424932652066-822-f REF : మహిళలపై వరుసగా చోటుచేసుకుంటున్న అత్యాచార ఘటనలు శివరాజ్ సింగ్ చౌహాన్ ప్రభుత్వానికి ఊపిరాడనివ్వడం లేదు
#   [telugu] #manifest:844424932652066-822-f PRED: వీటిపై వరుసగా చోటు చేసుకుంటున్న అత్యాచారాల ఘటనలో శివరాం సింగ్ చౌహాన్ ప్రభుత్వానికి ఊపిరాడడం లేదు
#   [telugu] running avg -> WER 0.1813 | CER 0.0253  (560/1492)
#   [telugu] #manifest:844424930596003-860-f REF : ముఖ్యంగా గ్రామీణ ప్రాంతాల ప్రజలు ఈ పాము కాటుకు బలైపోతున్నట్లు తేలింది
#   [telugu] #manifest:844424930596003-860-f PRED: ముఖ్యంగా గ్రామీణ ప్రాంతాల ప్రజలు ఈ పాము కాటుకు బలైపోతున్నట్లు తెలిసింది
#   [telugu] running avg -> WER 0.1803 | CER 0.0252  (580/1492)
#   [telugu] #manifest:844424930603346-860-f REF : ఇది ఒక సామాన్య అచ్చు యంత్రాన్ని ఉపయోగించి ఆపై పదార్థం ప్రాసెస్ చేయడానికి అనుమతిస్తుంది మరియు తర్వాత ఎండబెడతారు
#   [telugu] #manifest:844424930603346-860-f PRED: ఇదొక సామాన్య అచ్చు యంత్రాన్ని ఉపయోగించి ఆపై పదార్థం ప్రాసెస్ చేయడానికి అనుమతిస్తుంది మరియు తర్వాత ఎండబెడుతారు
#   [telugu] running avg -> WER 0.1823 | CER 0.0257  (600/1492)
#   [telugu] #manifest:844424931189534-76-f REF : అసెంబ్లీ ఎన్నికల్లో ఏ పార్టీకి స్పష్టమైన మెజార్టీ రాకపోవడంతో ఎవరు ప్రభుత్వం ఏర్పాటు చేస్తారనేది ఆసక్తిగా మారింది
#   [telugu] #manifest:844424931189534-76-f PRED: అసెంబ్లీ ఎన్నికల్లో ఏ పార్టీకి స్పష్టమైన మెజార్టీ రాకపోవడంతో ఎవరు ప్రభుత్వం ఏర్పాటు చేస్తారనేది ఆసక్తిగా మారింది
#   [telugu] running avg -> WER 0.1818 | CER 0.0259  (620/1492)
#   [telugu] #manifest:844424931189561-76-f REF : ఎంఎల్ఏలకు కూడా హరితహారం మీద శ్రద్ధ పెరగడంతో పాటు వారికి వనభోజనాలకు వచ్చిన తృప్తి కలుగుతుందని సిఎం వ్యాఖ్యానించారు
#   [telugu] #manifest:844424931189561-76-f PRED: ఎమ్మెల్యేలకు కూడా హరితహారం మీద శ్రద్ధ పెరగడంతో పాటు వారికి వనభోజనాలకు వచ్చిన తృప్తి కలుగుతుందని సీఎం వ్యాఖ్యానించారు
#   [telugu] running avg -> WER 0.1803 | CER 0.0257  (640/1492)
#   [telugu] #manifest:844424932537139-1154-f REF : నేరుగా మీ మోచేతులు లాక్ మరియు మీ వైపు మీ చేతులు ఉంచడం సాగిన ప్రాముఖ్యం పెంచుతుంది
#   [telugu] #manifest:844424932537139-1154-f PRED: నేరుగా మీ మోచేతులు లాక్ మరియు మీ వైపు మీ చేతులు ఉంచడం సాగిన ప్రాముఖ్యం పెంచుతుంది
#   [telugu] running avg -> WER 0.1810 | CER 0.0256  (660/1492)
#   [telugu] #manifest:844424932651844-944-f REF : ఇంటర్నెట్ను నిర్దిష్టమైన వెబ్సైట్లకో లేదా యాప్స్కో పరిమితం చేసే టెలికాం సంస్థల ప్రయత్నాలను అడ్డుకోవాలని డిమాండ్ చేశారు
#   [telugu] #manifest:844424932651844-944-f PRED: ఇంటర్నెట్ను నిర్దిష్టమైన వెబ్సైట్లకో లేదా యాప్స్కో పరిమితం చేసే టెలికం సంస్థల ప్రయత్నాలను అడ్డుకోవాలని డిమాండ్ చేశారు
#   [telugu] running avg -> WER 0.1809 | CER 0.0256  (680/1492)
#   [telugu] #manifest:844424932537158-1154-f REF : కోవ్య్రా క్రియేషన్స్ పతాకంపై రూపొందిన ఈ సినిమాకి నాగానిక చాగంరెడ్డి సమర్పించారు
#   [telugu] #manifest:844424932537158-1154-f PRED: కోవియా క్రియేషన్స్ పథకంపై రూపొందించిన ఈ సినిమాకి నాగానిక చాగం రెడ్డి సమర్పించారు
#   [telugu] running avg -> WER 0.1804 | CER 0.0258  (700/1492)
#   [telugu] #manifest:844424931358528-879-f REF : బుధవారం కురిసిన వర్షాలకు భద్రాచలంలోని శివారు ప్రాంతాలోని లోతట్టు ప్రాంతాల్లో వర్షం నీటికి ఇండ్లు నీటమునిగాయి
#   [telugu] #manifest:844424931358528-879-f PRED: బుధవారం కురిసిన వర్షాలకు భద్రాచలంలోని శివారు ప్రాంతాల్లోని లోతట్టు ప్రాంతాల్లో వర్షం నీటికి ఇండ్లు నీట మునిగాయి
#   [telugu] running avg -> WER 0.1795 | CER 0.0258  (720/1492)
#   [telugu] #manifest:844424932651879-944-f REF : వరుసగా ఐదారు ఫెయిల్యూర్లు ఎదురైనపుడు కూడా రవితేజ ఇంత గ్యాప్ ఎవరికీతీసుకున్నది లేదు
#   [telugu] #manifest:844424932651879-944-f PRED: వరుసగా ఐదారు ఫెయిల్యూర్లు ఎదురైనప్పుడు కూడా రవితేజ ఇంత గ్యాప్ ఎవరికీ తీసుకున్నది లేదు
#   [telugu] running avg -> WER 0.1805 | CER 0.0257  (740/1492)
#   [telugu] #manifest:844424931156872-213-f REF : అది అంతగా క్లిక్ కాకపోతే మళ్లీ తెలుగులోనే ఒక విభిన్నమైన సినిమా చేసేందుకు ప్రణాళిక రచించుకున్నాడు
#   [telugu] #manifest:844424931156872-213-f PRED: అది అంతగా క్లిక్ కాకపోతే మళ్లీ తెలుగులోనే ఒక విభిన్నమైన సినిమా చేసేందుకు ప్రణాళిక రచించుకున్నాడు
#   [telugu] running avg -> WER 0.1783 | CER 0.0254  (760/1492)
#   [telugu] #manifest:844424930593521-831-m REF : తమిళనాడు ముఖ్యమంత్రి ఎడప్పాడి పళనిసామి నీతి అయోగ్ సమావేశంలో పాల్గోనడానికి వెళ్లే ముందు చెన్నైలో బిజీబిజీగా గడిపారు
#   [telugu] #manifest:844424930593521-831-m PRED: తమిళనాడు ముఖ్యమంత్రి ఎడపాడ పళనిస్వామి నిత్యయోగ సమావేశంలో పాల్గొనడానికి వెళ్లేముందు చెన్నైలో బిజీబిజీగా గడిపారు
#   [telugu] running avg -> WER 0.1799 | CER 0.0257  (780/1492)
#   [telugu] #manifest:844424930593562-831-m REF : అంతా సానుకూలంగా ఉన్నట్టు కథనాలు వచ్చినప్పటికీ చివరి నిమిషంలో కాంగ్రెస్ చేయిచ్చింది
#   [telugu] #manifest:844424930593562-831-m PRED: అంత అసానుకూలంగా ఉన్నట్టు కథనాలు వచ్చినప్పటికీ చివరి నిమిషంలో కాంగ్రెస్ చేయిచ్చింది
#   [telugu] running avg -> WER 0.1801 | CER 0.0260  (800/1492)
#   [telugu] #manifest:844424930594234-352-m REF : తీవ్ర వర్షాభావం వల్ల పంట కోసం పెట్టిన పెట్టుబడులు సైతం రాక తీవ్ర అవస్థలు పడేవారు
#   [telugu] #manifest:844424930594234-352-m PRED: తీవ్ర వర్షాభావం వల్ల పంట కోసం పెట్టిన పెట్టుబడులు సైతం రాక తీవ్ర అవస్థలు పడేవారు
#   [telugu] running avg -> WER 0.1808 | CER 0.0263  (820/1492)
#   [telugu] #manifest:844424931035022-831-m REF : ఇది తన చేతులు చూడండి కాదు మరియు నేరుగా ముందుకు చూడండి మరియు ఒక మాన్ సమర్పించడానికి ముఖ్యం
#   [telugu] #manifest:844424931035022-831-m PRED: ఇక తన చేతులు చూడండి కాదు మరియు నేరుగా ముందుకు చూడండి మరియు ఒక మాన్ సమర్పించడానికి ముఖ్యం
#   [telugu] running avg -> WER 0.1805 | CER 0.0264  (840/1492)
#   [telugu] #manifest:844424930594210-352-m REF : ఆయన ఎంచుకున్న సబ్జక్ట్స్ ఫెయిల్ అయివుండొచ్చు కానీ ఆయన ప్రతిభ మీద ఎవరికీ అపనమ్మకాలు లేవు
#   [telugu] #manifest:844424930594210-352-m PRED: ఆయన ఎంచుకున్న సబ్జెక్ట్స్ ఫీల్ అయ్యుండొచ్చు కానీ ఆయన ప్రతిభ మీద ఎవరికీ అపనమ్మకాలు లేవు
#   [telugu] running avg -> WER 0.1815 | CER 0.0269  (860/1492)
#   [telugu] #manifest:844424930594272-352-m REF : ఈ నేపథ్యంలో అధినేతల దృష్టిని ఆకర్శించడానికి ఆయా పార్టీల్లోని ఆశావాహులంతా పోటీలు పడుతున్నారనే విశ్లేషణలు వినిపిస్తున్నాయి
#   [telugu] #manifest:844424930594272-352-m PRED: ఈ నేపథ్యంలో అధినేతల దృష్టిని ఆకర్షించడానికి ఆయా పార్టీలోనే ఆశావాహులంతా పోటీలు పడుతున్నారనే విశ్లేషణలు వినిపిస్తున్నాయి
#   [telugu] running avg -> WER 0.1811 | CER 0.0270  (880/1492)
#   [telugu] #manifest:844424930594206-352-m REF : తన భార్యను కాపురానికి పంపకపోతే అక్కడి నుంచి దూకి ఆత్మహత్య చేసుకుంటానని హల్చల్ చేశాడు
#   [telugu] #manifest:844424930594206-352-m PRED: తన భార్యను కాపురానికి పంపకపోతే అక్కడి నుంచి దూకి ఆత్మహత్య చేసుకుంటాడని హల్ చల్ చేశాడు
#   [telugu] running avg -> WER 0.1808 | CER 0.0271  (900/1492)
#   [telugu] #manifest:844424930594207-352-m REF : సరస్వతి నది ఒడ్డున ఉన్న అతి పెద్ద హరప్పా ప్రాంతం గానేరివాలా
#   [telugu] #manifest:844424930594207-352-m PRED: సరస్వతి నది ఒడ్డున ఉన్న అతి పెద్ద హరప్పా ప్రాంతం గానేరి వాలా
#   [telugu] running avg -> WER 0.1809 | CER 0.0273  (920/1492)
#   [telugu] #manifest:844424930594286-352-m REF : చెప్పను బ్రదర్ అనే ఒక్క మాటతో ఒక్కసారిగా నెగిటివ్ కామెంట్స్ ను తెచ్చుకున్నాడు
#   [telugu] #manifest:844424930594286-352-m PRED: చెప్పన్ బ్రదర్ అనే ఒక్క మాటతో ఒక్కసారిగా నెగటివ్ కామెంట్స్ ను తెచ్చుకున్నాడు
#   [telugu] running avg -> WER 0.1834 | CER 0.0284  (940/1492)
#   [telugu] #manifest:844424931035008-831-m REF : మీరు వీడియో కాల్ చేస్తున్న వ్యక్తికి స్కైప్ ఖాతా ఉందని మీరు నిర్ధారించుకోవాలి
#   [telugu] #manifest:844424931035008-831-m PRED: మీరు వీడియో కాల్ చేస్తున్న వ్యక్తి స్పైప్ ఖాతా ఉందని మీరు నిర్ధారించుకోవాలి
#   [telugu] running avg -> WER 0.1829 | CER 0.0285  (960/1492)
#   [telugu] #manifest:844424930563461-1123-m REF : కరోనాతో చనిపోయిన మహిళకు సంబంధించిన సమాచారం బంధువులకు ఇవ్వకుండానే అధికారులు అంత్యక్రియలు నిర్వహించారు
#   [telugu] #manifest:844424930563461-1123-m PRED: కరోనాతో చనిపోయిన మహిళకు సంబంధించిన సమాచారం బంధువులకు ఇవ్వకుండానే అధికారులు అంత్యక్రియలు నిర్వహించారు
#   [telugu] running avg -> WER 0.1829 | CER 0.0287  (980/1492)
#   [telugu] #manifest:844424930563433-1123-m REF : ఒకవేళ ఇంకేదైనా లోపం ఉంటే సైకాలజిస్టు సలహాతో తగిన నిపుణుని ద్వారా చికిత్స చేయించుకోండి
#   [telugu] #manifest:844424930563433-1123-m PRED: ఒకవేళ ఇంకేదైనా లోపముంటే సైకాలజిస్ట్ సలహాతో తగిన నిపుణుని ద్వారా చికిత్స చేయించుకోండి
#   [telugu] running avg -> WER 0.1838 | CER 0.0287  (1000/1492)
#   [telugu] #manifest:844424931034935-831-m REF : డిఎంకె పార్టీ పగ్గాలు యువనాయకుడు స్టాలిన్ కు అప్పగించనున్నారని పార్టీలో జోరుగా ప్రచారం సాగుతోంది
#   [telugu] #manifest:844424931034935-831-m PRED: డిఎంకే పార్టీ పగ్గాలు యువనాయకుడు స్టాలిన్కు అప్పగించనున్నారనే ఈ పార్టీలో జరుపుగా ప్రచారం సాగుతోంది
#   [telugu] running avg -> WER 0.1847 | CER 0.0290  (1020/1492)
#   [telugu] #manifest:844424933340296-1150-m REF : జెర్రిపోతు భారతదేశం అంతటా వ్యాపించి ఉన్న సాధారణంగా కనిపించే ఒక విషం లేని పాము
#   [telugu] #manifest:844424933340296-1150-m PRED: జర్రిపోతూ భారతదేశం అంతటా వ్యాపించి ఉన్న సాధారణంగా కనిపించే ఒక విషంలేని పాము
#   [telugu] running avg -> WER 0.1857 | CER 0.0292  (1040/1492)
#   [telugu] #manifest:844424933311448-1113-m REF : నీవు అతడిని వెంబడించి ఏకాంత సమయం చూసి భక్తితో ప్రార్ధించి నీ యాగముకు ఉపద్రష్టగా ఉండమని అడుగు
#   [telugu] #manifest:844424933311448-1113-m PRED: నీవు అతడిని వెంబడించి ఏకాంత సమయం చూసి భక్తితో ప్రార్థించి నీ యాగమునకు ఉపదృష్టగా ఉండమని అడుగు
#   [telugu] running avg -> WER 0.1864 | CER 0.0293  (1060/1492)
#   [telugu] #manifest:844424933277334-192-m REF : ఋగ్వేదములోని సోమ మండలంలో పెక్కు మంత్రములలో సోమరసము యొక్క శక్తి ప్రథమగు గుణముల గురించి ప్రసక్తి ఉంది
#   [telugu] #manifest:844424933277334-192-m PRED: ఋగ్వేదములోని సోమమండలంలో పెక్కు మంత్రముల్లో సోమరశమి యొక్క శక్తి ప్రథమగ గుణముల గురించి ప్రసక్తి ఉంది
#   [telugu] running avg -> WER 0.1876 | CER 0.0293  (1080/1492)
#   [telugu] #manifest:844424933340336-1150-m REF : ధర్మాన్ని గురించి రాస్తూ ఇలా అందరికీ అర్ధమయ్యేలా చెప్పడం కృష్ణమూర్తి శైలీ విన్యాసం
#   [telugu] #manifest:844424933340336-1150-m PRED: ధర్మాన్ని గురించి రాస్తూ ఇలా అందరికీ అర్థమయ్యేలా చెప్పడం కృష్ణమూర్తి శైలి విన్యాసం
#   [telugu] running avg -> WER 0.1898 | CER 0.0295  (1100/1492)
#   [telugu] #manifest:844424933340290-1150-m REF : కోల్బొగ్గును ఇంధనంగా వాడు వాటరు ట్యూబు బాయిలర్లులను స్తూలంగా మూడు రకాలు
#   [telugu] #manifest:844424933340290-1150-m PRED: కోల్బొగ్గును ఇంధనంగా వాడు వాటరు ట్యూబ్ బాయిలర్లను స్థూలంగా మూడు రకాలు
#   [telugu] running avg -> WER 0.1908 | CER 0.0297  (1120/1492)
#   [telugu] #manifest:844424933276825-192-m REF : శ్రీశైలం లాగా జ్యోతిర్లింగం శక్తిపీఠం కలిసి ఉన్న అతికొద్ది ప్రదేశాలలో ఒకటి
#   [telugu] #manifest:844424933276825-192-m PRED: శ్రీశైలంలాగా జ్యోతిర్లింగం శక్తిపీఠం కలిసి ఉన్న అతి కొద్ది ప్రదేశాలలో ఒకటి
#   [telugu] running avg -> WER 0.1922 | CER 0.0299  (1140/1492)
#   [telugu] #manifest:844424933276831-192-m REF : శ్రీలంక పురాణ చరిత్రలో కళింగ కూడా ఒక ముఖ్యమైన భాగం
#   [telugu] #manifest:844424933276831-192-m PRED: శ్రీలంక పురాణ చరిత్రలో ఒక కలింగ కూడా ఒక ముఖ్యమైన భాగం
#   [telugu] running avg -> WER 0.1929 | CER 0.0298  (1160/1492)
#   [telugu] #manifest:844424933327800-772-m REF : ఆమె తుది కోర్కె చెల్లించడానికి జగన్నాథం కుమార్తె నీలను పెళ్ళి చేసుకోవడానికి తల ఒగ్గుతాడు మధు
#   [telugu] #manifest:844424933327800-772-m PRED: ఆమె తుదికోర్కే చెల్లించడానికి జగన్నాధం కుమార్తె నీలాను పెళ్ళి చేసుకోవడానికి తల ఒగ్గుతాడు మధు
#   [telugu] running avg -> WER 0.1943 | CER 0.0299  (1180/1492)
#   [telugu] #manifest:844424933324917-810-m REF : తూర్పు తిమోర్ స్థానిక ప్రజలలో ఆస్ట్రేషియన్ మెలనేషియన్ సంస్కృతి మిశ్రితమై ఉంటుంది
#   [telugu] #manifest:844424933324917-810-m PRED: తూర్పు తిమోర్ స్థానిక ప్రజల్లో ఆస్ట్రేలియన్ మేలనీషియన్ సంస్కృతి మిశ్రితమై ఉంటుంది
#   [telugu] running avg -> WER 0.1962 | CER 0.0300  (1200/1492)
#   [telugu] #manifest:844424933323895-406-m REF : అతను సి ఎన్ కనకసభాపతి మద్రాసు రాజ్యంలో నజరేత్ గ్రామంలోని వెల్లాలార్ కుటుంబానికి చెందిన ముదలియార్ మల్లిక దంపతులకు జన్మించాడు
#   [telugu] #manifest:844424933323895-406-m PRED: అతను సి ఎన్ కనక సభాపతి మద్రాసు రాజ్యాంగంలో నజరెత్ గ్రామంలోని వెల్లాలార్ కుటుంబానికి చెందిన ముదలయ్యార్ మల్లిక దంపతులకు జన్మించాడు
#   [telugu] running avg -> WER 0.1980 | CER 0.0302  (1220/1492)
#   [telugu] #manifest:844424933323949-406-m REF : వి సత్యనారాయణ దర్శకత్వంలో శ్రీ బాలాజీ ఆర్ట్ క్రియేషన్స్ పతాకంపై జె భగవాన్ డివివి దానయ్య నిర్మించారు
#   [telugu] #manifest:844424933323949-406-m PRED: వి సత్యనారాయణ దర్శకత్వంలో శ్రీ బాలాజీ ఆర్ట్స్ క్రియేషన్స్ పతాకంపై జై భగవాన్ డివి వి దానేయ నిర్మించారు
#   [telugu] running avg -> WER 0.1988 | CER 0.0304  (1240/1492)
#   [telugu] #manifest:844424933324937-810-m REF : అందుకే గ్రామ మధ్య ఏడు నాభిశిలలు ఏడు బొడ్రాయిలు నెలకొల్పబడి ఉన్నాయి
#   [telugu] #manifest:844424933324937-810-m PRED: అందుకే గ్రామం మధ్యలో ఏడు నభి శిలలు ఏడు బొండ్రాయలు నెలకుల్పడి ఉన్నాయి
#   [telugu] running avg -> WER 0.1998 | CER 0.0305  (1260/1492)
#   [telugu] #manifest:844424933340340-1150-m REF : పోర్చుగల్కు మొదటినుండి ఇంగ్లాండుతో గల రాజకీయఆర్దిక సంబంధాల వల్ల భూఖండ విధానమును వ్యతిరేకించింది
#   [telugu] #manifest:844424933340340-1150-m PRED: పోర్చుగల్కు మొదటి నుండి ఇంగ్లాండుతో గల రాజకీయ ఆర్థిక సంబంధాల వల్ల భూఖండ విధానమును వ్యతిరేకించింది
#   [telugu] running avg -> WER 0.2013 | CER 0.0308  (1280/1492)
#   [telugu] #manifest:844424933340311-1150-m REF : పద్దెనిమిది పర్యాయాలు భరతఖండంపై జయఖెతనం ఎగురవేసిన మహమ్మదు సుల్తాను చరిత్ర ఉంది
#   [telugu] #manifest:844424933340311-1150-m PRED: పద్దెనిమిది పర్యాయాలు భరత ఖండంపై జయకేతనం ఎగరవేసిన మహమ్మద్ సుల్తాను చరిత్ర ఉంది
#   [telugu] running avg -> WER 0.2024 | CER 0.0308  (1300/1492)
#   [telugu] #manifest:844424933323975-406-m REF : ఒడిషా రాష్ట్రపాలన భారతదేశంలోని అన్ని రాష్ట్రాల పాలనా విధానాన్ని అనుసరించే ఉంటుంది గవర్నరు ముఖ్య మంత్రి కాబినెట్ అసెంబ్లీ మొదలగునవి
#   [telugu] #manifest:844424933323975-406-m PRED: ఒడిషా రాష్ట్ర పాలన భారతదేశంలోని అన్ని రాష్ట్రాల పాలన విధానాన్ని అనుసరించే ఉంటుంది గవర్నరు ముఖ్యమంత్రి క్యాబినెట్ అసెంబ్లీ మొదలగునవి
#   [telugu] running avg -> WER 0.2026 | CER 0.0307  (1320/1492)
#   [telugu] #manifest:844424933324209-119-m REF : చివరగా సీతా రాముల అద్భుతమైన కళ్యాణంతో ఈ చిత్రం ముగుస్తుంది
#   [telugu] #manifest:844424933324209-119-m PRED: చివరగా సీతారాముల అద్భుతమైన కళ్యాణంతో ఈ చిత్రం ముస్తుంది
#   [telugu] running avg -> WER 0.2024 | CER 0.0307  (1340/1492)
#   [telugu] #manifest:844424933277304-192-m REF : అతని ప్రధాన ఆవిష్కరణలలో విద్యుదయస్కాంత ప్రేరణ డయామాగ్నెటిజం విద్యుద్విశ్లేషణ వంటి అంతర్లీన సూత్రాలు ఉన్నాయి
#   [telugu] #manifest:844424933277304-192-m PRED: అతని ప్రధాన ఆవిష్కరణలలో విద్యుత్దయస్కాంత ప్రేరణ డయామాగ్నెటిజం విద్యుత్ విశ్లేషణ వంటి అంతర్లీన సూత్రాలు ఉన్నాయి
#   [telugu] running avg -> WER 0.2037 | CER 0.0310  (1360/1492)
#   [telugu] #manifest:844424933323986-406-m REF : డెన్మార్కుతో సంకీర్ణం కారణంగా నార్వేజియన్ సాహిత్యం రచన స్థాయిని తగ్గిస్తూ వ్రాతపూర్వక డానిషును ఉపయోగించాలని ప్రభుత్వం విధానాలలో మార్పును తీసుకువచ్చింది
#   [telugu] #manifest:844424933323986-406-m PRED: డెన్మార్కులో సంకీర్ణం కారణంగా నార్వేజియన్ సాహిత్యం రచనా స్థాయిని తగ్గిస్తూ వ్రాతపూర్వక డానీషిన్ ఉపయోగించాలని ప్రభుత్వం విధానాలలో మార్పును తీసుకొచ్చింది
#   [telugu] running avg -> WER 0.2045 | CER 0.0311  (1380/1492)
#   [telugu] #manifest:844424933323971-406-m REF : అలా కేరళలో జరిగిన ఓ సంఘటన ఆధారంగా గెలుపు సినిమా తీసాడు
#   [telugu] #manifest:844424933323971-406-m PRED: అలా కేరళలో జరిగిన ఓ సంఘటన ఆధారంగా గెలుపు సినిమా తీశాడు
#   [telugu] running avg -> WER 0.2062 | CER 0.0313  (1400/1492)
#   [telugu] #manifest:844424933276893-192-m REF : పైలట్లు వాతావరణం మరీ అధ్వాన్నంగా మారడాన్ని గమనించి కృష్ణానది దాటిన తరువాత మలుపు తిరిగేందుకు నిశ్చయించుకున్నారు
#   [telugu] #manifest:844424933276893-192-m PRED: పైలట్లు వాతావరణం మరీ అధ్వానంగా మారడాన్ని గమనించి కృష్ణానది దాటిన తరువాత మలుపు తిరిగేందుకు నిశ్చయించుకున్నారు
#   [telugu] running avg -> WER 0.2069 | CER 0.0314  (1420/1492)
#   [telugu] #manifest:844424933324926-810-m REF : తమను అందరూ ద్వితీయ శ్రేణి పౌరులుగా చూస్తున్నారని తాము కూడా సమాజంలో గౌరవంగా హుందాగా బతకేలా చూడాలని కోరారు
#   [telugu] #manifest:844424933324926-810-m PRED: తమను అందరూ ద్వితీయ శ్రేయీ పౌరులుగా చూస్తున్నారని తాము కూడా సమాజంలో గౌరవంగా ఉందాగా బతికేలా చూడాలని కోరారు
#   [telugu] running avg -> WER 0.2085 | CER 0.0317  (1440/1492)
#   [telugu] #manifest:844424933324199-119-m REF : కానీ హేబియాస్ కార్పస్ ఒక మినహాయింపు ఖైదీ తరపున ఎవరైనా పిటిషన్ దాఖలు చేయవచ్చు
#   [telugu] #manifest:844424933324199-119-m PRED: కానీ హెబియాస్ కర్పాస్ ఒక మినహాయింపు ఖైదీ తరపున ఎవరైనా పిటిషన్ దాఖలు చేయవచ్చు
#   [telugu] running avg -> WER 0.2086 | CER 0.0317  (1460/1492)
#   [telugu] #manifest:844424933324207-119-m REF : ఉల్లివేర్లు కత్తిరించి తీసేసి మిగిలిన కాడల్ని శుభ్రంగా కడిగి సన్నగా తరగాలి
#   [telugu] #manifest:844424933324207-119-m PRED: ఉల్లివేళ్లు కత్తిరించి తీసేసి మిగిలిన కాడల్ని శుభ్రంగా కడిగి సన్నగా తరగాలి
#   [telugu] running avg -> WER 0.2100 | CER 0.0317  (1480/1492)
#   DONE telugu: n=1492  WER=0.2100  CER=0.0317
#   -> /kaggle/working/sravaani_kathbath_eval/sravaani_kathbath_telugu_results.csv
#
# ======================================================================
# ALL LANGUAGES DONE in 2.3 min
# ======================================================================
# language  n_utterances      wer      cer
#   telugu          1492 0.210028 0.031686
#
# Per-language CSVs + summary written to: /kaggle/working/sravaani_kathbath_eval
#   language  n_utterances       wer       cer
# 0   telugu          1492  0.210028  0.031686

# %% [markdown]
# ## 13. Inspect a results CSV

# %%
# e.g. inspect Telugu results
pd.read_csv(OUT_DIR / "sravaani_kathbath_telugu_results.csv").head(20)
# Out:
#                                  id language  \
# 0    manifest:844424932651824-944-f   telugu
# 1   manifest:844424932537159-1154-f   telugu
# 2    manifest:844424931156864-213-f   telugu
# 3    manifest:844424931358649-879-f   telugu
# 4    manifest:844424930603374-860-f   telugu
# 5   manifest:844424932537226-1154-f   telugu
# 6   manifest:844424932537203-1154-f   telugu
# 7    manifest:844424932651858-944-f   telugu
# 8    manifest:844424932737147-944-f   telugu
# 9    manifest:844424932652117-822-f   telugu
# 10   manifest:844424931241469-860-f   telugu
# 11   manifest:844424932651921-944-f   telugu
# 12    manifest:844424931189566-76-f   telugu
# 13   manifest:844424931279383-194-f   telugu
# 14  manifest:844424932537181-1154-f   telugu
# 15  manifest:844424932537174-1154-f   telugu
# 16    manifest:844424931189548-76-f   telugu
# 17   manifest:844424931140354-213-f   telugu
# 18   manifest:844424932651859-944-f   telugu
# 19   manifest:844424932652060-822-f   telugu
#
#                                             reference  \
# 0   అయితే ప్రియాంక ఎంత ఫ్రీ షో ఇచ్చినా కానీ బేవాచ్...
# 1   అయితే కారులో ఉన్నవారికి ఎలాంటి గాయాలు కాకపోవడం...
# 2   ఉప్పల్ నియోజకవర్గంలో రెండు వేల రెండు వందల కోట్...
# 3   వాస్తవానికి ఇక్కడ ఇస్లాం మతం మినహా మరే ఇతర మతా...
# 4   రెండేళ్ల క్రితం హాత్ వే నుంచి బయటకొచ్చిన ఆయన ఎ...
# 5   ఈ పరీక్షించని మోడ్స్ అని ఒక ప్రమాదం ఉంది లేదు ...
# 6   మొత్తానికి తన హాట్ పెర్ఫామెన్స్తో బిగ్ బాస్ హౌ...
# 7   భూ సంస్కరణలు సరిగ్గా అమలు కాకపోవడం వల్లే భూమిల...
# 8   అట్లాంటిక్ ప్రవాహం వలన బారెంట్స్ సముద్రం యొక్క...
# 9   నిజానికి ఈ కొన్ని గ్రహాలు నిజానికి అలాంటి ఒక గ...
# 10  పంచాయతీ అధికారి తో ప్రజాప్రతినిధులు ప్రణాళికలక...
# 11  కాగా ఈ చిత్రం ట్రైలర్ను స్వాతంత్ర్య దినోత్సవం ...
# 12  ఇప్పుడు ఎన్నికలు దగ్గరపడ్డ నేపథ్యంలో కేంద్రం న...
# 13  ఇంట్లోనే సులభంగా ఎలా వ్యాయామం చేయాలో ఈ వీడియో ...
# 14  నలుగురు వ్యక్తులు దౌర్జన్యంగా ఇంట్లోకి ప్రవేశి...
# 15  త్వరలో నావిక్ సిగ్నల్స్ మొబైల్ ఫోన్లకు అందుబాట...
# 16  అలాగే ఈ రెండు ఫోన్లలోనూ హానర్ సూపర్ చార్జ్ ఫాస...
# 17  మరియు ఒక భారీ నిర్వాహక తరగతి సృష్టించడానికి సం...
# 18  టీడీపీ అవిశ్వాస తీర్మానం పెట్టడంతో గత శుక్రవార...
# 19  కొంతకాలంగా టీడీపీ నుంచి కొందరు ఎమ్మెల్యేలు బయట...
#
#                                            prediction     wer     cer
# 0   అయితే ప్రియాంక ఎంత ఫ్రీ షో ఇచ్చినా కానీ భావత్ ...  0.0833  0.0625
# 1   అయితే కారులో ఉన్నవారికి ఎలాంటి గాయాలు కాకపోవడం...  0.0000  0.0000
# 2   ఉప్పల్ నియోజకవర్గంలో రెండు వేల రెండు వందల కోట్...  0.0000  0.0000
# 3   వాస్తవానికి ఇక్కడ ఇస్లాం మతం మినహా మరే ఇతర మతా...  0.0000  0.0000
# 4   రెండేళ్ల క్రితం హాత్వే నుంచి బయటకొచ్చిన ఆయన ఎగ...  0.2727  0.0462
# 5   ఈ పరీక్షించని మోడ్స్ అని ఒక ప్రమాదం ఉంది లేదు ...  0.0000  0.0000
# 6   మొత్తానికి తన హార్ట్ పెర్ఫార్మెన్స్ తో బిగ్ బా...  0.5556  0.0635
# 7   భూ సంస్కరణలు సరిగ్గా అమలు కాకపోవడం వల్లే భూమిల...  0.2000  0.0000
# 8   అట్లాంటిక్ ప్రవాహం వలన బ్యారిన్స్ సముద్రం యొక్...  0.1111  0.0909
# 9   నిజానికి ఈ కొన్ని గ్రహాలు నిజానికి అలాంటి ఒక గ...  0.0833  0.0147
# 10  పంచాయతీ అధికారితో ప్రజా ప్రతినిధులు ప్రణాళికలక...  0.3333  0.0000
# 11  కాగా ఈ చిత్రం ట్రైలర్ ను స్వాతంత్ర్య దినోత్సవం...  0.2222  0.0000
# 12  ఇప్పుడు ఎన్నికలు దగ్గరపడ్డ నేపథ్యంలో కేంద్రం న...  0.0000  0.0000
# 13  ఇంట్లోనే సులభంగా ఎలా వ్యాయామం చేయాలో ఈ వీడియో ...  0.0909  0.0135
# 14  నలుగురు వ్యక్తులు దౌర్జన్యంగా ఇంట్లోకి ప్రవేశి...  0.0909  0.0116
# 15  త్వరలో నావిక్ సిగ్నల్స్ మొబైల్ ఫోన్లకు అందుబాట...  0.0000  0.0000
# 16  అలాగే ఈ రెండు ఫోన్లలోనూ హానర్ సూపర్ చార్జ్ ఫాస...  0.0000  0.0000
# 17  మరియు ఒక భారీ నిర్వాహక తరగతి సృష్టించడానికి సం...  0.0000  0.0000
# 18  టీడీపీ అవిశ్వాస తీర్మానం పెట్టడంతో గత శుక్రవార...  0.1667  0.0278
# 19  కొంతకాలంగా టీడీపీ నుంచి కొందరు ఎమ్మెల్యేలు బయట...  0.1000  0.0513
