# %% [markdown]
# # SraVaani-1.0 — Kathbath ASR evaluation (Hindi / Tamil / Telugu / Marathi / Bengali)
#
# Evaluates [`ARTPARK-IISc/SraVaani-1.0`](https://huggingface.co/ARTPARK-IISc/SraVaani-1.0) on the Kathbath test sets, downloaded automatically from the public Vistaar-benchmark mirror:
#
# ```
# https://indicwhisper.objectstore.e2enetworks.net/vistaar_benchmarks/kathbath.zip
# ```
#
# **What this notebook does**
# 1. Downloads + extracts `kathbath.zip` (cached — reruns skip this).
# 2. Locates each language's `test/` folder (`audio/` + `transcript.txt`), indexing audio files recursively to route around nested subfolders.
# 3. Loads SraVaani-1.0 (`trust_remote_code=True`) — **gated**, needs an HF token with accepted terms on the model page.
# 4. Runs inference in batches, printing reference / predicted text and running WER/CER as it goes.
# 5. Checkpoints every sample to a resumable `.jsonl` cache per language, so a Kaggle session timeout doesn't lose progress.
# 6. Writes one CSV per language (`id, reference, prediction, wer, cer`) plus a combined summary CSV.
#
# **Before running:** accept the gated-access terms at https://huggingface.co/ARTPARK-IISc/SraVaani-1.0, then add an HF token as a Kaggle secret named `HF_TOKEN` (Add-ons → Secrets) and enable it for this notebook — or set it directly in the cell below.

# %% [markdown]
# ## 1. Install dependencies

# %%
import os, sys

def _ensure(pkg_import, pip_name=None):
    try:
        __import__(pkg_import)
    except ImportError:
        os.system(f"{sys.executable} -m pip install -q {pip_name or pkg_import}")

for mod, pip_name in [
    ("editdistance", "editdistance"),
    ("soundfile", "soundfile"),
    ("librosa", "librosa"),
    ("tqdm", "tqdm"),
    ("requests", "requests"),
]:
    _ensure(mod, pip_name)

print("Dependencies ready.")
# Out:
# Dependencies ready.

# %% [markdown]
# ## 2. Imports and config

# %%
import gc
import json
import re
import time
import unicodedata
import zipfile
from pathlib import Path

import pandas as pd
import editdistance
import requests
import soundfile as sf
import librosa
import torch
from tqdm.auto import tqdm
from transformers import AutoModel

MODEL_REPO = "ARTPARK-IISc/SraVaani-1.0"
KATHBATH_ZIP_URL = "https://indicwhisper.objectstore.e2enetworks.net/vistaar_benchmarks/kathbath.zip"
TARGET_SR = 16000

# folder-name candidates inside the extracted zip, in case of casing/
# naming variants across mirrors
LANG_DIR_CANDIDATES = {
    # "hindi": ["hindi"],
    # "tamil": ["tamil"],
    # "telugu": ["telugu"],
    # "marathi": ["marathi"],
    "bengali": ["bengali", "bangla"],
}
SPLIT_DIR_CANDIDATES = ["test", "test_known", "test_unknown", "valid"]
AUDIO_EXTS = {".wav", ".m4a", ".mp3", ".flac"}

# %% [markdown]
# ## 3. Set your Hugging Face token
#
# Needed only to load the gated SraVaani-1.0 model — the Kathbath zip download needs no token.

# %%
# Option A: paste your token directly (quickest for a one-off Kaggle run)
# os.environ["HF_TOKEN"] = "hf_xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx"

# Option B: Kaggle secret named HF_TOKEN (Add-ons -> Secrets), picked up automatically below

def get_hf_token():
    token = os.environ.get("HF_TOKEN")
    if token:
        return token
    try:
        from kaggle_secrets import UserSecretsClient
        token = UserSecretsClient().get_secret("HF_TOKEN")
        if token:
            return token
    except Exception:
        pass
    raise RuntimeError(
        "No HF token found. Either set os.environ['HF_TOKEN'] = 'hf_...' before running, "
        "or add it as a Kaggle secret named HF_TOKEN (Add-ons -> Secrets) and enable it for this notebook. "
        "(Needed to load the gated SraVaani-1.0 model — the Kathbath download itself needs no token.)"
    )

# %% [markdown]
# ## 4. Download + extract Kathbath (Vistaar mirror)

# %%
# ================================================================ #
# Download + extract kathbath.zip (cached)
# ================================================================ #
def download_kathbath(dest_root: Path) -> Path:
    dest_root.mkdir(parents=True, exist_ok=True)
    zip_path = dest_root / "kathbath.zip"
    extract_marker = dest_root / "kathbath" / ".extracted_ok"
    extract_dir = dest_root / "kathbath"

    if extract_marker.exists():
        print(f"Kathbath already downloaded + extracted at {extract_dir}")
        return extract_dir

    if not zip_path.exists() or zip_path.stat().st_size == 0:
        print(f"Downloading kathbath.zip from {KATHBATH_ZIP_URL} ...")
        with requests.get(KATHBATH_ZIP_URL, stream=True, timeout=60) as r:
            r.raise_for_status()
            total = int(r.headers.get("content-length", 0))
            with open(zip_path, "wb") as f, tqdm(
                total=total, unit="B", unit_scale=True, desc="kathbath.zip"
            ) as pbar:
                for chunk in r.iter_content(chunk_size=1024 * 1024):
                    if chunk:
                        f.write(chunk)
                        pbar.update(len(chunk))
    else:
        print(f"Found existing {zip_path}, skipping download.")

    print(f"Extracting to {extract_dir} ...")
    extract_dir.mkdir(parents=True, exist_ok=True)
    with zipfile.ZipFile(zip_path, "r") as zf:
        members = zf.infolist()
        for m in tqdm(members, desc="extracting", unit="file"):
            zf.extract(m, extract_dir)

    extract_marker.touch()
    print("Extraction complete.")
    return extract_dir

# %% [markdown]
# ## 5. Locate each language's test split and match audio to transcripts

# %%
def find_first_existing(base: Path, candidates):
    for c in candidates:
        p = base / c
        if p.exists():
            return p
    # fuzzy fallback: case-insensitive scan of immediate children
    if base.exists():
        lower_map = {p.name.lower(): p for p in base.iterdir() if p.is_dir()}
        for c in candidates:
            if c.lower() in lower_map:
                return lower_map[c.lower()]
    return None


def locate_language_dir(kathbath_root: Path, lang: str) -> Path:
    # the zip extracts with an extra nested "kathbath/kathbath/<lang>/" layout
    # on some mirrors, and a flat "<lang>/" layout on others -- handle both.
    search_roots = [kathbath_root, kathbath_root / "kathbath"]
    for root in search_roots:
        lang_dir = find_first_existing(root, LANG_DIR_CANDIDATES[lang])
        if lang_dir is not None:
            return lang_dir
    raise FileNotFoundError(
        f"Could not locate a folder for '{lang}' under {kathbath_root}. "
        f"Check the extracted folder layout with `!find {kathbath_root} -maxdepth 4`."
    )


# manifest.json is a NeMo-style JSONL file: one JSON object per line, each
# with (at least) "audio_filepath" and "text" -- e.g.
#   {"audio_filepath": "audio/844424933726456-...-f.wav", "duration": 4.2, "text": "..."}
MANIFEST_NAME_CANDIDATES = [
    "manifest.json",
    "test_manifest.json",
    "test_known_manifest.json",
    "test_unknown_manifest.json",
    "valid_manifest.json",
]


def find_manifest_files(lang_dir: Path):
    """Return every manifest-like JSONL file for this language. Prefers an
    explicit test/known/unknown/valid manifest if several exist; otherwise
    falls back to whatever *manifest*.json files are present (recursively,
    in case they sit inside a test/ or manifests/ subfolder)."""
    found = []
    for name in MANIFEST_NAME_CANDIDATES:
        p = lang_dir / name
        if p.exists():
            found.append(p)
    if found:
        return found
    # recursive fallback: any file whose name contains "manifest" and ends in .json
    found = sorted(lang_dir.rglob("*manifest*.json"))
    if found:
        return found
    raise FileNotFoundError(
        f"No manifest.json-style file found under {lang_dir}. "
        f"Check the folder layout with `!find {lang_dir} -maxdepth 3`."
    )


def resolve_audio_path(audio_filepath: str, manifest_path: Path, lang_dir: Path, kathbath_root: Path):
    """audio_filepath inside the manifest may be absolute, relative to the
    manifest's own folder, relative to the language folder, or relative to
    the kathbath root -- try each in turn, then fall back to a recursive
    filename search under the language folder."""
    candidates = [
        Path(audio_filepath),
        manifest_path.parent / audio_filepath,
        lang_dir / audio_filepath,
        kathbath_root / audio_filepath,
    ]
    for c in candidates:
        if c.exists():
            return c

    # last resort: search for a file with this basename anywhere under lang_dir
    target_name = Path(audio_filepath).name
    for p in lang_dir.rglob(target_name):
        return p
    return None


def load_kathbath_lang(kathbath_root: Path, lang: str, max_samples: int = -1):
    lang_dir = locate_language_dir(kathbath_root, lang)
    print(f"  -> language folder for {lang}: {lang_dir}")
    manifest_paths = find_manifest_files(lang_dir)
    print(f"  -> manifest file(s): {[str(p) for p in manifest_paths]}")

    rows = []
    n_missing_audio = 0
    for manifest_path in manifest_paths:
        with open(manifest_path, "r", encoding="utf-8") as f:
            for line_no, line in enumerate(f):
                line = line.strip()
                if not line:
                    continue
                try:
                    entry = json.loads(line)
                except json.JSONDecodeError:
                    continue

                audio_filepath = entry.get("audio_filepath") or entry.get("audio_path")
                text = entry.get("text", "")
                if not audio_filepath:
                    continue

                audio_path = resolve_audio_path(audio_filepath, manifest_path, lang_dir, kathbath_root)
                if audio_path is None:
                    n_missing_audio += 1
                    continue

                utt_id = entry.get("id") or Path(audio_filepath).stem
                # disambiguate ids across multiple manifests (e.g. test_known + test_unknown)
                utt_id = f"{manifest_path.stem}:{utt_id}"

                rows.append({"id": utt_id, "audio_path": str(audio_path), "text": str(text).strip()})

    if n_missing_audio:
        print(f"  ! {n_missing_audio} manifest entries had an audio file that could not be resolved on disk")

    if max_samples and max_samples > 0:
        rows = rows[:max_samples]

    print(f"  -> {len(rows)} (audio, text) pairs loaded for {lang}")
    return rows

# %% [markdown]
# ## 6. Text normalization + WER / CER metrics

# %%
# ================================================================ #
# Text normalization + metrics (mirrors editdistance-based WER/CER
# methodology used elsewhere in this project)
# ================================================================ #
_PUNCT_RE = re.compile(r"[^\w\s\u0900-\u0DFF]", flags=re.UNICODE)


def normalize_text(text: str) -> str:
    if text is None:
        return ""
    text = unicodedata.normalize("NFC", str(text))
    text = _PUNCT_RE.sub(" ", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text


def wer(ref: str, hyp: str) -> float:
    ref_words = ref.split()
    hyp_words = hyp.split()
    if len(ref_words) == 0:
        return 0.0 if len(hyp_words) == 0 else 1.0
    return editdistance.eval(ref_words, hyp_words) / len(ref_words)


def cer(ref: str, hyp: str) -> float:
    ref_chars = ref.replace(" ", "")
    hyp_chars = hyp.replace(" ", "")
    if len(ref_chars) == 0:
        return 0.0 if len(hyp_chars) == 0 else 1.0
    return editdistance.eval(list(ref_chars), list(hyp_chars)) / len(ref_chars)

# %% [markdown]
# ## 7. Load the SraVaani-1.0 model

# %%
def load_model(hf_token: str, device: str):
    print(f"Loading {MODEL_REPO} on {device} ...")
    model = AutoModel.from_pretrained(
        MODEL_REPO, trust_remote_code=True, token=hf_token
    ).to(device).eval()
    print("Model loaded.")
    return model


def audio_to_temp_wav(audio_path: str, tmp_dir: Path, idx: int) -> str:
    """Decodes source audio (wav/m4a/mp3/flac) to a 16kHz mono wav and
    returns its path. Falls back to librosa (ffmpeg-backed) for formats
    soundfile can't read directly, e.g. m4a."""
    out_path = tmp_dir / f"sample_{idx}.wav"
    try:
        wav, sr = sf.read(audio_path, dtype="float32")
        if wav.ndim > 1:
            wav = wav.mean(axis=1)
    except Exception:
        wav, sr = librosa.load(audio_path, sr=None, mono=True)
    if sr != TARGET_SR:
        wav = librosa.resample(wav.astype("float32"), orig_sr=sr, target_sr=TARGET_SR)
    sf.write(out_path, wav, TARGET_SR)
    return str(out_path)

# %% [markdown]
# ## 8. Checkpoint cache (resumable)

# %%
# ================================================================ #
# Checkpoint cache (resumable jsonl, one line per evaluated sample)
# ================================================================ #
def load_cache(cache_path: Path):
    done = {}
    if cache_path.exists():
        with open(cache_path, "r", encoding="utf-8") as f:
            for line in f:
                line = line.strip()
                if not line:
                    continue
                try:
                    row = json.loads(line)
                    done[row["id"]] = row
                except json.JSONDecodeError:
                    continue
    return done


def append_cache(cache_path: Path, row: dict):
    with open(cache_path, "a", encoding="utf-8") as f:
        f.write(json.dumps(row, ensure_ascii=False) + "\n")

# %% [markdown]
# ## 9. Per-language evaluation loop
#
# Prints reference / predicted text and running WER/CER every `print_every` utterances, and appends every result to a `.jsonl` checkpoint so a rerun resumes instead of restarting.

# %%
# ================================================================ #
# Per-language evaluation
# ================================================================ #
def evaluate_language(model, lang, kathbath_root, out_dir, batch_size, max_samples, print_every, device):
    print(f"\n{'=' * 70}\nEvaluating language: {lang.upper()}\n{'=' * 70}")
    rows_meta = load_kathbath_lang(kathbath_root, lang, max_samples)
    n_total = len(rows_meta)
    if n_total == 0:
        print(f"  ! no utterances found for {lang}, skipping")
        return {"language": lang, "n_utterances": 0, "wer": float("nan"), "cer": float("nan")}

    cache_path = out_dir / f"{lang}_checkpoint.jsonl"
    csv_path = out_dir / f"sravaani_kathbath_{lang}_results.csv"
    tmp_dir = out_dir / f"_tmp_wav_{lang}"
    tmp_dir.mkdir(parents=True, exist_ok=True)

    done = load_cache(cache_path)
    if done:
        print(f"  resuming from checkpoint: {len(done)}/{n_total} already done")

    pending = [r for r in rows_meta if r["id"] not in done]

    running_wer_sum, running_cer_sum, running_n = 0.0, 0.0, 0
    for r in done.values():
        running_wer_sum += r["wer"]
        running_cer_sum += r["cer"]
        running_n += 1

    pbar = tqdm(total=n_total, initial=len(done), desc=f"{lang}", unit="utt")

    batch_paths, batch_meta = [], []

    def flush_batch():
        nonlocal running_wer_sum, running_cer_sum, running_n
        if not batch_paths:
            return
        try:
            hyps = model.transcribe(batch_paths, batch_size=len(batch_paths), return_hypotheses=True)
        except TypeError:
            hyps = model.transcribe(batch_paths, return_hypotheses=True)

        for wav_path, meta, hyp in zip(batch_paths, batch_meta, hyps):
            ref_raw = meta["text"]
            pred_raw = hyp.text if hasattr(hyp, "text") else str(hyp)

            ref_norm = normalize_text(ref_raw)
            pred_norm = normalize_text(pred_raw)
            u_wer = wer(ref_norm, pred_norm)
            u_cer = cer(ref_norm, pred_norm)

            row = {
                "id": meta["id"],
                "language": lang,
                "reference": ref_raw,
                "prediction": pred_raw,
                "wer": round(u_wer, 4),
                "cer": round(u_cer, 4),
            }
            append_cache(cache_path, row)
            done[meta["id"]] = row

            running_wer_sum += u_wer
            running_cer_sum += u_cer
            running_n += 1

            if running_n % print_every == 0:
                tqdm.write(
                    f"  [{lang}] #{meta['id']} REF : {ref_raw}\n"
                    f"  [{lang}] #{meta['id']} PRED: {pred_raw}\n"
                    f"  [{lang}] running avg -> WER {running_wer_sum / running_n:.4f} | "
                    f"CER {running_cer_sum / running_n:.4f}  ({running_n}/{n_total})"
                )
            try:
                os.remove(wav_path)
            except OSError:
                pass
            pbar.update(1)
        batch_paths.clear()
        batch_meta.clear()

    for i, meta in enumerate(pending):
        wav_path = audio_to_temp_wav(meta["audio_path"], tmp_dir, i)
        batch_paths.append(wav_path)
        batch_meta.append(meta)
        if len(batch_paths) >= batch_size:
            flush_batch()
    flush_batch()
    pbar.close()

    # final CSV for this language, in original transcript order
    ordered_rows = [done[r["id"]] for r in rows_meta if r["id"] in done]
    df = pd.DataFrame(ordered_rows)
    df.to_csv(csv_path, index=False, encoding="utf-8-sig")

    lang_wer = df["wer"].mean() if len(df) else float("nan")
    lang_cer = df["cer"].mean() if len(df) else float("nan")
    print(f"  DONE {lang}: n={len(df)}  WER={lang_wer:.4f}  CER={lang_cer:.4f}")
    print(f"  -> {csv_path}")

    try:
        tmp_dir.rmdir()
    except OSError:
        pass

    gc.collect()
    if device == "cuda":
        torch.cuda.empty_cache()

    return {"language": lang, "n_utterances": len(df), "wer": lang_wer, "cer": lang_cer}

# %% [markdown]
# ## 10. Run configuration

# %%
LANGUAGES = ["bengali"]
BATCH_SIZE = 8
MAX_SAMPLES = -1       # -1 = full test set; set e.g. 50 for a quick smoke test first
PRINT_EVERY = 20
OUT_DIR = Path("/kaggle/working/sravaani_kathbath_eval")
DATA_DIR = Path("/kaggle/working/kathbath_data")

OUT_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## 11. Download data + load model

# %%
kathbath_root = download_kathbath(DATA_DIR)

hf_token = get_hf_token()
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Device: {device}")

model = load_model(hf_token, device)
# Out:
# Kathbath already downloaded + extracted at /kaggle/working/kathbath_data/kathbath
# Device: cuda
# Loading ARTPARK-IISc/SraVaani-1.0 on cuda ...
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Model loaded.

# %% [markdown]
# ## 12. Run evaluation across all languages

# %%
summary = []
t0 = time.time()
for lang in LANGUAGES:
    result = evaluate_language(
        model, lang, kathbath_root, OUT_DIR,
        batch_size=BATCH_SIZE,
        max_samples=MAX_SAMPLES,
        print_every=PRINT_EVERY,
        device=device,
    )
    summary.append(result)
    pd.DataFrame(summary).to_csv(OUT_DIR / "sravaani_kathbath_summary.csv", index=False)

elapsed = time.time() - t0
print(f"\n{'=' * 70}\nALL LANGUAGES DONE in {elapsed / 60:.1f} min\n{'=' * 70}")
summary_df = pd.DataFrame(summary)
print(summary_df.to_string(index=False))
print(f"\nPer-language CSVs + summary written to: {OUT_DIR}")
summary_df
# Out:
# ======================================================================
# Evaluating language: BENGALI
# ======================================================================
#   -> language folder for bengali: /kaggle/working/kathbath_data/kathbath/kathbath/bengali
#   -> manifest file(s): ['/kaggle/working/kathbath_data/kathbath/kathbath/bengali/manifest.json']
#   -> 1783 (audio, text) pairs loaded for bengali
# bengali:   0%|          | 0/1783 [00:00<?, ?utt/s]
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:1787: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters(). (Triggered internally at /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1480.)
#   return forward_call(*args, **kwargs)
#   [bengali] #manifest:844424930757941-661-f REF : মুগদা হাসপাতালে রোগীর স্বজন ও সাংবাদিক লাঞ্ছনার ঘটনায় তদন্ত কমিটি
#   [bengali] #manifest:844424930757941-661-f PRED: মুগদা হাসপাতালে রোগীর স্বজন ও সাংবাদিক ক্লাঞ্ছনার ঘটনায় তদন্ত কমিটি
#   [bengali] running avg -> WER 0.1791 | CER 0.0448  (20/1783)
#   [bengali] #manifest:844424930757901-661-f REF : ভারতের বিপক্ষে মাঠে নেমেই বিরল রেকর্ড গড়লেন রস টেলর
#   [bengali] #manifest:844424930757901-661-f PRED: ভারতের বিপক্ষে মাঠে নেমেই বিরল রেকর্ড গড়লেন রস টেলর
#   [bengali] running avg -> WER 0.1360 | CER 0.0411  (40/1783)
#   [bengali] #manifest:844424931034384-760-f REF : অভিনব বাগান তৈরি করে সবুজায়নের বার্তা দিচ্ছেন দমদমের রানা দা
#   [bengali] #manifest:844424931034384-760-f PRED: অভিনব বাগান তৈরি করে সবুজায়নের বার্তা দিচ্ছেন দমদমের রানাদা
#   [bengali] running avg -> WER 0.1266 | CER 0.0351  (60/1783)
#   [bengali] #manifest:844424931382794-1116-f REF : নৈতিক একটি বৈপরীত্য ধারণা যে কিছুই অনৈতিক বা নৈতিক হতে পারে
#   [bengali] #manifest:844424931382794-1116-f PRED: নৈতিক একটি বৈপরীত্য ধারণা যে কিছুই অনৈতিক বা নৈতিক হতে পারে
#   [bengali] running avg -> WER 0.1164 | CER 0.0335  (80/1783)
#   [bengali] #manifest:844424931285074-906-f REF : অনুষ্ঠানে প্রধান পৃষ্ঠপোষক হিসেবে বক্তব্য দেন খুলনা বিশ্ববিদ্যালয়ের উপাচার্য অধ্যাপক ড
#   [bengali] #manifest:844424931285074-906-f PRED: অনুষ্ঠানে প্রধান পৃষ্ঠপোষক হিসেবে বক্তব্য দেন খুলনা বিশ্ববিদ্যালয়ের উপাচার্য অধ্যাপক ড
#   [bengali] running avg -> WER 0.1148 | CER 0.0336  (100/1783)
#   [bengali] #manifest:844424931185307-1116-f REF : এ বিষয়ে স্থানীয় প্রশাসন সহযোগিতা করলে উচ্ছেদের পর ফের
#   [bengali] #manifest:844424931185307-1116-f PRED: এ বিষয়ে স্থানীয় প্রশাসন সহজিতা করলে উচ্ছেদের পর ফের
#   [bengali] running avg -> WER 0.1141 | CER 0.0340  (120/1783)
#   [bengali] #manifest:844424932675128-725-f REF : করোনা পজেটিভ হয়েও করোনা রোগীর চিকিৎসা করছেন শরীয়তপুর সিভিল সার্জন অফিসের দায়িত্বরত মেডিকেল অফিসার ডা
#   [bengali] #manifest:844424932675128-725-f PRED: করোনা পজিটিভ হয়েও করোনা রোগীর চিকিৎসা করছেন শরিয়তপুর সিভিল সার্জন অফিসের দায়িত্বরত মেডিকেল অফিসার ডা
#   [bengali] running avg -> WER 0.1109 | CER 0.0313  (140/1783)
#   [bengali] #manifest:844424932355708-436-f REF : পুজোর খরচ বাঁচিয়ে বাড়ি বাড়ি ৫০০ টাকা ও সাবান বিলি তমলুকে
#   [bengali] #manifest:844424932355708-436-f PRED: পুজোর খরচ বাঁচিয়ে বাড়ি পাঁচশো টাকা ও সাবান বিলি তমলুকে
#   [bengali] running avg -> WER 0.1141 | CER 0.0338  (160/1783)
#   [bengali] #manifest:844424931185273-1116-f REF : বর্ষা কালে অসুস্থ হয়ে পড়ার আগেই প্রতি দিনই খাবারে রাখুন কিছু জিনিস যা ন্যাচারাল অ্যান্টিবায়োটিক
#   [bengali] #manifest:844424931185273-1116-f PRED: বর্ষাকালে অসুস্থ হয়ে পড়ার আগেই প্রতিদিনই খাবারে রাখুন কিছু জিনিস যা ন্যাচারাল অ্যান্টিবায়োটিক
#   [bengali] running avg -> WER 0.1124 | CER 0.0327  (180/1783)
#   [bengali] #manifest:844424931323244-906-f REF : সঙ্গে এই ফোন দুটি রং গোল্ড ও সিলভার এ নিতে পারেন
#   [bengali] #manifest:844424931323244-906-f PRED: সঙ্গে এই ফোন দুটি রং গোল্ড ও সিলভারে নিতে পারেন
#   [bengali] running avg -> WER 0.1137 | CER 0.0325  (200/1783)
#   [bengali] #manifest:844424932843761-725-f REF : এতে প্রধান অতিথি হিসেবে উপস্থিত ছিলেন বসুন্ধরা সিমেন্ট সেক্টরের ময়মনসিংহ বিভাগীয় সেলস ইনচার্জ মো
#   [bengali] #manifest:844424932843761-725-f PRED: এতে প্রধান অতিথি হিসেবে উপস্থিত ছিলেন বসুন্ধরা সিমেন্ট সেক্টরের ময়মনসিংহ বিভাগীয় সেলস ইনচার্জ মো
#   [bengali] running avg -> WER 0.1179 | CER 0.0351  (220/1783)
#   [bengali] #manifest:844424933095889-725-f REF : এ কারণে তিনি প্রায়ই গুরুতর অসুস্থ হয়ে পড়েন
#   [bengali] #manifest:844424933095889-725-f PRED: এ কারণে তিনি প্রায়ই গুরুতর অসুস্থ হয়ে পড়েন
#   [bengali] running avg -> WER 0.1191 | CER 0.0368  (240/1783)
#   [bengali] #manifest:844424932438012-436-f REF : বিদেশি শিক্ষার্থীদের ভিসা ইস্যুতে প্রেসিডেন্ট ডোনাল্ড ট্রাম্প প্রশাসনের বিরুদ্ধে মামলা দায়ের করেছে যুক্তরাষ্ট্রের হার্ভার্ড বিশ্ববিদ্যালয়
#   [bengali] #manifest:844424932438012-436-f PRED: বিদেশি শিক্ষার্থীদের ভিসাইসুতে প্রেসিডেন্ট ডোনাল্ড ট্রাম্প প্রশাসনের বিরুদ্ধে মামলা দায়ের করেছে যুক্তরাষ্ট্রের হার্ভার্ড বিশ্ববিদ্যালয়
#   [bengali] running avg -> WER 0.1201 | CER 0.0372  (260/1783)
#   [bengali] #manifest:844424931449844-906-f REF : সভায় অন্যদের মধ্যে জাতীয় ঐক্যফ্রন্টের আহ্বায়ক এবং গণফোরামের সভাপতি ড
#   [bengali] #manifest:844424931449844-906-f PRED: সভায় অন্যদের মধ্যে জাতীয় ঐক্যফ্রন্টের আহ্বায়ক এবং গণফোরামের সভাপতি ড
#   [bengali] running avg -> WER 0.1193 | CER 0.0375  (280/1783)
#   [bengali] #manifest:844424932843756-725-f REF : পাকিস্তানের প্রধানমন্ত্রী ইমরান খান ও ইরানের প্রেসিডেন্ট হাসান রুহানি
#   [bengali] #manifest:844424932843756-725-f PRED: পাকিস্তানের প্রধানমন্ত্রী ইমরান খান ও ইরানের প্রেসিডেন্ট হাসান রুহানি
#   [bengali] running avg -> WER 0.1147 | CER 0.0360  (300/1783)
#   [bengali] #manifest:844424932426776-37-f REF : এ প্রসঙ্গে আর্থিক প্রতিষ্ঠান ও বাজার বিভাগের মহাব্যবস্থাপক মো
#   [bengali] #manifest:844424932426776-37-f PRED: এ প্রসঙ্গে আর্থিক প্রতিষ্ঠান ও বাজার বিভাগের মহাব্যবস্থাস্থাপক মো
#   [bengali] running avg -> WER 0.1151 | CER 0.0357  (320/1783)
#   [bengali] #manifest:844424932325669-436-f REF : শিক্ষিত বেকারদের কর্মসংস্থানের জন্য সরকারি চাকরিতে প্রবেশের বয়সসীমা ৩৫ বছর করার পক্ষে
#   [bengali] #manifest:844424932325669-436-f PRED: শিক্ষিত বেকারদের কর্মসংস্থানের জন্য সরকারি চাকরিতে প্রবেশের বয়সসীমা পঁয়ত্রিশ বছর করার পক্ষে
#   [bengali] running avg -> WER 0.1157 | CER 0.0364  (340/1783)
#   [bengali] #manifest:844424932426846-37-f REF : ডেঙ্গুয়াঝাড়ের সাপ্তাহিক হাটে ৩০ টাকা কিলো মাংস কিনতে ভিড় জমালেন অনেকেই
#   [bengali] #manifest:844424932426846-37-f PRED: ডেঙ্গুয়া ঝড়ের সাপ্তাহিক হাটে তিরিশ টাকা কিলো মাংস কিনতে ভিড় জমালেন অনেকেই
#   [bengali] running avg -> WER 0.1141 | CER 0.0369  (360/1783)
#   [bengali] #manifest:844424931029468-760-f REF : মনোজ কুমার নামের এক ব্যক্তি ভিডিওটি শেয়ার করেন
#   [bengali] #manifest:844424931029468-760-f PRED: মনোজ কুমার নামের এক ব্যক্তি ভিডিওটি শেয়ার করেন
#   [bengali] running avg -> WER 0.1147 | CER 0.0373  (380/1783)
#   [bengali] #manifest:844424930939858-92-f REF : সোশ্যাল মিডিয়ায় রামদেবকে নিয়ে তৈরি মিম মুছে ফেলার নির্দেশ দিল আদালত
#   [bengali] #manifest:844424930939858-92-f PRED: সোশ্যাল মিডিয়ায় রামদেবকে নিয়ে তৈরি মিম মুছে ফেলার নির্দেশ দিল আদালত
#   [bengali] running avg -> WER 0.1167 | CER 0.0370  (400/1783)
#   [bengali] #manifest:844424930842529-92-f REF : একই সঙ্গে আগামী ২৫ মার্চ তাঁরা শিক্ষা সনদ গলায় ঝুলিয়ে রাস্তা
#   [bengali] #manifest:844424930842529-92-f PRED: একইসঙ্গে আগামী পঁচিশ মার্চ তারা শিক্ষা সনদ গলায় ঝুলিয়ে রাস্তা
#   [bengali] running avg -> WER 0.1154 | CER 0.0364  (420/1783)
#   [bengali] #manifest:844424930842572-92-f REF : পরবর্তী সংবাদ বগুড়া বারপুর জামিয়া ইউসুফিয়া হাফিজিয়া মাদ্রাসা প্রাঙ্গণে তাফসিরুল মাহফিলে পাগড়ী প্রদান
#   [bengali] #manifest:844424930842572-92-f PRED: পরবর্তী সংবাদ বগুড়া বারপুর জামিয়া ইউসুফিয়া হাফিজিয়া মাদ্রাসা প্রাঙ্গণে তাফসিরুল মাহফিলে পাগড়ি প্রদান
#   [bengali] running avg -> WER 0.1176 | CER 0.0362  (440/1783)
#   [bengali] #manifest:844424930939890-92-f REF : গহনা বিক্রি করে টাকা না দেওয়ায় স্ত্রীর কব্জি কাটল স্বামী
#   [bengali] #manifest:844424930939890-92-f PRED: গহনা বিক্রি করে টাকা না দেওয়ায় স্ত্রীর কব্জি কাটল স্বামী
#   [bengali] running avg -> WER 0.1169 | CER 0.0356  (460/1783)
#   [bengali] #manifest:844424932339456-436-f REF : তাকে জেরা করেই ঘটনার কিনারা করা সম্ভব বলেই আশা তদন্তকারীদের
#   [bengali] #manifest:844424932339456-436-f PRED: তাকে জেরা করেই ঘটনার কিনারা করা সম্ভব বলেই আশা তদন্তকারীদের
#   [bengali] running avg -> WER 0.1203 | CER 0.0368  (480/1783)
#   [bengali] #manifest:844424932678101-725-f REF : সব হোম ব্যবসায়ীরা একই সাথে আচরণ করা হয় না
#   [bengali] #manifest:844424932678101-725-f PRED: সব হোম ব্যবসায়ীরা একই সাথে আচরণ করা হয় না
#   [bengali] running avg -> WER 0.1212 | CER 0.0366  (500/1783)
#   [bengali] #manifest:844424932361167-1084-f REF : যথাযথ ধর্মীয় ভাবগাম্ভীর্যের মধ্য দিয়ে আজ দিবাগত রাতে দেশব্যাপী পালিত হবে
#   [bengali] #manifest:844424932361167-1084-f PRED: যথাযথ ধর্মীয় ভাবগাম্ভীর্যের মধ্য দিয়ে আজ দিবাগত রাত্রে দেশব্যাপী পালিত হবে
#   [bengali] running avg -> WER 0.1236 | CER 0.0373  (520/1783)
#   [bengali] #manifest:844424932678011-725-f REF : দুর্নীতি মামলায় খালেদা জিয়ার জামিনের ওপর স্থগিতাদেশ বাংলাদেশের সুপ্রিম কোর্টের
#   [bengali] #manifest:844424932678011-725-f PRED: দুর্নীতি মামলায় খালেদা জিয়ার জামিনের ওপর স্থগিতাদেশ বাংলাদেশের সুপ্রিম কোর্টের
#   [bengali] running avg -> WER 0.1251 | CER 0.0374  (540/1783)
#   [bengali] #manifest:844424933096445-725-f REF : পাঁচ লাখ টাকা চাঁদা না পেয়েই আসামিরা তাদের মারধর শেষে ধাওয়া করে
#   [bengali] #manifest:844424933096445-725-f PRED: পাঁচ লাখ টাকা চাঁদা না পেয়েই আসামিরা তাদের মারধর শেষে ধাওয়া করে
#   [bengali] running avg -> WER 0.1235 | CER 0.0365  (560/1783)
#   [bengali] #manifest:844424932327541-1084-f REF : গবেষণায় প্রমাণিত হয়েছে যে এই জাতীয় সামুদ্রিক গাছগুলি অর্থাত্ আগাছার প্রচুর পুষ্টিগুণ
#   [bengali] #manifest:844424932327541-1084-f PRED: গবেষণায় প্রমাণিত হয়েছে যে এই জাতীয় সামুদ্রিক গাছগুলি অর্থাৎ আগাছার প্রচুর পুষ্টিগুণ
#   [bengali] running avg -> WER 0.1231 | CER 0.0360  (580/1783)
#   [bengali] #manifest:844424931123539-92-f REF : শিশুর মগজে ওরা না পুঁতলে হিংস্র নিশান উঠতো না ফুটে
#   [bengali] #manifest:844424931123539-92-f PRED: শিশুর মগজে ওরা না পুঁতলে হিংস্র নিশান উঠতো না ফুটে
#   [bengali] running avg -> WER 0.1222 | CER 0.0368  (600/1783)
#   [bengali] #manifest:844424932394631-37-f REF : ওয়ালটনের কারখানা পরিদর্শন করেছেন প্রাথমিক ও গণশিক্ষা প্রতিমন্ত্রী মো
#   [bengali] #manifest:844424932394631-37-f PRED: ওয়ালটনের কারখানা পরিদর্শন করেছেন প্রাথমিক ও গণশিক্ষা প্রতিমন্ত্রী মো
#   [bengali] running avg -> WER 0.1220 | CER 0.0367  (620/1783)
#   [bengali] #manifest:844424932805242-725-f REF : সভায় আরও বক্তব্য দেন বিএনপির স্থায়ী কমিটির সদস্য ড
#   [bengali] #manifest:844424932805242-725-f PRED: সভায় আরও বক্তব্য দেন বিএনপির স্থায়ী কমিটির সদস্য ড
#   [bengali] running avg -> WER 0.1222 | CER 0.0367  (640/1783)
#   [bengali] #manifest:844424931309434-1116-f REF : লোন রিকভারির কাজে বেরিয়ে তিনি ফিরে না আসায় ডোমজুড় থানায় নিখোঁজসংক্রান্ত ডায়েরি করা হয়
#   [bengali] #manifest:844424931309434-1116-f PRED: লোন রিকভারির কাছে বেরিয়ে তিনি ফিরে না আসায় ডোমজুড় থানায় নিখোঁজ সংক্রান্ত ডায়েরি করা হয়
#   [bengali] running avg -> WER 0.1207 | CER 0.0362  (660/1783)
#   [bengali] #manifest:844424931382766-1116-f REF : ফায়ার সার্ভিস ও সিভিল ডিফেন্স অধিদফতরে ৫ টি পদে ১৮৫ জনকে নিয়োগ দেওয়া হবে
#   [bengali] #manifest:844424931382766-1116-f PRED: ফায়ার সার্ভিস ও সিভিল ডিফেন্স অধিদফতরে পাঁচটি পদে একশো পঁচাশি জনকে নিয়োগ দেয়া হবে
#   [bengali] running avg -> WER 0.1209 | CER 0.0362  (680/1783)
#   [bengali] #manifest:844424933096469-725-f REF : মিনিট সাতেক হয়েছে প্রধানমন্ত্রী নরেন্দ্র মোদীও হাজির হয়েছেন
#   [bengali] #manifest:844424933096469-725-f PRED: মিনিট সাতে হয়েছে প্রধানমন্ত্রী নরেন্দ্র মোদীও হাজির হয়েছেন
#   [bengali] running avg -> WER 0.1213 | CER 0.0367  (700/1783)
#   [bengali] #manifest:844424932339492-436-f REF : তারা বিস্তীর্ণ হাওরের বিভিন্ন এলাকা থেকে মাটি উত্তোলন করে চড়া দামে
#   [bengali] #manifest:844424932339492-436-f PRED: তারা বিস্তীর্ণ হাওয়ারের বিভিন্ন এলাকা থেকে মাটি উত্তোলন করে চড়া দামে
#   [bengali] running avg -> WER 0.1215 | CER 0.0367  (720/1783)
#   [bengali] #manifest:844424932412725-1084-f REF : কাজের ফাঁকে এক ফ্যাশন স্টুডিওয় পৌঁছে বেছে নিলেন নিজের পছন্দের পোশাক
#   [bengali] #manifest:844424932412725-1084-f PRED: কাজের ফাঁকে এক ফ্যাশন স্টুডিওয় পৌঁছে বেছে নিলেন নিজের পছন্দের পোশাক
#   [bengali] running avg -> WER 0.1225 | CER 0.0371  (740/1783)
#   [bengali] #manifest:844424930939863-92-f REF : রাখাইনে নিরস্ত্র ৬ ব্যক্তিকে হত্যার স্বীকারোক্তি দিলো মিয়ানমারের সেনাবাহিনী
#   [bengali] #manifest:844424930939863-92-f PRED: রাখাইনে নিরস্ত্র ছয় ব্যক্তিকে হত্যার স্বীকারোক্তি দিল মিয়ানমারের সেনাবাহিনী
#   [bengali] running avg -> WER 0.1234 | CER 0.0372  (760/1783)
#   [bengali] #manifest:844424931323271-906-f REF : ছাত্র কর্মীদের জন্য অক্ষর এবং সেটিং প্রস্তাব যে ইমপ্রোভ প্রারম্ভ
#   [bengali] #manifest:844424931323271-906-f PRED: ছাত্র কর্মীদের জন্য অক্ষর এবং সেটিং প্রস্তাব যে ইমপ্রুভ প্রারম্ভ
#   [bengali] running avg -> WER 0.1229 | CER 0.0370  (780/1783)
#   [bengali] #manifest:844424932678035-725-f REF : নির্বাচন কমিশনের নজরবন্দি থাকার মধ্যেই ডেপুটি ম্যাজিস্ট্রেটের সঙ্গে বাদানুবাদে জড়ালেন বীরভূমের
#   [bengali] #manifest:844424932678035-725-f PRED: নির্বাচন কমিশনের নজরবন্দি থাকার মধ্যেই ডেপুটি ম্যাজিস্ট্রেটের সঙ্গে বাদানুবাদে জড়ালেন বীরভূমের
#   [bengali] running avg -> WER 0.1221 | CER 0.0370  (800/1783)
#   [bengali] #manifest:844424932803524-725-f REF : থ্রিডি টাচ ডিসপ্লে নিয়ে আইফোন ৬ এস ও ৬ এস প্লাস
#   [bengali] #manifest:844424932803524-725-f PRED: থ্রিডি টাচ ডিসপ্লে নিয়ে আইফোন ছ এস ও ছয় এসপ্লাস
#   [bengali] running avg -> WER 0.1229 | CER 0.0375  (820/1783)
#   [bengali] #manifest:844424933095868-725-f REF : এ কারণে তার বীজ যেমন বড় হবে তেমন অনেকটা পাকাও হতে পারে
#   [bengali] #manifest:844424933095868-725-f PRED: এ কারণে তার বীজ যেমন বড় হবে তেমন অনেকটা পাকাও হতে পারে
#   [bengali] running avg -> WER 0.1229 | CER 0.0375  (840/1783)
#   [bengali] #manifest:844424930554358-92-f REF : মিয়ানমারের শরণার্থী ইস্যুতে একত্রে কাজের আগ্রহ প্রকাশ শেখ হাসিনার
#   [bengali] #manifest:844424930554358-92-f PRED: মিয়ানমারের শরণার্থী ইস্যুতে একত্রে কাজের আগ্রহ প্রকাশ শেখ হাসিনার
#   [bengali] running avg -> WER 0.1233 | CER 0.0374  (860/1783)
#   [bengali] #manifest:844424930935308-502-m REF : কেরিয়ারের প্রথম দিকে অঞ্জন দত্তের পরিচালনায় বেশ কিছু ছবিতে অভিনয় করেছিলেন পরমব্রত
#   [bengali] #manifest:844424930935308-502-m PRED: কেরিয়ারের প্রথম দিকে অঞ্জন দত্তের পরিচালনায় বেশ কিছু ছবিতে অভিনয় করেছিলেন পরমব্রত
#   [bengali] running avg -> WER 0.1229 | CER 0.0376  (880/1783)
#   [bengali] #manifest:844424931239822-1035-m REF : সোশ্যাল মিডিয়ায় ভাইরাল সিঙ্গাপুরের বিমানবন্দরের এই হার্টথ্রব সিকিউরিটি অফিসার
#   [bengali] #manifest:844424931239822-1035-m PRED: সোশ্যাল মিডিয়ায় ভাইরাল সিঙ্গাপুরের বিমানবন্দরের এই হার্ট থ্রব সিকিউরিটি অফিসার
#   [bengali] running avg -> WER 0.1228 | CER 0.0377  (900/1783)
#   [bengali] #manifest:844424930773521-372-m REF : ইসলামাবাদে ১০ কোটি রুপি ব্যয়ে নির্মিত হচ্ছে কৃষ্ণ মন্দির
#   [bengali] #manifest:844424930773521-372-m PRED: ইসলামাবাদে দশ কোটি রুপি ব্যয়ে নির্মিত হচ্ছে কৃষ্ণ মন্দির
#   [bengali] running avg -> WER 0.1220 | CER 0.0377  (920/1783)
#   [bengali] #manifest:844424930500960-1161-m REF : মাদারীপুরের গণপূর্ত বিভাগের তিন কর্মকর্তার বিরুদ্ধে হওয়া শুনানিতে প্রধান তথ্য কমিশনার অধ্যাপক ড
#   [bengali] #manifest:844424930500960-1161-m PRED: মাদারীপুরের গণভূত বিভাগে তিন কর্মকর্তার বিরুদ্ধে হওয়া শুনানিতে প্রধান তথ্য কমিশনার অধ্যাপক ড
#   [bengali] running avg -> WER 0.1221 | CER 0.0376  (940/1783)
#   [bengali] #manifest:844424930550801-1161-m REF : ওই সভায় প্রধান অতিথি ছিলেন তৎকালীন মন্ত্রিসভার সদস্য বগুড়ার মো
#   [bengali] #manifest:844424930550801-1161-m PRED: ওই সভায় প্রধান অতিথি ছিলেন তৎকালীন মন্ত্রিসভার সদস্য বগুড়ার মো
#   [bengali] running avg -> WER 0.1220 | CER 0.0378  (960/1783)
#   [bengali] #manifest:844424930935250-502-m REF : লাইফটাইম অ্যচিভমেন্ট পুরস্কার পেয়েছেন আমেরিকার খ্যাতিমান অভিনেতা ও পরিচালক রবার্ট ডি
#   [bengali] #manifest:844424930935250-502-m PRED: লাইফটাইম অ্যাচিভমেন্ট পুরস্কার পেয়েছেন আমেরিকার খ্যাতিমান অভিনেতা ও পরিচালক রবার্ট ড
#   [bengali] running avg -> WER 0.1219 | CER 0.0377  (980/1783)
#   [bengali] #manifest:844424930693423-372-m REF : বঙ্গভবনে রাষ্ট্রপতির সঙ্গে মিসর ও অষ্ট্রেলিয়ার দূতের পৃথক বিদায়ী সাক্ষাৎ
#   [bengali] #manifest:844424930693423-372-m PRED: বঙ্গভবনে রাষ্ট্রপতির সঙ্গে মিসর ও অস্ট্রেলিয়ার দূতের পৃথক বিদায়ী সাক্ষাৎ
#   [bengali] running avg -> WER 0.1215 | CER 0.0379  (1000/1783)
#   [bengali] #manifest:844424930693514-372-m REF : নিজ বাড়ির সামনে নিয়ন্ত্রণহীন ট্রাকের চাপায় প্রাণ হারালেন স্কুলশিক্ষক
#   [bengali] #manifest:844424930693514-372-m PRED: নিজ বাড়ির সামনে নিয়ন্ত্রণহীন ট্রাকের চাপায় প্রাণ হারালেন স্কুল শিক্ষক
#   [bengali] running avg -> WER 0.1210 | CER 0.0377  (1020/1783)
#   [bengali] #manifest:844424930693482-372-m REF : এই সমন্বয় কমিটির সভাপতি হিসেবে কাজ করবেন স্বাস্থ্য অধিদফতরের মহাপরিচালক অধ্যাপক ডা
#   [bengali] #manifest:844424930693482-372-m PRED: এই সমন্বয় কমিটির সভাপতি হিসেবে কাজ করবেন স্বাস্থ্য অধিদপ্তরের মহাপরিচালক অধ্যাপক ডা
#   [bengali] running avg -> WER 0.1209 | CER 0.0382  (1040/1783)
#   [bengali] #manifest:844424930554253-502-m REF : এগুলো মেনে চললে খুব কম সময়েই চোখের নিচের কালি ভ্যানিস
#   [bengali] #manifest:844424930554253-502-m PRED: এগুলো মেনে চললে খুব কম সময়ই চোখের নীচের কালি ভ্যানিশ
#   [bengali] running avg -> WER 0.1212 | CER 0.0381  (1060/1783)
#   [bengali] #manifest:844424930753582-372-m REF : এই ভুলগুলি এড়িয়ে চলুন এবং আপনার প্রচারটি বন্ধ হবে
#   [bengali] #manifest:844424930753582-372-m PRED: এই ভুলগুলি এড়িয়ে চলুন এবং আপনার প্রচারটি বন্ধ হবে
#   [bengali] running avg -> WER 0.1210 | CER 0.0378  (1080/1783)
#   [bengali] #manifest:844424930470442-210-m REF : ইউজিসির পোস্ট ডক রিসার্চ ফেলো ও বঙ্গবন্ধু গবেষক অধ্যাপক ড
#   [bengali] #manifest:844424930470442-210-m PRED: ইউজিসির পোস্ট ডক রিসার্চ ফেলো ও বঙ্গবন্ধুর গবেষক অধ্যাপক ড
#   [bengali] running avg -> WER 0.1218 | CER 0.0385  (1100/1783)
#   [bengali] #manifest:844424930554248-502-m REF : শিক্ষার্থীদের দিনব্যাপী এই আনন্দযজ্ঞে অংশ নেন বিশ্ববিদ্যালয়ের উপাচার্য অধ্যাপক ড
#   [bengali] #manifest:844424930554248-502-m PRED: শিক্ষার্থীদের দিনব্যাপী এই আনন্দযজ্ঞে অংশ নেন বিশ্ববিদ্যালয়ের উপাচার্য অধ্যাপক ড
#   [bengali] running avg -> WER 0.1213 | CER 0.0386  (1120/1783)
#   [bengali] #manifest:844424930550882-1161-m REF : অনবরত বর্ষণ মুখর বৃষ্টিধারার সুর এবং মাঝে মাঝে মেঘের ডাকে বর্ষার অনুভূতিতে শ্রোতাদের হৃদয়কে
#   [bengali] #manifest:844424930550882-1161-m PRED: অনবরত বর্ষণমুখর বৃষ্টিধারা সুর এবং মাঝে মাঝে মেঘের ডাকে বর্ষার অনুভূতিতে শ্রোতাদের হৃদয়কে
#   [bengali] running avg -> WER 0.1215 | CER 0.0389  (1140/1783)
#   [bengali] #manifest:844424931233458-1035-m REF : পুরো ঘটনায় মধ্যমণি হয়ে কাজ করেছেন ডাবলমুরিং থানা নির্বাচন অফিসের অফিস সহায়ক মো
#   [bengali] #manifest:844424931233458-1035-m PRED: পুরো ঘটনায় মধ্যমণি হয়ে কাজ করেছেন ডাবুলমুড়িং থানা নির্বাচন অফিসারের অফিস সহায়ক মো
#   [bengali] running avg -> WER 0.1208 | CER 0.0387  (1160/1783)
#   [bengali] #manifest:844424930464231-1161-m REF : আমন্ত্রণ না পেয়েও চৈতি বিয়েতে হাজির কারণ এটি তার সাবেক
#   [bengali] #manifest:844424930464231-1161-m PRED: আমন্ত্রণ না পেয়ে চৈতি বিয়েতে হাজির কারণ রীতা সাবেক
#   [bengali] running avg -> WER 0.1210 | CER 0.0387  (1180/1783)
#   [bengali] #manifest:844424930707841-210-m REF : আরও উপস্থিত ছিলেন বাংলাদেশ ইউনানি ও আয়ুর্বেদিক গ্র্যাজুয়েট চিকিৎসক সমন্বয় পরিষদের আহবায়ক ডা
#   [bengali] #manifest:844424930707841-210-m PRED: আরো উপস্থিত ছিলেন বাংলাদেশ ইউনানি ও আয়ুর্বেদিক গ্রাজুয়েট চিকিৎসক সমন্বয় পরিষদের আহ্বায়ক ডা
#   [bengali] running avg -> WER 0.1210 | CER 0.0386  (1200/1783)
#   [bengali] #manifest:844424930627036-210-m REF : সংগঠনটির জরুরি বৈঠকে আগামী তিন বছরের জন্য সাধারণ সম্পাদক হিসেবে আতিকুর রহমান সবুজকে
#   [bengali] #manifest:844424930627036-210-m PRED: সংগঠনটির জরুরি বৈঠকে আগামী তিন বছরের জন্য সাধারণ সম্পাদক হিসেবে অতিকুর রহমান সবুজকে
#   [bengali] running avg -> WER 0.1211 | CER 0.0383  (1220/1783)
#   [bengali] #manifest:844424931239851-1035-m REF : ইসলামী ব্যাংকের আমানত ৬৫ কোটি ও বিনিয়োগ ৫৭ কোটি টাকা
#   [bengali] #manifest:844424931239851-1035-m PRED: ইসলামী ব্যাংকের আমানত পঁয়ষট্টি কোটি ও বিনিয়োগ সাতান্ন কোটি টাকা
#   [bengali] running avg -> WER 0.1218 | CER 0.0387  (1240/1783)
#   [bengali] #manifest:844424930626997-210-m REF : মেডিকেল বোর্ডের এই পাঁচ সদস্য ওবায়দুল কাদেরকে নিবিড় পর্যবেক্ষণ করছেন বলে জানান ডা
#   [bengali] #manifest:844424930626997-210-m PRED: মেডিকেল বোর্ডের এই পাঁচ সদস্য ওবায়দুল কাদেরকে নিবিড় পর্যবেক্ষণ করছেন বলে জানান ডা
#   [bengali] running avg -> WER 0.1214 | CER 0.0387  (1260/1783)
#   [bengali] #manifest:844424930500917-1161-m REF : ওআইসির মিয়ানমার বিষয়ক কন্টাক্ট গ্রুপে বক্তব্য রাখছেন প্রেসিডেন্ট রুহানি
#   [bengali] #manifest:844424930500917-1161-m PRED: ওয়াইসির মিয়ানমার বিষয়ে কনট্যাক্ট গ্রুপে বক্তব্য রাখছেন প্রেসিডেন্ট রুহানি
#   [bengali] running avg -> WER 0.1217 | CER 0.0391  (1280/1783)
#   [bengali] #manifest:844424931233453-1035-m REF : অনেক সময় ভয় দেখিয়েও হেঁচকি থামানো সম্ভব বলে মনে করেন চিকিৎসকরা
#   [bengali] #manifest:844424931233453-1035-m PRED: অনেক সময় ভয় দেখিয়েও হেঁচকি থামানো সম্ভব বলে মনে করেন চিকিৎসকরা
#   [bengali] running avg -> WER 0.1213 | CER 0.0392  (1300/1783)
#   [bengali] #manifest:844424930554292-502-m REF : ২৯ বছর বয়সী মিডফিল্ডার জার্মানির মাঝমাঠে তো আলো ছড়িয়ে
#   [bengali] #manifest:844424930554292-502-m PRED: উনত্রিশ বছর বয়সী মিডফিল্ডার জার্মানির মাঝমাঠে তো আলো ছড়িয়ে
#   [bengali] running avg -> WER 0.1208 | CER 0.0391  (1320/1783)
#   [bengali] #manifest:844424930464169-1161-m REF : হয়তো আপনি যা ভাবছেন আপনার স্বামী সেই ভাবে ভাবছেন না
#   [bengali] #manifest:844424930464169-1161-m PRED: হয়তো আপনি যা ভাবছেন আপনার স্বামী সেই ভাবে ভাবছেন না
#   [bengali] running avg -> WER 0.1203 | CER 0.0388  (1340/1783)
#   [bengali] #manifest:844424930941004-417-m REF : তারপর তিনি অন্যান্য শয্যাতে তার ডিম রাখা শেষ করতে এগিয়ে যেতে পারে
#   [bengali] #manifest:844424930941004-417-m PRED: তারপর তিনি অন্যান্য শয্যাতে তার ডিম রাখা শেষ করতে এগিয়ে যেতে পারে
#   [bengali] running avg -> WER 0.1204 | CER 0.0389  (1360/1783)
#   [bengali] #manifest:844424930940947-417-m REF : গঙ্গায় নেমে ভিডিও তৈরি করতে গিয়ে তলিয়ে গেল দুই ছাত্র
#   [bengali] #manifest:844424930940947-417-m PRED: গঙ্গায় নেমে ভিডিও তৈরি করতে গিয়ে তলিয়ে গেল দুই ছাত্র
#   [bengali] running avg -> WER 0.1200 | CER 0.0387  (1380/1783)
#   [bengali] #manifest:844424930773537-372-m REF : ত্রাণের চাল আত্মসাতের ঘটনা অত্যন্ত দুঃখজনক বলে মন্তব্য করেছেন সংসদের বিরোধীদলীয় নেতা বেগম রওশন এরশাদ
#   [bengali] #manifest:844424930773537-372-m PRED: ত্রাণের চাল আত্মসতের ঘটনা অত্যন্ত দুঃখজনক বলে মন্তব্য করেছেন সংসদের বিরোধী দলীয় নেতা বেগম রাওসান এরশাদ
#   [bengali] running avg -> WER 0.1200 | CER 0.0389  (1400/1783)
#   [bengali] #manifest:844424930464177-1161-m REF : বান্ধবীর সঙ্গে গল্প করায় বিষ খাইয়ে প্রেমিককে খুনের অভিযোগ
#   [bengali] #manifest:844424930464177-1161-m PRED: বান্ধবীর সঙ্গে গল্প গড়ায় বিষ খাইয়ে প্রেমিককে খুনের অভিযোগ
#   [bengali] running avg -> WER 0.1201 | CER 0.0394  (1420/1783)
#   [bengali] #manifest:844424930436731-253-m REF : এই উদ্যোগকে ইতিবাচক উল্লেখ করেছেন তালিকায় থাকা টেকনাফের জাদিমুরা রোহিঙ্গা শিবিরের হেড মাঝি মো
#   [bengali] #manifest:844424930436731-253-m PRED: এই উদ্যোগকে ইতিবাচক উল্লেখ করেছেন তালিকায় থাকা টেকনাফের জাদিমুরা রোহিঙ্গা শিবিরের হেড মাঝি মো
#   [bengali] running avg -> WER 0.1195 | CER 0.0391  (1440/1783)
#   [bengali] #manifest:844424930935235-502-m REF : জনসমাবেশে দাঁড়িয়ে বিতর্কিত মন্তব্য করে প্রশ্নের মুখে জম্মু ও কাশ্মীরের রাজ্যপাল
#   [bengali] #manifest:844424930935235-502-m PRED: জনসমাবেশে দাঁড়িয়ে বিতর্কিত মন্তব্য করে প্রশ্নের মুখে জম্মু ও কাশ্মীরের রাজ্যপাল
#   [bengali] running avg -> WER 0.1197 | CER 0.0393  (1460/1783)
#   [bengali] #manifest:844424930436712-253-m REF : তামিলনাড়ুর কুয়ো থেকে তিন বছরের শিশুকে উদ্ধারে খোঁড়া হচ্ছে ১১০ ফুট গর্ত
#   [bengali] #manifest:844424930436712-253-m PRED: তামিলনাড়ুর কুয়ো থেকে তিন বছরের শিশুকে উদ্ধারে খুঁড়া হচ্ছে একশো দশ ফুট গর্ত
#   [bengali] running avg -> WER 0.1198 | CER 0.0393  (1480/1783)
#   [bengali] #manifest:844424930550857-1161-m REF : এ প্ল্যাটফর্ম থেকে দেশ ও দেশের বাইরের যে সব গান সম্প্রচার
#   [bengali] #manifest:844424930550857-1161-m PRED: এ প্ল্যাটফর্ম থেকে দেশ ও দেশের বাইরের যে সব গান সম্প্রচার
#   [bengali] running avg -> WER 0.1199 | CER 0.0392  (1500/1783)
#   [bengali] #manifest:844424930935278-502-m REF : এর ফলে প্রায় ১২ লাখ টাকার টাকার ক্ষতি হয়েছে
#   [bengali] #manifest:844424930935278-502-m PRED: এর ফলে প্রায় বারো লাখ টাকার টাকার ক্ষতি হয়েছে
#   [bengali] running avg -> WER 0.1201 | CER 0.0393  (1520/1783)
#   [bengali] #manifest:844424930554258-502-m REF : দ্বিতীয় প্রান্তিকে গ্রামীণফোনের আয় ৩ হাজার ২৪০ কোটি টাকা
#   [bengali] #manifest:844424930554258-502-m PRED: দ্বিতীয় প্রান্তিকে গ্রামীণ ফোনের আয় তিন হাজার দুশো চল্লিশ কোটি টাকা
#   [bengali] running avg -> WER 0.1210 | CER 0.0396  (1540/1783)
#   [bengali] #manifest:844424931233418-1035-m REF : আগামী ২৭ তারিখের পরবর্তী শুনানির আগেই শ্রীনিবাসনকে ইস্তফা দিতে বলেছে শীর্ষ আদালত
#   [bengali] #manifest:844424931233418-1035-m PRED: আগামী সাতাশ তারিখের পরবর্তী শুনানির আগেই শ্রীনিবাসনকে ইস্তফা দিতে বলেছে শীর্ষ আদালত
#   [bengali] running avg -> WER 0.1207 | CER 0.0395  (1560/1783)
#   [bengali] #manifest:844424930773518-372-m REF : তিনি বলেন যে তারা নিখুঁত সুখ খুঁজে পেতে চাই
#   [bengali] #manifest:844424930773518-372-m PRED: তিনি বলেন যে তারা নিখুঁত সুখ খুঁজে পেতে চাই
#   [bengali] running avg -> WER 0.1207 | CER 0.0394  (1580/1783)
#   [bengali] #manifest:844424931233395-1035-m REF : আম্ফানের সময় কর্মরত ৫০ জন এনডিআরএফ কর্মী করোনা সংক্রমিত
#   [bengali] #manifest:844424931233395-1035-m PRED: আম্ফানের সময় কর্মরত পঞ্চাশ জন এনডিআরএফ কর্মী করোনা সংক্রমিত
#   [bengali] running avg -> WER 0.1205 | CER 0.0391  (1600/1783)
#   [bengali] #manifest:844424931239834-1035-m REF : থানায় ডায়েরি করেছেন প্রশ্ন ফাঁসকারী নিলয়ের ফেসবুকের ছবির যুবক
#   [bengali] #manifest:844424931239834-1035-m PRED: থানায় ডায়েরি করেছেন প্রশ্ন ফাঁসকারী নির্লয়ের ফেসবুকের ছবির যুবক
#   [bengali] running avg -> WER 0.1212 | CER 0.0396  (1620/1783)
#   [bengali] #manifest:844424930753524-372-m REF : কেন্দ্রীয় বাজেটের জন্য সাধারণ মানুষের থেকে পরামর্শ চাইলেন নমো
#   [bengali] #manifest:844424930753524-372-m PRED: কেন্দ্রীয় বাজেটের জন্য সাধারণ মানুষের থেকে পরামর্শ চাইলেন নমো
#   [bengali] running avg -> WER 0.1216 | CER 0.0400  (1640/1783)
#   [bengali] #manifest:844424930554278-502-m REF : রাষ্ট্রপক্ষে মামলাটি পরিচালনা করেন সংশ্লিষ্ট আদালতের স্পেশাল পাবলিক প্রসিকিউটর মো
#   [bengali] #manifest:844424930554278-502-m PRED: রাষ্ট্রপক্ষে মামলাটি পরিচালনা করেন সংশ্লিষ্ট আদালতের স্পেশাল পাবলিক প্রসিকিউটর মো
#   [bengali] running avg -> WER 0.1214 | CER 0.0401  (1660/1783)
#   [bengali] #manifest:844424930627032-210-m REF : প্রধানমন্ত্রীকে চিঠি বিশেষজ্ঞ নিয়ে সীমিত পরিসরে আলোচনা চান ড
#   [bengali] #manifest:844424930627032-210-m PRED: প্রধানমন্ত্রীকে চিঠি বিশেষজ্ঞ নিয়ে সীমিত পরিসরে আলোচনা চান ড
#   [bengali] running avg -> WER 0.1216 | CER 0.0402  (1680/1783)
#   [bengali] #manifest:844424930773522-372-m REF : কংগ্রেসের গড় কাঁপিয়ে মনোনয়ন জমা কান্দি মহকুমার ৪ তৃণমূল প্রার্থীর
#   [bengali] #manifest:844424930773522-372-m PRED: কংগ্রেসের গড় কাঁপিয়ে মনোনয়ন জমা কান্দি মহকুমার চার তৃণমূল প্রার্থীর
#   [bengali] running avg -> WER 0.1214 | CER 0.0400  (1700/1783)
#   [bengali] #manifest:844424930627054-210-m REF : সংবাদ সম্মেলনে আরও বক্তব্য রাখেন পিকেএসএফের নির্বাহী চেয়ারম্যান ড
#   [bengali] #manifest:844424930627054-210-m PRED: সংবাদ সম্মেলনে আরও বক্তব্য রাখেন পিকেএসএফের নির্বাহী চেয়ারম্যান ড
#   [bengali] running avg -> WER 0.1213 | CER 0.0399  (1720/1783)
#   [bengali] #manifest:844424930693454-372-m REF : কোন ঝুঁকি না নিয়েই অবশেষে প্রার্থী বদল করল বিজেপি
#   [bengali] #manifest:844424930693454-372-m PRED: কোনও ঝুঁকি না নিয়েই অবশেষে প্রার্থী বদল করল বিজেপি
#   [bengali] running avg -> WER 0.1216 | CER 0.0400  (1740/1783)
#   [bengali] #manifest:844424930940934-417-m REF : কিন্তু এসব পণ্যের মাত্রাতিরিক্ত ব্যবহার সব সময় ভালো ফল বয়ে আনে
#   [bengali] #manifest:844424930940934-417-m PRED: কিন্তু এসব পণ্যের মাত্রাতিক্ত ব্যবহার সবসময় ভাল ফল বয়ে আনে
#   [bengali] running avg -> WER 0.1223 | CER 0.0405  (1760/1783)
#   [bengali] #manifest:844424930436732-253-m REF : শিশুদের হৃদরোগের বিষয়ে এনটিভির নিয়মিত আয়োজন স্বাস্থ্য প্রতিদিন অনুষ্ঠানের ৩২৫৯ তম পর্বে কথা বলেছেন ডা
#   [bengali] #manifest:844424930436732-253-m PRED: শিশুদের হৃদরোগের বিষয়ে এনটিভির নিয়মিত আয়োজন স্বাস্থ্য প্রতিদিন অনুষ্ঠানে তিন হাজার দুশো উনসাতম পর্বে কথা বলেছেন ডা
#   [bengali] running avg -> WER 0.1227 | CER 0.0407  (1780/1783)
#   DONE bengali: n=1783  WER=0.1228  CER=0.0410
#   -> /kaggle/working/sravaani_kathbath_eval/sravaani_kathbath_bengali_results.csv
#
# ======================================================================
# ALL LANGUAGES DONE in 2.4 min
# ======================================================================
# language  n_utterances     wer      cer
#  bengali          1783 0.12276 0.040988
#
# Per-language CSVs + summary written to: /kaggle/working/sravaani_kathbath_eval
#   language  n_utterances      wer       cer
# 0  bengali          1783  0.12276  0.040988

# %% [markdown]
# ## 13. Inspect a results CSV

# %%
# e.g. inspect Bengali results
pd.read_csv(OUT_DIR / "sravaani_kathbath_bengali_results.csv").head(20)
# Out:
#                                 id language  \
# 0   manifest:844424930757976-661-f  bengali
# 1    manifest:844424930841702-70-f  bengali
# 2   manifest:844424930757897-661-f  bengali
# 3   manifest:844424930757896-661-f  bengali
# 4   manifest:844424930757988-661-f  bengali
# 5    manifest:844424930841716-70-f  bengali
# 6   manifest:844424930757890-661-f  bengali
# 7   manifest:844424930757898-661-f  bengali
# 8   manifest:844424930757909-661-f  bengali
# 9    manifest:844424930841730-70-f  bengali
# 10  manifest:844424930757977-661-f  bengali
# 11   manifest:844424930841692-70-f  bengali
# 12  manifest:844424930757899-661-f  bengali
# 13   manifest:844424930841694-70-f  bengali
# 14   manifest:844424930841749-70-f  bengali
# 15  manifest:844424930757917-661-f  bengali
# 16   manifest:844424930841718-70-f  bengali
# 17  manifest:844424930757914-661-f  bengali
# 18  manifest:844424930757903-661-f  bengali
# 19  manifest:844424930757941-661-f  bengali
#
#                                             reference  \
# 0   জাপা চেয়ারম্যানের একান্ত ব্যক্তিগত সচিব ও দলট...
# 1    মাস্টার্স পরীক্ষা শেষে ১৫ দিন থাকা যাবে ইবির হলে
# 2   নড়াইলে বিশ্ববরেণ্য চিত্রশিল্পী এসএম সুলতানের ...
# 3   লন্ডনে অবস্থানরত বিএনপির ভারপ্রাপ্ত চেয়ারম্যা...
# 4   ১০০ কোম্পানি সেনা পাঠিয়ে কাশ্মীরে উন্নয়নের ঢ...
# 5   সহযোগিতা চেয়ে ব্লাড ক্যান্সারে আক্রান্ত বিয়া...
# 6   তবে সার্বিক বৈশ্বিক এবং দেশীয় পরিস্থিতি বিবেচ...
# 7   ভ্রমণের ফলে নেতিবাচক আবেগ থেকে দূরে থাকেন বলে ...
# 8   বন্দুকধারী রক্ষী ছাড়া খাবারের ট্রাক রাস্তায় ...
# 9   কেরী ফিশার হিসেবে প্রিন্সেস লেয়াকে চমত্কার মু...
# 10  গোপালপুর ডিগ্রি কলেজে শিক্ষক নিয়োগ সাংসদসহ কম...
# 11  তবে সামর্থ্যবানদের অনেকেরই বাড়িতে সময় কাটছে ...
# 12  সারদা গোষ্ঠীকে একটি চ্যানেল বিক্রির বিষয়ে মধ্...
# 13  দেড় বছরের শিশুকে গামলায় বসিয়ে মাথায় নিয়েই...
# 14   বাংলাদেশের ৯ টি পেজ ও ৬ টি আইডি বন্ধ করলো ফেসবুক
# 15       ভিড় সামলাতে না পেরে বন্ধ করা হলো সব মার্কেট
# 16  ১০ জন ডাক্তারের সমন্বয়ে গঠিত এই মেডিক্যাল টিম...
# 17  টেকনোক্র্যাটদের নিয়ে নয়া সরকার গঠনের আহ্বান ...
# 18  লক্ষ্মীপুর জেলা জাতীয় পার্টির সাবেক সভাপতি বি...
# 19  মুগদা হাসপাতালে রোগীর স্বজন ও সাংবাদিক লাঞ্ছনা...
#
#                                            prediction     wer     cer
# 0   জাপা চেয়ারম্যানের একান্ত ব্যক্তিগত সচিব ও দলট...  0.0000  0.0000
# 1   মাস্টার্স পরীক্ষা শেষে পনের দিন থাকা যাইবে ইবি...  0.3333  0.1500
# 2   নড়াইলে বিশ্ব বরেণ্য চিত্রশিল্পী এস এম সুলতানে...  0.4000  0.0968
# 3   লন্ডনে অবস্থানরত বিএনপির ভারপ্রাপ্ত চেয়ারম্যা...  0.0000  0.0000
# 4   একশো কোম্পানি সেনা পাঠিয়ে কাশ্মীর উন্নয়নে ঢা...  0.4444  0.1321
# 5   সহযোগিতা চেয়ে ব্লাড ক্যানসারে আক্রান্ত বিয়ান...  0.1818  0.0267
# 6   তবে সার্বিক বৈশ্বিক এবং দেশেও পরিস্থিতি বিবেচন...  0.2143  0.0370
# 7   ভ্রমণের ফলে নেতিবাচক আবেগ থেকে দূরে থাকেন বলে ...  0.0000  0.0000
# 8   বন্দুকধারী রক্ষী ছাড়া খাবারের ট্রাক রাস্তায় ...  0.0000  0.0000
# 9   কেরি ফিশার হিসাবে প্রিন্সেস লেয়াকে চমৎকার মুভ...  0.5000  0.0678
# 10  গোপালপুর ডিগ্রি কলেজে শিক্ষক নিয়োগ সাংসদসহ কম...  0.0000  0.0000
# 11  তবে সমর্থবানদের অনেকেরই বাড়িতে সময় কাটছে খাও...  0.0909  0.0455
# 12  সারদা গোষ্ঠীকে একটি চ্যানেল বিক্রির বিষয়ে মধ্...  0.0769  0.0143
# 13  দেড় বছরের শিশুকে গামলায় বসিয়ে মাথায় নিয়ে ...  0.2308  0.0141
# 14    বাংলাদেশের নয়টি পেজ ও ছটি আইডি বন্ধ করল ফেসবুক  0.4545  0.1316
# 15        ভিড় সামলাতে না পেরে বন্ধ করা হল সব মার্কেট  0.1111  0.0278
# 16  দশজন ডাক্তারের সমন্বয়ে গঠিত এই মেডিকেল টিমের ...  0.3333  0.0875
# 17  টেকনোক্র্যাটদের নিয়ে নয়া সরকার গঠনের আহ্বান ...  0.1111  0.0303
# 18  লক্ষ্মীপুর জেলা জাতীয় পার্টির সাবেক সভাপতি বি...  0.0000  0.0000
# 19  মুগদা হাসপাতালে রোগীর স্বজন ও সাংবাদিক ক্লাঞ্ছ...  0.1000  0.0351
